# %% [markdown]
# **CS 5834, Fall 2020: Intro to Urban Computing Project - STUCCO analysis for Gentrification using Cleveland Data Set**

# %% [markdown]
# ### Imports and Mount File Directories

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
# modify "customized_path_to_homework", path of folder in drive, where you project is stored
customized_path_to_homework = "/content/drive/My Drive/cs5834/urbcomp_fall2020/project"
file_name = "Cleveland_typology_output.csv"

sys.path.append(customized_path_to_homework)

# %%
# %cd $customized_path_to_homework/data
# Out:
# /content/drive/My Drive/cs5834/urbcomp_fall2020/project/data

# %%
import os, sys
import pandas as pd
import numpy as np
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
import datetime
import warnings

# %%
"""
sys.path.insert(0,'../')
# %load_ext autoreload
# %autoreload 2
import nyctaxi_helpers
warnings.filterwarnings('ignore')
"""
# Out:
# "\nsys.path.insert(0,'../')\n%load_ext autoreload\n%autoreload 2\nimport nyctaxi_helpers\nwarnings.filterwarnings('ignore')\n"

# %%
#pip install --upgrade mlxtend

# %%
#ref https://pbpython.com/market-basket-analysis.html


#may need to install mlxtend package - pip install mlxtend in console
import pandas as pd
# #from mlxtend.frequent_patterns import apriori
# from mlxtend.frequent_patterns import fpgrowth
# from mlxtend.frequent_patterns import association_rules

# %%
# !wget -nc https://raw.githubusercontent.com/parsahosseini/contrast/master/stucco.py
# Out:
# File ‘stucco.py’ already there; not retrieving.

# %% [markdown]
# # **Process Urban Displacement Model Data for Gentrificaiton**

# %% [markdown]
# Reference: https://www.urbandisplacement.org/open-source-project

# %% [markdown]
# Based on the work https://ww2.arb.ca.gov/sites/default/files/classic//research/apr/past/13-310.pdf?_ga=2.269282425.968981409.1605209194-851335111.1605209194
#
# **Developing a New
# Methodology for Analyzing
# Potential Displacement**
#
# University of California, Berkeley
#
# Principal Investigator:
# Karen Chapple
#
# https://ww3.arb.ca.gov/research/single-project.php?row_id=65188

# %% [markdown]
# ## **Obtain the Data**
#
# Data can be found at https://github.com/urban-displacement/displacement-typologies/blob/main/data/outputs/typologies/LosAngeles_typology_output.csv

# %%
download_file = ("https://raw.githubusercontent.com/urban-displacement/displacement-typologies/main/data/outputs/typologies/{}".format(file_name))

# %%
#!wget -nc $download_file

# %%
## Process Data - if data file already processed then can start at Associaton Rules section
# get the Data File

df = pd.read_csv("https://raw.githubusercontent.com/urban-displacement/displacement-typologies/main/data/outputs/typologies/{}".format(file_name), index_col=0)
#df = pd.read_csv("{}/data/{}".format(customized_path_to_homework, file_name), index_col=0)

# sneak peak in the data
df.head(10)
# Out:
#    pop_18  white_18   hh_18   hinc_18  ...  LISD  double_counted  typology   typ_cat
# 0  2821.0    2780.0  1034.0   69125.0  ...     0             1.0       6.0  ['SMMI']
# 1  6611.0    6428.0  2540.0   81857.0  ...     0             1.0       7.0   ['ARE']
# 2  3664.0    3618.0  1059.0   56625.0  ...     0             1.0       7.0   ['ARE']
# 3  4438.0    4249.0  1738.0   56402.0  ...     0             1.0       6.0  ['SMMI']
# 4  3706.0    3612.0  1621.0   71326.0  ...     0             1.0       7.0   ['ARE']
# 5  5355.0    5279.0  2199.0  106712.0  ...     0             1.0       9.0   ['SAE']
# 6  4355.0    3790.0  1807.0  109671.0  ...     0             1.0       7.0   ['ARE']
# 7  4169.0    4104.0  1036.0   64167.0  ...     0             1.0       7.0   ['ARE']
# 8  5464.0    5162.0  2409.0   70096.0  ...     0             1.0       7.0   ['ARE']
# 9  6500.0    6205.0  2236.0  128977.0  ...     0             1.0       9.0   ['SAE']
#
# [10 rows x 305 columns]

# %%
df.columns
# Out:
# Index(['pop_18', 'white_18', 'hh_18', 'hinc_18', 'mhval_18', 'mhval_18_se',
#        'mrent_18', 'mrent_18_se', 'total_25_18', 'total_25_col_bd_18',
#        ...
#        'BE', 'SMMI', 'ARG', 'EOG', 'OD', 'OD_loss', 'LISD', 'double_counted',
#        'typology', 'typ_cat'],
#       dtype='object', length=305)

# %%
"""
# create a working copy of the data to process
df2 = df.copy()

#removed  'inc_cat_medhhinc_encoded18', 'inc_cat_medhhinc_encoded00',
df2 = df2[[ 'inc80_18',
 'inc120_18',
 'inc80_00',
 'inc120_00',
 'inc80_90',
 'low_80120_18',
 'mod_80120_18',
 'high_80120_18',
 'low_pdmt_medhhinc_18',
 'high_pdmt_medhhinc_18',
 'mod_pdmt_medhhinc_18',
 'mix_low_medhhinc_18',
 'mix_mod_medhhinc_18',
 'mix_high_medhhinc_18',

 'low_80120_00',
 'mod_80120_00',
 'high_80120_00',
 'low_pdmt_medhhinc_00',
 'high_pdmt_medhhinc_00',
 'mod_pdmt_medhhinc_00',
 'mix_low_medhhinc_00',
 'mix_mod_medhhinc_00',
 'mix_high_medhhinc_00',

 'per_all_li_90',
 'per_all_li_00',
 'per_all_li_18',
 'per_nonwhite_90',
 'per_nonwhite_00',
 'per_nonwhite_18',
 'per_rent_90',
 'per_rent_00',
 'per_rent_18',
 'per_col_90',
 'per_col_00',
 'per_col_18',
 'per_units_pre50_18',
 'per_limove_18',
 'per_limove_12',
 'lmh_flag_category',
 'pctch_real_mhval_00_18',
 'pctch_real_mrent_12_18',
 'rent_decrease',
 'rent_marginal',
 'rent_increase',
 'rent_rapid_increase',
 'house_decrease',
 'house_marginal',
 'house_increase',
 'house_rapid_increase',
 'tot_decrease',
 'tot_marginal',
 'tot_increase',
 'tot_rapid_increase',
 'change_flag_category',
 'per_ch_zillow_12_18',
 'ab_50pct_ch',
 'ab_90percentile_ch',
 'rent_50pct_ch',
 'rent_90percentile_ch',
 'hv_abrm_ch',
 'rent_abrm_ch',
 'pctch_real_mhval_90_00',
 'pctch_real_mrent_90_00',
 'pctch_real_hinc_90_00',
 'pctch_real_mrent_00_18',
 'pctch_real_hinc_00_18',
 'ch_per_col_90_00',
 'ch_per_col_00_18',
 'ch_per_limove_12_18',
 'aboverm_per_all_li_90',
 'aboverm_per_all_li_00',
 'aboverm_per_all_li_18',
 'aboverm_per_nonwhite_18',
 'aboverm_per_nonwhite_90',
 'aboverm_per_nonwhite_00',
 'aboverm_per_rent_90',
 'aboverm_per_rent_00',
 'aboverm_per_rent_18',
 'aboverm_per_col_90',
 'aboverm_per_col_00',
 'aboverm_per_col_18',
 'aboverm_real_mrent_90',
 'aboverm_real_mrent_00',
 'aboverm_real_mrent_12',
 'aboverm_real_mrent_18',
 'aboverm_real_mhval_90',
 'aboverm_real_mhval_00',
 'aboverm_real_mhval_18',
 'aboverm_pctch_real_mhval_00_18',
 'aboverm_pctch_real_mrent_00_18',
 'aboverm_pctch_real_mrent_12_18',
 'aboverm_pctch_real_mhval_90_00',
 'aboverm_pctch_real_mrent_90_00',
 'lostli_00',
 'lostli_18',
 'aboverm_pctch_real_hinc_90_00',
 'aboverm_pctch_real_hinc_00_18',
 'aboverm_ch_per_col_90_00',
 'aboverm_ch_per_col_00_18',
 'aboverm_per_units_pre50_18',
 'GEOID',
 'rail',
 'presence_ph_LIHTC',
 'hotmarket_00',
 'hotmarket_18',
 'dp_PChRent',
 'dp_RentGap',
 'dense',
 'typology']]


# drop rows which dont have a gentrification category
df2.dropna(subset=['typology'], inplace=True)
df2 = df2.set_index('GEOID')

#fill the nas
df2.fillna(0.0, inplace=True)


df2.head(10)
"""
# Out:
# "\n# create a working copy of the data to process\ndf2 = df.copy()\n\n#removed  'inc_cat_medhhinc_encoded18', 'inc_cat_medhhinc_encoded00',\ndf2 = df2[[ 'inc80_18',\n 'inc120_18',\n 'inc80_00',\n 'inc120_00',\n 'inc80_90',\n 'low_80120_18',\n 'mod_80120_18',\n 'high_80120_18',\n 'low_pdmt_medhhinc_18',\n 'high_pdmt_medhhinc_18',\n 'mod_pdmt_medhhinc_18',\n 'mix_low_medhhinc_18',\n 'mix_mod_medhhinc_18',\n 'mix_high_medhhinc_18',\n\n 'low_80120_00',\n 'mod_80120_00',\n 'high_80120_00',\n 'low_pdmt_medhhinc_00',\n 'high_pdmt_medhhinc_00',\n 'mod_pdmt_medhhinc_00',\n 'mix_low_medhhinc_00',\n 'mix_mod_medhhinc_00',\n 'mix_high_medhhinc_00',\n\n 'per_all_li_90',\n 'per_all_li_00',\n 'per_all_li_18',\n 'per_nonwhite_90',\n 'per_nonwhite_00',\n 'per_nonwhite_18',\n 'per_rent_90',\n 'per_rent_00',\n 'per_rent_18',\n 'per_col_90',\n 'per_col_00',\n 'per_col_18',\n 'per_units_pre50_18',\n 'per_limove_18',\n 'per_limove_12',\n 'lmh_flag_category',\n 'pctch_real_mhval_00_18',\n 'pctch_real_mrent_12_18',\n 'rent_decrease',\n 'rent_marginal',\n 'rent_increase',\n 'rent_rapid_increase',\n 'house_decrease',\n 'house_marginal',\n 'house_increase',\n 'house_rapid_increase',\n 'tot_decrease',\n 'tot_marginal',\n 'tot_increase',\n 'tot_rapid_increase',\n 'change_flag_category',\n 'per_ch_zillow_12_18',\n 'ab_50pct_ch',\n 'ab_90percentile_ch',\n 'rent_50pct_ch',\n 'rent_90percentile_ch',\n 'hv_abrm_ch',\n 'rent_abrm_ch',\n 'pctch_real_mhval_90_00',\n 'pctch_real_mrent_90_00',\n 'pctch_real_hinc_90_00',\n 'pctch_real_mrent_00_18',\n 'pctch_real_hinc_00_18',\n 'ch_per_col_90_00',\n 'ch_per_col_00_18',\n 'ch_per_limove_12_18',\n 'aboverm_per_all_li_90',\n 'aboverm_per_all_li_00',\n 'aboverm_per_all_li_18',\n 'aboverm_per_nonwhite_18',\n 'aboverm_per_nonwhite_90',\n 'aboverm_per_nonwhite_00',\n 'aboverm_per_rent_90',\n 'aboverm_per_rent_00',\n 'aboverm_per_rent_18',\n 'aboverm_per_col_90',\n 'aboverm_per_col_00',\n 'aboverm_per_col_18',\n 'aboverm_real_mrent_90',\n 'aboverm_real_mrent_00',\n 'aboverm_real_mrent_12',\n 'aboverm_real_mrent_18',\n 'aboverm_real_mhval_90',\n 'aboverm_real_mhval_00',\n 'aboverm_real_mhval_18',\n 'aboverm_pctch_real_mhval_00_18',\n 'aboverm_pctch_real_mrent_00_18',\n 'aboverm_pctch_real_mrent_12_18',\n 'aboverm_pctch_real_mhval_90_00',\n 'aboverm_pctch_real_mrent_90_00',\n 'lostli_00',\n 'lostli_18',\n 'aboverm_pctch_real_hinc_90_00',\n 'aboverm_pctch_real_hinc_00_18',\n 'aboverm_ch_per_col_90_00',\n 'aboverm_ch_per_col_00_18',\n 'aboverm_per_units_pre50_18',\n 'GEOID',\n 'rail',\n 'presence_ph_LIHTC',\n 'hotmarket_00',\n 'hotmarket_18',\n 'dp_PChRent',\n 'dp_RentGap',\n 'dense',\n 'typology']]\n\n\n# drop rows which dont have a gentrification category\ndf2.dropna(subset=['typology'], inplace=True)\ndf2 = df2.set_index('GEOID')\n\n#fill the nas\ndf2.fillna(0.0, inplace=True)\n\n\ndf2.head(10)\n"

# %%
# create a working copy of the data to process
df2 = df.copy()

"""
removed  'inc_cat_medhhinc_encoded18', 'inc_cat_medhhinc_encoded00', 
'inc80_18',
 'inc120_18',
 'inc80_00',
 'inc120_00',
 'inc80_90',
  'per_col_90',
 'per_col_00',
 'per_col_18',
  'tot_decrease',
 'tot_marginal',
 'tot_increase',
 'tot_rapid_increase',
  'pctch_real_mhval_90_00',
 'pctch_real_mrent_90_00',
 'pctch_real_mrent_00_18',
 'per_units_pre50_18',
  
"""

df2.head(10)
df2 = df2[[ 

 'low_80120_18',
 'mod_80120_18',
 'high_80120_18',
 'low_pdmt_medhhinc_18',
 'high_pdmt_medhhinc_18',
 'mod_pdmt_medhhinc_18',
 'mix_low_medhhinc_18',
 'mix_mod_medhhinc_18',
 'mix_high_medhhinc_18',

 'low_80120_00',
 'mod_80120_00',
 'high_80120_00',
 'low_pdmt_medhhinc_00',
 'high_pdmt_medhhinc_00',
 'mod_pdmt_medhhinc_00',
 'mix_low_medhhinc_00',
 'mix_mod_medhhinc_00',
 'mix_high_medhhinc_00',

 'per_all_li_90',
 'per_all_li_00',
 'per_all_li_18',
 'per_nonwhite_90',
 'per_nonwhite_00',
 'per_nonwhite_18',
 'per_rent_90',
 'per_rent_00',
 'per_rent_18',

 
 'per_limove_18',
 'per_limove_12',
 'lmh_flag_category',
 'pctch_real_mhval_00_18',
 'pctch_real_mrent_12_18',
 'rent_decrease',
 'rent_marginal',
 'rent_increase',
 'rent_rapid_increase',
 'house_decrease',
 'house_marginal',
 'house_increase',
 'house_rapid_increase',

 'change_flag_category',
 'per_ch_zillow_12_18',
 'ab_50pct_ch',
 'ab_90percentile_ch',
 'rent_50pct_ch',
 'rent_90percentile_ch',
 'hv_abrm_ch',
 'rent_abrm_ch',

 'pctch_real_hinc_90_00',
 
 'pctch_real_hinc_00_18',
 'ch_per_col_90_00',
 'ch_per_col_00_18',
 'ch_per_limove_12_18',
 'aboverm_per_all_li_90',
 'aboverm_per_all_li_00',
 'aboverm_per_all_li_18',
 'aboverm_per_nonwhite_18',
 'aboverm_per_nonwhite_90',
 'aboverm_per_nonwhite_00',
 'aboverm_per_rent_90',
 'aboverm_per_rent_00',
 'aboverm_per_rent_18',
 'aboverm_per_col_90',
 'aboverm_per_col_00',
 'aboverm_per_col_18',
 'aboverm_real_mrent_90',
 'aboverm_real_mrent_00',
 'aboverm_real_mrent_12',
 'aboverm_real_mrent_18',
 'aboverm_real_mhval_90',
 'aboverm_real_mhval_00',
 'aboverm_real_mhval_18',
 'aboverm_pctch_real_mhval_00_18',
 'aboverm_pctch_real_mrent_00_18',
 'aboverm_pctch_real_mrent_12_18',
 'aboverm_pctch_real_mhval_90_00',
 'aboverm_pctch_real_mrent_90_00',
 'lostli_00',
 'lostli_18',
 'aboverm_pctch_real_hinc_90_00',
 'aboverm_pctch_real_hinc_00_18',
 'aboverm_ch_per_col_90_00',
 'aboverm_ch_per_col_00_18',
 'aboverm_per_units_pre50_18',
 'GEOID',
 'rail',
 'presence_ph_LIHTC',
 'hotmarket_00',
 'hotmarket_18',
 'dp_PChRent',
 'dp_RentGap',
 'dense',
 'typology']]

# drop rows which dont have a gentrification category
df2.dropna(subset=['typology'], inplace=True)
df2 = df2.set_index('GEOID')

#fill the nas
df2.fillna(0.0, inplace=True)


df2.head(10)
# Out:
#              low_80120_18  mod_80120_18  ...  dense  typology
# GEOID                                    ...
# 39055312000      0.255773      0.187286  ...      0       6.0
# 39055310600      0.246643      0.134087  ...      0       7.0
# 39055311000      0.335374      0.252017  ...      0       7.0
# 39055311300      0.312035      0.263590  ...      0       6.0
# 39055310700      0.285819      0.150907  ...      0       7.0
# 39055311500      0.144824      0.117032  ...      0       9.0
# 39055311700      0.183136      0.113600  ...      0       7.0
# 39055312100      0.233000      0.269123  ...      0       7.0
# 39055312201      0.311560      0.158779  ...      0       7.0
# 39055311900      0.117416      0.059137  ...      0       9.0
#
# [10 rows x 92 columns]

# %% [markdown]
# ### Convert select continous variables to categorical and one hot encode

# %%
# # convert already dummy variables from float to int
# dummy_var_list = ['hotmarket_00', 'hotmarket_18', 'low_pdmt_medhhinc_00', 'high_pdmt_medhhinc_00', 'mod_pdmt_medhhinc_00',
#                   'mix_low_medhhinc_00', 'mix_mod_medhhinc_00',  'mix_high_medhhinc_00', 'low_pdmt_medhhinc_18', 'high_pdmt_medhhinc_18',
#                   'mod_pdmt_medhhinc_18', 'mix_low_medhhinc_18', 'mix_mod_medhhinc_18', 'mix_high_medhhinc_18', 'presence_ph_LIHTC',
#                   'typology']
# for dummycol in dummy_var_list:
#   df2.loc[:,(dummycol)] = df2[dummycol].astype(int, copy=False)

# %%
# use float variables to represent each categorical variable by dividing into quartiles
def convert_percents_to_dummy_vars(X):

    columns = X.columns

    bin_labels_4 = ['VL', 'L', 'H',  'VH']


    for i in range(0, len(columns)):
        if X[columns[i]].dtype=='float64':
          print("Processing: " + columns[i])

          X[columns[i]] = X[columns[i]].fillna(0)
          cat_label = "{}_cat".format(columns[i])
          dummy_label = "{}_dummy".format(columns[i])
          X[cat_label] = pd.qcut(X[columns[i]], 
                                 4,
                              precision=5,
                              duplicates = 'drop',
                              labels=bin_labels_4)
          X = pd.get_dummies(X, columns=[cat_label], prefix=[dummy_label])
          X = X.drop([columns[i]], axis=1)

    return X

# %%
# check if categorical then convert to dummy using label and onehot encoding
def convert_categorical_to_dummy_vars(X):

    from sklearn.preprocessing import LabelEncoder
    from sklearn.preprocessing import OneHotEncoder    

    columns = X.columns
    indices = X.index
    new_columns = []
    encoded_x = None

    for i in range(0, len(columns)):
        if X[columns[i]].dtype=='O':
          print("Processing: " + columns[i])


          label_encoder = LabelEncoder()
          le = label_encoder.fit(X[columns[i]].apply(str))
          for class_ in le.classes_:
              new_columns.append("{}_{}".format(columns[i],class_))
              
          feature = le.transform(X[columns[i]].apply(str))
          feature = feature.reshape(X.shape[0], 1)
          onehot_encoder = OneHotEncoder(sparse=False)
          onehot_encoder.fit(feature)
          feature = onehot_encoder.transform(feature)
          if encoded_x is None:
              encoded_x = feature
          else:
              encoded_x = np.concatenate((encoded_x, feature), axis=1)
          X = X.drop(columns[i], axis=1)
    new_columns.extend(X.columns)

    X = pd.DataFrame(np.concatenate((encoded_x,X),axis=1),index=indices,columns=new_columns)
    
    return X

# %% [markdown]
# ### Convert Percentage (floats) to Quartiles and Dummy Variables

# %%
# # process and save data all converted to one hot encoding
# df2 = convert_percents_to_dummy_vars(df2)

# %%
# df2 = convert_categorical_to_dummy_vars(df2)

# %% [markdown]
# iii. Save the dataset as a CSV file. The first line of the CSV file should be the attribute
# names as described in the previous question.

# %%
# df2.to_csv("{}/data/processed_{}".format(customized_path_to_homework, file_name))

# %% [markdown]
# # **STUCCO Rule Calculations**

# %%
# load already processed data 
# df3 = pd.read_csv("{}/data/processed_{}".format(customized_path_to_homework, file_name), index_col=0)
# df3 = df3.astype(int)

# %%
confidence_cut = 0.8
lift_cut = 1.0
conviction_cut = 0.8
support_cut = 0.65

# %%
#ref: https://www.ics.uci.edu/~pazzani/Publications/stucco.pdf
#ref: https://github.com/parsahosseini/contrast/blob/master/README.md

# %%
from stucco import ContrastSetLearner
learner = ContrastSetLearner(df2, group_feature='typology')
# Out:
# INFO:root:User-defined feature is 'typology'
# INFO:root:Data dimensions: 631 x 92
# INFO:root:Reading object features (n=3)
# INFO:root:Reading numeric features (n=89)
# INFO:root:29 features lack value; dropping
# INFO:root:New data dimensions: 631 x 63
# INFO:root:Record count (pre-index): 631
# INFO:root:Record count (index): 631

# %%
# derive 3-length combinations of a rule and enumerate their abundance.
learner.learn(max_length=3)
# Out:
# INFO:root:Enumerating 631 item-sets, i
# INFO:root:i=0; n(matrix)=0
# INFO:root:i=200; n(matrix)=427,779
# INFO:root:i=400; n(matrix)=534,762
# INFO:root:i=600; n(matrix)=545,855
# INFO:root:555,443 contingency matrices made
# INFO:root:i=0 matrix not-rules enumerated
# INFO:root:i=2500 matrix not-rules enumerated
# INFO:root:i=5000 matrix not-rules enumerated
# INFO:root:i=7500 matrix not-rules enumerated
# INFO:root:i=10000 matrix not-rules enumerated
# INFO:root:i=12500 matrix not-rules enumerated
# INFO:root:i=15000 matrix not-rules enumerated
# INFO:root:i=17500 matrix not-rules enumerated
# INFO:root:i=20000 matrix not-rules enumerated
# INFO:root:i=22500 matrix not-rules enumerated
# INFO:root:i=25000 matrix not-rules enumerated
# INFO:root:i=27500 matrix not-rules enumerated
# INFO:root:i=30000 matrix not-rules enumerated
# INFO:root:i=32500 matrix not-rules enumerated
# INFO:root:i=35000 matrix not-rules enumerated
# INFO:root:i=37500 matrix not-rules enumerated
# INFO:root:i=40000 matrix not-rules enumerated
# INFO:root:i=42500 matrix not-rules enumerated
# INFO:root:i=45000 matrix not-rules enumerated
# INFO:root:i=47500 matrix not-rules enumerated
# INFO:root:i=50000 matrix not-rules enumerated
# INFO:root:i=52500 matrix not-rules enumerated
# INFO:root:i=55000 matrix not-rules enumerated
# INFO:root:i=57500 matrix not-rules enumerated
# INFO:root:i=60000 matrix not-rules enumerated
# INFO:root:i=62500 matrix not-rules enumerated
# INFO:root:i=65000 matrix not-rules enumerated
# INFO:root:i=67500 matrix not-rules enumerated
# INFO:root:i=70000 matrix not-rules enumerated
# INFO:root:i=72500 matrix not-rules enumerated
# INFO:root:i=75000 matrix not-rules enumerated
# INFO:root:i=77500 matrix not-rules enumerated
# INFO:root:i=80000 matrix not-rules enumerated
# INFO:root:i=82500 matrix not-rules enumerated
# INFO:root:i=85000 matrix not-rules enumerated
# INFO:root:i=87500 matrix not-rules enumerated
# INFO:root:i=90000 matrix not-rules enumerated
# INFO:root:i=92500 matrix not-rules enumerated
# INFO:root:i=95000 matrix not-rules enumerated
# INFO:root:i=97500 matrix not-rules enumerated
# INFO:root:i=100000 matrix not-rules enumerated
# INFO:root:i=102500 matrix not-rules enumerated
# INFO:root:i=105000 matrix not-rules enumerated
# INFO:root:i=107500 matrix not-rules enumerated
# INFO:root:i=110000 matrix not-rules enumerated
# INFO:root:i=112500 matrix not-rules enumerated
# INFO:root:i=115000 matrix not-rules enumerated
# INFO:root:i=117500 matrix not-rules enumerated
# INFO:root:i=120000 matrix not-rules enumerated
# INFO:root:i=122500 matrix not-rules enumerated
# INFO:root:i=125000 matrix not-rules enumerated
# INFO:root:i=127500 matrix not-rules enumerated
# INFO:root:i=130000 matrix not-rules enumerated
# INFO:root:i=132500 matrix not-rules enumerated
# INFO:root:i=135000 matrix not-rules enumerated
# INFO:root:i=137500 matrix not-rules enumerated
# INFO:root:i=140000 matrix not-rules enumerated
# INFO:root:i=142500 matrix not-rules enumerated
# INFO:root:i=145000 matrix not-rules enumerated
# INFO:root:i=147500 matrix not-rules enumerated
# INFO:root:i=150000 matrix not-rules enumerated
# INFO:root:i=152500 matrix not-rules enumerated
# INFO:root:i=155000 matrix not-rules enumerated
# INFO:root:i=157500 matrix not-rules enumerated
# INFO:root:i=160000 matrix not-rules enumerated
# INFO:root:i=162500 matrix not-rules enumerated
# INFO:root:i=165000 matrix not-rules enumerated
# INFO:root:i=167500 matrix not-rules enumerated
# INFO:root:i=170000 matrix not-rules enumerated
# INFO:root:i=172500 matrix not-rules enumerated
# INFO:root:i=175000 matrix not-rules enumerated
# INFO:root:i=177500 matrix not-rules enumerated
# INFO:root:i=180000 matrix not-rules enumerated
# INFO:root:i=182500 matrix not-rules enumerated
# INFO:root:i=185000 matrix not-rules enumerated
# INFO:root:i=187500 matrix not-rules enumerated
# INFO:root:i=190000 matrix not-rules enumerated
# INFO:root:i=192500 matrix not-rules enumerated
# INFO:root:i=195000 matrix not-rules enumerated
# INFO:root:i=197500 matrix not-rules enumerated
# INFO:root:i=200000 matrix not-rules enumerated
# INFO:root:i=202500 matrix not-rules enumerated
# INFO:root:i=205000 matrix not-rules enumerated
# INFO:root:i=207500 matrix not-rules enumerated
# INFO:root:i=210000 matrix not-rules enumerated
# INFO:root:i=212500 matrix not-rules enumerated
# INFO:root:i=215000 matrix not-rules enumerated
# INFO:root:i=217500 matrix not-rules enumerated
# INFO:root:i=220000 matrix not-rules enumerated
# INFO:root:i=222500 matrix not-rules enumerated
# INFO:root:i=225000 matrix not-rules enumerated
# INFO:root:i=227500 matrix not-rules enumerated
# INFO:root:i=230000 matrix not-rules enumerated
# INFO:root:i=232500 matrix not-rules enumerated
# INFO:root:i=235000 matrix not-rules enumerated
# INFO:root:i=237500 matrix not-rules enumerated
# INFO:root:i=240000 matrix not-rules enumerated
# INFO:root:i=242500 matrix not-rules enumerated
# INFO:root:i=245000 matrix not-rules enumerated
# INFO:root:i=247500 matrix not-rules enumerated
# INFO:root:i=250000 matrix not-rules enumerated
# INFO:root:i=252500 matrix not-rules enumerated
# INFO:root:i=255000 matrix not-rules enumerated
# INFO:root:i=257500 matrix not-rules enumerated
# INFO:root:i=260000 matrix not-rules enumerated
# INFO:root:i=262500 matrix not-rules enumerated
# INFO:root:i=265000 matrix not-rules enumerated
# INFO:root:i=267500 matrix not-rules enumerated
# INFO:root:i=270000 matrix not-rules enumerated
# INFO:root:i=272500 matrix not-rules enumerated
# INFO:root:i=275000 matrix not-rules enumerated
# INFO:root:i=277500 matrix not-rules enumerated
# INFO:root:i=280000 matrix not-rules enumerated
# INFO:root:i=282500 matrix not-rules enumerated
# INFO:root:i=285000 matrix not-rules enumerated
# INFO:root:i=287500 matrix not-rules enumerated
# INFO:root:i=290000 matrix not-rules enumerated
# INFO:root:i=292500 matrix not-rules enumerated
# INFO:root:i=295000 matrix not-rules enumerated
# INFO:root:i=297500 matrix not-rules enumerated
# INFO:root:i=300000 matrix not-rules enumerated
# INFO:root:i=302500 matrix not-rules enumerated
# INFO:root:i=305000 matrix not-rules enumerated
# INFO:root:i=307500 matrix not-rules enumerated
# INFO:root:i=310000 matrix not-rules enumerated
# INFO:root:i=312500 matrix not-rules enumerated
# INFO:root:i=315000 matrix not-rules enumerated
# INFO:root:i=317500 matrix not-rules enumerated
# INFO:root:i=320000 matrix not-rules enumerated
# INFO:root:i=322500 matrix not-rules enumerated
# INFO:root:i=325000 matrix not-rules enumerated
# INFO:root:i=327500 matrix not-rules enumerated
# INFO:root:i=330000 matrix not-rules enumerated
# INFO:root:i=332500 matrix not-rules enumerated
# INFO:root:i=335000 matrix not-rules enumerated
# INFO:root:i=337500 matrix not-rules enumerated
# INFO:root:i=340000 matrix not-rules enumerated
# INFO:root:i=342500 matrix not-rules enumerated
# INFO:root:i=345000 matrix not-rules enumerated
# INFO:root:i=347500 matrix not-rules enumerated
# INFO:root:i=350000 matrix not-rules enumerated
# INFO:root:i=352500 matrix not-rules enumerated
# INFO:root:i=355000 matrix not-rules enumerated
# INFO:root:i=357500 matrix not-rules enumerated
# INFO:root:i=360000 matrix not-rules enumerated
# INFO:root:i=362500 matrix not-rules enumerated
# INFO:root:i=365000 matrix not-rules enumerated
# INFO:root:i=367500 matrix not-rules enumerated
# INFO:root:i=370000 matrix not-rules enumerated
# INFO:root:i=372500 matrix not-rules enumerated
# INFO:root:i=375000 matrix not-rules enumerated
# INFO:root:i=377500 matrix not-rules enumerated
# INFO:root:i=380000 matrix not-rules enumerated
# INFO:root:i=382500 matrix not-rules enumerated
# INFO:root:i=385000 matrix not-rules enumerated
# INFO:root:i=387500 matrix not-rules enumerated
# INFO:root:i=390000 matrix not-rules enumerated
# INFO:root:i=392500 matrix not-rules enumerated
# INFO:root:i=395000 matrix not-rules enumerated
# INFO:root:i=397500 matrix not-rules enumerated
# INFO:root:i=400000 matrix not-rules enumerated
# INFO:root:i=402500 matrix not-rules enumerated
# INFO:root:i=405000 matrix not-rules enumerated
# INFO:root:i=407500 matrix not-rules enumerated
# INFO:root:i=410000 matrix not-rules enumerated
# INFO:root:i=412500 matrix not-rules enumerated
# INFO:root:i=415000 matrix not-rules enumerated
# INFO:root:i=417500 matrix not-rules enumerated
# INFO:root:i=420000 matrix not-rules enumerated
# INFO:root:i=422500 matrix not-rules enumerated
# INFO:root:i=425000 matrix not-rules enumerated
# INFO:root:i=427500 matrix not-rules enumerated
# INFO:root:i=430000 matrix not-rules enumerated
# INFO:root:i=432500 matrix not-rules enumerated
# INFO:root:i=435000 matrix not-rules enumerated
# INFO:root:i=437500 matrix not-rules enumerated
# INFO:root:i=440000 matrix not-rules enumerated
# INFO:root:i=442500 matrix not-rules enumerated
# INFO:root:i=445000 matrix not-rules enumerated
# INFO:root:i=447500 matrix not-rules enumerated
# INFO:root:i=450000 matrix not-rules enumerated
# INFO:root:i=452500 matrix not-rules enumerated
# INFO:root:i=455000 matrix not-rules enumerated
# INFO:root:i=457500 matrix not-rules enumerated
# INFO:root:i=460000 matrix not-rules enumerated
# INFO:root:i=462500 matrix not-rules enumerated
# INFO:root:i=465000 matrix not-rules enumerated
# INFO:root:i=467500 matrix not-rules enumerated
# INFO:root:i=470000 matrix not-rules enumerated
# INFO:root:i=472500 matrix not-rules enumerated
# INFO:root:i=475000 matrix not-rules enumerated
# INFO:root:i=477500 matrix not-rules enumerated
# INFO:root:i=480000 matrix not-rules enumerated
# INFO:root:i=482500 matrix not-rules enumerated
# INFO:root:i=485000 matrix not-rules enumerated
# INFO:root:i=487500 matrix not-rules enumerated
# INFO:root:i=490000 matrix not-rules enumerated
# INFO:root:i=492500 matrix not-rules enumerated
# INFO:root:i=495000 matrix not-rules enumerated
# INFO:root:i=497500 matrix not-rules enumerated
# INFO:root:i=500000 matrix not-rules enumerated
# INFO:root:i=502500 matrix not-rules enumerated
# INFO:root:i=505000 matrix not-rules enumerated
# INFO:root:i=507500 matrix not-rules enumerated
# INFO:root:i=510000 matrix not-rules enumerated
# INFO:root:i=512500 matrix not-rules enumerated
# INFO:root:i=515000 matrix not-rules enumerated
# INFO:root:i=517500 matrix not-rules enumerated
# INFO:root:i=520000 matrix not-rules enumerated
# INFO:root:i=522500 matrix not-rules enumerated
# INFO:root:i=525000 matrix not-rules enumerated
# INFO:root:i=527500 matrix not-rules enumerated
# INFO:root:i=530000 matrix not-rules enumerated
# INFO:root:i=532500 matrix not-rules enumerated
# INFO:root:i=535000 matrix not-rules enumerated
# INFO:root:i=537500 matrix not-rules enumerated
# INFO:root:i=540000 matrix not-rules enumerated
# INFO:root:i=542500 matrix not-rules enumerated
# INFO:root:i=545000 matrix not-rules enumerated
# INFO:root:i=547500 matrix not-rules enumerated
# INFO:root:i=550000 matrix not-rules enumerated
# INFO:root:i=552500 matrix not-rules enumerated
# INFO:root:i=555000 matrix not-rules enumerated
# 555443

# %%
output = learner.score(min_lift=3)
# Out:
# Streaming output truncated to the last 5000 lines.
# INFO:root:428830 / 555443: {'rule': ('per_rent_90=>(0.17478896787608067, 0.4591593973037272)', 'aboverm_per_all_li_90=>0', 'aboverm_ch_per_col_90_00=>1'), 'group': 'typology=>7.0', 'lift': 3.1650595575723197}
# INFO:root:428901 / 555443: {'rule': ('per_rent_00=>(0.16666666666666666, 0.4411347517730497)', 'pctch_real_hinc_00_18=>(-0.13695903541694002, 3.0656010952679837)', 'aboverm_per_all_li_90=>0'), 'group': 'typology=>7.0', 'lift': 3.6637335009428034}
# INFO:root:428902 / 555443: {'rule': ('per_rent_00=>(0.16666666666666666, 0.4411347517730497)', 'pctch_real_hinc_00_18=>(-0.13695903541694002, 3.0656010952679837)', 'aboverm_per_all_li_00=>0'), 'group': 'typology=>7.0', 'lift': 3.3940379403794037}
# INFO:root:428976 / 555443: {'rule': ('per_rent_18=>(0.23743627093954844, 0.5034293552812071)', 'aboverm_per_all_li_90=>0', 'aboverm_pctch_real_hinc_00_18=>1'), 'group': 'typology=>7.0', 'lift': 3.439506172839506}
# INFO:root:428977 / 555443: {'rule': ('per_rent_18=>(0.23743627093954844, 0.5034293552812071)', 'aboverm_per_all_li_00=>0', 'aboverm_pctch_real_hinc_00_18=>1'), 'group': 'typology=>7.0', 'lift': 3.2551020408163267}
# INFO:root:429003 / 555443: {'rule': ('per_limove_18=>(0.3822076953390085, 0.5690708082667881)', 'pctch_real_hinc_90_00=>(-0.02731848081586968, 0.08823727033730405)', 'aboverm_per_all_li_90=>0'), 'group': 'typology=>7.0', 'lift': 3.2}
# INFO:root:429006 / 555443: {'rule': ('per_limove_18=>(0.3822076953390085, 0.5690708082667881)', 'pctch_real_hinc_00_18=>(-0.13695903541694002, 3.0656010952679837)', 'aboverm_per_all_li_90=>0'), 'group': 'typology=>7.0', 'lift': 3.7062937062937062}
# INFO:root:429007 / 555443: {'rule': ('per_limove_18=>(0.3822076953390085, 0.5690708082667881)', 'pctch_real_hinc_00_18=>(-0.13695903541694002, 3.0656010952679837)', 'aboverm_per_all_li_00=>0'), 'group': 'typology=>7.0', 'lift': 3.8329238329238327}
# INFO:root:429011 / 555443: {'rule': ('per_limove_18=>(0.3822076953390085, 0.5690708082667881)', 'ch_per_col_90_00=>(0.036788563071054665, 0.30503921757049884)', 'aboverm_per_all_li_90=>0'), 'group': 'typology=>7.0', 'lift': 3.513178294573644}
# INFO:root:429033 / 555443: {'rule': ('per_limove_18=>(0.3822076953390085, 0.5690708082667881)', 'aboverm_per_all_li_00=>0', 'aboverm_pctch_real_hinc_00_18=>1'), 'group': 'typology=>7.0', 'lift': 3.055137844611529}
# INFO:root:429137 / 555443: {'rule': ('pctch_real_mhval_00_18=>(-0.22903090694797545, inf)', 'ch_per_col_00_18=>(-0.15605899454388406, 0.03432783112568166)', 'aboverm_per_all_li_90=>0'), 'group': 'typology=>7.0', 'lift': 3.2083333333333335}
# INFO:root:429213 / 555443: {'rule': ('pctch_real_mrent_12_18=>(-1716002.714285714, -0.08530276064732427)', 'pctch_real_hinc_90_00=>(-0.02731848081586968, 0.08823727033730405)', 'aboverm_per_all_li_90=>0'), 'group': 'typology=>7.0', 'lift': 3.2427536231884053}
# INFO:root:429214 / 555443: {'rule': ('pctch_real_mrent_12_18=>(-1716002.714285714, -0.08530276064732427)', 'pctch_real_hinc_90_00=>(-0.02731848081586968, 0.08823727033730405)', 'aboverm_per_all_li_00=>0'), 'group': 'typology=>7.0', 'lift': 3.1298076923076925}
# INFO:root:429215 / 555443: {'rule': ('pctch_real_mrent_12_18=>(-1716002.714285714, -0.08530276064732427)', 'pctch_real_hinc_00_18=>(-0.13695903541694002, 3.0656010952679837)', 'aboverm_per_all_li_90=>0'), 'group': 'typology=>7.0', 'lift': 3.0003501400560224}
# INFO:root:429220 / 555443: {'rule': ('pctch_real_mrent_12_18=>(-1716002.714285714, -0.08530276064732427)', 'ch_per_col_90_00=>(0.036788563071054665, 0.30503921757049884)', 'aboverm_per_all_li_90=>0'), 'group': 'typology=>7.0', 'lift': 3.59453781512605}
# INFO:root:429221 / 555443: {'rule': ('pctch_real_mrent_12_18=>(-1716002.714285714, -0.08530276064732427)', 'ch_per_col_90_00=>(0.036788563071054665, 0.30503921757049884)', 'aboverm_per_nonwhite_18=>0'), 'group': 'typology=>7.0', 'lift': 3.0057651991614254}
# INFO:root:429371 / 555443: {'rule': ('pctch_real_hinc_00_18=>(-0.13695903541694002, 3.0656010952679837)', 'ch_per_col_90_00=>(0.036788563071054665, 0.30503921757049884)', 'aboverm_per_all_li_90=>0'), 'group': 'typology=>7.0', 'lift': 3.328928571428572}
# INFO:root:429460 / 555443: {'rule': ('ch_per_col_90_00=>(0.036788563071054665, 0.30503921757049884)', 'ch_per_limove_12_18=>(-0.10069002337614008, 0.044185927565587424)', 'aboverm_per_nonwhite_18=>0'), 'group': 'typology=>7.0', 'lift': 3.0092682926829273}
# INFO:root:429514 / 555443: {'rule': ('ch_per_col_00_18=>(-0.15605899454388406, 0.03432783112568166)', 'aboverm_per_all_li_90=>0', 'aboverm_pctch_real_hinc_00_18=>1'), 'group': 'typology=>7.0', 'lift': 3.5700000000000003}
# INFO:root:429517 / 555443: {'rule': ('ch_per_col_00_18=>(-0.15605899454388406, 0.03432783112568166)', 'aboverm_per_all_li_00=>0', 'aboverm_pctch_real_hinc_00_18=>1'), 'group': 'typology=>7.0', 'lift': 3.3115384615384618}
# INFO:root:430170 / 555443: {'rule': ('mod_80120_00=>(0.1656163843494337, 0.2123134316119312)', 'pctch_real_mrent_12_18=>(-1716002.714285714, -0.08530276064732427)', 'aboverm_per_nonwhite_00=>0'), 'group': 'typology=>7.0', 'lift': 3.038602941176471}
# INFO:root:430195 / 555443: {'rule': ('high_80120_00=>(0.28498117786752303, 0.4717376730711314)', 'per_nonwhite_00=>(0.00781540751767773, 0.055932314653761805)', 'pctch_real_mrent_12_18=>(-1716002.714285714, -0.08530276064732427)'), 'group': 'typology=>7.0', 'lift': 3.187570621468926}
# INFO:root:430205 / 555443: {'rule': ('high_80120_00=>(0.28498117786752303, 0.4717376730711314)', 'per_nonwhite_00=>(0.00781540751767773, 0.055932314653761805)', 'aboverm_per_nonwhite_18=>0'), 'group': 'typology=>7.0', 'lift': 3.055229142185664}
# INFO:root:430218 / 555443: {'rule': ('high_80120_00=>(0.28498117786752303, 0.4717376730711314)', 'per_nonwhite_18=>(0.0, 0.11714391967274085)', 'per_rent_18=>(0.23743627093954844, 0.5034293552812071)'), 'group': 'typology=>7.0', 'lift': 3.243421052631579}
# INFO:root:430268 / 555443: {'rule': ('high_80120_00=>(0.28498117786752303, 0.4717376730711314)', 'pctch_real_hinc_90_00=>(-0.7259640254905292, -0.02898869160063426)', 'aboverm_per_nonwhite_18=>0'), 'group': 'typology=>7.0', 'lift': 3.095744680851064}
# INFO:root:430269 / 555443: {'rule': ('high_80120_00=>(0.28498117786752303, 0.4717376730711314)', 'pctch_real_hinc_00_18=>(-0.2713997752586948, -0.13703613720336605)', 'aboverm_per_nonwhite_18=>0'), 'group': 'typology=>7.0', 'lift': 3.535714285714286}
# INFO:root:430270 / 555443: {'rule': ('high_80120_00=>(0.28498117786752303, 0.4717376730711314)', 'pctch_real_hinc_00_18=>(-0.2713997752586948, -0.13703613720336605)', 'aboverm_per_nonwhite_00=>0'), 'group': 'typology=>7.0', 'lift': 3.5106382978723407}
# INFO:root:430303 / 555443: {'rule': ('per_all_li_90=>(0.2769078791009645, 0.4733512989784461)', 'per_nonwhite_18=>(0.0, 0.11714391967274085)', 'lostli_18=>0'), 'group': 'typology=>7.0', 'lift': 3.4347048300536676}
# INFO:root:430314 / 555443: {'rule': ('per_all_li_90=>(0.2769078791009645, 0.4733512989784461)', 'pctch_real_mhval_00_18=>(-0.22903090694797545, inf)', 'aboverm_per_nonwhite_90=>0'), 'group': 'typology=>7.0', 'lift': 3.277089783281734}
# INFO:root:430315 / 555443: {'rule': ('per_all_li_90=>(0.2769078791009645, 0.4733512989784461)', 'pctch_real_mhval_00_18=>(-0.22903090694797545, inf)', 'aboverm_per_nonwhite_00=>0'), 'group': 'typology=>7.0', 'lift': 3.58974358974359}
# INFO:root:431862 / 555443: {'rule': ('per_all_li_90=>(0.2769078791009645, 0.4733512989784461)', 'pctch_real_mhval_00_18=>(-0.22903090694797545, inf)', 'aboverm_real_mhval_90=>1'), 'group': 'typology=>7.0', 'lift': 3.985879332477536}
# INFO:root:431897 / 555443: {'rule': ('per_rent_18=>(0.23743627093954844, 0.5034293552812071)', 'pctch_real_mhval_00_18=>(-0.22903090694797545, inf)', 'aboverm_real_mhval_90=>1'), 'group': 'typology=>7.0', 'lift': 3.175595238095238}
# INFO:root:431899 / 555443: {'rule': ('per_rent_18=>(0.23743627093954844, 0.5034293552812071)', 'pctch_real_mhval_00_18=>(-0.22903090694797545, inf)', 'aboverm_pctch_real_mhval_90_00=>0'), 'group': 'typology=>7.0', 'lift': 3.013793103448276}
# INFO:root:431904 / 555443: {'rule': ('per_rent_18=>(0.23743627093954844, 0.5034293552812071)', 'aboverm_real_mhval_90=>1', 'aboverm_pctch_real_hinc_00_18=>1'), 'group': 'typology=>7.0', 'lift': 3.0037546933667083}
# INFO:root:431987 / 555443: {'rule': ('change_flag_category=>ch_rapid_increase', 'hv_abrm_ch=>1', 'aboverm_per_units_pre50_18=>0'), 'group': 'typology=>6.0', 'lift': 5.489736070381232}
# INFO:root:431990 / 555443: {'rule': ('change_flag_category=>ch_rapid_increase', 'aboverm_real_mrent_18=>1', 'aboverm_per_units_pre50_18=>0'), 'group': 'typology=>6.0', 'lift': 4.009963768115942}
# INFO:root:432041 / 555443: {'rule': ('per_all_li_90=>(0.2769078791009645, 0.4733512989784461)', 'per_limove_12=>(0.0, 0.4281782073448741)', 'aboverm_real_mhval_00=>1'), 'group': 'typology=>7.0', 'lift': 4.226055919095776}
# INFO:root:432042 / 555443: {'rule': ('per_all_li_90=>(0.2769078791009645, 0.4733512989784461)', 'per_limove_12=>(0.0, 0.4281782073448741)', 'aboverm_real_mhval_18=>1'), 'group': 'typology=>7.0', 'lift': 3.9387407827566654}
# INFO:root:432044 / 555443: {'rule': ('per_all_li_90=>(0.2769078791009645, 0.4733512989784461)', 'ch_per_limove_12_18=>(0.04491097713901665, 0.8275862068965517)', 'aboverm_real_mhval_18=>1'), 'group': 'typology=>7.0', 'lift': 3.4346938775510205}
# INFO:root:432247 / 555443: {'rule': ('pctch_real_mrent_12_18=>(-1716002.714285714, -0.08530276064732427)', 'per_ch_zillow_12_18=>(0.10589403973509914, 0.16298988926336047)', 'aboverm_per_col_18=>1'), 'group': 'typology=>7.0', 'lift': 3.0320855614973263}
# INFO:root:432248 / 555443: {'rule': ('pctch_real_mrent_12_18=>(-1716002.714285714, -0.08530276064732427)', 'pctch_real_hinc_90_00=>(-0.02731848081586968, 0.08823727033730405)', 'aboverm_per_col_18=>1'), 'group': 'typology=>7.0', 'lift': 3.055555555555556}
# INFO:root:432423 / 555443: {'rule': ('per_ch_zillow_12_18=>(0.16664233576642334, 0.3979646017699114)', 'aboverm_per_col_90=>1', 'aboverm_per_units_pre50_18=>0'), 'group': 'typology=>7.0', 'lift': 3.1923701298701306}
# INFO:root:432431 / 555443: {'rule': ('per_all_li_90=>(0.2769078791009645, 0.4733512989784461)', 'per_limove_12=>(0.0, 0.4281782073448741)', 'pctch_real_mhval_00_18=>(-0.3809809337708313, -0.22935893850408626)'), 'group': 'typology=>7.0', 'lift': 3.09815668202765}
# INFO:root:432463 / 555443: {'rule': ('mod_80120_18=>(0.1823460588574932, 0.3264770400377759)', 'per_limove_12=>(0.0, 0.4281782073448741)', 'aboverm_per_all_li_90=>0'), 'group': 'typology=>7.0', 'lift': 3.5181818181818185}
# INFO:root:432467 / 555443: {'rule': ('mod_80120_18=>(0.1823460588574932, 0.3264770400377759)', 'pctch_real_mrent_12_18=>(-1716002.714285714, -0.08530276064732427)', 'aboverm_per_all_li_90=>0'), 'group': 'typology=>7.0', 'lift': 3.566013071895425}
# INFO:root:432472 / 555443: {'rule': ('mod_80120_18=>(0.1823460588574932, 0.3264770400377759)', 'ch_per_limove_12_18=>(0.04491097713901665, 0.8275862068965517)', 'aboverm_per_all_li_90=>0'), 'group': 'typology=>7.0', 'lift': 3.617886178861789}
# INFO:root:432496 / 555443: {'rule': ('low_80120_00=>(0.3142368933608505, 0.4987524369606564)', 'per_limove_12=>(0.0, 0.4281782073448741)', 'aboverm_per_all_li_90=>0'), 'group': 'typology=>7.0', 'lift': 4.797312430011199}
# INFO:root:432499 / 555443: {'rule': ('mod_80120_00=>(0.2123670838890891, 0.31031714663329063)', 'per_limove_12=>(0.0, 0.4281782073448741)', 'aboverm_per_all_li_90=>0'), 'group': 'typology=>7.0', 'lift': 3.8333333333333335}
# INFO:root:432502 / 555443: {'rule': ('mod_80120_00=>(0.2123670838890891, 0.31031714663329063)', 'pctch_real_mrent_12_18=>(-1716002.714285714, -0.08530276064732427)', 'aboverm_per_all_li_90=>0'), 'group': 'typology=>7.0', 'lift': 3.89363722697056}
# INFO:root:432505 / 555443: {'rule': ('mod_80120_00=>(0.2123670838890891, 0.31031714663329063)', 'ch_per_limove_12_18=>(0.04491097713901665, 0.8275862068965517)', 'aboverm_per_all_li_90=>0'), 'group': 'typology=>7.0', 'lift': 4.083333333333333}
# INFO:root:432517 / 555443: {'rule': ('high_80120_00=>(0.28498117786752303, 0.4717376730711314)', 'per_limove_12=>(0.0, 0.4281782073448741)', 'aboverm_per_all_li_90=>0'), 'group': 'typology=>7.0', 'lift': 5.139705882352941}
# INFO:root:432520 / 555443: {'rule': ('per_all_li_90=>(0.2769078791009645, 0.4733512989784461)', 'per_limove_12=>(0.0, 0.4281782073448741)', 'aboverm_per_all_li_90=>0'), 'group': 'typology=>7.0', 'lift': 4.732163742690059}
# INFO:root:432522 / 555443: {'rule': ('per_all_li_90=>(0.2769078791009645, 0.4733512989784461)', 'aboverm_per_all_li_90=>0', 'aboverm_pctch_real_mrent_00_18=>0'), 'group': 'typology=>7.0', 'lift': 3.1306233062330624}
# INFO:root:432525 / 555443: {'rule': ('per_all_li_00=>(0.3142368933608505, 0.4987524369606564)', 'per_limove_12=>(0.0, 0.4281782073448741)', 'aboverm_per_all_li_90=>0'), 'group': 'typology=>7.0', 'lift': 4.797312430011199}
# INFO:root:432587 / 555443: {'rule': ('per_rent_00=>(0.16666666666666666, 0.4411347517730497)', 'per_limove_12=>(0.0, 0.4281782073448741)', 'aboverm_per_all_li_90=>0'), 'group': 'typology=>7.0', 'lift': 3.623529411764706}
# INFO:root:432590 / 555443: {'rule': ('per_rent_18=>(0.23743627093954844, 0.5034293552812071)', 'per_limove_12=>(0.0, 0.4281782073448741)', 'aboverm_per_all_li_90=>0'), 'group': 'typology=>7.0', 'lift': 4.259423503325943}
# INFO:root:432598 / 555443: {'rule': ('per_limove_12=>(0.0, 0.4281782073448741)', 'pctch_real_mrent_12_18=>(-1716002.714285714, -0.08530276064732427)', 'aboverm_per_all_li_90=>0'), 'group': 'typology=>7.0', 'lift': 3.0526315789473686}
# INFO:root:432605 / 555443: {'rule': ('per_limove_12=>(0.0, 0.4281782073448741)', 'pctch_real_hinc_90_00=>(-0.02731848081586968, 0.08823727033730405)', 'aboverm_per_all_li_90=>0'), 'group': 'typology=>7.0', 'lift': 3.107993197278912}
# INFO:root:432608 / 555443: {'rule': ('per_limove_12=>(0.0, 0.4281782073448741)', 'ch_per_col_00_18=>(-0.15605899454388406, 0.03432783112568166)', 'aboverm_per_all_li_90=>0'), 'group': 'typology=>7.0', 'lift': 3.6192714453584016}
# INFO:root:432728 / 555443: {'rule': ('ch_per_col_90_00=>(0.0051872797661838615, 0.03666492591408997)', 'ch_per_limove_12_18=>(0.04491097713901665, 0.8275862068965517)', 'aboverm_per_all_li_90=>0'), 'group': 'typology=>7.0', 'lift': 3.085470085470085}
# INFO:root:432805 / 555443: {'rule': ('mod_80120_18=>(0.1823460588574932, 0.3264770400377759)', 'pctch_real_mhval_00_18=>(-0.3809809337708313, -0.22935893850408626)', 'aboverm_real_mhval_18=>1'), 'group': 'typology=>7.0', 'lift': 3.2713178294573644}
# INFO:root:432921 / 555443: {'rule': ('per_nonwhite_90=>(0.029793783123638895, 0.16557669994894852)', 'per_ch_zillow_12_18=>(0.10589403973509914, 0.16298988926336047)', 'aboverm_per_nonwhite_90=>0'), 'group': 'typology=>7.0', 'lift': 3.265993265993265}
# INFO:root:432927 / 555443: {'rule': ('per_nonwhite_90=>(0.029793783123638895, 0.16557669994894852)', 'aboverm_per_nonwhite_90=>0', 'aboverm_real_mhval_90=>1'), 'group': 'typology=>7.0', 'lift': 3.028846153846154}
# INFO:root:432972 / 555443: {'rule': ('pctch_real_mrent_12_18=>(-0.0843990843990845, 0.029794855096059808)', 'per_ch_zillow_12_18=>(0.10589403973509914, 0.16298988926336047)', 'aboverm_per_nonwhite_00=>0'), 'group': 'typology=>7.0', 'lift': 3.276190476190476}
# INFO:root:433152 / 555443: {'rule': ('mod_80120_18=>(0.1823460588574932, 0.3264770400377759)', 'aboverm_per_col_18=>1', 'aboverm_per_units_pre50_18=>0'), 'group': 'typology=>7.0', 'lift': 3.3884297520661155}
# INFO:root:433165 / 555443: {'rule': ('per_ch_zillow_12_18=>(0.16664233576642334, 0.3979646017699114)', 'pctch_real_hinc_00_18=>(-0.2713997752586948, -0.13703613720336605)', 'aboverm_per_col_90=>1'), 'group': 'typology=>7.0', 'lift': 3.0294117647058822}
# INFO:root:433179 / 555443: {'rule': ('ch_per_col_00_18=>(-0.15605899454388406, 0.03432783112568166)', 'aboverm_per_col_18=>1', 'aboverm_per_units_pre50_18=>0'), 'group': 'typology=>7.0', 'lift': 3.4}
# INFO:root:433192 / 555443: {'rule': ('mod_80120_18=>(0.1823460588574932, 0.3264770400377759)', 'mod_80120_00=>(0.2123670838890891, 0.31031714663329063)', 'aboverm_real_mhval_18=>1'), 'group': 'typology=>7.0', 'lift': 3.164068908941755}
# INFO:root:433208 / 555443: {'rule': ('mod_80120_18=>(0.1823460588574932, 0.3264770400377759)', 'ch_per_limove_12_18=>(0.04491097713901665, 0.8275862068965517)', 'aboverm_real_mhval_18=>1'), 'group': 'typology=>7.0', 'lift': 3.459207459207459}
# INFO:root:433221 / 555443: {'rule': ('mod_80120_00=>(0.2123670838890891, 0.31031714663329063)', 'pctch_real_hinc_00_18=>(-0.2713997752586948, -0.13703613720336605)', 'aboverm_per_col_00=>1'), 'group': 'typology=>7.0', 'lift': 3.2080344332855093}
# INFO:root:433222 / 555443: {'rule': ('mod_80120_00=>(0.2123670838890891, 0.31031714663329063)', 'pctch_real_hinc_00_18=>(-0.2713997752586948, -0.13703613720336605)', 'aboverm_per_col_18=>1'), 'group': 'typology=>7.0', 'lift': 3.896774193548387}
# INFO:root:433223 / 555443: {'rule': ('mod_80120_00=>(0.2123670838890891, 0.31031714663329063)', 'pctch_real_hinc_00_18=>(-0.2713997752586948, -0.13703613720336605)', 'aboverm_real_mhval_18=>1'), 'group': 'typology=>7.0', 'lift': 3.791360294117647}
# INFO:root:433224 / 555443: {'rule': ('mod_80120_00=>(0.2123670838890891, 0.31031714663329063)', 'ch_per_limove_12_18=>(0.04491097713901665, 0.8275862068965517)', 'aboverm_real_mhval_18=>1'), 'group': 'typology=>7.0', 'lift': 3.705882352941177}
# INFO:root:433256 / 555443: {'rule': ('per_ch_zillow_12_18=>(0.16664233576642334, 0.3979646017699114)', 'pctch_real_hinc_00_18=>(-0.2713997752586948, -0.13703613720336605)', 'aboverm_real_mhval_18=>1'), 'group': 'typology=>7.0', 'lift': 3.3474099099099095}
# INFO:root:433409 / 555443: {'rule': ('low_80120_18=>(0.306658629772009, 0.5542653276877436)', 'ch_per_col_90_00=>(0.036788563071054665, 0.30503921757049884)', 'aboverm_per_nonwhite_18=>0'), 'group': 'typology=>7.0', 'lift': 4.339181286549708}
# INFO:root:433411 / 555443: {'rule': ('low_80120_18=>(0.306658629772009, 0.5542653276877436)', 'ch_per_col_90_00=>(0.036788563071054665, 0.30503921757049884)', 'aboverm_real_mhval_18=>1'), 'group': 'typology=>7.0', 'lift': 4.404605263157895}
# INFO:root:433413 / 555443: {'rule': ('low_80120_18=>(0.306658629772009, 0.5542653276877436)', 'aboverm_per_nonwhite_18=>0', 'dp_RentGap=>0'), 'group': 'typology=>7.0', 'lift': 3.6144927536231886}
# INFO:root:433417 / 555443: {'rule': ('low_80120_18=>(0.306658629772009, 0.5542653276877436)', 'aboverm_real_mhval_00=>1', 'aboverm_ch_per_col_90_00=>1'), 'group': 'typology=>7.0', 'lift': 3.5598086124401918}
# INFO:root:433418 / 555443: {'rule': ('low_80120_18=>(0.306658629772009, 0.5542653276877436)', 'aboverm_real_mhval_18=>1', 'aboverm_ch_per_col_90_00=>1'), 'group': 'typology=>7.0', 'lift': 4.0120030007501875}
# INFO:root:433423 / 555443: {'rule': ('mod_80120_18=>(0.14146394394991135, 0.182308410986374)', 'lmh_flag_category=>aff_mix_mod', 'ch_per_col_00_18=>(0.09822832063015048, 0.4779607892633261)'), 'group': 'typology=>7.0', 'lift': 3.083636363636364}
# INFO:root:433435 / 555443: {'rule': ('high_80120_18=>(0.27023749595829083, 0.5083931492879976)', 'per_limove_18=>(0.03629639993276357, 0.3815684465035114)', 'lmh_flag_category=>aff_mix_mod'), 'group': 'typology=>7.0', 'lift': 4.383838383838383}
# INFO:root:433439 / 555443: {'rule': ('high_80120_18=>(0.27023749595829083, 0.5083931492879976)', 'per_limove_18=>(0.03629639993276357, 0.3815684465035114)', 'aboverm_pctch_real_mrent_12_18=>0'), 'group': 'typology=>7.0', 'lift': 3.2512499999999993}
# INFO:root:433444 / 555443: {'rule': ('high_80120_18=>(0.27023749595829083, 0.5083931492879976)', 'ch_per_col_90_00=>(0.036788563071054665, 0.30503921757049884)', 'aboverm_per_nonwhite_18=>0'), 'group': 'typology=>7.0', 'lift': 3.74025974025974}
# INFO:root:433446 / 555443: {'rule': ('high_80120_18=>(0.27023749595829083, 0.5083931492879976)', 'aboverm_per_nonwhite_18=>0', 'aboverm_real_mrent_90=>1'), 'group': 'typology=>7.0', 'lift': 3.0119774011299434}
# INFO:root:433447 / 555443: {'rule': ('high_80120_18=>(0.27023749595829083, 0.5083931492879976)', 'aboverm_per_nonwhite_18=>0', 'aboverm_real_mrent_00=>1'), 'group': 'typology=>7.0', 'lift': 3.1086860670194}
# INFO:root:433449 / 555443: {'rule': ('high_80120_18=>(0.27023749595829083, 0.5083931492879976)', 'aboverm_per_nonwhite_18=>0', 'dp_RentGap=>0'), 'group': 'typology=>6.0', 'lift': 3.0634615384615387}
# INFO:root:433488 / 555443: {'rule': ('mod_80120_00=>(0.0006198163656830903, 0.1655644523466696)', 'lmh_flag_category=>aff_mix_mod', 'pctch_real_mrent_12_18=>(-0.0843990843990845, 0.029794855096059808)'), 'group': 'typology=>7.0', 'lift': 3.205387205387205}
# INFO:root:433489 / 555443: {'rule': ('mod_80120_00=>(0.0006198163656830903, 0.1655644523466696)', 'lmh_flag_category=>aff_mix_mod', 'per_ch_zillow_12_18=>(0.16664233576642334, 0.3979646017699114)'), 'group': 'typology=>7.0', 'lift': 3.0337301587301586}
# INFO:root:433593 / 555443: {'rule': ('per_all_li_18=>(0.306658629772009, 0.5542653276877436)', 'ch_per_col_90_00=>(0.036788563071054665, 0.30503921757049884)', 'aboverm_per_nonwhite_18=>0'), 'group': 'typology=>7.0', 'lift': 4.339181286549708}
# INFO:root:433595 / 555443: {'rule': ('per_all_li_18=>(0.306658629772009, 0.5542653276877436)', 'ch_per_col_90_00=>(0.036788563071054665, 0.30503921757049884)', 'aboverm_real_mhval_18=>1'), 'group': 'typology=>7.0', 'lift': 4.404605263157895}
# INFO:root:433597 / 555443: {'rule': ('per_all_li_18=>(0.306658629772009, 0.5542653276877436)', 'aboverm_per_nonwhite_18=>0', 'dp_RentGap=>0'), 'group': 'typology=>7.0', 'lift': 3.6144927536231886}
# INFO:root:433601 / 555443: {'rule': ('per_all_li_18=>(0.306658629772009, 0.5542653276877436)', 'aboverm_real_mhval_00=>1', 'aboverm_ch_per_col_90_00=>1'), 'group': 'typology=>7.0', 'lift': 3.5598086124401918}
# INFO:root:433602 / 555443: {'rule': ('per_all_li_18=>(0.306658629772009, 0.5542653276877436)', 'aboverm_real_mhval_18=>1', 'aboverm_ch_per_col_90_00=>1'), 'group': 'typology=>7.0', 'lift': 4.0120030007501875}
# INFO:root:433718 / 555443: {'rule': ('per_rent_90=>(0.4597290818203511, 1.0)', 'lmh_flag_category=>aff_mix_mod', 'per_ch_zillow_12_18=>(0.16664233576642334, 0.3979646017699114)'), 'group': 'typology=>7.0', 'lift': 3.570666666666667}
# INFO:root:433722 / 555443: {'rule': ('per_rent_00=>(0.4423735260555344, 0.995702005730659)', 'lmh_flag_category=>aff_mix_mod', 'per_ch_zillow_12_18=>(0.16664233576642334, 0.3979646017699114)'), 'group': 'typology=>7.0', 'lift': 3.818181818181818}
# INFO:root:433723 / 555443: {'rule': ('per_rent_00=>(0.4423735260555344, 0.995702005730659)', 'lmh_flag_category=>aff_mix_mod', 'hv_abrm_ch=>1'), 'group': 'typology=>7.0', 'lift': 3.235294117647059}
# INFO:root:433734 / 555443: {'rule': ('per_limove_18=>(0.03629639993276357, 0.3815684465035114)', 'lmh_flag_category=>aff_mix_mod', 'per_ch_zillow_12_18=>(0.16664233576642334, 0.3979646017699114)'), 'group': 'typology=>7.0', 'lift': 3.588377723970944}
# INFO:root:433737 / 555443: {'rule': ('per_limove_18=>(0.03629639993276357, 0.3815684465035114)', 'lmh_flag_category=>aff_mix_mod', 'ch_per_col_90_00=>(0.036788563071054665, 0.30503921757049884)'), 'group': 'typology=>7.0', 'lift': 3.2875}
# INFO:root:433754 / 555443: {'rule': ('per_limove_18=>(0.03629639993276357, 0.3815684465035114)', 'pctch_real_mhval_00_18=>(-0.3809809337708313, -0.22935893850408626)', 'aboverm_real_mhval_18=>1'), 'group': 'typology=>7.0', 'lift': 3.0282331511839713}
# INFO:root:433836 / 555443: {'rule': ('per_limove_12=>(0.595935775547426, 1.0)', 'aboverm_per_nonwhite_18=>0', 'aboverm_real_mrent_90=>1'), 'group': 'typology=>7.0', 'lift': 3.1000000000000005}
# INFO:root:433837 / 555443: {'rule': ('per_limove_12=>(0.595935775547426, 1.0)', 'aboverm_per_nonwhite_18=>0', 'aboverm_real_mrent_00=>1'), 'group': 'typology=>7.0', 'lift': 3.3333333333333335}
# INFO:root:433844 / 555443: {'rule': ('lmh_flag_category=>aff_mix_mod', 'pctch_real_mhval_00_18=>(-0.3809809337708313, -0.22935893850408626)', 'ch_per_col_00_18=>(0.09822832063015048, 0.4779607892633261)'), 'group': 'typology=>7.0', 'lift': 3.7587301587301587}
# INFO:root:433865 / 555443: {'rule': ('lmh_flag_category=>aff_mix_mod', 'ch_per_col_90_00=>(0.036788563071054665, 0.30503921757049884)', 'ch_per_col_00_18=>(0.09822832063015048, 0.4779607892633261)'), 'group': 'typology=>7.0', 'lift': 3.3965014577259476}
# INFO:root:433909 / 555443: {'rule': ('pctch_real_mhval_00_18=>(-0.3809809337708313, -0.22935893850408626)', 'per_ch_zillow_12_18=>(0.16664233576642334, 0.3979646017699114)', 'aboverm_real_mrent_90=>1'), 'group': 'typology=>7.0', 'lift': 3.2420634920634925}
# INFO:root:433916 / 555443: {'rule': ('pctch_real_mhval_00_18=>(-0.3809809337708313, -0.22935893850408626)', 'ch_per_col_90_00=>(0.036788563071054665, 0.30503921757049884)', 'aboverm_per_nonwhite_18=>0'), 'group': 'typology=>7.0', 'lift': 3.1142857142857143}
# INFO:root:433922 / 555443: {'rule': ('pctch_real_mrent_12_18=>(-0.0843990843990845, 0.029794855096059808)', 'per_ch_zillow_12_18=>(0.16664233576642334, 0.3979646017699114)', 'aboverm_real_mhval_00=>1'), 'group': 'typology=>7.0', 'lift': 3.0788177339901472}
# INFO:root:434140 / 555443: {'rule': ('change_flag_category=>ch_rapid_increase', 'aboverm_per_col_90=>1'), 'group': 'typology=>6.0', 'lift': 4.495614035087718}
# INFO:root:434160 / 555443: {'rule': ('mod_80120_00=>(0.0006198163656830903, 0.1655644523466696)', 'lmh_flag_category=>aff_mix_mod', 'ch_per_col_90_00=>(-0.2223373283918293, 0.005089233163388995)'), 'group': 'typology=>7.0', 'lift': 3.0961538461538463}
# INFO:root:434189 / 555443: {'rule': ('lmh_flag_category=>aff_mix_mod', 'change_flag_category=>ch_rapid_increase', 'ch_per_col_00_18=>(0.09822832063015048, 0.4779607892633261)'), 'group': 'typology=>6.0', 'lift': 3.982843137254902}
# INFO:root:434191 / 555443: {'rule': ('lmh_flag_category=>aff_mix_mod', 'change_flag_category=>ch_rapid_increase', 'aboverm_per_col_90=>1'), 'group': 'typology=>6.0', 'lift': 3.984415584415585}
# INFO:root:434193 / 555443: {'rule': ('lmh_flag_category=>aff_mix_mod', 'change_flag_category=>ch_rapid_increase', 'aboverm_ch_per_col_00_18=>1'), 'group': 'typology=>6.0', 'lift': 3.5816326530612246}
# INFO:root:434197 / 555443: {'rule': ('lmh_flag_category=>aff_mix_mod', 'pctch_real_hinc_00_18=>(-0.13695903541694002, 3.0656010952679837)', 'ch_per_limove_12_18=>(-0.10069002337614008, 0.044185927565587424)'), 'group': 'typology=>7.0', 'lift': 3.0874085483249907}
# INFO:root:434218 / 555443: {'rule': ('pctch_real_mrent_12_18=>(0.030576030576030543, 4.4238664894402575)', 'change_flag_category=>ch_rapid_increase', 'aboverm_per_col_90=>1'), 'group': 'typology=>6.0', 'lift': 4.241566014160766}
# INFO:root:434221 / 555443: {'rule': ('rent_decrease=>0', 'change_flag_category=>ch_rapid_increase', 'aboverm_per_col_90=>1'), 'group': 'typology=>6.0', 'lift': 3.3800000000000003}
# INFO:root:434225 / 555443: {'rule': ('change_flag_category=>ch_rapid_increase', 'rent_abrm_ch=>1', 'aboverm_per_col_90=>1'), 'group': 'typology=>6.0', 'lift': 3.667659574468085}
# INFO:root:434252 / 555443: {'rule': ('change_flag_category=>ch_rapid_increase', 'aboverm_per_col_90=>1', 'aboverm_per_col_00=>1'), 'group': 'typology=>6.0', 'lift': 4.429356357927786}
# INFO:root:434253 / 555443: {'rule': ('change_flag_category=>ch_rapid_increase', 'aboverm_per_col_90=>1', 'aboverm_per_col_18=>1'), 'group': 'typology=>6.0', 'lift': 4.662349676225717}
# INFO:root:434254 / 555443: {'rule': ('change_flag_category=>ch_rapid_increase', 'aboverm_per_col_90=>1', 'aboverm_real_mrent_90=>0'), 'group': 'typology=>6.0', 'lift': 4.176136363636364}
# INFO:root:434255 / 555443: {'rule': ('change_flag_category=>ch_rapid_increase', 'aboverm_per_col_90=>1', 'aboverm_real_mrent_00=>0'), 'group': 'typology=>6.0', 'lift': 5.51470588235294}
# INFO:root:434257 / 555443: {'rule': ('change_flag_category=>ch_rapid_increase', 'aboverm_per_col_90=>1', 'aboverm_real_mrent_18=>1'), 'group': 'typology=>6.0', 'lift': 3.9853723404255317}
# INFO:root:434258 / 555443: {'rule': ('change_flag_category=>ch_rapid_increase', 'aboverm_per_col_90=>1', 'aboverm_real_mhval_90=>0'), 'group': 'typology=>6.0', 'lift': 3.3892857142857147}
# INFO:root:434259 / 555443: {'rule': ('change_flag_category=>ch_rapid_increase', 'aboverm_per_col_90=>1', 'aboverm_real_mhval_00=>0'), 'group': 'typology=>6.0', 'lift': 3.3809523809523814}
# INFO:root:434261 / 555443: {'rule': ('change_flag_category=>ch_rapid_increase', 'aboverm_per_col_90=>1', 'aboverm_pctch_real_mhval_00_18=>0'), 'group': 'typology=>6.0', 'lift': 3.80625}
# INFO:root:434262 / 555443: {'rule': ('change_flag_category=>ch_rapid_increase', 'aboverm_per_col_90=>1', 'aboverm_pctch_real_mrent_00_18=>1'), 'group': 'typology=>6.0', 'lift': 3.527131782945736}
# INFO:root:434263 / 555443: {'rule': ('change_flag_category=>ch_rapid_increase', 'aboverm_per_col_90=>1', 'aboverm_pctch_real_mrent_12_18=>1'), 'group': 'typology=>6.0', 'lift': 3.449333333333333}
# INFO:root:434264 / 555443: {'rule': ('change_flag_category=>ch_rapid_increase', 'aboverm_per_col_90=>1', 'aboverm_pctch_real_mhval_90_00=>1'), 'group': 'typology=>6.0', 'lift': 3.0388198757763973}
# INFO:root:434268 / 555443: {'rule': ('change_flag_category=>ch_rapid_increase', 'aboverm_per_col_90=>1', 'aboverm_pctch_real_hinc_00_18=>1'), 'group': 'typology=>6.0', 'lift': 4.850094876660342}
# INFO:root:434269 / 555443: {'rule': ('change_flag_category=>ch_rapid_increase', 'aboverm_per_col_90=>1', 'aboverm_ch_per_col_90_00=>0'), 'group': 'typology=>6.0', 'lift': 3.2467532467532463}
# INFO:root:434273 / 555443: {'rule': ('change_flag_category=>ch_rapid_increase', 'aboverm_per_col_90=>1', 'dp_RentGap=>0'), 'group': 'typology=>6.0', 'lift': 3.4899470899470892}
# INFO:root:434274 / 555443: {'rule': ('change_flag_category=>ch_rapid_increase', 'aboverm_per_col_00=>1', 'aboverm_real_mrent_12=>0'), 'group': 'typology=>6.0', 'lift': 4.024621212121213}
# INFO:root:434280 / 555443: {'rule': ('change_flag_category=>ch_rapid_increase', 'aboverm_pctch_real_mhval_00_18=>0', 'aboverm_ch_per_col_00_18=>1'), 'group': 'typology=>6.0', 'lift': 4.291666666666667}
# INFO:root:434281 / 555443: {'rule': ('change_flag_category=>ch_rapid_increase', 'aboverm_pctch_real_mrent_90_00=>0', 'aboverm_ch_per_col_00_18=>1'), 'group': 'typology=>6.0', 'lift': 4.2909482758620685}
# INFO:root:434343 / 555443: {'rule': ('lmh_flag_category=>aff_mix_mod', 'change_flag_category=>ch_increase', 'aboverm_ch_per_col_90_00=>1'), 'group': 'typology=>7.0', 'lift': 5.275735294117646}
# INFO:root:434368 / 555443: {'rule': ('mod_80120_18=>(0.1823460588574932, 0.3264770400377759)', 'per_nonwhite_90=>(0.029793783123638895, 0.16557669994894852)', 'lmh_flag_category=>aff_mix_mod'), 'group': 'typology=>7.0', 'lift': 4.229166666666668}
# INFO:root:434370 / 555443: {'rule': ('mod_80120_00=>(0.1656163843494337, 0.2123134316119312)', 'per_nonwhite_90=>(0.029793783123638895, 0.16557669994894852)', 'lmh_flag_category=>aff_mix_mod'), 'group': 'typology=>7.0', 'lift': 3.352340425531915}
# INFO:root:434377 / 555443: {'rule': ('lmh_flag_category=>aff_mix_mod', 'per_ch_zillow_12_18=>(0.10589403973509914, 0.16298988926336047)', 'pctch_real_hinc_90_00=>(-0.02731848081586968, 0.08823727033730405)'), 'group': 'typology=>7.0', 'lift': 3.7851021753460774}
# INFO:root:434623 / 555443: {'rule': ('change_flag_category=>ch_increase', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>7.0', 'lift': 3.5813953488372094}
# INFO:root:434685 / 555443: {'rule': ('low_80120_18=>(0.07076486425245124, 0.30633406572935595)', 'mod_80120_18=>(0.1823460588574932, 0.3264770400377759)', 'lmh_flag_category=>aff_mix_mod'), 'group': 'typology=>7.0', 'lift': 3.416640890813486}
# INFO:root:434688 / 555443: {'rule': ('low_80120_18=>(0.07076486425245124, 0.30633406572935595)', 'mod_80120_18=>(0.1823460588574932, 0.3264770400377759)', 'rent_decrease=>0'), 'group': 'typology=>6.0', 'lift': 3.3018292682926833}
# INFO:root:434859 / 555443: {'rule': ('low_80120_18=>(0.07076486425245124, 0.30633406572935595)', 'mod_80120_00=>(0.2123670838890891, 0.31031714663329063)', 'lmh_flag_category=>aff_mix_mod'), 'group': 'typology=>7.0', 'lift': 4.2496940024479795}
# INFO:root:434902 / 555443: {'rule': ('low_80120_18=>(0.07076486425245124, 0.30633406572935595)', 'mod_80120_00=>(0.2123670838890891, 0.31031714663329063)', 'presence_ph_LIHTC=>False'), 'group': 'typology=>7.0', 'lift': 3.2840909090909087}
# INFO:root:434958 / 555443: {'rule': ('low_80120_18=>(0.07076486425245124, 0.30633406572935595)', 'high_80120_00=>(0.28498117786752303, 0.4717376730711314)', 'presence_ph_LIHTC=>False'), 'group': 'typology=>7.0', 'lift': 5.336774193548388}
# INFO:root:434984 / 555443: {'rule': ('low_80120_18=>(0.07076486425245124, 0.30633406572935595)', 'per_all_li_90=>(0.2769078791009645, 0.4733512989784461)', 'aboverm_per_all_li_00=>0'), 'group': 'typology=>7.0', 'lift': 5.105882352941177}
# INFO:root:434985 / 555443: {'rule': ('low_80120_18=>(0.07076486425245124, 0.30633406572935595)', 'per_all_li_90=>(0.2769078791009645, 0.4733512989784461)', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>7.0', 'lift': 5.0215208034433285}
# INFO:root:434987 / 555443: {'rule': ('low_80120_18=>(0.07076486425245124, 0.30633406572935595)', 'per_all_li_90=>(0.2769078791009645, 0.4733512989784461)', 'aboverm_per_nonwhite_90=>0'), 'group': 'typology=>7.0', 'lift': 4.305247597930524}
# INFO:root:435000 / 555443: {'rule': ('low_80120_18=>(0.07076486425245124, 0.30633406572935595)', 'per_all_li_90=>(0.2769078791009645, 0.4733512989784461)', 'aboverm_real_mhval_00=>1'), 'group': 'typology=>7.0', 'lift': 5.359288097886541}
# INFO:root:435013 / 555443: {'rule': ('low_80120_18=>(0.07076486425245124, 0.30633406572935595)', 'per_all_li_90=>(0.2769078791009645, 0.4733512989784461)', 'presence_ph_LIHTC=>False'), 'group': 'typology=>7.0', 'lift': 4.514519056261343}
# INFO:root:435279 / 555443: {'rule': ('low_80120_18=>(0.07076486425245124, 0.30633406572935595)', 'per_rent_90=>(0.17478896787608067, 0.4591593973037272)', 'lmh_flag_category=>aff_mix_mod'), 'group': 'typology=>7.0', 'lift': 3.3123689727463312}
# INFO:root:435325 / 555443: {'rule': ('low_80120_18=>(0.07076486425245124, 0.30633406572935595)', 'per_rent_00=>(0.16666666666666666, 0.4411347517730497)', 'per_limove_18=>(0.03629639993276357, 0.3815684465035114)'), 'group': 'typology=>7.0', 'lift': 3.0734767025089607}
# INFO:root:435327 / 555443: {'rule': ('low_80120_18=>(0.07076486425245124, 0.30633406572935595)', 'per_rent_00=>(0.16666666666666666, 0.4411347517730497)', 'lmh_flag_category=>aff_mix_mod'), 'group': 'typology=>7.0', 'lift': 3.5543958249698915}
# INFO:root:435341 / 555443: {'rule': ('low_80120_18=>(0.07076486425245124, 0.30633406572935595)', 'per_rent_00=>(0.16666666666666666, 0.4411347517730497)', 'aboverm_per_all_li_00=>0'), 'group': 'typology=>7.0', 'lift': 3.2440657334144856}
# INFO:root:435342 / 555443: {'rule': ('low_80120_18=>(0.07076486425245124, 0.30633406572935595)', 'per_rent_00=>(0.16666666666666666, 0.4411347517730497)', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>7.0', 'lift': 3.171744324970131}
# INFO:root:435343 / 555443: {'rule': ('low_80120_18=>(0.07076486425245124, 0.30633406572935595)', 'per_rent_00=>(0.16666666666666666, 0.4411347517730497)', 'aboverm_per_nonwhite_18=>0'), 'group': 'typology=>7.0', 'lift': 3.3875391849529786}
# INFO:root:435344 / 555443: {'rule': ('low_80120_18=>(0.07076486425245124, 0.30633406572935595)', 'per_rent_00=>(0.16666666666666666, 0.4411347517730497)', 'aboverm_per_nonwhite_90=>0'), 'group': 'typology=>7.0', 'lift': 3.6}
# INFO:root:435345 / 555443: {'rule': ('low_80120_18=>(0.07076486425245124, 0.30633406572935595)', 'per_rent_00=>(0.16666666666666666, 0.4411347517730497)', 'aboverm_per_nonwhite_00=>0'), 'group': 'typology=>7.0', 'lift': 3.649373881932021}
# INFO:root:435347 / 555443: {'rule': ('low_80120_18=>(0.07076486425245124, 0.30633406572935595)', 'per_rent_00=>(0.16666666666666666, 0.4411347517730497)', 'aboverm_per_rent_00=>0'), 'group': 'typology=>7.0', 'lift': 3.3104395604395602}
# INFO:root:435348 / 555443: {'rule': ('low_80120_18=>(0.07076486425245124, 0.30633406572935595)', 'per_rent_00=>(0.16666666666666666, 0.4411347517730497)', 'aboverm_per_rent_18=>0'), 'group': 'typology=>7.0', 'lift': 3.084153005464481}
# INFO:root:435350 / 555443: {'rule': ('low_80120_18=>(0.07076486425245124, 0.30633406572935595)', 'per_rent_00=>(0.16666666666666666, 0.4411347517730497)', 'aboverm_per_col_00=>1'), 'group': 'typology=>7.0', 'lift': 3.030172413793103}
# INFO:root:435357 / 555443: {'rule': ('low_80120_18=>(0.07076486425245124, 0.30633406572935595)', 'per_rent_00=>(0.16666666666666666, 0.4411347517730497)', 'aboverm_real_mhval_00=>1'), 'group': 'typology=>7.0', 'lift': 3.0278592375366564}
# INFO:root:435367 / 555443: {'rule': ('low_80120_18=>(0.07076486425245124, 0.30633406572935595)', 'per_rent_00=>(0.16666666666666666, 0.4411347517730497)', 'aboverm_ch_per_col_90_00=>1'), 'group': 'typology=>7.0', 'lift': 3.00314465408805}
# INFO:root:435369 / 555443: {'rule': ('low_80120_18=>(0.07076486425245124, 0.30633406572935595)', 'per_rent_00=>(0.16666666666666666, 0.4411347517730497)', 'aboverm_per_units_pre50_18=>0'), 'group': 'typology=>7.0', 'lift': 3.2377136752136755}
# INFO:root:435370 / 555443: {'rule': ('low_80120_18=>(0.07076486425245124, 0.30633406572935595)', 'per_rent_00=>(0.16666666666666666, 0.4411347517730497)', 'presence_ph_LIHTC=>False'), 'group': 'typology=>7.0', 'lift': 3.212200435729847}
# INFO:root:435514 / 555443: {'rule': ('low_80120_18=>(0.07076486425245124, 0.30633406572935595)', 'lmh_flag_category=>aff_mix_mod', 'per_ch_zillow_12_18=>(0.10589403973509914, 0.16298988926336047)'), 'group': 'typology=>7.0', 'lift': 3.3163100989187946}
# INFO:root:435519 / 555443: {'rule': ('low_80120_18=>(0.07076486425245124, 0.30633406572935595)', 'lmh_flag_category=>aff_mix_mod', 'ch_per_col_90_00=>(0.036788563071054665, 0.30503921757049884)'), 'group': 'typology=>7.0', 'lift': 3.0415686274509803}
# INFO:root:435610 / 555443: {'rule': ('low_80120_18=>(0.07076486425245124, 0.30633406572935595)', 'pctch_real_mrent_12_18=>(0.030576030576030543, 4.4238664894402575)', 'aboverm_per_nonwhite_18=>0'), 'group': 'typology=>6.0', 'lift': 3.1555273994298387}
# INFO:root:436514 / 555443: {'rule': ('mod_80120_18=>(0.1823460588574932, 0.3264770400377759)', 'high_80120_18=>(0.5084084428901685, 0.8819577938444018)', 'lmh_flag_category=>aff_mix_mod'), 'group': 'typology=>7.0', 'lift': 4.430555555555555}
# INFO:root:436557 / 555443: {'rule': ('mod_80120_18=>(0.1823460588574932, 0.3264770400377759)', 'high_80120_18=>(0.5084084428901685, 0.8819577938444018)', 'presence_ph_LIHTC=>False'), 'group': 'typology=>7.0', 'lift': 3.695652173913043}
# INFO:root:436565 / 555443: {'rule': ('mod_80120_18=>(0.1823460588574932, 0.3264770400377759)', 'low_80120_00=>(0.3142368933608505, 0.4987524369606564)', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>7.0', 'lift': 3.708643815201192}
# INFO:root:436567 / 555443: {'rule': ('mod_80120_18=>(0.1823460588574932, 0.3264770400377759)', 'low_80120_00=>(0.3142368933608505, 0.4987524369606564)', 'aboverm_real_mhval_00=>1'), 'group': 'typology=>7.0', 'lift': 3.4959349593495928}
# INFO:root:436568 / 555443: {'rule': ('mod_80120_18=>(0.1823460588574932, 0.3264770400377759)', 'low_80120_00=>(0.3142368933608505, 0.4987524369606564)', 'aboverm_real_mhval_18=>1'), 'group': 'typology=>7.0', 'lift': 4.0309617918313565}
# INFO:root:436579 / 555443: {'rule': ('mod_80120_18=>(0.1823460588574932, 0.3264770400377759)', 'high_80120_00=>(0.28498117786752303, 0.4717376730711314)', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>7.0', 'lift': 3.5852564102564104}
# INFO:root:436584 / 555443: {'rule': ('mod_80120_18=>(0.1823460588574932, 0.3264770400377759)', 'per_all_li_90=>(0.2769078791009645, 0.4733512989784461)', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>7.0', 'lift': 3.549726775956284}
# INFO:root:436585 / 555443: {'rule': ('mod_80120_18=>(0.1823460588574932, 0.3264770400377759)', 'per_all_li_90=>(0.2769078791009645, 0.4733512989784461)', 'aboverm_real_mhval_00=>1'), 'group': 'typology=>7.0', 'lift': 3.485}
# INFO:root:436586 / 555443: {'rule': ('mod_80120_18=>(0.1823460588574932, 0.3264770400377759)', 'per_all_li_90=>(0.2769078791009645, 0.4733512989784461)', 'aboverm_real_mhval_18=>1'), 'group': 'typology=>7.0', 'lift': 4.015238095238095}
# INFO:root:436593 / 555443: {'rule': ('mod_80120_18=>(0.1823460588574932, 0.3264770400377759)', 'per_all_li_00=>(0.3142368933608505, 0.4987524369606564)', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>7.0', 'lift': 3.708643815201192}
# INFO:root:436595 / 555443: {'rule': ('mod_80120_18=>(0.1823460588574932, 0.3264770400377759)', 'per_all_li_00=>(0.3142368933608505, 0.4987524369606564)', 'aboverm_real_mhval_00=>1'), 'group': 'typology=>7.0', 'lift': 3.4959349593495928}
# INFO:root:436596 / 555443: {'rule': ('mod_80120_18=>(0.1823460588574932, 0.3264770400377759)', 'per_all_li_00=>(0.3142368933608505, 0.4987524369606564)', 'aboverm_real_mhval_18=>1'), 'group': 'typology=>7.0', 'lift': 4.0309617918313565}
# INFO:root:436606 / 555443: {'rule': ('mod_80120_18=>(0.1823460588574932, 0.3264770400377759)', 'per_all_li_18=>(0.07076486425245124, 0.30633406572935595)', 'lmh_flag_category=>aff_mix_mod'), 'group': 'typology=>7.0', 'lift': 3.416640890813486}
# INFO:root:436609 / 555443: {'rule': ('mod_80120_18=>(0.1823460588574932, 0.3264770400377759)', 'per_all_li_18=>(0.07076486425245124, 0.30633406572935595)', 'rent_decrease=>0'), 'group': 'typology=>6.0', 'lift': 3.3018292682926833}
# INFO:root:436660 / 555443: {'rule': ('mod_80120_18=>(0.1823460588574932, 0.3264770400377759)', 'per_nonwhite_90=>(0.0, 0.02933479901474745)', 'aboverm_per_all_li_00=>0'), 'group': 'typology=>7.0', 'lift': 3.0827480245829677}
# INFO:root:436664 / 555443: {'rule': ('mod_80120_18=>(0.1823460588574932, 0.3264770400377759)', 'per_nonwhite_90=>(0.0, 0.02933479901474745)', 'aboverm_real_mhval_18=>1'), 'group': 'typology=>7.0', 'lift': 3.063885267275098}
# INFO:root:436682 / 555443: {'rule': ('mod_80120_18=>(0.1823460588574932, 0.3264770400377759)', 'per_nonwhite_00=>(0.00781540751767773, 0.055932314653761805)', 'aboverm_per_all_li_00=>0'), 'group': 'typology=>7.0', 'lift': 3.1343283582089554}
# INFO:root:436686 / 555443: {'rule': ('mod_80120_18=>(0.1823460588574932, 0.3264770400377759)', 'per_nonwhite_00=>(0.00781540751767773, 0.055932314653761805)', 'aboverm_per_col_00=>1'), 'group': 'typology=>7.0', 'lift': 4.207446808510638}
# INFO:root:436687 / 555443: {'rule': ('mod_80120_18=>(0.1823460588574932, 0.3264770400377759)', 'per_nonwhite_00=>(0.00781540751767773, 0.055932314653761805)', 'aboverm_per_col_18=>1'), 'group': 'typology=>7.0', 'lift': 4.33090705487122}
# INFO:root:436692 / 555443: {'rule': ('mod_80120_18=>(0.1823460588574932, 0.3264770400377759)', 'per_nonwhite_00=>(0.00781540751767773, 0.055932314653761805)', 'aboverm_real_mhval_18=>1'), 'group': 'typology=>7.0', 'lift': 3.0320942045716928}
# INFO:root:436704 / 555443: {'rule': ('mod_80120_18=>(0.1823460588574932, 0.3264770400377759)', 'per_nonwhite_18=>(0.0, 0.11714391967274085)', 'lmh_flag_category=>aff_mix_mod'), 'group': 'typology=>7.0', 'lift': 3.1300533943554534}
# INFO:root:436707 / 555443: {'rule': ('mod_80120_18=>(0.1823460588574932, 0.3264770400377759)', 'per_nonwhite_18=>(0.0, 0.11714391967274085)', 'rent_decrease=>0'), 'group': 'typology=>6.0', 'lift': 3.6204545454545456}
# INFO:root:436718 / 555443: {'rule': ('mod_80120_18=>(0.1823460588574932, 0.3264770400377759)', 'per_nonwhite_18=>(0.0, 0.11714391967274085)', 'aboverm_per_all_li_00=>0'), 'group': 'typology=>7.0', 'lift': 3.1182244985061884}
# INFO:root:436727 / 555443: {'rule': ('mod_80120_18=>(0.1823460588574932, 0.3264770400377759)', 'per_nonwhite_18=>(0.0, 0.11714391967274085)', 'aboverm_per_col_00=>1'), 'group': 'typology=>7.0', 'lift': 3.9057971014492754}
# INFO:root:436728 / 555443: {'rule': ('mod_80120_18=>(0.1823460588574932, 0.3264770400377759)', 'per_nonwhite_18=>(0.0, 0.11714391967274085)', 'aboverm_per_col_18=>1'), 'group': 'typology=>7.0', 'lift': 3.9690522243713735}
# INFO:root:436762 / 555443: {'rule': ('mod_80120_18=>(0.1823460588574932, 0.3264770400377759)', 'per_rent_18=>(0.0, 0.2365887207702889)', 'lmh_flag_category=>aff_mix_mod'), 'group': 'typology=>7.0', 'lift': 3.297992794647452}
# INFO:root:436775 / 555443: {'rule': ('mod_80120_18=>(0.1823460588574932, 0.3264770400377759)', 'per_rent_18=>(0.0, 0.2365887207702889)', 'aboverm_per_col_00=>1'), 'group': 'typology=>7.0', 'lift': 4.327096327096327}
# INFO:root:436776 / 555443: {'rule': ('mod_80120_18=>(0.1823460588574932, 0.3264770400377759)', 'per_rent_18=>(0.0, 0.2365887207702889)', 'aboverm_per_col_18=>1'), 'group': 'typology=>7.0', 'lift': 4.313222079589217}
# INFO:root:436793 / 555443: {'rule': ('mod_80120_18=>(0.1823460588574932, 0.3264770400377759)', 'per_limove_18=>(0.03629639993276357, 0.3815684465035114)', 'aboverm_per_col_00=>1'), 'group': 'typology=>7.0', 'lift': 3.5918367346938775}
# INFO:root:436804 / 555443: {'rule': ('mod_80120_18=>(0.1823460588574932, 0.3264770400377759)', 'pctch_real_mrent_12_18=>(0.030576030576030543, 4.4238664894402575)', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>6.0', 'lift': 3.9986413043478257}
# INFO:root:436824 / 555443: {'rule': ('mod_80120_18=>(0.1823460588574932, 0.3264770400377759)', 'pctch_real_hinc_90_00=>(0.08881160285719343, 11.70834029461591)', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>7.0', 'lift': 3.1698379140239608}
# INFO:root:436827 / 555443: {'rule': ('mod_80120_18=>(0.1823460588574932, 0.3264770400377759)', 'pctch_real_hinc_00_18=>(-0.13695903541694002, 3.0656010952679837)', 'aboverm_per_all_li_00=>0'), 'group': 'typology=>7.0', 'lift': 4.514814814814816}
# INFO:root:436839 / 555443: {'rule': ('mod_80120_18=>(0.1823460588574932, 0.3264770400377759)', 'ch_per_col_00_18=>(0.09822832063015048, 0.4779607892633261)', 'aboverm_per_all_li_00=>0'), 'group': 'typology=>7.0', 'lift': 4.858131487889272}
# INFO:root:436855 / 555443: {'rule': ('mod_80120_18=>(0.1823460588574932, 0.3264770400377759)', 'aboverm_per_all_li_00=>0', 'aboverm_pctch_real_hinc_00_18=>1'), 'group': 'typology=>7.0', 'lift': 3.1904161412358136}
# INFO:root:436856 / 555443: {'rule': ('mod_80120_18=>(0.1823460588574932, 0.3264770400377759)', 'aboverm_per_all_li_00=>0', 'aboverm_ch_per_col_00_18=>1'), 'group': 'typology=>7.0', 'lift': 3.4782608695652177}
# INFO:root:436864 / 555443: {'rule': ('mod_80120_18=>(0.1823460588574932, 0.3264770400377759)', 'aboverm_per_all_li_18=>0', 'aboverm_per_col_00=>1'), 'group': 'typology=>7.0', 'lift': 3.016824849007765}
# INFO:root:436865 / 555443: {'rule': ('mod_80120_18=>(0.1823460588574932, 0.3264770400377759)', 'aboverm_per_all_li_18=>0', 'aboverm_per_col_18=>1'), 'group': 'typology=>7.0', 'lift': 3.07351598173516}
# INFO:root:436882 / 555443: {'rule': ('mod_80120_18=>(0.1823460588574932, 0.3264770400377759)', 'aboverm_per_all_li_18=>0', 'aboverm_ch_per_col_00_18=>1'), 'group': 'typology=>7.0', 'lift': 3.05868700265252}
# INFO:root:436886 / 555443: {'rule': ('mod_80120_18=>(0.1823460588574932, 0.3264770400377759)', 'aboverm_per_nonwhite_18=>0', 'aboverm_per_col_00=>1'), 'group': 'typology=>7.0', 'lift': 3.202729044834308}
# INFO:root:436887 / 555443: {'rule': ('mod_80120_18=>(0.1823460588574932, 0.3264770400377759)', 'aboverm_per_nonwhite_18=>0', 'aboverm_per_col_18=>1'), 'group': 'typology=>7.0', 'lift': 3.3159420289855075}
# INFO:root:436892 / 555443: {'rule': ('mod_80120_18=>(0.1823460588574932, 0.3264770400377759)', 'aboverm_per_nonwhite_18=>0', 'aboverm_ch_per_col_00_18=>1'), 'group': 'typology=>7.0', 'lift': 3.073840445269017}
# INFO:root:436896 / 555443: {'rule': ('mod_80120_18=>(0.1823460588574932, 0.3264770400377759)', 'aboverm_per_rent_00=>0', 'aboverm_per_col_00=>1'), 'group': 'typology=>7.0', 'lift': 3.5696969696969694}
# INFO:root:436897 / 555443: {'rule': ('mod_80120_18=>(0.1823460588574932, 0.3264770400377759)', 'aboverm_per_rent_00=>0', 'aboverm_per_col_18=>1'), 'group': 'typology=>7.0', 'lift': 3.8763654419066538}
# INFO:root:436899 / 555443: {'rule': ('mod_80120_18=>(0.1823460588574932, 0.3264770400377759)', 'aboverm_per_rent_00=>0', 'aboverm_real_mhval_18=>1'), 'group': 'typology=>7.0', 'lift': 3.189542483660131}
# ...
# INFO:root:535598 / 555443: {'rule': ('per_rent_90=>(0.4597290818203511, 1.0)', 'aboverm_per_all_li_00=>0', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>7.0', 'lift': 3.5}
# INFO:root:535599 / 555443: {'rule': ('per_rent_90=>(0.4597290818203511, 1.0)', 'aboverm_per_all_li_00=>0', 'aboverm_per_nonwhite_18=>0'), 'group': 'typology=>7.0', 'lift': 4.208333333333334}
# INFO:root:535600 / 555443: {'rule': ('per_rent_90=>(0.4597290818203511, 1.0)', 'aboverm_per_all_li_00=>0', 'aboverm_per_nonwhite_00=>0'), 'group': 'typology=>7.0', 'lift': 4.043478260869565}
# INFO:root:535603 / 555443: {'rule': ('per_rent_90=>(0.4597290818203511, 1.0)', 'aboverm_per_all_li_00=>0', 'aboverm_real_mhval_18=>1'), 'group': 'typology=>7.0', 'lift': 3.1239316239316244}
# INFO:root:535605 / 555443: {'rule': ('per_rent_90=>(0.4597290818203511, 1.0)', 'aboverm_per_all_li_00=>0', 'lostli_18=>1'), 'group': 'typology=>7.0', 'lift': 3.1753846153846155}
# INFO:root:535607 / 555443: {'rule': ('per_rent_90=>(0.4597290818203511, 1.0)', 'aboverm_per_all_li_00=>0', 'aboverm_ch_per_col_00_18=>1'), 'group': 'typology=>7.0', 'lift': 3.323076923076923}
# INFO:root:536159 / 555443: {'rule': ('per_rent_00=>(0.4423735260555344, 0.995702005730659)', 'per_limove_12=>(0.0, 0.4281782073448741)', 'aboverm_per_all_li_90=>0'), 'group': 'typology=>7.0', 'lift': 3.5161290322580645}
# INFO:root:536160 / 555443: {'rule': ('per_rent_00=>(0.4423735260555344, 0.995702005730659)', 'per_limove_12=>(0.0, 0.4281782073448741)', 'aboverm_per_all_li_00=>0'), 'group': 'typology=>7.0', 'lift': 3.34375}
# INFO:root:536161 / 555443: {'rule': ('per_rent_00=>(0.4423735260555344, 0.995702005730659)', 'lmh_flag_category=>aff_mix_mod', 'aboverm_per_all_li_90=>0'), 'group': 'typology=>7.0', 'lift': 5.5}
# INFO:root:536186 / 555443: {'rule': ('per_rent_00=>(0.4423735260555344, 0.995702005730659)', 'aboverm_per_all_li_90=>0', 'aboverm_per_all_li_00=>0'), 'group': 'typology=>7.0', 'lift': 3.309090909090909}
# INFO:root:536187 / 555443: {'rule': ('per_rent_00=>(0.4423735260555344, 0.995702005730659)', 'aboverm_per_all_li_90=>0', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>7.0', 'lift': 3.4531250000000004}
# INFO:root:536188 / 555443: {'rule': ('per_rent_00=>(0.4423735260555344, 0.995702005730659)', 'aboverm_per_all_li_90=>0', 'aboverm_per_nonwhite_18=>0'), 'group': 'typology=>7.0', 'lift': 3.777777777777778}
# INFO:root:536194 / 555443: {'rule': ('per_rent_00=>(0.4423735260555344, 0.995702005730659)', 'aboverm_per_all_li_90=>0', 'aboverm_per_col_90=>1'), 'group': 'typology=>7.0', 'lift': 3.2058823529411766}
# INFO:root:536195 / 555443: {'rule': ('per_rent_00=>(0.4423735260555344, 0.995702005730659)', 'aboverm_per_all_li_90=>0', 'aboverm_per_col_00=>1'), 'group': 'typology=>7.0', 'lift': 3.0432098765432096}
# INFO:root:536196 / 555443: {'rule': ('per_rent_00=>(0.4423735260555344, 0.995702005730659)', 'aboverm_per_all_li_90=>0', 'aboverm_per_col_18=>1'), 'group': 'typology=>7.0', 'lift': 3.084967320261437}
# INFO:root:536197 / 555443: {'rule': ('per_rent_00=>(0.4423735260555344, 0.995702005730659)', 'aboverm_per_all_li_90=>0', 'aboverm_real_mrent_90=>1'), 'group': 'typology=>7.0', 'lift': 3.3427991886409734}
# INFO:root:536199 / 555443: {'rule': ('per_rent_00=>(0.4423735260555344, 0.995702005730659)', 'aboverm_per_all_li_90=>0', 'aboverm_real_mrent_12=>1'), 'group': 'typology=>7.0', 'lift': 3.3509316770186337}
# INFO:root:536204 / 555443: {'rule': ('per_rent_00=>(0.4423735260555344, 0.995702005730659)', 'aboverm_per_all_li_90=>0', 'aboverm_pctch_real_mhval_00_18=>1'), 'group': 'typology=>7.0', 'lift': 3.0694444444444446}
# INFO:root:536209 / 555443: {'rule': ('per_rent_00=>(0.4423735260555344, 0.995702005730659)', 'aboverm_per_all_li_90=>0', 'lostli_18=>1'), 'group': 'typology=>7.0', 'lift': 3.2847222222222223}
# INFO:root:536211 / 555443: {'rule': ('per_rent_00=>(0.4423735260555344, 0.995702005730659)', 'aboverm_per_all_li_90=>0', 'aboverm_pctch_real_hinc_00_18=>1'), 'group': 'typology=>7.0', 'lift': 3.8576388888888893}
# INFO:root:536213 / 555443: {'rule': ('per_rent_00=>(0.4423735260555344, 0.995702005730659)', 'aboverm_per_all_li_90=>0', 'aboverm_ch_per_col_00_18=>1'), 'group': 'typology=>7.0', 'lift': 3.208333333333334}
# INFO:root:536215 / 555443: {'rule': ('per_rent_00=>(0.4423735260555344, 0.995702005730659)', 'aboverm_per_all_li_90=>0', 'presence_ph_LIHTC=>False'), 'group': 'typology=>7.0', 'lift': 3.4090909090909087}
# INFO:root:536216 / 555443: {'rule': ('per_rent_00=>(0.4423735260555344, 0.995702005730659)', 'aboverm_per_all_li_90=>0', 'dp_RentGap=>1'), 'group': 'typology=>7.0', 'lift': 3.347826086956522}
# INFO:root:536217 / 555443: {'rule': ('per_rent_00=>(0.4423735260555344, 0.995702005730659)', 'aboverm_per_all_li_00=>0', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>7.0', 'lift': 3.4447004608294933}
# INFO:root:536219 / 555443: {'rule': ('per_rent_00=>(0.4423735260555344, 0.995702005730659)', 'aboverm_per_all_li_00=>0', 'aboverm_per_col_90=>1'), 'group': 'typology=>7.0', 'lift': 3.4838709677419355}
# INFO:root:536220 / 555443: {'rule': ('per_rent_00=>(0.4423735260555344, 0.995702005730659)', 'aboverm_per_all_li_00=>0', 'aboverm_per_col_00=>1'), 'group': 'typology=>7.0', 'lift': 3.1985294117647065}
# INFO:root:536221 / 555443: {'rule': ('per_rent_00=>(0.4423735260555344, 0.995702005730659)', 'aboverm_per_all_li_00=>0', 'aboverm_per_col_18=>1'), 'group': 'typology=>7.0', 'lift': 3.4277343749999987}
# INFO:root:536223 / 555443: {'rule': ('per_rent_00=>(0.4423735260555344, 0.995702005730659)', 'aboverm_per_all_li_00=>0', 'aboverm_real_mhval_18=>1'), 'group': 'typology=>7.0', 'lift': 3.177083333333333}
# INFO:root:536224 / 555443: {'rule': ('per_rent_00=>(0.4423735260555344, 0.995702005730659)', 'aboverm_per_all_li_00=>0', 'aboverm_pctch_real_mhval_00_18=>1'), 'group': 'typology=>7.0', 'lift': 3.3006993006993013}
# INFO:root:536227 / 555443: {'rule': ('per_rent_00=>(0.4423735260555344, 0.995702005730659)', 'aboverm_per_all_li_00=>0', 'lostli_18=>1'), 'group': 'typology=>7.0', 'lift': 3.2282608695652173}
# INFO:root:536231 / 555443: {'rule': ('per_rent_00=>(0.4423735260555344, 0.995702005730659)', 'aboverm_per_all_li_00=>0', 'aboverm_ch_per_col_00_18=>1'), 'group': 'typology=>7.0', 'lift': 3.4375}
# INFO:root:536234 / 555443: {'rule': ('per_rent_00=>(0.4423735260555344, 0.995702005730659)', 'aboverm_per_all_li_18=>0', 'aboverm_real_mrent_00=>1'), 'group': 'typology=>7.0', 'lift': 3.2500000000000004}
# INFO:root:536265 / 555443: {'rule': ('low_80120_00=>(0.06673656332387297, 0.3136229638497014)', 'per_all_li_90=>(0.2769078791009645, 0.4733512989784461)', 'rent_abrm_ch=>0'), 'group': 'typology=>7.0', 'lift': 4.285714285714286}
# INFO:root:536269 / 555443: {'rule': ('per_all_li_90=>(0.2769078791009645, 0.4733512989784461)', 'per_all_li_00=>(0.06673656332387297, 0.3136229638497014)', 'rent_abrm_ch=>0'), 'group': 'typology=>7.0', 'lift': 4.285714285714286}
# INFO:root:536633 / 555443: {'rule': ('lmh_flag_category=>aff_predominantly_MI', 'change_flag_category=>ch_decrease_marginal', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>7.0', 'lift': 3.296296296296296}
# INFO:root:536635 / 555443: {'rule': ('lmh_flag_category=>aff_predominantly_MI', 'change_flag_category=>ch_decrease_marginal', 'aboverm_per_nonwhite_00=>0'), 'group': 'typology=>7.0', 'lift': 4.08695652173913}
# INFO:root:536636 / 555443: {'rule': ('lmh_flag_category=>aff_predominantly_MI', 'change_flag_category=>ch_decrease_marginal', 'aboverm_per_rent_18=>0'), 'group': 'typology=>7.0', 'lift': 3.3333333333333335}
# INFO:root:536780 / 555443: {'rule': ('low_80120_18=>(0.07076486425245124, 0.30633406572935595)', 'high_80120_00=>(0.28498117786752303, 0.4717376730711314)', 'change_flag_category=>ch_decrease_marginal'), 'group': 'typology=>7.0', 'lift': 3.4090909090909087}
# INFO:root:536880 / 555443: {'rule': ('high_80120_18=>(0.5084084428901685, 0.8819577938444018)', 'high_80120_00=>(0.28498117786752303, 0.4717376730711314)', 'change_flag_category=>ch_decrease_marginal'), 'group': 'typology=>7.0', 'lift': 3.523809523809524}
# INFO:root:536973 / 555443: {'rule': ('low_80120_00=>(0.06673656332387297, 0.3136229638497014)', 'high_80120_00=>(0.28498117786752303, 0.4717376730711314)', 'change_flag_category=>ch_decrease_marginal'), 'group': 'typology=>7.0', 'lift': 4.466666666666667}
# INFO:root:537073 / 555443: {'rule': ('high_80120_00=>(0.28498117786752303, 0.4717376730711314)', 'per_all_li_00=>(0.06673656332387297, 0.3136229638497014)', 'change_flag_category=>ch_decrease_marginal'), 'group': 'typology=>7.0', 'lift': 4.466666666666667}
# INFO:root:537082 / 555443: {'rule': ('high_80120_00=>(0.28498117786752303, 0.4717376730711314)', 'per_all_li_18=>(0.07076486425245124, 0.30633406572935595)', 'change_flag_category=>ch_decrease_marginal'), 'group': 'typology=>7.0', 'lift': 3.4090909090909087}
# INFO:root:537332 / 555443: {'rule': ('per_rent_18=>(0.5035211267605634, 1.0)', 'aboverm_per_all_li_90=>0', 'aboverm_per_all_li_00=>0'), 'group': 'typology=>7.0', 'lift': 3.193548387096774}
# INFO:root:537340 / 555443: {'rule': ('per_rent_18=>(0.5035211267605634, 1.0)', 'aboverm_per_all_li_90=>0', 'aboverm_per_col_90=>1'), 'group': 'typology=>7.0', 'lift': 3.413793103448276}
# INFO:root:537341 / 555443: {'rule': ('per_rent_18=>(0.5035211267605634, 1.0)', 'aboverm_per_all_li_90=>0', 'aboverm_per_col_00=>1'), 'group': 'typology=>7.0', 'lift': 3.1152073732718897}
# INFO:root:537342 / 555443: {'rule': ('per_rent_18=>(0.5035211267605634, 1.0)', 'aboverm_per_all_li_90=>0', 'aboverm_per_col_18=>1'), 'group': 'typology=>7.0', 'lift': 3.147222222222222}
# INFO:root:537343 / 555443: {'rule': ('per_rent_18=>(0.5035211267605634, 1.0)', 'aboverm_per_all_li_90=>0', 'aboverm_real_mrent_90=>1'), 'group': 'typology=>7.0', 'lift': 3.213675213675213}
# INFO:root:537345 / 555443: {'rule': ('per_rent_18=>(0.5035211267605634, 1.0)', 'aboverm_per_all_li_90=>0', 'aboverm_real_mrent_12=>1'), 'group': 'typology=>7.0', 'lift': 3.2282608695652173}
# INFO:root:537347 / 555443: {'rule': ('per_rent_18=>(0.5035211267605634, 1.0)', 'aboverm_per_all_li_90=>0', 'aboverm_real_mhval_90=>1'), 'group': 'typology=>7.0', 'lift': 3.0294117647058822}
# INFO:root:537367 / 555443: {'rule': ('per_rent_18=>(0.5035211267605634, 1.0)', 'aboverm_per_all_li_00=>0', 'aboverm_per_col_90=>1'), 'group': 'typology=>7.0', 'lift': 3.7037037037037037}
# INFO:root:537368 / 555443: {'rule': ('per_rent_18=>(0.5035211267605634, 1.0)', 'aboverm_per_all_li_00=>0', 'aboverm_per_col_00=>1'), 'group': 'typology=>7.0', 'lift': 3.2388888888888894}
# INFO:root:537369 / 555443: {'rule': ('per_rent_18=>(0.5035211267605634, 1.0)', 'aboverm_per_all_li_00=>0', 'aboverm_per_col_18=>1'), 'group': 'typology=>7.0', 'lift': 3.530864197530864}
# INFO:root:537370 / 555443: {'rule': ('per_rent_18=>(0.5035211267605634, 1.0)', 'aboverm_per_all_li_00=>0', 'aboverm_real_mhval_00=>1'), 'group': 'typology=>7.0', 'lift': 3.037220843672457}
# INFO:root:538117 / 555443: {'rule': ('per_rent_00=>(0.4423735260555344, 0.995702005730659)', 'aboverm_per_all_li_90=>0', 'aboverm_per_nonwhite_00=>0'), 'group': 'typology=>7.0', 'lift': 3.68}
# INFO:root:538125 / 555443: {'rule': ('per_rent_00=>(0.4423735260555344, 0.995702005730659)', 'aboverm_per_all_li_90=>0', 'aboverm_per_units_pre50_18=>0'), 'group': 'typology=>7.0', 'lift': 3.1212121212121207}
# INFO:root:538164 / 555443: {'rule': ('per_rent_18=>(0.5035211267605634, 1.0)', 'aboverm_per_all_li_90=>0', 'presence_ph_LIHTC=>False'), 'group': 'typology=>7.0', 'lift': 3.6111111111111107}
# INFO:root:538519 / 555443: {'rule': ('low_80120_00=>(0.3142368933608505, 0.4987524369606564)', 'per_rent_00=>(0.4423735260555344, 0.995702005730659)', 'aboverm_per_all_li_90=>0'), 'group': 'typology=>7.0', 'lift': 3.022222222222222}
# INFO:root:538524 / 555443: {'rule': ('high_80120_00=>(0.28498117786752303, 0.4717376730711314)', 'per_rent_00=>(0.4423735260555344, 0.995702005730659)', 'aboverm_per_all_li_90=>0'), 'group': 'typology=>7.0', 'lift': 4.285714285714286}
# INFO:root:538527 / 555443: {'rule': ('per_all_li_90=>(0.2769078791009645, 0.4733512989784461)', 'per_rent_00=>(0.4423735260555344, 0.995702005730659)', 'aboverm_per_all_li_90=>0'), 'group': 'typology=>7.0', 'lift': 4.0}
# INFO:root:538536 / 555443: {'rule': ('per_all_li_00=>(0.3142368933608505, 0.4987524369606564)', 'per_rent_00=>(0.4423735260555344, 0.995702005730659)', 'aboverm_per_all_li_90=>0'), 'group': 'typology=>7.0', 'lift': 3.022222222222222}
# INFO:root:538633 / 555443: {'rule': ('low_80120_18=>(0.07076486425245124, 0.30633406572935595)', 'high_80120_18=>(0.27023749595829083, 0.5083931492879976)', 'change_flag_category=>ch_decrease_marginal'), 'group': 'typology=>7.0', 'lift': 3.833333333333333}
# INFO:root:538641 / 555443: {'rule': ('high_80120_18=>(0.27023749595829083, 0.5083931492879976)', 'per_all_li_18=>(0.07076486425245124, 0.30633406572935595)', 'change_flag_category=>ch_decrease_marginal'), 'group': 'typology=>7.0', 'lift': 3.833333333333333}
# INFO:root:540057 / 555443: {'rule': ('high_80120_18=>(0.27023749595829083, 0.5083931492879976)', 'per_rent_00=>(0.4423735260555344, 0.995702005730659)', 'aboverm_per_all_li_90=>0'), 'group': 'typology=>7.0', 'lift': 5.133333333333333}
# INFO:root:540084 / 555443: {'rule': ('low_80120_00=>(0.3142368933608505, 0.4987524369606564)', 'per_rent_18=>(0.5035211267605634, 1.0)', 'aboverm_per_all_li_90=>0'), 'group': 'typology=>7.0', 'lift': 3.446153846153846}
# INFO:root:540195 / 555443: {'rule': ('per_all_li_00=>(0.3142368933608505, 0.4987524369606564)', 'per_rent_18=>(0.5035211267605634, 1.0)', 'aboverm_per_all_li_90=>0'), 'group': 'typology=>7.0', 'lift': 3.446153846153846}
# INFO:root:540249 / 555443: {'rule': ('per_rent_00=>(0.4423735260555344, 0.995702005730659)', 'aboverm_per_all_li_90=>0', 'aboverm_pctch_real_mhval_90_00=>0'), 'group': 'typology=>7.0', 'lift': 3.7368421052631584}
# INFO:root:541273 / 555443: {'rule': ('per_nonwhite_90=>(0.029793783123638895, 0.16557669994894852)', 'per_rent_00=>(0.4423735260555344, 0.995702005730659)', 'lmh_flag_category=>aff_mix_mod'), 'group': 'typology=>7.0', 'lift': 3.5199999999999996}
# INFO:root:541371 / 555443: {'rule': ('low_80120_18=>(0.306658629772009, 0.5542653276877436)', 'per_rent_90=>(0.4597290818203511, 1.0)', 'aboverm_per_all_li_90=>0'), 'group': 'typology=>7.0', 'lift': 4.411764705882353}
# INFO:root:541372 / 555443: {'rule': ('low_80120_18=>(0.306658629772009, 0.5542653276877436)', 'per_rent_00=>(0.4423735260555344, 0.995702005730659)', 'aboverm_per_all_li_90=>0'), 'group': 'typology=>7.0', 'lift': 3.9473684210526314}
# INFO:root:541376 / 555443: {'rule': ('per_all_li_18=>(0.306658629772009, 0.5542653276877436)', 'per_rent_90=>(0.4597290818203511, 1.0)', 'aboverm_per_all_li_90=>0'), 'group': 'typology=>7.0', 'lift': 4.411764705882353}
# INFO:root:541377 / 555443: {'rule': ('per_all_li_18=>(0.306658629772009, 0.5542653276877436)', 'per_rent_00=>(0.4423735260555344, 0.995702005730659)', 'aboverm_per_all_li_90=>0'), 'group': 'typology=>7.0', 'lift': 3.9473684210526314}
# INFO:root:541733 / 555443: {'rule': ('low_80120_18=>(0.306658629772009, 0.5542653276877436)', 'high_80120_18=>(0.5084084428901685, 0.8819577938444018)', 'change_flag_category=>ch_decrease_marginal'), 'group': 'typology=>7.0', 'lift': 4.0}
# INFO:root:541742 / 555443: {'rule': ('high_80120_18=>(0.5084084428901685, 0.8819577938444018)', 'per_all_li_18=>(0.306658629772009, 0.5542653276877436)', 'change_flag_category=>ch_decrease_marginal'), 'group': 'typology=>7.0', 'lift': 4.0}
# INFO:root:541762 / 555443: {'rule': ('low_80120_18=>(0.306658629772009, 0.5542653276877436)', 'per_rent_18=>(0.5035211267605634, 1.0)', 'aboverm_per_all_li_90=>0'), 'group': 'typology=>7.0', 'lift': 4.133333333333334}
# INFO:root:541902 / 555443: {'rule': ('per_all_li_18=>(0.306658629772009, 0.5542653276877436)', 'per_rent_18=>(0.5035211267605634, 1.0)', 'aboverm_per_all_li_90=>0'), 'group': 'typology=>7.0', 'lift': 4.133333333333334}

# %%
output.to_csv("{}/data/stucco_{}".format(customized_path_to_homework, file_name))

# %% [markdown]
# ###  Rule Metrics

# %% [markdown]
# **Rules with high Lift and Confidence**

# %% [markdown]
# ref: http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.150.6616&rep=rep1&type=pdf
#
# Confidence ranges from 0 to 1. Confidence is an estimate of Pr(C | A), the
# probability of observing C given A. After obtaining a rule set, one can immediatly
# use confidence as a basis for classifying one new case x. Of all the rules that
# apply to x (i.e., the rules whose antecedent is true in x), we choose the one
# with highest confidence. This loosely follows the optimal Bayes classifier

# %% [markdown]
# ref: http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.150.6616&rep=rep1&type=pdf
#
# Conviction is another measure proposed in [4] to tackle some of the weaknesses of confidence and lift. Unlike lift, conviction is sensitive to rule direction
# (conv(A → C) 6= conv(C → A)). Conviction is somewhat inspired in the logical
# definition of implication and attempts to measure the degree of implication of
# a rule. Conviction is infinite for logical implications (confidence 1), and is 1 if
# A and C are independent

# %% [markdown]
# ref: http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.150.6616&rep=rep1&type=pdf
#
# Lift measures how far from independence are A and C. It ranges within
# [0, +∞[. Values close to 1 imply that A and C are independent and the rule
# is not interesting.
