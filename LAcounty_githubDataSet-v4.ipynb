# %% [markdown]
# **CS 5834, Fall 2020: Intro to Urban Computing Project - Association Rules analysis for Gentrification using LA Data Set**

# %% [markdown]
# ### Imports and Mount File Directories

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
# modify "customized_path_to_homework", path of folder in drive, where you project is stored
customized_path_to_homework = "/content/drive/My Drive/cs5834/urbcomp_fall2020/project"
file_name = "LosAngeles_typology_output.csv"

sys.path.append(customized_path_to_homework)

# %%
# %cd $customized_path_to_homework/data
# Out:
# /content/drive/My Drive/cs5834/urbcomp_fall2020/project/data

# %%
import os, sys
import pandas as pd
import numpy as np
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
import datetime
import warnings

# %%
"""
sys.path.insert(0,'../')
# %load_ext autoreload
# %autoreload 2
import nyctaxi_helpers
warnings.filterwarnings('ignore')
"""
# Out:
# "\nsys.path.insert(0,'../')\n%load_ext autoreload\n%autoreload 2\nimport nyctaxi_helpers\nwarnings.filterwarnings('ignore')\n"

# %%
pip install --upgrade mlxtend
# Out:
# Collecting mlxtend
#   Downloading https://files.pythonhosted.org/packages/86/30/781c0b962a70848db83339567ecab656638c62f05adb064cb33c0ae49244/mlxtend-0.18.0-py2.py3-none-any.whl (1.3MB)
#      |████████████████████████████████| 1.4MB 12.2MB/s
# Requirement already satisfied, skipping upgrade: scipy>=1.2.1 in /usr/local/lib/python3.6/dist-packages (from mlxtend) (1.4.1)
# Requirement already satisfied, skipping upgrade: matplotlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from mlxtend) (3.2.2)
# Requirement already satisfied, skipping upgrade: scikit-learn>=0.20.3 in /usr/local/lib/python3.6/dist-packages (from mlxtend) (0.22.2.post1)
# Requirement already satisfied, skipping upgrade: numpy>=1.16.2 in /usr/local/lib/python3.6/dist-packages (from mlxtend) (1.18.5)
# Requirement already satisfied, skipping upgrade: pandas>=0.24.2 in /usr/local/lib/python3.6/dist-packages (from mlxtend) (1.1.4)
# Requirement already satisfied, skipping upgrade: joblib>=0.13.2 in /usr/local/lib/python3.6/dist-packages (from mlxtend) (0.17.0)
# Requirement already satisfied, skipping upgrade: setuptools in /usr/local/lib/python3.6/dist-packages (from mlxtend) (50.3.2)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib>=3.0.0->mlxtend) (1.3.1)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib>=3.0.0->mlxtend) (2.8.1)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib>=3.0.0->mlxtend) (2.4.7)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /usr/local/lib/python3.6/dist-packages (from matplotlib>=3.0.0->mlxtend) (0.10.0)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.24.2->mlxtend) (2018.9)
# Requirement already satisfied, skipping upgrade: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.1->matplotlib>=3.0.0->mlxtend) (1.15.0)
# Installing collected packages: mlxtend
#   Found existing installation: mlxtend 0.14.0
#     Uninstalling mlxtend-0.14.0:
#       Successfully uninstalled mlxtend-0.14.0
# Successfully installed mlxtend-0.18.0

# %%
#ref https://pbpython.com/market-basket-analysis.html


#may need to install mlxtend package - pip install mlxtend in console
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import fpgrowth
from mlxtend.frequent_patterns import association_rules

# %% [markdown]
# # **Process Urban Displacement Model Data for Gentrificaiton**

# %% [markdown]
# Reference: https://www.urbandisplacement.org/open-source-project

# %% [markdown]
# Based on the work https://ww2.arb.ca.gov/sites/default/files/classic//research/apr/past/13-310.pdf?_ga=2.269282425.968981409.1605209194-851335111.1605209194
#
# **Developing a New
# Methodology for Analyzing
# Potential Displacement**
#
# University of California, Berkeley
#
# Principal Investigator:
# Karen Chapple
#
# https://ww3.arb.ca.gov/research/single-project.php?row_id=65188

# %% [markdown]
# **Obtain the Data**
#
# Data can be found at https://github.com/urban-displacement/displacement-typologies/blob/main/data/outputs/typologies/LosAngeles_typology_output.csv

# %%
#!wget -nc https://raw.githubusercontent.com/urban-displacement/displacement-typologies/main/data/outputs/typologies/LosAngeles_typology_output.csv

# %%
## Process Data - if data file already processed then can start at Associaton Rules section
# get the Data File

#df = pd.read_csv("https://raw.githubusercontent.com/urban-displacement/displacement-typologies/main/data/outputs/typologies/{}".format(file_name), index_col=0)
df = pd.read_csv("{}/data/{}".format(customized_path_to_homework, file_name), index_col=0)

# sneak peak in the data
df.head(10)
# Out:
#    pop_18  white_18   hh_18   hinc_18  ...  SLI  double_counted  typology   typ_cat
# 0  7222.0    5614.0  2903.0  166383.0  ...    0             1.0       9.0   ['SAE']
# 1  2053.0     977.0   819.0   77039.0  ...    0             1.0       7.0   ['ARE']
# 2  7037.0    2161.0  2180.0  112368.0  ...    0             1.0       9.0   ['SAE']
# 3  9862.0    2165.0  3200.0  110455.0  ...    0             1.0       9.0   ['SAE']
# 4  6576.0    2761.0  2116.0   63625.0  ...    0             1.0       6.0  ['SMMI']
# 5  7427.0    5283.0  3096.0   71875.0  ...    0             1.0       6.0  ['SMMI']
# 6  3275.0    1719.0  1589.0   48004.0  ...    1             1.0       1.0   ['SLI']
# 7  5619.0     551.0  1820.0   85465.0  ...    0             1.0       6.0  ['SMMI']
# 8  4424.0     529.0  1390.0   63582.0  ...    0             1.0       6.0  ['SMMI']
# 9  7441.0     550.0  1886.0   71133.0  ...    0             1.0       7.0   ['ARE']
#
# [10 rows x 305 columns]

# %%
df.columns
# Out:
# Index(['pop_18', 'white_18', 'hh_18', 'hinc_18', 'mhval_18', 'mhval_18_se',
#        'mrent_18', 'mrent_18_se', 'total_25_18', 'total_25_col_bd_18',
#        ...
#        'BE', 'SMMI', 'ARG', 'EOG', 'OD', 'OD_loss', 'SLI', 'double_counted',
#        'typology', 'typ_cat'],
#       dtype='object', length=305)

# %%
"""
# create a working copy of the data to process
df2 = df.copy()

#removed  'inc_cat_medhhinc_encoded18', 'inc_cat_medhhinc_encoded00',
df2 = df2[[ 'inc80_18',
 'inc120_18',
 'inc80_00',
 'inc120_00',
 'inc80_90',
 'low_80120_18',
 'mod_80120_18',
 'high_80120_18',
 'low_pdmt_medhhinc_18',
 'high_pdmt_medhhinc_18',
 'mod_pdmt_medhhinc_18',
 'mix_low_medhhinc_18',
 'mix_mod_medhhinc_18',
 'mix_high_medhhinc_18',

 'low_80120_00',
 'mod_80120_00',
 'high_80120_00',
 'low_pdmt_medhhinc_00',
 'high_pdmt_medhhinc_00',
 'mod_pdmt_medhhinc_00',
 'mix_low_medhhinc_00',
 'mix_mod_medhhinc_00',
 'mix_high_medhhinc_00',

 'per_all_li_90',
 'per_all_li_00',
 'per_all_li_18',
 'per_nonwhite_90',
 'per_nonwhite_00',
 'per_nonwhite_18',
 'per_rent_90',
 'per_rent_00',
 'per_rent_18',
 'per_col_90',
 'per_col_00',
 'per_col_18',
 'per_units_pre50_18',
 'per_limove_18',
 'per_limove_12',
 'lmh_flag_category',
 'pctch_real_mhval_00_18',
 'pctch_real_mrent_12_18',
 'rent_decrease',
 'rent_marginal',
 'rent_increase',
 'rent_rapid_increase',
 'house_decrease',
 'house_marginal',
 'house_increase',
 'house_rapid_increase',
 'tot_decrease',
 'tot_marginal',
 'tot_increase',
 'tot_rapid_increase',
 'change_flag_category',
 'per_ch_zillow_12_18',
 'ab_50pct_ch',
 'ab_90percentile_ch',
 'rent_50pct_ch',
 'rent_90percentile_ch',
 'hv_abrm_ch',
 'rent_abrm_ch',
 'pctch_real_mhval_90_00',
 'pctch_real_mrent_90_00',
 'pctch_real_hinc_90_00',
 'pctch_real_mrent_00_18',
 'pctch_real_hinc_00_18',
 'ch_per_col_90_00',
 'ch_per_col_00_18',
 'ch_per_limove_12_18',
 'aboverm_per_all_li_90',
 'aboverm_per_all_li_00',
 'aboverm_per_all_li_18',
 'aboverm_per_nonwhite_18',
 'aboverm_per_nonwhite_90',
 'aboverm_per_nonwhite_00',
 'aboverm_per_rent_90',
 'aboverm_per_rent_00',
 'aboverm_per_rent_18',
 'aboverm_per_col_90',
 'aboverm_per_col_00',
 'aboverm_per_col_18',
 'aboverm_real_mrent_90',
 'aboverm_real_mrent_00',
 'aboverm_real_mrent_12',
 'aboverm_real_mrent_18',
 'aboverm_real_mhval_90',
 'aboverm_real_mhval_00',
 'aboverm_real_mhval_18',
 'aboverm_pctch_real_mhval_00_18',
 'aboverm_pctch_real_mrent_00_18',
 'aboverm_pctch_real_mrent_12_18',
 'aboverm_pctch_real_mhval_90_00',
 'aboverm_pctch_real_mrent_90_00',
 'lostli_00',
 'lostli_18',
 'aboverm_pctch_real_hinc_90_00',
 'aboverm_pctch_real_hinc_00_18',
 'aboverm_ch_per_col_90_00',
 'aboverm_ch_per_col_00_18',
 'aboverm_per_units_pre50_18',
 'GEOID',
 'rail',
 'presence_ph_LIHTC',
 'hotmarket_00',
 'hotmarket_18',
 'dp_PChRent',
 'dp_RentGap',
 'dense',
 'typology']]


# drop rows which dont have a gentrification category
df2.dropna(subset=['typology'], inplace=True)
df2 = df2.set_index('GEOID')

#fill the nas
df2.fillna(0.0, inplace=True)


df2.head(10)
"""
# Out:
# "\n# create a working copy of the data to process\ndf2 = df.copy()\n\n#removed  'inc_cat_medhhinc_encoded18', 'inc_cat_medhhinc_encoded00',\ndf2 = df2[[ 'inc80_18',\n 'inc120_18',\n 'inc80_00',\n 'inc120_00',\n 'inc80_90',\n 'low_80120_18',\n 'mod_80120_18',\n 'high_80120_18',\n 'low_pdmt_medhhinc_18',\n 'high_pdmt_medhhinc_18',\n 'mod_pdmt_medhhinc_18',\n 'mix_low_medhhinc_18',\n 'mix_mod_medhhinc_18',\n 'mix_high_medhhinc_18',\n\n 'low_80120_00',\n 'mod_80120_00',\n 'high_80120_00',\n 'low_pdmt_medhhinc_00',\n 'high_pdmt_medhhinc_00',\n 'mod_pdmt_medhhinc_00',\n 'mix_low_medhhinc_00',\n 'mix_mod_medhhinc_00',\n 'mix_high_medhhinc_00',\n\n 'per_all_li_90',\n 'per_all_li_00',\n 'per_all_li_18',\n 'per_nonwhite_90',\n 'per_nonwhite_00',\n 'per_nonwhite_18',\n 'per_rent_90',\n 'per_rent_00',\n 'per_rent_18',\n 'per_col_90',\n 'per_col_00',\n 'per_col_18',\n 'per_units_pre50_18',\n 'per_limove_18',\n 'per_limove_12',\n 'lmh_flag_category',\n 'pctch_real_mhval_00_18',\n 'pctch_real_mrent_12_18',\n 'rent_decrease',\n 'rent_marginal',\n 'rent_increase',\n 'rent_rapid_increase',\n 'house_decrease',\n 'house_marginal',\n 'house_increase',\n 'house_rapid_increase',\n 'tot_decrease',\n 'tot_marginal',\n 'tot_increase',\n 'tot_rapid_increase',\n 'change_flag_category',\n 'per_ch_zillow_12_18',\n 'ab_50pct_ch',\n 'ab_90percentile_ch',\n 'rent_50pct_ch',\n 'rent_90percentile_ch',\n 'hv_abrm_ch',\n 'rent_abrm_ch',\n 'pctch_real_mhval_90_00',\n 'pctch_real_mrent_90_00',\n 'pctch_real_hinc_90_00',\n 'pctch_real_mrent_00_18',\n 'pctch_real_hinc_00_18',\n 'ch_per_col_90_00',\n 'ch_per_col_00_18',\n 'ch_per_limove_12_18',\n 'aboverm_per_all_li_90',\n 'aboverm_per_all_li_00',\n 'aboverm_per_all_li_18',\n 'aboverm_per_nonwhite_18',\n 'aboverm_per_nonwhite_90',\n 'aboverm_per_nonwhite_00',\n 'aboverm_per_rent_90',\n 'aboverm_per_rent_00',\n 'aboverm_per_rent_18',\n 'aboverm_per_col_90',\n 'aboverm_per_col_00',\n 'aboverm_per_col_18',\n 'aboverm_real_mrent_90',\n 'aboverm_real_mrent_00',\n 'aboverm_real_mrent_12',\n 'aboverm_real_mrent_18',\n 'aboverm_real_mhval_90',\n 'aboverm_real_mhval_00',\n 'aboverm_real_mhval_18',\n 'aboverm_pctch_real_mhval_00_18',\n 'aboverm_pctch_real_mrent_00_18',\n 'aboverm_pctch_real_mrent_12_18',\n 'aboverm_pctch_real_mhval_90_00',\n 'aboverm_pctch_real_mrent_90_00',\n 'lostli_00',\n 'lostli_18',\n 'aboverm_pctch_real_hinc_90_00',\n 'aboverm_pctch_real_hinc_00_18',\n 'aboverm_ch_per_col_90_00',\n 'aboverm_ch_per_col_00_18',\n 'aboverm_per_units_pre50_18',\n 'GEOID',\n 'rail',\n 'presence_ph_LIHTC',\n 'hotmarket_00',\n 'hotmarket_18',\n 'dp_PChRent',\n 'dp_RentGap',\n 'dense',\n 'typology']]\n\n\n# drop rows which dont have a gentrification category\ndf2.dropna(subset=['typology'], inplace=True)\ndf2 = df2.set_index('GEOID')\n\n#fill the nas\ndf2.fillna(0.0, inplace=True)\n\n\ndf2.head(10)\n"

# %%
# create a working copy of the data to process
df2 = df.copy()

"""
removed  'inc_cat_medhhinc_encoded18', 'inc_cat_medhhinc_encoded00', 
'inc80_18',
 'inc120_18',
 'inc80_00',
 'inc120_00',
 'inc80_90',
  'per_col_90',
 'per_col_00',
 'per_col_18',
  'tot_decrease',
 'tot_marginal',
 'tot_increase',
 'tot_rapid_increase',
  'pctch_real_mhval_90_00',
 'pctch_real_mrent_90_00',
 'pctch_real_mrent_00_18',
 'per_units_pre50_18',
  
"""

df2.head(10)
df2 = df2[[ 

 'low_80120_18',
 'mod_80120_18',
 'high_80120_18',
 'low_pdmt_medhhinc_18',
 'high_pdmt_medhhinc_18',
 'mod_pdmt_medhhinc_18',
 'mix_low_medhhinc_18',
 'mix_mod_medhhinc_18',
 'mix_high_medhhinc_18',

 'low_80120_00',
 'mod_80120_00',
 'high_80120_00',
 'low_pdmt_medhhinc_00',
 'high_pdmt_medhhinc_00',
 'mod_pdmt_medhhinc_00',
 'mix_low_medhhinc_00',
 'mix_mod_medhhinc_00',
 'mix_high_medhhinc_00',

 'per_all_li_90',
 'per_all_li_00',
 'per_all_li_18',
 'per_nonwhite_90',
 'per_nonwhite_00',
 'per_nonwhite_18',
 'per_rent_90',
 'per_rent_00',
 'per_rent_18',

 
 'per_limove_18',
 'per_limove_12',
 'lmh_flag_category',
 'pctch_real_mhval_00_18',
 'pctch_real_mrent_12_18',
 'rent_decrease',
 'rent_marginal',
 'rent_increase',
 'rent_rapid_increase',
 'house_decrease',
 'house_marginal',
 'house_increase',
 'house_rapid_increase',

 'change_flag_category',
 'per_ch_zillow_12_18',
 'ab_50pct_ch',
 'ab_90percentile_ch',
 'rent_50pct_ch',
 'rent_90percentile_ch',
 'hv_abrm_ch',
 'rent_abrm_ch',

 'pctch_real_hinc_90_00',
 
 'pctch_real_hinc_00_18',
 'ch_per_col_90_00',
 'ch_per_col_00_18',
 'ch_per_limove_12_18',
 'aboverm_per_all_li_90',
 'aboverm_per_all_li_00',
 'aboverm_per_all_li_18',
 'aboverm_per_nonwhite_18',
 'aboverm_per_nonwhite_90',
 'aboverm_per_nonwhite_00',
 'aboverm_per_rent_90',
 'aboverm_per_rent_00',
 'aboverm_per_rent_18',
 'aboverm_per_col_90',
 'aboverm_per_col_00',
 'aboverm_per_col_18',
 'aboverm_real_mrent_90',
 'aboverm_real_mrent_00',
 'aboverm_real_mrent_12',
 'aboverm_real_mrent_18',
 'aboverm_real_mhval_90',
 'aboverm_real_mhval_00',
 'aboverm_real_mhval_18',
 'aboverm_pctch_real_mhval_00_18',
 'aboverm_pctch_real_mrent_00_18',
 'aboverm_pctch_real_mrent_12_18',
 'aboverm_pctch_real_mhval_90_00',
 'aboverm_pctch_real_mrent_90_00',
 'lostli_00',
 'lostli_18',
 'aboverm_pctch_real_hinc_90_00',
 'aboverm_pctch_real_hinc_00_18',
 'aboverm_ch_per_col_90_00',
 'aboverm_ch_per_col_00_18',
 'aboverm_per_units_pre50_18',
 'GEOID',
 'rail',
 'presence_ph_LIHTC',
 'hotmarket_00',
 'hotmarket_18',
 'dp_PChRent',
 'dp_RentGap',
 'dense',
 'typology']]

# drop rows which dont have a gentrification category
df2.dropna(subset=['typology'], inplace=True)
df2 = df2.set_index('GEOID')

#fill the nas
df2.fillna(0.0, inplace=True)


df2.head(10)
# Out:
#             low_80120_18  mod_80120_18  ...  dense  typology
# GEOID                                   ...
# 6073008324      0.135421      0.107385  ...      0       9.0
# 6073008339      0.420550      0.115488  ...      0       7.0
# 6073008347      0.203963      0.145846  ...      0       9.0
# 6073008354      0.205465      0.158679  ...      0       9.0
# 6073008505      0.412422      0.160840  ...      0       6.0
# 6073017604      0.412958      0.134944  ...      0       6.0
# 6073018400      0.560880      0.153976  ...      0       1.0
# 6037543321      0.281085      0.206899  ...      0       6.0
# 6037543502      0.461369      0.145520  ...      0       6.0
# 6037550100      0.332950      0.247749  ...      1       7.0
#
# [10 rows x 92 columns]

# %% [markdown]
# Correlation Heatmap

# %%
import seaborn as sns

sns.heatmap(df2.corr())

# %%
#df2.corr()['inc80_18'] > 0.9

# %%
#ref: https://chrisalbon.com/machine_learning/feature_selection/drop_highly_correlated_features/

# Create correlation matrix
corr_matrix = df2.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Find index of feature columns with correlation greater than 0.95
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]

# %%
to_drop
# Out:
# ['high_80120_18',
#  'high_80120_00',
#  'per_all_li_00',
#  'per_all_li_18',
#  'per_nonwhite_00',
#  'per_rent_00',
#  'per_rent_18']

# %%
# Drop features 
#df2.drop(df[to_drop], axis=1)

# %% [markdown]
# ### Convert select continous variables to categorical and one hot encode

# %%
# convert already dummy variables from float to int
dummy_var_list = ['hotmarket_00', 'hotmarket_18', 'low_pdmt_medhhinc_00', 'high_pdmt_medhhinc_00', 'mod_pdmt_medhhinc_00',
                  'mix_low_medhhinc_00', 'mix_mod_medhhinc_00',  'mix_high_medhhinc_00', 'low_pdmt_medhhinc_18', 'high_pdmt_medhhinc_18',
                  'mod_pdmt_medhhinc_18', 'mix_low_medhhinc_18', 'mix_mod_medhhinc_18', 'mix_high_medhhinc_18', 'presence_ph_LIHTC',
                  'typology']
for dummycol in dummy_var_list:
  df2.loc[:,(dummycol)] = df2[dummycol].astype(int, copy=False)

# %%
# use float variables to represent each categorical variable by dividing into quartiles
def convert_percents_to_dummy_vars(X):

    columns = X.columns

    bin_labels_4 = ['VL', 'L', 'H',  'VH']


    for i in range(0, len(columns)):
        if X[columns[i]].dtype=='float64':
          print("Processing: " + columns[i])

          X[columns[i]] = X[columns[i]].fillna(0)
          cat_label = "{}_cat".format(columns[i])
          dummy_label = "{}_dummy".format(columns[i])
          X[cat_label] = pd.qcut(X[columns[i]], 
                                 4,
                              precision=5,
                              duplicates = 'drop',
                              labels=bin_labels_4)
          X = pd.get_dummies(X, columns=[cat_label], prefix=[dummy_label])
          X = X.drop([columns[i]], axis=1)

    return X

# %%
# check if categorical then convert to dummy using label and onehot encoding
def convert_categorical_to_dummy_vars(X):

    from sklearn.preprocessing import LabelEncoder
    from sklearn.preprocessing import OneHotEncoder    

    columns = X.columns
    indices = X.index
    new_columns = []
    encoded_x = None

    for i in range(0, len(columns)):
        if X[columns[i]].dtype=='O':
          print("Processing: " + columns[i])


          label_encoder = LabelEncoder()
          le = label_encoder.fit(X[columns[i]].apply(str))
          for class_ in le.classes_:
              new_columns.append("{}_{}".format(columns[i],class_))
              
          feature = le.transform(X[columns[i]].apply(str))
          feature = feature.reshape(X.shape[0], 1)
          onehot_encoder = OneHotEncoder(sparse=False)
          onehot_encoder.fit(feature)
          feature = onehot_encoder.transform(feature)
          if encoded_x is None:
              encoded_x = feature
          else:
              encoded_x = np.concatenate((encoded_x, feature), axis=1)
          X = X.drop(columns[i], axis=1)
    new_columns.extend(X.columns)

    X = pd.DataFrame(np.concatenate((encoded_x,X),axis=1),index=indices,columns=new_columns)
    
    return X

# %% [markdown]
# ### Convert Percentage (floats) to Quartiles and Dummy Variables

# %%
# process and save data all converted to one hot encoding
df2 = convert_percents_to_dummy_vars(df2)
# Out:
# Processing: low_80120_18
# Processing: mod_80120_18
# Processing: high_80120_18
# Processing: low_80120_00
# Processing: mod_80120_00
# Processing: high_80120_00
# Processing: per_all_li_90
# Processing: per_all_li_00
# Processing: per_all_li_18
# Processing: per_nonwhite_90
# Processing: per_nonwhite_00
# Processing: per_nonwhite_18
# Processing: per_rent_90
# Processing: per_rent_00
# Processing: per_rent_18
# Processing: per_limove_18
# Processing: per_limove_12
# Processing: pctch_real_mhval_00_18
# Processing: pctch_real_mrent_12_18
# Processing: per_ch_zillow_12_18
# Processing: pctch_real_hinc_90_00
# Processing: pctch_real_hinc_00_18
# Processing: ch_per_col_90_00
# Processing: ch_per_col_00_18
# Processing: ch_per_limove_12_18

# %%
df2 = convert_categorical_to_dummy_vars(df2)
# Out:
# Processing: lmh_flag_category
# Processing: change_flag_category

# %% [markdown]
# iii. Save the dataset as a CSV file. The first line of the CSV file should be the attribute
# names as described in the previous question.

# %%
df2.to_csv("{}/data/processed_{}".format(customized_path_to_homework, file_name))

# %% [markdown]
# # **Association Rule Calculations**

# %%
#load already processed data 
df3 = pd.read_csv("{}/data/processed_{}".format(customized_path_to_homework, file_name), index_col=0)
df3 = df3.astype(int)

# %%
confidence_cut = 0.8
lift_cut = 1.0
conviction_cut = 0.9
support_cut = 0.6

# %% [markdown]
# # Associaton Rules Analysis - Gentrified

# %%
gent_class = 'gent'
df_class = df3[df3['typology'].isin(['4', '5','99'])].drop(['typology'], axis=1)

# %%
df_class = df_class.astype(bool)

# %%
frequent_itemsets = fpgrowth(df_class, min_support= support_cut, use_colnames=True, verbose=1)
#%timeit  frequent_itemsets_gent = apriori(df_gent, min_support=0.07, use_colnames=True, verbose=1, low_memory=False)
# Out:
# 26 itemset(s) from tree conditioned on items ()
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90)
# 2 itemset(s) from tree conditioned on items (aboverm_per_all_li_00)
# 0 itemset(s) from tree conditioned on items (aboverm_per_all_li_00, aboverm_per_nonwhite_90)
# 1 itemset(s) from tree conditioned on items (aboverm_per_all_li_00, aboverm_per_all_li_90)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00)
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_nonwhite_90)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_all_li_00)
# 2 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_all_li_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_all_li_90, aboverm_per_nonwhite_90)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_all_li_90, aboverm_per_all_li_00)
# 4 itemset(s) from tree conditioned on items (aboverm_per_rent_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_rent_90, aboverm_per_all_li_00)
# 1 itemset(s) from tree conditioned on items (aboverm_per_rent_90, aboverm_per_nonwhite_90)
# 3 itemset(s) from tree conditioned on items (aboverm_per_rent_90, aboverm_per_nonwhite_00)
# 0 itemset(s) from tree conditioned on items (aboverm_per_rent_90, aboverm_per_nonwhite_00, aboverm_per_nonwhite_90)
# 1 itemset(s) from tree conditioned on items (aboverm_per_rent_90, aboverm_per_nonwhite_00, aboverm_per_all_li_00)
# 2 itemset(s) from tree conditioned on items (aboverm_per_rent_90, aboverm_per_nonwhite_00, aboverm_per_all_li_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_rent_90, aboverm_per_nonwhite_00, aboverm_per_all_li_90, aboverm_per_nonwhite_90)
# 1 itemset(s) from tree conditioned on items (aboverm_per_rent_90, aboverm_per_nonwhite_00, aboverm_per_all_li_90, aboverm_per_all_li_00)
# 2 itemset(s) from tree conditioned on items (aboverm_per_rent_90, aboverm_per_all_li_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_nonwhite_90)
# 1 itemset(s) from tree conditioned on items (aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_all_li_00)
# 5 itemset(s) from tree conditioned on items (ab_50pct_ch)
# 0 itemset(s) from tree conditioned on items (ab_50pct_ch, aboverm_per_nonwhite_90)
# 2 itemset(s) from tree conditioned on items (ab_50pct_ch, aboverm_per_all_li_00)
# 0 itemset(s) from tree conditioned on items (ab_50pct_ch, aboverm_per_all_li_00, aboverm_per_nonwhite_90)
# 1 itemset(s) from tree conditioned on items (ab_50pct_ch, aboverm_per_all_li_00, aboverm_per_all_li_90)
# 3 itemset(s) from tree conditioned on items (ab_50pct_ch, aboverm_per_rent_90)
# 0 itemset(s) from tree conditioned on items (ab_50pct_ch, aboverm_per_rent_90, aboverm_per_nonwhite_90)
# 1 itemset(s) from tree conditioned on items (ab_50pct_ch, aboverm_per_rent_90, aboverm_per_all_li_00)
# 2 itemset(s) from tree conditioned on items (ab_50pct_ch, aboverm_per_rent_90, aboverm_per_all_li_90)
# 0 itemset(s) from tree conditioned on items (ab_50pct_ch, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_all_li_00)
# 1 itemset(s) from tree conditioned on items (ab_50pct_ch, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_nonwhite_90)
# 4 itemset(s) from tree conditioned on items (ab_50pct_ch, aboverm_per_nonwhite_00)
# 0 itemset(s) from tree conditioned on items (ab_50pct_ch, aboverm_per_nonwhite_00, aboverm_per_nonwhite_90)
# 1 itemset(s) from tree conditioned on items (ab_50pct_ch, aboverm_per_nonwhite_00, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (ab_50pct_ch, aboverm_per_nonwhite_00, aboverm_per_rent_90)
# 0 itemset(s) from tree conditioned on items (ab_50pct_ch, aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_nonwhite_90)
# 1 itemset(s) from tree conditioned on items (ab_50pct_ch, aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_all_li_00)
# 2 itemset(s) from tree conditioned on items (ab_50pct_ch, aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_all_li_90)
# 0 itemset(s) from tree conditioned on items (ab_50pct_ch, aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_nonwhite_90)
# 1 itemset(s) from tree conditioned on items (ab_50pct_ch, aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_all_li_00)
# 2 itemset(s) from tree conditioned on items (ab_50pct_ch, aboverm_per_nonwhite_00, aboverm_per_all_li_90)
# 0 itemset(s) from tree conditioned on items (ab_50pct_ch, aboverm_per_nonwhite_00, aboverm_per_all_li_90, aboverm_per_nonwhite_90)
# 1 itemset(s) from tree conditioned on items (ab_50pct_ch, aboverm_per_nonwhite_00, aboverm_per_all_li_90, aboverm_per_all_li_00)
# 1 itemset(s) from tree conditioned on items (ab_50pct_ch, aboverm_per_all_li_90)
# 6 itemset(s) from tree conditioned on items (aboverm_per_rent_00)
# 0 itemset(s) from tree conditioned on items (aboverm_per_rent_00, aboverm_per_all_li_00)
# 1 itemset(s) from tree conditioned on items (aboverm_per_rent_00, aboverm_per_rent_90)
# 2 itemset(s) from tree conditioned on items (aboverm_per_rent_00, aboverm_per_nonwhite_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_rent_00, aboverm_per_nonwhite_90, aboverm_per_all_li_00)
# 1 itemset(s) from tree conditioned on items (aboverm_per_rent_00, aboverm_per_nonwhite_90, aboverm_per_rent_90)
# 4 itemset(s) from tree conditioned on items (aboverm_per_rent_00, aboverm_per_nonwhite_00)
# 0 itemset(s) from tree conditioned on items (aboverm_per_rent_00, aboverm_per_nonwhite_00, aboverm_per_nonwhite_90)
# 1 itemset(s) from tree conditioned on items (aboverm_per_rent_00, aboverm_per_nonwhite_00, aboverm_per_all_li_00)
# 2 itemset(s) from tree conditioned on items (aboverm_per_rent_00, aboverm_per_nonwhite_00, aboverm_per_rent_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_rent_00, aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_nonwhite_90)
# 1 itemset(s) from tree conditioned on items (aboverm_per_rent_00, aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_rent_00, aboverm_per_nonwhite_00, aboverm_per_all_li_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_rent_00, aboverm_per_nonwhite_00, aboverm_per_all_li_90, aboverm_per_all_li_00)
# 1 itemset(s) from tree conditioned on items (aboverm_per_rent_00, aboverm_per_nonwhite_00, aboverm_per_all_li_90, aboverm_per_nonwhite_90)
# 2 itemset(s) from tree conditioned on items (aboverm_per_rent_00, aboverm_per_nonwhite_00, aboverm_per_all_li_90, aboverm_per_rent_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_rent_00, aboverm_per_nonwhite_00, aboverm_per_all_li_90, aboverm_per_rent_90, aboverm_per_nonwhite_90)
# 1 itemset(s) from tree conditioned on items (aboverm_per_rent_00, aboverm_per_nonwhite_00, aboverm_per_all_li_90, aboverm_per_rent_90, aboverm_per_all_li_00)
# 5 itemset(s) from tree conditioned on items (aboverm_per_rent_00, ab_50pct_ch)
# 0 itemset(s) from tree conditioned on items (aboverm_per_rent_00, ab_50pct_ch, aboverm_per_rent_90)
# 1 itemset(s) from tree conditioned on items (aboverm_per_rent_00, ab_50pct_ch, aboverm_per_all_li_00)
# 2 itemset(s) from tree conditioned on items (aboverm_per_rent_00, ab_50pct_ch, aboverm_per_nonwhite_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_rent_00, ab_50pct_ch, aboverm_per_nonwhite_90, aboverm_per_all_li_00)
# 1 itemset(s) from tree conditioned on items (aboverm_per_rent_00, ab_50pct_ch, aboverm_per_nonwhite_90, aboverm_per_rent_90)
# 4 itemset(s) from tree conditioned on items (aboverm_per_rent_00, ab_50pct_ch, aboverm_per_nonwhite_00)
# 0 itemset(s) from tree conditioned on items (aboverm_per_rent_00, ab_50pct_ch, aboverm_per_nonwhite_00, aboverm_per_nonwhite_90)
# 1 itemset(s) from tree conditioned on items (aboverm_per_rent_00, ab_50pct_ch, aboverm_per_nonwhite_00, aboverm_per_all_li_00)
# 2 itemset(s) from tree conditioned on items (aboverm_per_rent_00, ab_50pct_ch, aboverm_per_nonwhite_00, aboverm_per_rent_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_rent_00, ab_50pct_ch, aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_nonwhite_90)
# 1 itemset(s) from tree conditioned on items (aboverm_per_rent_00, ab_50pct_ch, aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_rent_00, ab_50pct_ch, aboverm_per_nonwhite_00, aboverm_per_all_li_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_rent_00, ab_50pct_ch, aboverm_per_nonwhite_00, aboverm_per_all_li_90, aboverm_per_all_li_00)
# 1 itemset(s) from tree conditioned on items (aboverm_per_rent_00, ab_50pct_ch, aboverm_per_nonwhite_00, aboverm_per_all_li_90, aboverm_per_nonwhite_90)
# 2 itemset(s) from tree conditioned on items (aboverm_per_rent_00, ab_50pct_ch, aboverm_per_nonwhite_00, aboverm_per_all_li_90, aboverm_per_rent_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_rent_00, ab_50pct_ch, aboverm_per_nonwhite_00, aboverm_per_all_li_90, aboverm_per_rent_90, aboverm_per_nonwhite_90)
# 1 itemset(s) from tree conditioned on items (aboverm_per_rent_00, ab_50pct_ch, aboverm_per_nonwhite_00, aboverm_per_all_li_90, aboverm_per_rent_90, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_rent_00, ab_50pct_ch, aboverm_per_all_li_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_rent_00, ab_50pct_ch, aboverm_per_all_li_90, aboverm_per_all_li_00)
# 1 itemset(s) from tree conditioned on items (aboverm_per_rent_00, ab_50pct_ch, aboverm_per_all_li_90, aboverm_per_rent_90)
# 2 itemset(s) from tree conditioned on items (aboverm_per_rent_00, ab_50pct_ch, aboverm_per_all_li_90, aboverm_per_nonwhite_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_rent_00, ab_50pct_ch, aboverm_per_all_li_90, aboverm_per_nonwhite_90, aboverm_per_all_li_00)
# 1 itemset(s) from tree conditioned on items (aboverm_per_rent_00, ab_50pct_ch, aboverm_per_all_li_90, aboverm_per_nonwhite_90, aboverm_per_rent_90)
# 3 itemset(s) from tree conditioned on items (aboverm_per_rent_00, aboverm_per_all_li_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_rent_00, aboverm_per_all_li_90, aboverm_per_all_li_00)
# 1 itemset(s) from tree conditioned on items (aboverm_per_rent_00, aboverm_per_all_li_90, aboverm_per_rent_90)
# 2 itemset(s) from tree conditioned on items (aboverm_per_rent_00, aboverm_per_all_li_90, aboverm_per_nonwhite_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_rent_00, aboverm_per_all_li_90, aboverm_per_nonwhite_90, aboverm_per_all_li_00)
# 1 itemset(s) from tree conditioned on items (aboverm_per_rent_00, aboverm_per_all_li_90, aboverm_per_nonwhite_90, aboverm_per_rent_90)
# 7 itemset(s) from tree conditioned on items (dense)
# 0 itemset(s) from tree conditioned on items (dense, aboverm_per_nonwhite_90)
# 1 itemset(s) from tree conditioned on items (dense, aboverm_per_nonwhite_00)
# 2 itemset(s) from tree conditioned on items (dense, aboverm_per_all_li_00)
# 0 itemset(s) from tree conditioned on items (dense, aboverm_per_all_li_00, aboverm_per_nonwhite_90)
# 1 itemset(s) from tree conditioned on items (dense, aboverm_per_all_li_00, aboverm_per_nonwhite_00)
# 4 itemset(s) from tree conditioned on items (dense, aboverm_per_rent_90)
# 0 itemset(s) from tree conditioned on items (dense, aboverm_per_rent_90, aboverm_per_all_li_00)
# 1 itemset(s) from tree conditioned on items (dense, aboverm_per_rent_90, aboverm_per_nonwhite_90)
# 2 itemset(s) from tree conditioned on items (dense, aboverm_per_rent_90, aboverm_per_nonwhite_00)
# 0 itemset(s) from tree conditioned on items (dense, aboverm_per_rent_90, aboverm_per_nonwhite_00, aboverm_per_nonwhite_90)
# 1 itemset(s) from tree conditioned on items (dense, aboverm_per_rent_90, aboverm_per_nonwhite_00, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (dense, aboverm_per_rent_90, aboverm_per_all_li_90)
# 0 itemset(s) from tree conditioned on items (dense, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_all_li_00)
# 1 itemset(s) from tree conditioned on items (dense, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_nonwhite_90)
# 2 itemset(s) from tree conditioned on items (dense, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_nonwhite_00)
# 0 itemset(s) from tree conditioned on items (dense, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_nonwhite_00, aboverm_per_nonwhite_90)
# 1 itemset(s) from tree conditioned on items (dense, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_nonwhite_00, aboverm_per_all_li_00)
# 5 itemset(s) from tree conditioned on items (dense, aboverm_per_rent_00)
# 0 itemset(s) from tree conditioned on items (dense, aboverm_per_rent_00, aboverm_per_all_li_00)
# 1 itemset(s) from tree conditioned on items (dense, aboverm_per_rent_00, aboverm_per_rent_90)
# 2 itemset(s) from tree conditioned on items (dense, aboverm_per_rent_00, aboverm_per_nonwhite_90)
# 0 itemset(s) from tree conditioned on items (dense, aboverm_per_rent_00, aboverm_per_nonwhite_90, aboverm_per_all_li_00)
# 1 itemset(s) from tree conditioned on items (dense, aboverm_per_rent_00, aboverm_per_nonwhite_90, aboverm_per_rent_90)
# 3 itemset(s) from tree conditioned on items (dense, aboverm_per_rent_00, aboverm_per_nonwhite_00)
# 0 itemset(s) from tree conditioned on items (dense, aboverm_per_rent_00, aboverm_per_nonwhite_00, aboverm_per_nonwhite_90)
# 1 itemset(s) from tree conditioned on items (dense, aboverm_per_rent_00, aboverm_per_nonwhite_00, aboverm_per_all_li_00)
# 2 itemset(s) from tree conditioned on items (dense, aboverm_per_rent_00, aboverm_per_nonwhite_00, aboverm_per_rent_90)
# 0 itemset(s) from tree conditioned on items (dense, aboverm_per_rent_00, aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_nonwhite_90)
# 1 itemset(s) from tree conditioned on items (dense, aboverm_per_rent_00, aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_all_li_00)
# 4 itemset(s) from tree conditioned on items (dense, aboverm_per_rent_00, aboverm_per_all_li_90)
# 0 itemset(s) from tree conditioned on items (dense, aboverm_per_rent_00, aboverm_per_all_li_90, aboverm_per_all_li_00)
# 1 itemset(s) from tree conditioned on items (dense, aboverm_per_rent_00, aboverm_per_all_li_90, aboverm_per_nonwhite_90)
# 2 itemset(s) from tree conditioned on items (dense, aboverm_per_rent_00, aboverm_per_all_li_90, aboverm_per_rent_90)
# 0 itemset(s) from tree conditioned on items (dense, aboverm_per_rent_00, aboverm_per_all_li_90, aboverm_per_rent_90, aboverm_per_all_li_00)
# 1 itemset(s) from tree conditioned on items (dense, aboverm_per_rent_00, aboverm_per_all_li_90, aboverm_per_rent_90, aboverm_per_nonwhite_90)
# 3 itemset(s) from tree conditioned on items (dense, aboverm_per_rent_00, aboverm_per_all_li_90, aboverm_per_nonwhite_00)
# 0 itemset(s) from tree conditioned on items (dense, aboverm_per_rent_00, aboverm_per_all_li_90, aboverm_per_nonwhite_00, aboverm_per_nonwhite_90)
# 1 itemset(s) from tree conditioned on items (dense, aboverm_per_rent_00, aboverm_per_all_li_90, aboverm_per_nonwhite_00, aboverm_per_all_li_00)
# 2 itemset(s) from tree conditioned on items (dense, aboverm_per_rent_00, aboverm_per_all_li_90, aboverm_per_nonwhite_00, aboverm_per_rent_90)
# 0 itemset(s) from tree conditioned on items (dense, aboverm_per_rent_00, aboverm_per_all_li_90, aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_all_li_00)
# 1 itemset(s) from tree conditioned on items (dense, aboverm_per_rent_00, aboverm_per_all_li_90, aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_nonwhite_90)
# 6 itemset(s) from tree conditioned on items (dense, ab_50pct_ch)
# 0 itemset(s) from tree conditioned on items (dense, ab_50pct_ch, aboverm_per_nonwhite_90)
# 1 itemset(s) from tree conditioned on items (dense, ab_50pct_ch, aboverm_per_all_li_00)
# 2 itemset(s) from tree conditioned on items (dense, ab_50pct_ch, aboverm_per_nonwhite_00)
# 0 itemset(s) from tree conditioned on items (dense, ab_50pct_ch, aboverm_per_nonwhite_00, aboverm_per_nonwhite_90)
# 1 itemset(s) from tree conditioned on items (dense, ab_50pct_ch, aboverm_per_nonwhite_00, aboverm_per_all_li_00)
# 4 itemset(s) from tree conditioned on items (dense, ab_50pct_ch, aboverm_per_rent_90)
# 0 itemset(s) from tree conditioned on items (dense, ab_50pct_ch, aboverm_per_rent_90, aboverm_per_all_li_00)
# 1 itemset(s) from tree conditioned on items (dense, ab_50pct_ch, aboverm_per_rent_90, aboverm_per_nonwhite_90)
# 2 itemset(s) from tree conditioned on items (dense, ab_50pct_ch, aboverm_per_rent_90, aboverm_per_nonwhite_00)
# 0 itemset(s) from tree conditioned on items (dense, ab_50pct_ch, aboverm_per_rent_90, aboverm_per_nonwhite_00, aboverm_per_nonwhite_90)
# 1 itemset(s) from tree conditioned on items (dense, ab_50pct_ch, aboverm_per_rent_90, aboverm_per_nonwhite_00, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (dense, ab_50pct_ch, aboverm_per_rent_90, aboverm_per_all_li_90)
# 0 itemset(s) from tree conditioned on items (dense, ab_50pct_ch, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_all_li_00)
# 1 itemset(s) from tree conditioned on items (dense, ab_50pct_ch, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_nonwhite_90)
# 2 itemset(s) from tree conditioned on items (dense, ab_50pct_ch, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_nonwhite_00)
# 0 itemset(s) from tree conditioned on items (dense, ab_50pct_ch, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_nonwhite_00, aboverm_per_nonwhite_90)
# 1 itemset(s) from tree conditioned on items (dense, ab_50pct_ch, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_nonwhite_00, aboverm_per_all_li_00)
# 5 itemset(s) from tree conditioned on items (dense, ab_50pct_ch, aboverm_per_rent_00)
# 0 itemset(s) from tree conditioned on items (dense, ab_50pct_ch, aboverm_per_rent_00, aboverm_per_all_li_00)
# 1 itemset(s) from tree conditioned on items (dense, ab_50pct_ch, aboverm_per_rent_00, aboverm_per_rent_90)
# 2 itemset(s) from tree conditioned on items (dense, ab_50pct_ch, aboverm_per_rent_00, aboverm_per_nonwhite_90)
# 0 itemset(s) from tree conditioned on items (dense, ab_50pct_ch, aboverm_per_rent_00, aboverm_per_nonwhite_90, aboverm_per_all_li_00)
# 1 itemset(s) from tree conditioned on items (dense, ab_50pct_ch, aboverm_per_rent_00, aboverm_per_nonwhite_90, aboverm_per_rent_90)
# 3 itemset(s) from tree conditioned on items (dense, ab_50pct_ch, aboverm_per_rent_00, aboverm_per_nonwhite_00)
# 0 itemset(s) from tree conditioned on items (dense, ab_50pct_ch, aboverm_per_rent_00, aboverm_per_nonwhite_00, aboverm_per_nonwhite_90)
# 1 itemset(s) from tree conditioned on items (dense, ab_50pct_ch, aboverm_per_rent_00, aboverm_per_nonwhite_00, aboverm_per_all_li_00)
# 2 itemset(s) from tree conditioned on items (dense, ab_50pct_ch, aboverm_per_rent_00, aboverm_per_nonwhite_00, aboverm_per_rent_90)
# 0 itemset(s) from tree conditioned on items (dense, ab_50pct_ch, aboverm_per_rent_00, aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_nonwhite_90)
# 1 itemset(s) from tree conditioned on items (dense, ab_50pct_ch, aboverm_per_rent_00, aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_all_li_00)
# 4 itemset(s) from tree conditioned on items (dense, ab_50pct_ch, aboverm_per_rent_00, aboverm_per_all_li_90)
# 0 itemset(s) from tree conditioned on items (dense, ab_50pct_ch, aboverm_per_rent_00, aboverm_per_all_li_90, aboverm_per_all_li_00)
# 1 itemset(s) from tree conditioned on items (dense, ab_50pct_ch, aboverm_per_rent_00, aboverm_per_all_li_90, aboverm_per_rent_90)
# 2 itemset(s) from tree conditioned on items (dense, ab_50pct_ch, aboverm_per_rent_00, aboverm_per_all_li_90, aboverm_per_nonwhite_90)
# 0 itemset(s) from tree conditioned on items (dense, ab_50pct_ch, aboverm_per_rent_00, aboverm_per_all_li_90, aboverm_per_nonwhite_90, aboverm_per_all_li_00)
# 1 itemset(s) from tree conditioned on items (dense, ab_50pct_ch, aboverm_per_rent_00, aboverm_per_all_li_90, aboverm_per_nonwhite_90, aboverm_per_rent_90)
# 3 itemset(s) from tree conditioned on items (dense, ab_50pct_ch, aboverm_per_rent_00, aboverm_per_all_li_90, aboverm_per_nonwhite_00)
# 0 itemset(s) from tree conditioned on items (dense, ab_50pct_ch, aboverm_per_rent_00, aboverm_per_all_li_90, aboverm_per_nonwhite_00, aboverm_per_nonwhite_90)
# 1 itemset(s) from tree conditioned on items (dense, ab_50pct_ch, aboverm_per_rent_00, aboverm_per_all_li_90, aboverm_per_nonwhite_00, aboverm_per_all_li_00)
# 2 itemset(s) from tree conditioned on items (dense, ab_50pct_ch, aboverm_per_rent_00, aboverm_per_all_li_90, aboverm_per_nonwhite_00, aboverm_per_rent_90)
# 0 itemset(s) from tree conditioned on items (dense, ab_50pct_ch, aboverm_per_rent_00, aboverm_per_all_li_90, aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_all_li_00)
# 1 itemset(s) from tree conditioned on items (dense, ab_50pct_ch, aboverm_per_rent_00, aboverm_per_all_li_90, aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_nonwhite_90)
# 3 itemset(s) from tree conditioned on items (dense, ab_50pct_ch, aboverm_per_all_li_90)
# 0 itemset(s) from tree conditioned on items (dense, ab_50pct_ch, aboverm_per_all_li_90, aboverm_per_nonwhite_90)
# 1 itemset(s) from tree conditioned on items (dense, ab_50pct_ch, aboverm_per_all_li_90, aboverm_per_all_li_00)
# 2 itemset(s) from tree conditioned on items (dense, ab_50pct_ch, aboverm_per_all_li_90, aboverm_per_nonwhite_00)
# 0 itemset(s) from tree conditioned on items (dense, ab_50pct_ch, aboverm_per_all_li_90, aboverm_per_nonwhite_00, aboverm_per_nonwhite_90)
# 1 itemset(s) from tree conditioned on items (dense, ab_50pct_ch, aboverm_per_all_li_90, aboverm_per_nonwhite_00, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (dense, aboverm_per_all_li_90)
# 0 itemset(s) from tree conditioned on items (dense, aboverm_per_all_li_90, aboverm_per_nonwhite_90)
# 1 itemset(s) from tree conditioned on items (dense, aboverm_per_all_li_90, aboverm_per_all_li_00)
# 2 itemset(s) from tree conditioned on items (dense, aboverm_per_all_li_90, aboverm_per_nonwhite_00)
# 0 itemset(s) from tree conditioned on items (dense, aboverm_per_all_li_90, aboverm_per_nonwhite_00, aboverm_per_nonwhite_90)
# 1 itemset(s) from tree conditioned on items (dense, aboverm_per_all_li_90, aboverm_per_nonwhite_00, aboverm_per_all_li_00)
# 8 itemset(s) from tree conditioned on items (aboverm_per_all_li_18)
# 0 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, aboverm_per_nonwhite_90)
# 1 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, aboverm_per_rent_00)
# 0 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, aboverm_per_rent_00, aboverm_per_all_li_00)
# 1 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, aboverm_per_rent_00, aboverm_per_nonwhite_90)
# 2 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, aboverm_per_rent_00, aboverm_per_all_li_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, aboverm_per_rent_00, aboverm_per_all_li_90, aboverm_per_all_li_00)
# 1 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, aboverm_per_rent_00, aboverm_per_all_li_90, aboverm_per_nonwhite_90)
# 4 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, aboverm_per_rent_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, aboverm_per_rent_90, aboverm_per_rent_00)
# 1 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, aboverm_per_rent_90, aboverm_per_all_li_00)
# 2 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, aboverm_per_rent_90, aboverm_per_nonwhite_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, aboverm_per_rent_90, aboverm_per_nonwhite_90, aboverm_per_rent_00)
# 1 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, aboverm_per_rent_90, aboverm_per_nonwhite_90, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, aboverm_per_rent_90, aboverm_per_all_li_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_rent_00)
# 1 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_all_li_00)
# 2 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_nonwhite_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_nonwhite_90, aboverm_per_rent_00)
# 1 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_nonwhite_90, aboverm_per_all_li_00)
# 5 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, aboverm_per_nonwhite_00)
# 0 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, aboverm_per_nonwhite_00, aboverm_per_nonwhite_90)
# 1 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, aboverm_per_nonwhite_00, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, aboverm_per_nonwhite_00, aboverm_per_rent_00)
# 0 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, aboverm_per_nonwhite_00, aboverm_per_rent_00, aboverm_per_all_li_00)
# 1 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, aboverm_per_nonwhite_00, aboverm_per_rent_00, aboverm_per_nonwhite_90)
# 2 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, aboverm_per_nonwhite_00, aboverm_per_rent_00, aboverm_per_all_li_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, aboverm_per_nonwhite_00, aboverm_per_rent_00, aboverm_per_all_li_90, aboverm_per_all_li_00)
# 1 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, aboverm_per_nonwhite_00, aboverm_per_rent_00, aboverm_per_all_li_90, aboverm_per_nonwhite_90)
# 4 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, aboverm_per_nonwhite_00, aboverm_per_rent_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_rent_00)
# 1 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_nonwhite_90)
# 2 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_all_li_00)
# 0 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_all_li_00, aboverm_per_rent_00)
# 1 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_all_li_00, aboverm_per_nonwhite_90)
# 3 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_all_li_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_nonwhite_90)
# 1 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_rent_00)
# 2 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_all_li_00)
# 0 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_all_li_00, aboverm_per_rent_00)
# 1 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_all_li_00, aboverm_per_nonwhite_90)
# 2 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, aboverm_per_nonwhite_00, aboverm_per_all_li_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, aboverm_per_nonwhite_00, aboverm_per_all_li_90, aboverm_per_nonwhite_90)
# 1 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, aboverm_per_nonwhite_00, aboverm_per_all_li_90, aboverm_per_all_li_00)
# 6 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, dense)
# 0 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, dense, aboverm_per_nonwhite_90)
# 1 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, dense, aboverm_per_all_li_00)
# 2 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, dense, aboverm_per_nonwhite_00)
# 0 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, dense, aboverm_per_nonwhite_00, aboverm_per_nonwhite_90)
# 1 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, dense, aboverm_per_nonwhite_00, aboverm_per_all_li_00)
# 4 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, dense, aboverm_per_rent_00)
# 0 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, dense, aboverm_per_rent_00, aboverm_per_all_li_00)
# 1 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, dense, aboverm_per_rent_00, aboverm_per_nonwhite_90)
# 2 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, dense, aboverm_per_rent_00, aboverm_per_nonwhite_00)
# 0 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, dense, aboverm_per_rent_00, aboverm_per_nonwhite_00, aboverm_per_nonwhite_90)
# 1 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, dense, aboverm_per_rent_00, aboverm_per_nonwhite_00, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, dense, aboverm_per_rent_00, aboverm_per_all_li_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, dense, aboverm_per_rent_00, aboverm_per_all_li_90, aboverm_per_all_li_00)
# 1 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, dense, aboverm_per_rent_00, aboverm_per_all_li_90, aboverm_per_nonwhite_90)
# 2 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, dense, aboverm_per_rent_00, aboverm_per_all_li_90, aboverm_per_nonwhite_00)
# 0 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, dense, aboverm_per_rent_00, aboverm_per_all_li_90, aboverm_per_nonwhite_00, aboverm_per_all_li_00)
# 1 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, dense, aboverm_per_rent_00, aboverm_per_all_li_90, aboverm_per_nonwhite_00, aboverm_per_nonwhite_90)
# 5 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, dense, aboverm_per_rent_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, dense, aboverm_per_rent_90, aboverm_per_rent_00)
# 1 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, dense, aboverm_per_rent_90, aboverm_per_all_li_00)
# 2 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, dense, aboverm_per_rent_90, aboverm_per_nonwhite_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, dense, aboverm_per_rent_90, aboverm_per_nonwhite_90, aboverm_per_rent_00)
# 1 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, dense, aboverm_per_rent_90, aboverm_per_nonwhite_90, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, dense, aboverm_per_rent_90, aboverm_per_nonwhite_00)
# 0 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, dense, aboverm_per_rent_90, aboverm_per_nonwhite_00, aboverm_per_rent_00)
# 1 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, dense, aboverm_per_rent_90, aboverm_per_nonwhite_00, aboverm_per_nonwhite_90)
# 2 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, dense, aboverm_per_rent_90, aboverm_per_nonwhite_00, aboverm_per_all_li_00)
# 0 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, dense, aboverm_per_rent_90, aboverm_per_nonwhite_00, aboverm_per_all_li_00, aboverm_per_rent_00)
# 1 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, dense, aboverm_per_rent_90, aboverm_per_nonwhite_00, aboverm_per_all_li_00, aboverm_per_nonwhite_90)
# 4 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, dense, aboverm_per_rent_90, aboverm_per_all_li_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, dense, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_rent_00)
# 1 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, dense, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_all_li_00)
# 2 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, dense, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_nonwhite_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, dense, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_nonwhite_90, aboverm_per_rent_00)
# 1 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, dense, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_nonwhite_90, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, dense, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_nonwhite_00)
# 0 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, dense, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_nonwhite_00, aboverm_per_rent_00)
# 1 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, dense, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_nonwhite_00, aboverm_per_nonwhite_90)
# 2 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, dense, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_nonwhite_00, aboverm_per_all_li_00)
# 0 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, dense, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_nonwhite_00, aboverm_per_all_li_00, aboverm_per_rent_00)
# 1 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, dense, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_nonwhite_00, aboverm_per_all_li_00, aboverm_per_nonwhite_90)
# 3 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, dense, aboverm_per_all_li_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, dense, aboverm_per_all_li_90, aboverm_per_nonwhite_90)
# 1 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, dense, aboverm_per_all_li_90, aboverm_per_all_li_00)
# 2 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, dense, aboverm_per_all_li_90, aboverm_per_nonwhite_00)
# 0 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, dense, aboverm_per_all_li_90, aboverm_per_nonwhite_00, aboverm_per_nonwhite_90)
# 1 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, dense, aboverm_per_all_li_90, aboverm_per_nonwhite_00, aboverm_per_all_li_00)
# 7 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch)
# 0 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, aboverm_per_nonwhite_90)
# 1 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, aboverm_per_rent_00)
# 0 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, aboverm_per_rent_00, aboverm_per_all_li_00)
# 1 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, aboverm_per_rent_00, aboverm_per_nonwhite_90)
# 2 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, aboverm_per_rent_00, aboverm_per_all_li_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, aboverm_per_rent_00, aboverm_per_all_li_90, aboverm_per_all_li_00)
# 1 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, aboverm_per_rent_00, aboverm_per_all_li_90, aboverm_per_nonwhite_90)
# 4 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, aboverm_per_rent_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, aboverm_per_rent_90, aboverm_per_rent_00)
# 1 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, aboverm_per_rent_90, aboverm_per_all_li_00)
# 2 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, aboverm_per_rent_90, aboverm_per_nonwhite_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, aboverm_per_rent_90, aboverm_per_nonwhite_90, aboverm_per_rent_00)
# 1 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, aboverm_per_rent_90, aboverm_per_nonwhite_90, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, aboverm_per_rent_90, aboverm_per_all_li_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_rent_00)
# 1 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_all_li_00)
# 2 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_nonwhite_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_nonwhite_90, aboverm_per_rent_00)
# 1 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_nonwhite_90, aboverm_per_all_li_00)
# 5 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, aboverm_per_nonwhite_00)
# 0 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, aboverm_per_nonwhite_00, aboverm_per_nonwhite_90)
# 1 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, aboverm_per_nonwhite_00, aboverm_per_all_li_00)
# 2 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, aboverm_per_nonwhite_00, aboverm_per_rent_00)
# 0 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, aboverm_per_nonwhite_00, aboverm_per_rent_00, aboverm_per_all_li_00)
# 1 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, aboverm_per_nonwhite_00, aboverm_per_rent_00, aboverm_per_nonwhite_90)
# 4 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, aboverm_per_nonwhite_00, aboverm_per_rent_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_rent_00)
# 1 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_nonwhite_90)
# 2 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_all_li_00)
# 0 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_all_li_00, aboverm_per_rent_00)
# 1 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_all_li_00, aboverm_per_nonwhite_90)
# 3 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_all_li_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_nonwhite_90)
# 1 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_rent_00)
# 2 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_all_li_00)
# 0 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_all_li_00, aboverm_per_rent_00)
# 1 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_all_li_00, aboverm_per_nonwhite_90)
# 3 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, aboverm_per_nonwhite_00, aboverm_per_all_li_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, aboverm_per_nonwhite_00, aboverm_per_all_li_90, aboverm_per_nonwhite_90)
# 1 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, aboverm_per_nonwhite_00, aboverm_per_all_li_90, aboverm_per_all_li_00)
# 2 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, aboverm_per_nonwhite_00, aboverm_per_all_li_90, aboverm_per_rent_00)
# 0 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, aboverm_per_nonwhite_00, aboverm_per_all_li_90, aboverm_per_rent_00, aboverm_per_all_li_00)
# 1 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, aboverm_per_nonwhite_00, aboverm_per_all_li_90, aboverm_per_rent_00, aboverm_per_nonwhite_90)
# 6 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, dense)
# 0 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, dense, aboverm_per_nonwhite_90)
# 1 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, dense, aboverm_per_all_li_00)
# 2 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, dense, aboverm_per_rent_00)
# 0 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, dense, aboverm_per_rent_00, aboverm_per_all_li_00)
# 1 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, dense, aboverm_per_rent_00, aboverm_per_nonwhite_90)
# 4 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, dense, aboverm_per_nonwhite_00)
# 0 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, dense, aboverm_per_nonwhite_00, aboverm_per_nonwhite_90)
# 1 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, dense, aboverm_per_nonwhite_00, aboverm_per_all_li_00)
# 2 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, dense, aboverm_per_nonwhite_00, aboverm_per_rent_00)
# 0 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, dense, aboverm_per_nonwhite_00, aboverm_per_rent_00, aboverm_per_all_li_00)
# 1 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, dense, aboverm_per_nonwhite_00, aboverm_per_rent_00, aboverm_per_nonwhite_90)
# 3 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, dense, aboverm_per_nonwhite_00, aboverm_per_all_li_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, dense, aboverm_per_nonwhite_00, aboverm_per_all_li_90, aboverm_per_nonwhite_90)
# 1 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, dense, aboverm_per_nonwhite_00, aboverm_per_all_li_90, aboverm_per_all_li_00)
# 2 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, dense, aboverm_per_nonwhite_00, aboverm_per_all_li_90, aboverm_per_rent_00)
# 0 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, dense, aboverm_per_nonwhite_00, aboverm_per_all_li_90, aboverm_per_rent_00, aboverm_per_all_li_00)
# 0 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, dense, aboverm_per_nonwhite_00, aboverm_per_all_li_90, aboverm_per_rent_00, aboverm_per_nonwhite_90)
# 5 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, dense, aboverm_per_rent_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, dense, aboverm_per_rent_90, aboverm_per_rent_00)
# 1 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, dense, aboverm_per_rent_90, aboverm_per_all_li_00)
# 2 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, dense, aboverm_per_rent_90, aboverm_per_nonwhite_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, dense, aboverm_per_rent_90, aboverm_per_nonwhite_90, aboverm_per_rent_00)
# 1 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, dense, aboverm_per_rent_90, aboverm_per_nonwhite_90, aboverm_per_all_li_00)
# 4 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, dense, aboverm_per_rent_90, aboverm_per_nonwhite_00)
# 0 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, dense, aboverm_per_rent_90, aboverm_per_nonwhite_00, aboverm_per_rent_00)
# 1 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, dense, aboverm_per_rent_90, aboverm_per_nonwhite_00, aboverm_per_nonwhite_90)
# 2 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, dense, aboverm_per_rent_90, aboverm_per_nonwhite_00, aboverm_per_all_li_00)
# 0 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, dense, aboverm_per_rent_90, aboverm_per_nonwhite_00, aboverm_per_all_li_00, aboverm_per_rent_00)
# 1 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, dense, aboverm_per_rent_90, aboverm_per_nonwhite_00, aboverm_per_all_li_00, aboverm_per_nonwhite_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, dense, aboverm_per_rent_90, aboverm_per_nonwhite_00, aboverm_per_all_li_90)
# 3 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, dense, aboverm_per_rent_90, aboverm_per_all_li_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, dense, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_rent_00)
# 1 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, dense, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_all_li_00)
# 2 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, dense, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_nonwhite_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, dense, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_nonwhite_90, aboverm_per_rent_00)
# 1 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, dense, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_nonwhite_90, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, dense, aboverm_per_all_li_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, dense, aboverm_per_all_li_90, aboverm_per_all_li_00)
# 1 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, dense, aboverm_per_all_li_90, aboverm_per_nonwhite_90)
# 2 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, dense, aboverm_per_all_li_90, aboverm_per_rent_00)
# 0 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, dense, aboverm_per_all_li_90, aboverm_per_rent_00, aboverm_per_all_li_00)
# 1 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, dense, aboverm_per_all_li_90, aboverm_per_rent_00, aboverm_per_nonwhite_90)
# 2 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, aboverm_per_all_li_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, aboverm_per_all_li_90, aboverm_per_all_li_00)
# 1 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, ab_50pct_ch, aboverm_per_all_li_90, aboverm_per_nonwhite_90)
# 2 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, aboverm_per_all_li_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_all_li_18, aboverm_per_all_li_90, aboverm_per_nonwhite_90)
# ...
# 0 itemset(s) from tree conditioned on items (change_flag_category_ch_rapid_increase, aboverm_per_rent_00, aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_all_li_00)
# 1 itemset(s) from tree conditioned on items (change_flag_category_ch_rapid_increase, aboverm_per_rent_00, aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_nonwhite_90)
# 1 itemset(s) from tree conditioned on items (change_flag_category_ch_rapid_increase, aboverm_per_rent_00, aboverm_per_nonwhite_00, aboverm_per_rent_90, hotmarket_18)
# 2 itemset(s) from tree conditioned on items (change_flag_category_ch_rapid_increase, aboverm_per_rent_00, aboverm_per_nonwhite_00, aboverm_per_all_li_90)
# 0 itemset(s) from tree conditioned on items (change_flag_category_ch_rapid_increase, aboverm_per_rent_00, aboverm_per_nonwhite_00, aboverm_per_all_li_90, aboverm_per_all_li_00)
# 0 itemset(s) from tree conditioned on items (change_flag_category_ch_rapid_increase, aboverm_per_rent_00, aboverm_per_nonwhite_00, aboverm_per_all_li_90, aboverm_per_nonwhite_90)
# 4 itemset(s) from tree conditioned on items (change_flag_category_ch_rapid_increase, aboverm_per_rent_00, ab_50pct_ch)
# 0 itemset(s) from tree conditioned on items (change_flag_category_ch_rapid_increase, aboverm_per_rent_00, ab_50pct_ch, aboverm_per_all_li_00)
# 1 itemset(s) from tree conditioned on items (change_flag_category_ch_rapid_increase, aboverm_per_rent_00, ab_50pct_ch, hotmarket_18)
# 1 itemset(s) from tree conditioned on items (change_flag_category_ch_rapid_increase, aboverm_per_rent_00, ab_50pct_ch, aboverm_per_rent_90)
# 0 itemset(s) from tree conditioned on items (change_flag_category_ch_rapid_increase, aboverm_per_rent_00, ab_50pct_ch, aboverm_per_all_li_90)
# 7 itemset(s) from tree conditioned on items (change_flag_category_ch_rapid_increase, aboverm_per_rent_18)
# 0 itemset(s) from tree conditioned on items (change_flag_category_ch_rapid_increase, aboverm_per_rent_18, aboverm_per_all_li_00)
# 1 itemset(s) from tree conditioned on items (change_flag_category_ch_rapid_increase, aboverm_per_rent_18, aboverm_per_rent_00)
# 2 itemset(s) from tree conditioned on items (change_flag_category_ch_rapid_increase, aboverm_per_rent_18, aboverm_per_rent_90)
# 0 itemset(s) from tree conditioned on items (change_flag_category_ch_rapid_increase, aboverm_per_rent_18, aboverm_per_rent_90, aboverm_per_rent_00)
# 1 itemset(s) from tree conditioned on items (change_flag_category_ch_rapid_increase, aboverm_per_rent_18, aboverm_per_rent_90, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (change_flag_category_ch_rapid_increase, aboverm_per_rent_18, aboverm_per_nonwhite_90)
# 0 itemset(s) from tree conditioned on items (change_flag_category_ch_rapid_increase, aboverm_per_rent_18, aboverm_per_nonwhite_90, aboverm_per_all_li_00)
# 1 itemset(s) from tree conditioned on items (change_flag_category_ch_rapid_increase, aboverm_per_rent_18, aboverm_per_nonwhite_90, aboverm_per_rent_00)
# 2 itemset(s) from tree conditioned on items (change_flag_category_ch_rapid_increase, aboverm_per_rent_18, aboverm_per_nonwhite_90, aboverm_per_rent_90)
# 0 itemset(s) from tree conditioned on items (change_flag_category_ch_rapid_increase, aboverm_per_rent_18, aboverm_per_nonwhite_90, aboverm_per_rent_90, aboverm_per_rent_00)
# 0 itemset(s) from tree conditioned on items (change_flag_category_ch_rapid_increase, aboverm_per_rent_18, aboverm_per_nonwhite_90, aboverm_per_rent_90, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (change_flag_category_ch_rapid_increase, aboverm_per_rent_18, hotmarket_18)
# 0 itemset(s) from tree conditioned on items (change_flag_category_ch_rapid_increase, aboverm_per_rent_18, hotmarket_18, aboverm_per_rent_00)
# 1 itemset(s) from tree conditioned on items (change_flag_category_ch_rapid_increase, aboverm_per_rent_18, hotmarket_18, aboverm_per_all_li_00)
# 2 itemset(s) from tree conditioned on items (change_flag_category_ch_rapid_increase, aboverm_per_rent_18, hotmarket_18, aboverm_per_rent_90)
# 0 itemset(s) from tree conditioned on items (change_flag_category_ch_rapid_increase, aboverm_per_rent_18, hotmarket_18, aboverm_per_rent_90, aboverm_per_rent_00)
# 1 itemset(s) from tree conditioned on items (change_flag_category_ch_rapid_increase, aboverm_per_rent_18, hotmarket_18, aboverm_per_rent_90, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (change_flag_category_ch_rapid_increase, aboverm_per_rent_18, aboverm_per_all_li_90)
# 0 itemset(s) from tree conditioned on items (change_flag_category_ch_rapid_increase, aboverm_per_rent_18, aboverm_per_all_li_90, aboverm_per_rent_00)
# 1 itemset(s) from tree conditioned on items (change_flag_category_ch_rapid_increase, aboverm_per_rent_18, aboverm_per_all_li_90, aboverm_per_all_li_00)
# 1 itemset(s) from tree conditioned on items (change_flag_category_ch_rapid_increase, aboverm_per_rent_18, aboverm_per_all_li_90, aboverm_per_rent_90)
# 0 itemset(s) from tree conditioned on items (change_flag_category_ch_rapid_increase, aboverm_per_rent_18, aboverm_per_nonwhite_00)
# 8 itemset(s) from tree conditioned on items (change_flag_category_ch_rapid_increase, aboverm_per_all_li_18)
# 0 itemset(s) from tree conditioned on items (change_flag_category_ch_rapid_increase, aboverm_per_all_li_18, aboverm_per_all_li_00)
# 1 itemset(s) from tree conditioned on items (change_flag_category_ch_rapid_increase, aboverm_per_all_li_18, aboverm_per_nonwhite_90)
# 2 itemset(s) from tree conditioned on items (change_flag_category_ch_rapid_increase, aboverm_per_all_li_18, aboverm_per_all_li_90)
# 0 itemset(s) from tree conditioned on items (change_flag_category_ch_rapid_increase, aboverm_per_all_li_18, aboverm_per_all_li_90, aboverm_per_all_li_00)
# 0 itemset(s) from tree conditioned on items (change_flag_category_ch_rapid_increase, aboverm_per_all_li_18, aboverm_per_all_li_90, aboverm_per_nonwhite_90)
# 1 itemset(s) from tree conditioned on items (change_flag_category_ch_rapid_increase, aboverm_per_all_li_18, aboverm_per_rent_00)
# 1 itemset(s) from tree conditioned on items (change_flag_category_ch_rapid_increase, aboverm_per_all_li_18, hotmarket_18)
# 0 itemset(s) from tree conditioned on items (change_flag_category_ch_rapid_increase, aboverm_per_all_li_18, aboverm_per_nonwhite_00)
# 0 itemset(s) from tree conditioned on items (change_flag_category_ch_rapid_increase, aboverm_per_all_li_18, aboverm_per_rent_90)
# 0 itemset(s) from tree conditioned on items (change_flag_category_ch_rapid_increase, aboverm_per_all_li_18, dense)
# 13 itemset(s) from tree conditioned on items (house_rapid_increase)
# 0 itemset(s) from tree conditioned on items (house_rapid_increase, change_flag_category_ch_rapid_increase)
# 1 itemset(s) from tree conditioned on items (house_rapid_increase, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (house_rapid_increase, hotmarket_18)
# 3 itemset(s) from tree conditioned on items (house_rapid_increase, aboverm_per_nonwhite_90)
# 0 itemset(s) from tree conditioned on items (house_rapid_increase, aboverm_per_nonwhite_90, change_flag_category_ch_rapid_increase)
# 1 itemset(s) from tree conditioned on items (house_rapid_increase, aboverm_per_nonwhite_90, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (house_rapid_increase, aboverm_per_nonwhite_90, hotmarket_18)
# 4 itemset(s) from tree conditioned on items (house_rapid_increase, aboverm_per_all_li_90)
# 0 itemset(s) from tree conditioned on items (house_rapid_increase, aboverm_per_all_li_90, change_flag_category_ch_rapid_increase)
# 1 itemset(s) from tree conditioned on items (house_rapid_increase, aboverm_per_all_li_90, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (house_rapid_increase, aboverm_per_all_li_90, aboverm_per_nonwhite_90)
# 3 itemset(s) from tree conditioned on items (house_rapid_increase, aboverm_per_all_li_90, hotmarket_18)
# 0 itemset(s) from tree conditioned on items (house_rapid_increase, aboverm_per_all_li_90, hotmarket_18, change_flag_category_ch_rapid_increase)
# 1 itemset(s) from tree conditioned on items (house_rapid_increase, aboverm_per_all_li_90, hotmarket_18, aboverm_per_all_li_00)
# 1 itemset(s) from tree conditioned on items (house_rapid_increase, aboverm_per_all_li_90, hotmarket_18, aboverm_per_nonwhite_90)
# 5 itemset(s) from tree conditioned on items (house_rapid_increase, aboverm_per_nonwhite_00)
# 0 itemset(s) from tree conditioned on items (house_rapid_increase, aboverm_per_nonwhite_00, change_flag_category_ch_rapid_increase)
# 1 itemset(s) from tree conditioned on items (house_rapid_increase, aboverm_per_nonwhite_00, aboverm_per_nonwhite_90)
# 3 itemset(s) from tree conditioned on items (house_rapid_increase, aboverm_per_nonwhite_00, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (house_rapid_increase, aboverm_per_nonwhite_00, hotmarket_18)
# 0 itemset(s) from tree conditioned on items (house_rapid_increase, aboverm_per_nonwhite_00, hotmarket_18, change_flag_category_ch_rapid_increase)
# 1 itemset(s) from tree conditioned on items (house_rapid_increase, aboverm_per_nonwhite_00, hotmarket_18, aboverm_per_nonwhite_90)
# 3 itemset(s) from tree conditioned on items (house_rapid_increase, aboverm_per_nonwhite_00, hotmarket_18, aboverm_per_all_li_00)
# 4 itemset(s) from tree conditioned on items (house_rapid_increase, aboverm_per_nonwhite_00, aboverm_per_all_li_90)
# 0 itemset(s) from tree conditioned on items (house_rapid_increase, aboverm_per_nonwhite_00, aboverm_per_all_li_90, change_flag_category_ch_rapid_increase)
# 1 itemset(s) from tree conditioned on items (house_rapid_increase, aboverm_per_nonwhite_00, aboverm_per_all_li_90, aboverm_per_nonwhite_90)
# 3 itemset(s) from tree conditioned on items (house_rapid_increase, aboverm_per_nonwhite_00, aboverm_per_all_li_90, aboverm_per_all_li_00)
# 1 itemset(s) from tree conditioned on items (house_rapid_increase, aboverm_per_nonwhite_00, aboverm_per_all_li_90, hotmarket_18)
# 6 itemset(s) from tree conditioned on items (house_rapid_increase, dense)
# 0 itemset(s) from tree conditioned on items (house_rapid_increase, dense, change_flag_category_ch_rapid_increase)
# 1 itemset(s) from tree conditioned on items (house_rapid_increase, dense, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (house_rapid_increase, dense, aboverm_per_nonwhite_90)
# 3 itemset(s) from tree conditioned on items (house_rapid_increase, dense, aboverm_per_nonwhite_00)
# 1 itemset(s) from tree conditioned on items (house_rapid_increase, dense, hotmarket_18)
# 1 itemset(s) from tree conditioned on items (house_rapid_increase, dense, aboverm_per_all_li_90)
# 5 itemset(s) from tree conditioned on items (house_rapid_increase, ab_50pct_ch)
# 0 itemset(s) from tree conditioned on items (house_rapid_increase, ab_50pct_ch, change_flag_category_ch_rapid_increase)
# 1 itemset(s) from tree conditioned on items (house_rapid_increase, ab_50pct_ch, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (house_rapid_increase, ab_50pct_ch, hotmarket_18)
# 3 itemset(s) from tree conditioned on items (house_rapid_increase, ab_50pct_ch, aboverm_per_nonwhite_90)
# 1 itemset(s) from tree conditioned on items (house_rapid_increase, ab_50pct_ch, aboverm_per_all_li_90)
# 1 itemset(s) from tree conditioned on items (house_rapid_increase, aboverm_per_units_pre50_18)
# 7 itemset(s) from tree conditioned on items (house_rapid_increase, aboverm_per_rent_90)
# 0 itemset(s) from tree conditioned on items (house_rapid_increase, aboverm_per_rent_90, change_flag_category_ch_rapid_increase)
# 1 itemset(s) from tree conditioned on items (house_rapid_increase, aboverm_per_rent_90, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (house_rapid_increase, aboverm_per_rent_90, hotmarket_18)
# 0 itemset(s) from tree conditioned on items (house_rapid_increase, aboverm_per_rent_90, hotmarket_18, change_flag_category_ch_rapid_increase)
# 1 itemset(s) from tree conditioned on items (house_rapid_increase, aboverm_per_rent_90, hotmarket_18, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (house_rapid_increase, aboverm_per_rent_90, hotmarket_18, aboverm_per_rent_00)
# 3 itemset(s) from tree conditioned on items (house_rapid_increase, aboverm_per_rent_90, aboverm_per_nonwhite_90)
# 0 itemset(s) from tree conditioned on items (house_rapid_increase, aboverm_per_rent_90, aboverm_per_nonwhite_90, change_flag_category_ch_rapid_increase)
# 1 itemset(s) from tree conditioned on items (house_rapid_increase, aboverm_per_rent_90, aboverm_per_nonwhite_90, aboverm_per_all_li_00)
# 1 itemset(s) from tree conditioned on items (house_rapid_increase, aboverm_per_rent_90, aboverm_per_nonwhite_90, aboverm_per_rent_00)
# 3 itemset(s) from tree conditioned on items (house_rapid_increase, aboverm_per_rent_90, aboverm_per_all_li_90)
# 0 itemset(s) from tree conditioned on items (house_rapid_increase, aboverm_per_rent_90, aboverm_per_all_li_90, change_flag_category_ch_rapid_increase)
# 1 itemset(s) from tree conditioned on items (house_rapid_increase, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_all_li_00)
# 1 itemset(s) from tree conditioned on items (house_rapid_increase, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_rent_00)
# 1 itemset(s) from tree conditioned on items (house_rapid_increase, aboverm_per_rent_90, aboverm_per_nonwhite_00)
# 3 itemset(s) from tree conditioned on items (house_rapid_increase, aboverm_per_rent_90, aboverm_per_rent_00)
# 6 itemset(s) from tree conditioned on items (house_rapid_increase, aboverm_per_rent_00)
# 0 itemset(s) from tree conditioned on items (house_rapid_increase, aboverm_per_rent_00, change_flag_category_ch_rapid_increase)
# 1 itemset(s) from tree conditioned on items (house_rapid_increase, aboverm_per_rent_00, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (house_rapid_increase, aboverm_per_rent_00, hotmarket_18)
# 3 itemset(s) from tree conditioned on items (house_rapid_increase, aboverm_per_rent_00, aboverm_per_all_li_90)
# 3 itemset(s) from tree conditioned on items (house_rapid_increase, aboverm_per_rent_00, aboverm_per_nonwhite_90)
# 3 itemset(s) from tree conditioned on items (house_rapid_increase, aboverm_per_rent_00, aboverm_per_nonwhite_00)
# 0 itemset(s) from tree conditioned on items (house_rapid_increase, aboverm_per_rent_00, aboverm_per_nonwhite_00, change_flag_category_ch_rapid_increase)
# 1 itemset(s) from tree conditioned on items (house_rapid_increase, aboverm_per_rent_00, aboverm_per_nonwhite_00, aboverm_per_all_li_00)
# 1 itemset(s) from tree conditioned on items (house_rapid_increase, aboverm_per_rent_00, aboverm_per_nonwhite_00, aboverm_per_nonwhite_90)
# 3 itemset(s) from tree conditioned on items (house_rapid_increase, aboverm_per_rent_18)
# 0 itemset(s) from tree conditioned on items (house_rapid_increase, aboverm_per_rent_18, change_flag_category_ch_rapid_increase)
# 1 itemset(s) from tree conditioned on items (house_rapid_increase, aboverm_per_rent_18, aboverm_per_all_li_00)
# 1 itemset(s) from tree conditioned on items (house_rapid_increase, aboverm_per_rent_18, aboverm_per_rent_00)
# 1 itemset(s) from tree conditioned on items (house_rapid_increase, aboverm_per_all_li_18)
# 7 itemset(s) from tree conditioned on items (aboverm_pctch_real_mhval_00_18)
# 0 itemset(s) from tree conditioned on items (aboverm_pctch_real_mhval_00_18, house_rapid_increase)
# 1 itemset(s) from tree conditioned on items (aboverm_pctch_real_mhval_00_18, change_flag_category_ch_rapid_increase)
# 3 itemset(s) from tree conditioned on items (aboverm_pctch_real_mhval_00_18, hotmarket_18)
# 7 itemset(s) from tree conditioned on items (aboverm_pctch_real_mhval_00_18, aboverm_per_all_li_00)
# 15 itemset(s) from tree conditioned on items (aboverm_pctch_real_mhval_00_18, aboverm_per_nonwhite_90)
# 15 itemset(s) from tree conditioned on items (aboverm_pctch_real_mhval_00_18, aboverm_per_nonwhite_00)
# 7 itemset(s) from tree conditioned on items (aboverm_pctch_real_mhval_00_18, aboverm_per_all_li_90)
# 3 itemset(s) from tree conditioned on items (low_80120_00_dummy_VH)
# 7 itemset(s) from tree conditioned on items (per_all_li_00_dummy_VH)

# %%
frequent_itemsets.dtypes
# Out:
# support     float64
# itemsets     object
# dtype: object

# %%
import pickle 

filehandler = open("{}/data/freqitems_{}_{}".format(customized_path_to_homework, gent_class, file_name), 'wb') 
pickle.dump(frequent_itemsets, filehandler)

# %% [markdown]
# ### Gentrification Calculate Rule Metrics

# %%
import pickle 
filehandler = open("{}/data/freqitems_{}_{}".format(customized_path_to_homework, gent_class, file_name), 'rb') 
frequent_itemsets = pickle.load(filehandler)

# %%
frequent_itemsets.head(10)
# Out:
#     support                      itemsets
# 0  0.957447     (aboverm_per_nonwhite_90)
# 1  0.933131       (aboverm_per_all_li_00)
# 2  0.920973     (aboverm_per_nonwhite_00)
# 3  0.908815         (aboverm_per_rent_90)
# 4  0.905775                 (ab_50pct_ch)
# 5  0.884498         (aboverm_per_rent_00)
# 6  0.878419                       (dense)
# 7  0.844985       (aboverm_per_all_li_18)
# 8  0.841945  (aboverm_per_units_pre50_18)
# 9  0.832827         (aboverm_per_rent_18)

# %%
rules = association_rules(frequent_itemsets, metric='confidence', min_threshold=confidence_cut)
rules.head(10)
# Out:
#                                         antecedents  ... conviction
# 0                           (aboverm_per_all_li_00)  ...   1.088652
# 1                         (aboverm_per_nonwhite_90)  ...   1.053191
# 2                           (aboverm_per_all_li_00)  ...   0.977565
# 3                           (aboverm_per_all_li_90)  ...   0.977565
# 4    (aboverm_per_all_li_00, aboverm_per_all_li_90)  ...   1.217021
# 5  (aboverm_per_all_li_00, aboverm_per_nonwhite_90)  ...   1.038234
# 6  (aboverm_per_all_li_90, aboverm_per_nonwhite_90)  ...   1.038234
# 7                           (aboverm_per_all_li_00)  ...   1.023434
# 8                           (aboverm_per_all_li_90)  ...   1.023434
# 9                         (aboverm_per_nonwhite_90)  ...   1.055646
#
# [10 rows x 9 columns]

# %%
# save association rules
import pickle 

filehandler = open("{}/data/assocrules_{}_{}".format(customized_path_to_homework, gent_class, file_name), 'wb') 
pickle.dump(rules, filehandler)

# %% [markdown]
# **Rules with high Lift and Confidence**

# %%
#load association rules 
import pickle 
filehandler = open("{}/data/assocrules_{}_{}".format(customized_path_to_homework, gent_class, file_name), 'rb') 
rules = pickle.load(filehandler)

# %%
rules[ (rules['lift'] >= lift_cut) &
       (rules['conviction'] >= conviction_cut) ]
# Out:
#                                             antecedents  ... conviction
# 0                               (aboverm_per_all_li_00)  ...   1.088652
# 1                             (aboverm_per_nonwhite_90)  ...   1.053191
# 4        (aboverm_per_all_li_00, aboverm_per_all_li_90)  ...   1.217021
# 5      (aboverm_per_all_li_00, aboverm_per_nonwhite_90)  ...   1.038234
# 6      (aboverm_per_all_li_90, aboverm_per_nonwhite_90)  ...   1.038234
# ...                                                 ...  ...        ...
# 85995     (per_all_li_00_dummy_VH, aboverm_per_rent_00)  ...        inf
# 85996   (per_all_li_00_dummy_VH, low_80120_00_dummy_VH)  ...        inf
# 85997      (aboverm_per_rent_00, low_80120_00_dummy_VH)  ...        inf
# 85998                          (per_all_li_00_dummy_VH)  ...        inf
# 85999                           (low_80120_00_dummy_VH)  ...        inf
#
# [84892 rows x 9 columns]

# %% [markdown]
# ref: http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.150.6616&rep=rep1&type=pdf
#
# Confidence ranges from 0 to 1. Confidence is an estimate of Pr(C | A), the
# probability of observing C given A. After obtaining a rule set, one can immediatly
# use confidence as a basis for classifying one new case x. Of all the rules that
# apply to x (i.e., the rules whose antecedent is true in x), we choose the one
# with highest confidence. This loosely follows the optimal Bayes classifier

# %%
rules.nlargest(10, 'confidence')
# Out:
#                                              antecedents  ... conviction
# 25617  (aboverm_per_all_li_90, aboverm_per_rent_18, a...  ...        inf
# 25694  (aboverm_per_all_li_90, aboverm_per_nonwhite_9...  ...        inf
# 25749  (aboverm_per_all_li_90, aboverm_per_all_li_00,...  ...        inf
# 25859  (aboverm_per_all_li_90, aboverm_per_all_li_00,...  ...        inf
# 26900  (aboverm_per_all_li_90, aboverm_per_rent_18, a...  ...        inf
# 26954  (aboverm_per_all_li_90, aboverm_per_all_li_00,...  ...        inf
# 27137  (aboverm_per_all_li_90, aboverm_per_nonwhite_9...  ...        inf
# 27244  (aboverm_per_all_li_90, aboverm_per_all_li_00,...  ...        inf
# 27706  (aboverm_per_all_li_90, aboverm_per_nonwhite_0...  ...        inf
# 27855  (aboverm_per_all_li_90, aboverm_per_all_li_00,...  ...        inf
#
# [10 rows x 9 columns]

# %% [markdown]
# ref: http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.150.6616&rep=rep1&type=pdf
#
# Conviction is another measure proposed in [4] to tackle some of the weaknesses of confidence and lift. Unlike lift, conviction is sensitive to rule direction
# (conv(A → C) 6= conv(C → A)). Conviction is somewhat inspired in the logical
# definition of implication and attempts to measure the degree of implication of
# a rule. Conviction is infinite for logical implications (confidence 1), and is 1 if
# A and C are independent

# %%
rules.nlargest(10, 'conviction')
# Out:
#                                              antecedents  ... conviction
# 25617  (aboverm_per_all_li_90, aboverm_per_rent_18, a...  ...        inf
# 25694  (aboverm_per_all_li_90, aboverm_per_nonwhite_9...  ...        inf
# 25749  (aboverm_per_all_li_90, aboverm_per_all_li_00,...  ...        inf
# 25859  (aboverm_per_all_li_90, aboverm_per_all_li_00,...  ...        inf
# 26900  (aboverm_per_all_li_90, aboverm_per_rent_18, a...  ...        inf
# 26954  (aboverm_per_all_li_90, aboverm_per_all_li_00,...  ...        inf
# 27137  (aboverm_per_all_li_90, aboverm_per_nonwhite_9...  ...        inf
# 27244  (aboverm_per_all_li_90, aboverm_per_all_li_00,...  ...        inf
# 27706  (aboverm_per_all_li_90, aboverm_per_nonwhite_0...  ...        inf
# 27855  (aboverm_per_all_li_90, aboverm_per_all_li_00,...  ...        inf
#
# [10 rows x 9 columns]

# %% [markdown]
# ref: http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.150.6616&rep=rep1&type=pdf
#
# Lift measures how far from independence are A and C. It ranges within
# [0, +∞[. Values close to 1 imply that A and C are independent and the rule
# is not interesting.

# %%
rules.nlargest(10, 'lift')
# Out:
#                                            antecedents  ... conviction
# 85972                         (per_all_li_00_dummy_VH)  ...        inf
# 85973                          (low_80120_00_dummy_VH)  ...        inf
# 85976    (per_all_li_00_dummy_VH, aboverm_per_rent_00)  ...        inf
# 85978     (aboverm_per_rent_00, low_80120_00_dummy_VH)  ...        inf
# 85979                         (per_all_li_00_dummy_VH)  ...        inf
# 85980                          (low_80120_00_dummy_VH)  ...        inf
# 85981  (aboverm_per_all_li_00, per_all_li_00_dummy_VH)  ...        inf
# 85982   (aboverm_per_all_li_00, low_80120_00_dummy_VH)  ...        inf
# 85984                         (per_all_li_00_dummy_VH)  ...        inf
# 85985                          (low_80120_00_dummy_VH)  ...        inf
#
# [10 rows x 9 columns]

# %%
rules.nlargest(100, ['conviction', 'lift', 'confidence', 'support'])
# Out:
#                                              antecedents  ... conviction
# 85972                           (per_all_li_00_dummy_VH)  ...        inf
# 85973                            (low_80120_00_dummy_VH)  ...        inf
# 85976      (per_all_li_00_dummy_VH, aboverm_per_rent_00)  ...        inf
# 85978       (aboverm_per_rent_00, low_80120_00_dummy_VH)  ...        inf
# 85979                           (per_all_li_00_dummy_VH)  ...        inf
# ...                                                  ...  ...        ...
# 85849  (aboverm_pctch_real_mhval_00_18, aboverm_per_n...  ...        inf
# 83754                             (house_rapid_increase)  ...        inf
# 83769      (aboverm_per_all_li_00, house_rapid_increase)  ...        inf
# 83774               (house_rapid_increase, hotmarket_18)  ...        inf
# 83798    (aboverm_per_nonwhite_90, house_rapid_increase)  ...        inf
#
# [100 rows x 9 columns]

# %% [markdown]
# Plot Metrics

# %%
plt.scatter(rules['support'], rules['confidence'], alpha=0.5)
plt.xlabel('support')
plt.ylabel('confidence')
plt.title('Support vs Confidence')
plt.show()

# %%
plt.scatter(rules['support'], rules['lift'], alpha=0.5)
plt.xlabel('support')
plt.ylabel('lift')
plt.title('Support vs Lift')
plt.show()

# %%
fit = np.polyfit(rules['lift'], rules['confidence'], 1)
fit_fn = np.poly1d(fit)
plt.plot(rules['lift'], rules['confidence'], 'yo', rules['lift'], 
 fit_fn(rules['lift']))
# Out:
# [<matplotlib.lines.Line2D at 0x7f1123e9f048>,
#  <matplotlib.lines.Line2D at 0x7f1123e9f2e8>]

# %% [markdown]
# # **Association Analysis - Non Gentrified**

# %%
gent_class = 'nongent'

# %%
df_class = df3[df3['typology'].isin(['1', '2', '3'])].drop(['typology'], axis=1)
df_class = df_class.astype(bool)

# %%
frequent_itemsets = fpgrowth(df_class, min_support=support_cut, use_colnames=True, verbose=1)
# Out:
# 23 itemset(s) from tree conditioned on items ()
# 0 itemset(s) from tree conditioned on items (aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (ab_50pct_ch)
# 3 itemset(s) from tree conditioned on items (aboverm_per_rent_18)
# 0 itemset(s) from tree conditioned on items (aboverm_per_rent_18, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_rent_18, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_rent_18, ab_50pct_ch)
# 4 itemset(s) from tree conditioned on items (aboverm_per_all_li_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_all_li_90, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_all_li_90, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_all_li_90, ab_50pct_ch)
# 3 itemset(s) from tree conditioned on items (aboverm_per_all_li_90, aboverm_per_rent_18)
# 0 itemset(s) from tree conditioned on items (aboverm_per_all_li_90, aboverm_per_rent_18, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_all_li_90, aboverm_per_rent_18, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_all_li_90, aboverm_per_rent_18, ab_50pct_ch)
# 5 itemset(s) from tree conditioned on items (aboverm_per_rent_00)
# 0 itemset(s) from tree conditioned on items (aboverm_per_rent_00, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_rent_00, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_rent_00, aboverm_per_rent_18)
# 3 itemset(s) from tree conditioned on items (aboverm_per_rent_00, ab_50pct_ch)
# 0 itemset(s) from tree conditioned on items (aboverm_per_rent_00, ab_50pct_ch, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_rent_00, ab_50pct_ch, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_rent_00, ab_50pct_ch, aboverm_per_rent_18)
# 4 itemset(s) from tree conditioned on items (aboverm_per_rent_00, aboverm_per_all_li_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_rent_00, aboverm_per_all_li_90, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_rent_00, aboverm_per_all_li_90, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_rent_00, aboverm_per_all_li_90, aboverm_per_rent_18)
# 3 itemset(s) from tree conditioned on items (aboverm_per_rent_00, aboverm_per_all_li_90, ab_50pct_ch)
# 0 itemset(s) from tree conditioned on items (aboverm_per_rent_00, aboverm_per_all_li_90, ab_50pct_ch, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_rent_00, aboverm_per_all_li_90, ab_50pct_ch, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_rent_00, aboverm_per_all_li_90, ab_50pct_ch, aboverm_per_rent_18)
# 7 itemset(s) from tree conditioned on items (aboverm_per_rent_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_rent_90, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_rent_90, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_rent_90, aboverm_per_rent_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_rent_90, aboverm_per_rent_18)
# 0 itemset(s) from tree conditioned on items (aboverm_per_rent_90, aboverm_per_rent_18, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_rent_90, aboverm_per_rent_18, aboverm_per_rent_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_rent_90, aboverm_per_rent_18, aboverm_per_all_li_00)
# 4 itemset(s) from tree conditioned on items (aboverm_per_rent_90, ab_50pct_ch)
# 0 itemset(s) from tree conditioned on items (aboverm_per_rent_90, ab_50pct_ch, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_rent_90, ab_50pct_ch, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_rent_90, ab_50pct_ch, aboverm_per_rent_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_rent_90, ab_50pct_ch, aboverm_per_rent_18)
# 0 itemset(s) from tree conditioned on items (aboverm_per_rent_90, ab_50pct_ch, aboverm_per_rent_18, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_rent_90, ab_50pct_ch, aboverm_per_rent_18, aboverm_per_rent_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_rent_90, ab_50pct_ch, aboverm_per_rent_18, aboverm_per_all_li_00)
# 5 itemset(s) from tree conditioned on items (aboverm_per_rent_90, aboverm_per_all_li_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_rent_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_rent_18)
# 0 itemset(s) from tree conditioned on items (aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_rent_18, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_rent_18, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_rent_18, aboverm_per_rent_00)
# 4 itemset(s) from tree conditioned on items (aboverm_per_rent_90, aboverm_per_all_li_90, ab_50pct_ch)
# 0 itemset(s) from tree conditioned on items (aboverm_per_rent_90, aboverm_per_all_li_90, ab_50pct_ch, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_rent_90, aboverm_per_all_li_90, ab_50pct_ch, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_rent_90, aboverm_per_all_li_90, ab_50pct_ch, aboverm_per_rent_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_rent_90, aboverm_per_all_li_90, ab_50pct_ch, aboverm_per_rent_18)
# 0 itemset(s) from tree conditioned on items (aboverm_per_rent_90, aboverm_per_all_li_90, ab_50pct_ch, aboverm_per_rent_18, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_rent_90, aboverm_per_all_li_90, ab_50pct_ch, aboverm_per_rent_18, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_rent_90, aboverm_per_all_li_90, ab_50pct_ch, aboverm_per_rent_18, aboverm_per_rent_00)
# 6 itemset(s) from tree conditioned on items (aboverm_per_rent_90, aboverm_per_nonwhite_18)
# 0 itemset(s) from tree conditioned on items (aboverm_per_rent_90, aboverm_per_nonwhite_18, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_rent_90, aboverm_per_nonwhite_18, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_rent_90, aboverm_per_nonwhite_18, aboverm_per_rent_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_rent_90, aboverm_per_nonwhite_18, aboverm_per_rent_18)
# 0 itemset(s) from tree conditioned on items (aboverm_per_rent_90, aboverm_per_nonwhite_18, aboverm_per_rent_18, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_rent_90, aboverm_per_nonwhite_18, aboverm_per_rent_18, aboverm_per_rent_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_rent_90, aboverm_per_nonwhite_18, aboverm_per_rent_18, aboverm_per_all_li_00)
# 4 itemset(s) from tree conditioned on items (aboverm_per_rent_90, aboverm_per_nonwhite_18, aboverm_per_all_li_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_rent_90, aboverm_per_nonwhite_18, aboverm_per_all_li_90, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_rent_90, aboverm_per_nonwhite_18, aboverm_per_all_li_90, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_rent_90, aboverm_per_nonwhite_18, aboverm_per_all_li_90, aboverm_per_rent_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_rent_90, aboverm_per_nonwhite_18, aboverm_per_all_li_90, aboverm_per_rent_18)
# 0 itemset(s) from tree conditioned on items (aboverm_per_rent_90, aboverm_per_nonwhite_18, aboverm_per_all_li_90, aboverm_per_rent_18, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_rent_90, aboverm_per_nonwhite_18, aboverm_per_all_li_90, aboverm_per_rent_18, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_rent_90, aboverm_per_nonwhite_18, aboverm_per_all_li_90, aboverm_per_rent_18, aboverm_per_rent_00)
# 5 itemset(s) from tree conditioned on items (aboverm_per_rent_90, aboverm_per_nonwhite_18, ab_50pct_ch)
# 0 itemset(s) from tree conditioned on items (aboverm_per_rent_90, aboverm_per_nonwhite_18, ab_50pct_ch, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_rent_90, aboverm_per_nonwhite_18, ab_50pct_ch, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_rent_90, aboverm_per_nonwhite_18, ab_50pct_ch, aboverm_per_rent_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_rent_90, aboverm_per_nonwhite_18, ab_50pct_ch, aboverm_per_rent_18)
# 0 itemset(s) from tree conditioned on items (aboverm_per_rent_90, aboverm_per_nonwhite_18, ab_50pct_ch, aboverm_per_rent_18, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_rent_90, aboverm_per_nonwhite_18, ab_50pct_ch, aboverm_per_rent_18, aboverm_per_rent_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_rent_90, aboverm_per_nonwhite_18, ab_50pct_ch, aboverm_per_rent_18, aboverm_per_all_li_00)
# 4 itemset(s) from tree conditioned on items (aboverm_per_rent_90, aboverm_per_nonwhite_18, ab_50pct_ch, aboverm_per_all_li_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_rent_90, aboverm_per_nonwhite_18, ab_50pct_ch, aboverm_per_all_li_90, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_rent_90, aboverm_per_nonwhite_18, ab_50pct_ch, aboverm_per_all_li_90, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_rent_90, aboverm_per_nonwhite_18, ab_50pct_ch, aboverm_per_all_li_90, aboverm_per_rent_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_rent_90, aboverm_per_nonwhite_18, ab_50pct_ch, aboverm_per_all_li_90, aboverm_per_rent_18)
# 0 itemset(s) from tree conditioned on items (aboverm_per_rent_90, aboverm_per_nonwhite_18, ab_50pct_ch, aboverm_per_all_li_90, aboverm_per_rent_18, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_rent_90, aboverm_per_nonwhite_18, ab_50pct_ch, aboverm_per_all_li_90, aboverm_per_rent_18, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_rent_90, aboverm_per_nonwhite_18, ab_50pct_ch, aboverm_per_all_li_90, aboverm_per_rent_18, aboverm_per_rent_00)
# 8 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00)
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, ab_50pct_ch)
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, ab_50pct_ch, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, ab_50pct_ch, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, ab_50pct_ch, aboverm_per_nonwhite_18)
# 4 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_18)
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_18, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_18, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_18, ab_50pct_ch)
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_18, ab_50pct_ch, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_18, ab_50pct_ch, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_18, ab_50pct_ch, aboverm_per_nonwhite_18)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_18, aboverm_per_nonwhite_18)
# 5 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_all_li_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_all_li_90, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_all_li_90, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_all_li_90, ab_50pct_ch)
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_all_li_90, ab_50pct_ch, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_all_li_90, ab_50pct_ch, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_all_li_90, ab_50pct_ch, aboverm_per_nonwhite_18)
# 4 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_all_li_90, aboverm_per_rent_18)
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_all_li_90, aboverm_per_rent_18, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_all_li_90, aboverm_per_rent_18, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_all_li_90, aboverm_per_rent_18, ab_50pct_ch)
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_all_li_90, aboverm_per_rent_18, ab_50pct_ch, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_all_li_90, aboverm_per_rent_18, ab_50pct_ch, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_all_li_90, aboverm_per_rent_18, ab_50pct_ch, aboverm_per_nonwhite_18)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_all_li_90, aboverm_per_rent_18, aboverm_per_nonwhite_18)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_all_li_90, aboverm_per_nonwhite_18)
# 6 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_00)
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_00, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_00, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_00, aboverm_per_rent_18)
# 4 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_00, ab_50pct_ch)
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_00, ab_50pct_ch, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_00, ab_50pct_ch, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_00, ab_50pct_ch, aboverm_per_rent_18)
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_00, ab_50pct_ch, aboverm_per_rent_18, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_00, ab_50pct_ch, aboverm_per_rent_18, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_00, ab_50pct_ch, aboverm_per_rent_18, aboverm_per_nonwhite_18)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_00, ab_50pct_ch, aboverm_per_nonwhite_18)
# 5 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_00, aboverm_per_all_li_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_00, aboverm_per_all_li_90, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_00, aboverm_per_all_li_90, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_00, aboverm_per_all_li_90, aboverm_per_rent_18)
# 4 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_00, aboverm_per_all_li_90, ab_50pct_ch)
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_00, aboverm_per_all_li_90, ab_50pct_ch, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_00, aboverm_per_all_li_90, ab_50pct_ch, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_00, aboverm_per_all_li_90, ab_50pct_ch, aboverm_per_rent_18)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_00, aboverm_per_all_li_90, ab_50pct_ch, aboverm_per_nonwhite_18)
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_00, aboverm_per_all_li_90, ab_50pct_ch, aboverm_per_nonwhite_18, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_00, aboverm_per_all_li_90, ab_50pct_ch, aboverm_per_nonwhite_18, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_00, aboverm_per_all_li_90, ab_50pct_ch, aboverm_per_nonwhite_18, aboverm_per_rent_18)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_00, aboverm_per_all_li_90, aboverm_per_nonwhite_18)
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_00, aboverm_per_all_li_90, aboverm_per_nonwhite_18, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_00, aboverm_per_all_li_90, aboverm_per_nonwhite_18, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_00, aboverm_per_all_li_90, aboverm_per_nonwhite_18, aboverm_per_rent_18)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_00, aboverm_per_nonwhite_18)
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_00, aboverm_per_nonwhite_18, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_00, aboverm_per_nonwhite_18, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_00, aboverm_per_nonwhite_18, aboverm_per_rent_18)
# 7 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_rent_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_rent_18)
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_rent_18, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_rent_18, aboverm_per_rent_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_rent_18, aboverm_per_all_li_00)
# 5 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_all_li_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_rent_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_rent_18)
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_rent_18, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_rent_18, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_rent_18, aboverm_per_rent_00)
# 4 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_nonwhite_18)
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_nonwhite_18, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_nonwhite_18, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_nonwhite_18, aboverm_per_rent_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_nonwhite_18, aboverm_per_rent_18)
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_nonwhite_18, aboverm_per_rent_18, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_nonwhite_18, aboverm_per_rent_18, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_nonwhite_18, aboverm_per_rent_18, aboverm_per_rent_00)
# 6 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_90, ab_50pct_ch)
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_90, ab_50pct_ch, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_90, ab_50pct_ch, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_90, ab_50pct_ch, aboverm_per_rent_00)
# 4 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_90, ab_50pct_ch, aboverm_per_rent_18)
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_90, ab_50pct_ch, aboverm_per_rent_18, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_90, ab_50pct_ch, aboverm_per_rent_18, aboverm_per_rent_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_90, ab_50pct_ch, aboverm_per_rent_18, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_90, ab_50pct_ch, aboverm_per_rent_18, aboverm_per_nonwhite_18)
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_90, ab_50pct_ch, aboverm_per_rent_18, aboverm_per_nonwhite_18, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_90, ab_50pct_ch, aboverm_per_rent_18, aboverm_per_nonwhite_18, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_90, ab_50pct_ch, aboverm_per_rent_18, aboverm_per_nonwhite_18, aboverm_per_rent_00)
# 5 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_90, ab_50pct_ch, aboverm_per_all_li_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_90, ab_50pct_ch, aboverm_per_all_li_90, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_90, ab_50pct_ch, aboverm_per_all_li_90, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_90, ab_50pct_ch, aboverm_per_all_li_90, aboverm_per_rent_00)
# 4 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_90, ab_50pct_ch, aboverm_per_all_li_90, aboverm_per_rent_18)
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_90, ab_50pct_ch, aboverm_per_all_li_90, aboverm_per_rent_18, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_90, ab_50pct_ch, aboverm_per_all_li_90, aboverm_per_rent_18, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_90, ab_50pct_ch, aboverm_per_all_li_90, aboverm_per_rent_18, aboverm_per_rent_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_90, ab_50pct_ch, aboverm_per_all_li_90, aboverm_per_rent_18, aboverm_per_nonwhite_18)
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_90, ab_50pct_ch, aboverm_per_all_li_90, aboverm_per_rent_18, aboverm_per_nonwhite_18, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_90, ab_50pct_ch, aboverm_per_all_li_90, aboverm_per_rent_18, aboverm_per_nonwhite_18, aboverm_per_all_li_00)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_90, ab_50pct_ch, aboverm_per_all_li_90, aboverm_per_rent_18, aboverm_per_nonwhite_18, aboverm_per_rent_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_90, ab_50pct_ch, aboverm_per_all_li_90, aboverm_per_nonwhite_18)
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_90, ab_50pct_ch, aboverm_per_all_li_90, aboverm_per_nonwhite_18, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_90, ab_50pct_ch, aboverm_per_all_li_90, aboverm_per_nonwhite_18, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_90, ab_50pct_ch, aboverm_per_all_li_90, aboverm_per_nonwhite_18, aboverm_per_rent_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_90, ab_50pct_ch, aboverm_per_nonwhite_18)
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_90, ab_50pct_ch, aboverm_per_nonwhite_18, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_90, ab_50pct_ch, aboverm_per_nonwhite_18, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_90, ab_50pct_ch, aboverm_per_nonwhite_18, aboverm_per_rent_00)
# 4 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_nonwhite_18)
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_nonwhite_18, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_nonwhite_18, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_nonwhite_18, aboverm_per_rent_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_nonwhite_18, aboverm_per_rent_18)
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_nonwhite_18, aboverm_per_rent_18, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_nonwhite_18, aboverm_per_rent_18, aboverm_per_rent_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_nonwhite_18, aboverm_per_rent_18, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_00, aboverm_per_nonwhite_18)
# 9 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_nonwhite_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_all_li_00)
# 4 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, ab_50pct_ch)
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, ab_50pct_ch, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, ab_50pct_ch, aboverm_per_nonwhite_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, ab_50pct_ch, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, ab_50pct_ch, aboverm_per_nonwhite_18)
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, ab_50pct_ch, aboverm_per_nonwhite_18, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, ab_50pct_ch, aboverm_per_nonwhite_18, aboverm_per_nonwhite_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, ab_50pct_ch, aboverm_per_nonwhite_18, aboverm_per_all_li_00)
# 5 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_18)
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_18, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_18, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_18, aboverm_per_nonwhite_00)
# 4 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_18, ab_50pct_ch)
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_18, ab_50pct_ch, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_18, ab_50pct_ch, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_18, ab_50pct_ch, aboverm_per_nonwhite_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_18, ab_50pct_ch, aboverm_per_nonwhite_18)
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_18, ab_50pct_ch, aboverm_per_nonwhite_18, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_18, ab_50pct_ch, aboverm_per_nonwhite_18, aboverm_per_nonwhite_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_18, ab_50pct_ch, aboverm_per_nonwhite_18, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_18, aboverm_per_nonwhite_18)
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_18, aboverm_per_nonwhite_18, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_18, aboverm_per_nonwhite_18, aboverm_per_nonwhite_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_18, aboverm_per_nonwhite_18, aboverm_per_all_li_00)
# 6 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_all_li_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_all_li_90, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_all_li_90, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_all_li_90, aboverm_per_nonwhite_00)
# 4 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_all_li_90, ab_50pct_ch)
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_all_li_90, ab_50pct_ch, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_all_li_90, ab_50pct_ch, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_all_li_90, ab_50pct_ch, aboverm_per_nonwhite_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_all_li_90, ab_50pct_ch, aboverm_per_nonwhite_18)
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_all_li_90, ab_50pct_ch, aboverm_per_nonwhite_18, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_all_li_90, ab_50pct_ch, aboverm_per_nonwhite_18, aboverm_per_nonwhite_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_all_li_90, ab_50pct_ch, aboverm_per_nonwhite_18, aboverm_per_all_li_00)
# 5 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_all_li_90, aboverm_per_rent_18)
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_all_li_90, aboverm_per_rent_18, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_all_li_90, aboverm_per_rent_18, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_all_li_90, aboverm_per_rent_18, aboverm_per_nonwhite_00)
# 4 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_all_li_90, aboverm_per_rent_18, ab_50pct_ch)
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_all_li_90, aboverm_per_rent_18, ab_50pct_ch, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_all_li_90, aboverm_per_rent_18, ab_50pct_ch, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_all_li_90, aboverm_per_rent_18, ab_50pct_ch, aboverm_per_nonwhite_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_all_li_90, aboverm_per_rent_18, ab_50pct_ch, aboverm_per_nonwhite_18)
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_all_li_90, aboverm_per_rent_18, ab_50pct_ch, aboverm_per_nonwhite_18, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_all_li_90, aboverm_per_rent_18, ab_50pct_ch, aboverm_per_nonwhite_18, aboverm_per_nonwhite_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_all_li_90, aboverm_per_rent_18, ab_50pct_ch, aboverm_per_nonwhite_18, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_all_li_90, aboverm_per_rent_18, aboverm_per_nonwhite_18)
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_all_li_90, aboverm_per_rent_18, aboverm_per_nonwhite_18, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_all_li_90, aboverm_per_rent_18, aboverm_per_nonwhite_18, aboverm_per_nonwhite_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_all_li_90, aboverm_per_rent_18, aboverm_per_nonwhite_18, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_all_li_90, aboverm_per_nonwhite_18)
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_all_li_90, aboverm_per_nonwhite_18, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_all_li_90, aboverm_per_nonwhite_18, aboverm_per_nonwhite_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_all_li_90, aboverm_per_nonwhite_18, aboverm_per_all_li_00)
# 7 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_00)
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_00, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_00, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_00, aboverm_per_nonwhite_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_00, aboverm_per_rent_18)
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_00, aboverm_per_rent_18, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_00, aboverm_per_rent_18, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_00, aboverm_per_rent_18, aboverm_per_nonwhite_00)
# 5 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_00, ab_50pct_ch)
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_00, ab_50pct_ch, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_00, ab_50pct_ch, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_00, ab_50pct_ch, aboverm_per_nonwhite_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_00, ab_50pct_ch, aboverm_per_rent_18)
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_00, ab_50pct_ch, aboverm_per_rent_18, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_00, ab_50pct_ch, aboverm_per_rent_18, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_00, ab_50pct_ch, aboverm_per_rent_18, aboverm_per_nonwhite_00)
# 4 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_00, ab_50pct_ch, aboverm_per_nonwhite_18)
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_00, ab_50pct_ch, aboverm_per_nonwhite_18, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_00, ab_50pct_ch, aboverm_per_nonwhite_18, aboverm_per_nonwhite_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_00, ab_50pct_ch, aboverm_per_nonwhite_18, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_00, ab_50pct_ch, aboverm_per_nonwhite_18, aboverm_per_rent_18)
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_00, ab_50pct_ch, aboverm_per_nonwhite_18, aboverm_per_rent_18, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_00, ab_50pct_ch, aboverm_per_nonwhite_18, aboverm_per_rent_18, aboverm_per_nonwhite_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_00, ab_50pct_ch, aboverm_per_nonwhite_18, aboverm_per_rent_18, aboverm_per_all_li_00)
# 6 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_00, aboverm_per_all_li_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_00, aboverm_per_all_li_90, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_00, aboverm_per_all_li_90, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_00, aboverm_per_all_li_90, aboverm_per_nonwhite_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_00, aboverm_per_all_li_90, aboverm_per_rent_18)
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_00, aboverm_per_all_li_90, aboverm_per_rent_18, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_00, aboverm_per_all_li_90, aboverm_per_rent_18, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_00, aboverm_per_all_li_90, aboverm_per_rent_18, aboverm_per_nonwhite_00)
# 5 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_00, aboverm_per_all_li_90, ab_50pct_ch)
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_00, aboverm_per_all_li_90, ab_50pct_ch, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_00, aboverm_per_all_li_90, ab_50pct_ch, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_00, aboverm_per_all_li_90, ab_50pct_ch, aboverm_per_nonwhite_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_00, aboverm_per_all_li_90, ab_50pct_ch, aboverm_per_rent_18)
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_00, aboverm_per_all_li_90, ab_50pct_ch, aboverm_per_rent_18, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_00, aboverm_per_all_li_90, ab_50pct_ch, aboverm_per_rent_18, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_00, aboverm_per_all_li_90, ab_50pct_ch, aboverm_per_rent_18, aboverm_per_nonwhite_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_00, aboverm_per_all_li_90, ab_50pct_ch, aboverm_per_nonwhite_18)
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_00, aboverm_per_all_li_90, ab_50pct_ch, aboverm_per_nonwhite_18, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_00, aboverm_per_all_li_90, ab_50pct_ch, aboverm_per_nonwhite_18, aboverm_per_nonwhite_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_00, aboverm_per_all_li_90, ab_50pct_ch, aboverm_per_nonwhite_18, aboverm_per_all_li_00)
# 4 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_00, aboverm_per_all_li_90, aboverm_per_nonwhite_18)
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_00, aboverm_per_all_li_90, aboverm_per_nonwhite_18, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_00, aboverm_per_all_li_90, aboverm_per_nonwhite_18, aboverm_per_nonwhite_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_00, aboverm_per_all_li_90, aboverm_per_nonwhite_18, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_00, aboverm_per_all_li_90, aboverm_per_nonwhite_18, aboverm_per_rent_18)
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_00, aboverm_per_all_li_90, aboverm_per_nonwhite_18, aboverm_per_rent_18, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_00, aboverm_per_all_li_90, aboverm_per_nonwhite_18, aboverm_per_rent_18, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_00, aboverm_per_all_li_90, aboverm_per_nonwhite_18, aboverm_per_rent_18, aboverm_per_nonwhite_00)
# 4 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_00, aboverm_per_nonwhite_18)
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_00, aboverm_per_nonwhite_18, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_00, aboverm_per_nonwhite_18, aboverm_per_nonwhite_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_00, aboverm_per_nonwhite_18, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_00, aboverm_per_nonwhite_18, aboverm_per_rent_18)
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_00, aboverm_per_nonwhite_18, aboverm_per_rent_18, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_00, aboverm_per_nonwhite_18, aboverm_per_rent_18, aboverm_per_nonwhite_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_00, aboverm_per_nonwhite_18, aboverm_per_rent_18, aboverm_per_all_li_00)
# 8 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_90, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_90, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_90, aboverm_per_rent_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_90, aboverm_per_nonwhite_00)
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_90, aboverm_per_nonwhite_00, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_90, aboverm_per_nonwhite_00, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_90, aboverm_per_nonwhite_00, aboverm_per_rent_00)
# 4 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_90, aboverm_per_rent_18)
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_90, aboverm_per_rent_18, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_90, aboverm_per_rent_18, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_90, aboverm_per_rent_18, aboverm_per_rent_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_90, aboverm_per_rent_18, aboverm_per_nonwhite_00)
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_90, aboverm_per_rent_18, aboverm_per_nonwhite_00, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_90, aboverm_per_rent_18, aboverm_per_nonwhite_00, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_90, aboverm_per_rent_18, aboverm_per_nonwhite_00, aboverm_per_rent_00)
# 6 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_90, aboverm_per_all_li_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_rent_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_nonwhite_90, aboverm_per_rent_90, aboverm_per_all_li_90, aboverm_per_nonwhite_00)
# ...
# 0 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_00, aboverm_per_rent_00, aboverm_per_all_li_00)
# 1 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_00, aboverm_per_rent_00, aboverm_per_all_li_18)
# 3 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_00, aboverm_per_rent_00, aboverm_per_rent_18)
# 7 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_00, aboverm_per_rent_00, aboverm_per_nonwhite_18)
# 3 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_00, ab_50pct_ch)
# 0 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_00, ab_50pct_ch, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_00, ab_50pct_ch, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_00, ab_50pct_ch, aboverm_per_nonwhite_18)
# 5 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_00, aboverm_per_rent_90)
# 0 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_rent_00)
# 7 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_rent_18)
# 4 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_nonwhite_18)
# 0 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_nonwhite_18, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_nonwhite_18, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_nonwhite_18, aboverm_per_rent_00)
# 7 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_00, aboverm_per_rent_90, aboverm_per_nonwhite_18, aboverm_per_rent_18)
# 3 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_00, aboverm_per_all_li_90)
# 0 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_00, aboverm_per_all_li_90, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_00, aboverm_per_all_li_90, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_00, aboverm_per_all_li_90, aboverm_per_nonwhite_18)
# 3 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_00, low_pdmt_medhhinc_18)
# 0 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_00, low_pdmt_medhhinc_18, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_00, low_pdmt_medhhinc_18, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_00, low_pdmt_medhhinc_18, aboverm_per_nonwhite_18)
# 4 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_00, per_all_li_18_dummy_VH)
# 0 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_00, per_all_li_18_dummy_VH, low_pdmt_medhhinc_18)
# 1 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_00, per_all_li_18_dummy_VH, aboverm_per_all_li_18)
# 3 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_00, per_all_li_18_dummy_VH, aboverm_per_all_li_00)
# 7 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_00, per_all_li_18_dummy_VH, aboverm_per_nonwhite_18)
# 5 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_00, low_80120_18_dummy_VH)
# 0 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_00, low_80120_18_dummy_VH, per_all_li_18_dummy_VH)
# 1 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_00, low_80120_18_dummy_VH, low_pdmt_medhhinc_18)
# 3 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_00, low_80120_18_dummy_VH, aboverm_per_all_li_18)
# 7 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_00, low_80120_18_dummy_VH, aboverm_per_all_li_00)
# 15 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_00, low_80120_18_dummy_VH, aboverm_per_nonwhite_18)
# 12 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_90)
# 0 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_90, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_90, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_90, aboverm_per_nonwhite_00)
# 7 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_90, aboverm_per_nonwhite_18)
# 15 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_90, aboverm_per_rent_18)
# 5 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_90, aboverm_per_rent_00)
# 0 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_90, aboverm_per_rent_00, aboverm_per_all_li_00)
# 1 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_90, aboverm_per_rent_00, aboverm_per_all_li_18)
# 3 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_90, aboverm_per_rent_00, aboverm_per_nonwhite_00)
# 7 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_90, aboverm_per_rent_00, aboverm_per_rent_18)
# 15 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_90, aboverm_per_rent_00, aboverm_per_nonwhite_18)
# 4 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_90, ab_50pct_ch)
# 0 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_90, ab_50pct_ch, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_90, ab_50pct_ch, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_90, ab_50pct_ch, aboverm_per_nonwhite_00)
# 7 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_90, ab_50pct_ch, aboverm_per_nonwhite_18)
# 6 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_90, aboverm_per_rent_90)
# 0 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_90, aboverm_per_rent_90, aboverm_per_all_li_00)
# 1 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_90, aboverm_per_rent_90, aboverm_per_all_li_18)
# 3 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_90, aboverm_per_rent_90, aboverm_per_rent_00)
# 7 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_90, aboverm_per_rent_90, aboverm_per_nonwhite_00)
# 4 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_90, aboverm_per_rent_90, aboverm_per_rent_18)
# 0 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_90, aboverm_per_rent_90, aboverm_per_rent_18, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_90, aboverm_per_rent_90, aboverm_per_rent_18, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_90, aboverm_per_rent_90, aboverm_per_rent_18, aboverm_per_rent_00)
# 7 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_90, aboverm_per_rent_90, aboverm_per_rent_18, aboverm_per_nonwhite_00)
# 15 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_90, aboverm_per_rent_90, aboverm_per_nonwhite_18)
# 4 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_90, aboverm_per_all_li_90)
# 0 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_90, aboverm_per_all_li_90, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_90, aboverm_per_all_li_90, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_90, aboverm_per_all_li_90, aboverm_per_nonwhite_00)
# 7 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_90, aboverm_per_all_li_90, aboverm_per_nonwhite_18)
# 7 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_90, low_pdmt_medhhinc_18)
# 15 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_90, per_all_li_18_dummy_VH)
# 31 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, aboverm_per_nonwhite_90, low_80120_18_dummy_VH)
# 7 itemset(s) from tree conditioned on items (high_80120_18_dummy_VL, hv_abrm_ch)
# 11 itemset(s) from tree conditioned on items (aboverm_per_units_pre50_18)
# 0 itemset(s) from tree conditioned on items (aboverm_per_units_pre50_18, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_units_pre50_18, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_units_pre50_18, ab_50pct_ch)
# 3 itemset(s) from tree conditioned on items (aboverm_per_units_pre50_18, aboverm_per_all_li_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_units_pre50_18, aboverm_per_all_li_90, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_units_pre50_18, aboverm_per_all_li_90, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_units_pre50_18, aboverm_per_all_li_90, ab_50pct_ch)
# 4 itemset(s) from tree conditioned on items (aboverm_per_units_pre50_18, aboverm_per_nonwhite_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_units_pre50_18, aboverm_per_nonwhite_90, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_units_pre50_18, aboverm_per_nonwhite_90, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_units_pre50_18, aboverm_per_nonwhite_90, ab_50pct_ch)
# 3 itemset(s) from tree conditioned on items (aboverm_per_units_pre50_18, aboverm_per_nonwhite_90, aboverm_per_all_li_90)
# 5 itemset(s) from tree conditioned on items (aboverm_per_units_pre50_18, aboverm_per_nonwhite_00)
# 0 itemset(s) from tree conditioned on items (aboverm_per_units_pre50_18, aboverm_per_nonwhite_00, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_units_pre50_18, aboverm_per_nonwhite_00, aboverm_per_nonwhite_90)
# 3 itemset(s) from tree conditioned on items (aboverm_per_units_pre50_18, aboverm_per_nonwhite_00, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_units_pre50_18, aboverm_per_nonwhite_00, ab_50pct_ch)
# 0 itemset(s) from tree conditioned on items (aboverm_per_units_pre50_18, aboverm_per_nonwhite_00, ab_50pct_ch, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_units_pre50_18, aboverm_per_nonwhite_00, ab_50pct_ch, aboverm_per_nonwhite_90)
# 3 itemset(s) from tree conditioned on items (aboverm_per_units_pre50_18, aboverm_per_nonwhite_00, ab_50pct_ch, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_units_pre50_18, aboverm_per_nonwhite_00, aboverm_per_all_li_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_units_pre50_18, aboverm_per_nonwhite_00, aboverm_per_all_li_90, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_units_pre50_18, aboverm_per_nonwhite_00, aboverm_per_all_li_90, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_units_pre50_18, aboverm_per_nonwhite_00, aboverm_per_all_li_90, aboverm_per_nonwhite_90)
# 4 itemset(s) from tree conditioned on items (aboverm_per_units_pre50_18, aboverm_per_rent_18)
# 0 itemset(s) from tree conditioned on items (aboverm_per_units_pre50_18, aboverm_per_rent_18, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_units_pre50_18, aboverm_per_rent_18, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_units_pre50_18, aboverm_per_rent_18, ab_50pct_ch)
# 3 itemset(s) from tree conditioned on items (aboverm_per_units_pre50_18, aboverm_per_rent_18, aboverm_per_all_li_90)
# 5 itemset(s) from tree conditioned on items (aboverm_per_units_pre50_18, aboverm_per_rent_00)
# 0 itemset(s) from tree conditioned on items (aboverm_per_units_pre50_18, aboverm_per_rent_00, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_units_pre50_18, aboverm_per_rent_00, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_units_pre50_18, aboverm_per_rent_00, aboverm_per_rent_18)
# 3 itemset(s) from tree conditioned on items (aboverm_per_units_pre50_18, aboverm_per_rent_00, aboverm_per_all_li_90)
# 1 itemset(s) from tree conditioned on items (aboverm_per_units_pre50_18, aboverm_per_rent_00, ab_50pct_ch)
# 5 itemset(s) from tree conditioned on items (aboverm_per_units_pre50_18, aboverm_per_nonwhite_18)
# 0 itemset(s) from tree conditioned on items (aboverm_per_units_pre50_18, aboverm_per_nonwhite_18, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_units_pre50_18, aboverm_per_nonwhite_18, aboverm_per_nonwhite_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_units_pre50_18, aboverm_per_nonwhite_18, aboverm_per_all_li_00)
# 7 itemset(s) from tree conditioned on items (aboverm_per_units_pre50_18, aboverm_per_nonwhite_18, aboverm_per_nonwhite_90)
# 1 itemset(s) from tree conditioned on items (aboverm_per_units_pre50_18, aboverm_per_nonwhite_18, ab_50pct_ch)
# 5 itemset(s) from tree conditioned on items (aboverm_per_units_pre50_18, aboverm_per_rent_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_units_pre50_18, aboverm_per_rent_90, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_units_pre50_18, aboverm_per_rent_90, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_units_pre50_18, aboverm_per_rent_90, aboverm_per_rent_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_units_pre50_18, aboverm_per_rent_90, aboverm_per_rent_18)
# 0 itemset(s) from tree conditioned on items (aboverm_per_units_pre50_18, aboverm_per_rent_90, aboverm_per_rent_18, aboverm_per_all_li_18)
# 1 itemset(s) from tree conditioned on items (aboverm_per_units_pre50_18, aboverm_per_rent_90, aboverm_per_rent_18, aboverm_per_rent_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_units_pre50_18, aboverm_per_rent_90, aboverm_per_rent_18, aboverm_per_all_li_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_units_pre50_18, aboverm_per_rent_90, aboverm_per_all_li_90)
# 3 itemset(s) from tree conditioned on items (aboverm_per_units_pre50_18, hv_abrm_ch)
# 3 itemset(s) from tree conditioned on items (dense)

# %%
import pickle 

filehandler = open("{}/data/freqitems_{}_{}".format(customized_path_to_homework, gent_class, file_name), 'wb') 
pickle.dump(frequent_itemsets, filehandler)

# %% [markdown]
# ### Non-Gentrification Calculate Rule Metrics

# %%
import pickle 
filehandler = open("{}/data/freqitems_{}_{}".format(customized_path_to_homework, gent_class, file_name), 'rb') 
frequent_itemsets = pickle.load(filehandler)

# %%
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=confidence_cut)
rules.head(10)
# Out:
#                                       antecedents  ... conviction
# 0                         (aboverm_per_all_li_00)  ...        inf
# 1                         (aboverm_per_all_li_18)  ...   1.000000
# 2                         (aboverm_per_all_li_18)  ...   1.000000
# 3                                   (ab_50pct_ch)  ...        inf
# 4                         (aboverm_per_all_li_00)  ...   1.044776
# 5                                   (ab_50pct_ch)  ...   1.126541
# 6  (aboverm_per_all_li_00, aboverm_per_all_li_18)  ...   1.044776
# 7            (aboverm_per_all_li_00, ab_50pct_ch)  ...        inf
# 8            (aboverm_per_all_li_18, ab_50pct_ch)  ...   1.126541
# 9                         (aboverm_per_all_li_00)  ...   1.044776
#
# [10 rows x 9 columns]

# %%
# save association rules
import pickle 

filehandler = open("{}/data/assocrules_{}_{}".format(customized_path_to_homework, gent_class, file_name), 'wb') 
pickle.dump(rules, filehandler)

# %% [markdown]
# **Rules with high Lift and Confidence**

# %%
#load association rules 
import pickle 
filehandler = open("{}/data/assocrules_{}_{}".format(customized_path_to_homework, gent_class, file_name), 'rb') 
rules = pickle.load(filehandler)

# %%
rules.head(10)
# Out:
#                                       antecedents  ... conviction
# 0                         (aboverm_per_all_li_00)  ...        inf
# 1                         (aboverm_per_all_li_18)  ...   1.000000
# 2                         (aboverm_per_all_li_18)  ...   1.000000
# 3                                   (ab_50pct_ch)  ...        inf
# 4                         (aboverm_per_all_li_00)  ...   1.044776
# 5                                   (ab_50pct_ch)  ...   1.126541
# 6  (aboverm_per_all_li_00, aboverm_per_all_li_18)  ...   1.044776
# 7            (aboverm_per_all_li_00, ab_50pct_ch)  ...        inf
# 8            (aboverm_per_all_li_18, ab_50pct_ch)  ...   1.126541
# 9                         (aboverm_per_all_li_00)  ...   1.044776
#
# [10 rows x 9 columns]

# %%
rules[ (rules['lift'] >= lift_cut) &
       (rules['conviction'] >= conviction_cut) ]
# Out:
#                            antecedents  ... conviction
# 0              (aboverm_per_all_li_00)  ...        inf
# 1              (aboverm_per_all_li_18)  ...   1.000000
# 2              (aboverm_per_all_li_18)  ...   1.000000
# 3                        (ab_50pct_ch)  ...        inf
# 4              (aboverm_per_all_li_00)  ...   1.044776
# ...                                ...  ...        ...
# 223346                         (dense)  ...        inf
# 223347                         (dense)  ...   1.758209
# 223348  (aboverm_per_all_li_00, dense)  ...        inf
# 223349  (aboverm_per_all_li_18, dense)  ...   1.758209
# 223350                         (dense)  ...   1.758209
#
# [223249 rows x 9 columns]

# %%
#print( (rules.nlargest(100, ['conviction', 'lift', 'confidence', 'support']))[['antecedents', 'consequents']] )
rules.nlargest(100, ['conviction', 'lift', 'confidence', 'support'])
# Out:
#                                               antecedents  ... conviction
# 190220    (per_all_li_00_dummy_VH, low_80120_18_dummy_VH)  ...        inf
# 190221   (per_all_li_00_dummy_VH, per_all_li_18_dummy_VH)  ...        inf
# 190223     (low_80120_18_dummy_VH, low_80120_00_dummy_VH)  ...        inf
# 190224    (per_all_li_18_dummy_VH, low_80120_00_dummy_VH)  ...        inf
# 190316  (per_all_li_00_dummy_VH, low_pdmt_medhhinc_18,...  ...        inf
# ...                                                   ...  ...        ...
# 190762  (per_all_li_00_dummy_VH, aboverm_per_all_li_18...  ...        inf
# 190764  (aboverm_per_all_li_00, per_all_li_00_dummy_VH...  ...        inf
# 190767  (per_all_li_00_dummy_VH, low_80120_18_dummy_VH...  ...        inf
# 190770  (per_all_li_18_dummy_VH, low_pdmt_medhhinc_18,...  ...        inf
# 190772  (low_80120_18_dummy_VH, low_pdmt_medhhinc_18, ...  ...        inf
#
# [100 rows x 9 columns]

# %%
plt.scatter(rules['support'], rules['confidence'], alpha=0.5)
plt.xlabel('support')
plt.ylabel('confidence')
plt.title('Support vs Confidence')
plt.show()

# %%
plt.scatter(rules['support'], rules['lift'], alpha=0.5)
plt.xlabel('support')
plt.ylabel('lift')
plt.title('Support vs Lift')
plt.show()

# %%
fit = np.polyfit(rules['lift'], rules['confidence'], 1)
fit_fn = np.poly1d(fit)
plt.plot(rules['lift'], rules['confidence'], 'yo', rules['lift'], 
 fit_fn(rules['lift']))
# Out:
# [<matplotlib.lines.Line2D at 0x7f1126648320>,
#  <matplotlib.lines.Line2D at 0x7f1126648b38>]

# %% [markdown]
# ## Association Analysis - Stable/Exclusive

# %%
gent_class = 'exclusive'

# %%
df_class = df3[df3['typology'].isin([ '7', '8', '9'])].drop(['typology'], axis=1)
df_class = df_class.astype(bool)

# %%
frequent_itemsets = fpgrowth(df_class, min_support=support_cut, use_colnames=True, verbose=1)
# Out:
# 14 itemset(s) from tree conditioned on items ()
# 0 itemset(s) from tree conditioned on items (aboverm_real_mrent_12)
# 1 itemset(s) from tree conditioned on items (aboverm_real_mrent_00)
# 2 itemset(s) from tree conditioned on items (aboverm_per_col_00)
# 0 itemset(s) from tree conditioned on items (aboverm_per_col_00, aboverm_real_mrent_12)
# 1 itemset(s) from tree conditioned on items (aboverm_per_col_00, aboverm_real_mrent_00)
# 3 itemset(s) from tree conditioned on items (aboverm_real_mhval_00)
# 0 itemset(s) from tree conditioned on items (aboverm_real_mhval_00, aboverm_per_col_00)
# 1 itemset(s) from tree conditioned on items (aboverm_real_mhval_00, aboverm_real_mrent_00)
# 2 itemset(s) from tree conditioned on items (aboverm_real_mhval_00, aboverm_real_mrent_12)
# 0 itemset(s) from tree conditioned on items (aboverm_real_mhval_00, aboverm_real_mrent_12, aboverm_real_mrent_00)
# 0 itemset(s) from tree conditioned on items (aboverm_real_mhval_00, aboverm_real_mrent_12, aboverm_per_col_00)
# 4 itemset(s) from tree conditioned on items (aboverm_per_col_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_col_90, aboverm_per_col_00)
# 1 itemset(s) from tree conditioned on items (aboverm_per_col_90, aboverm_real_mhval_00)
# 2 itemset(s) from tree conditioned on items (aboverm_per_col_90, aboverm_real_mrent_12)
# 0 itemset(s) from tree conditioned on items (aboverm_per_col_90, aboverm_real_mrent_12, aboverm_per_col_00)
# 1 itemset(s) from tree conditioned on items (aboverm_per_col_90, aboverm_real_mrent_12, aboverm_real_mhval_00)
# 3 itemset(s) from tree conditioned on items (aboverm_per_col_90, aboverm_real_mrent_00)
# 0 itemset(s) from tree conditioned on items (aboverm_per_col_90, aboverm_real_mrent_00, aboverm_per_col_00)
# 1 itemset(s) from tree conditioned on items (aboverm_per_col_90, aboverm_real_mrent_00, aboverm_real_mhval_00)
# 1 itemset(s) from tree conditioned on items (aboverm_per_col_90, aboverm_real_mrent_00, aboverm_real_mrent_12)
# 5 itemset(s) from tree conditioned on items (aboverm_real_mrent_18)
# 0 itemset(s) from tree conditioned on items (aboverm_real_mrent_18, aboverm_real_mrent_12)
# 1 itemset(s) from tree conditioned on items (aboverm_real_mrent_18, aboverm_per_col_00)
# 2 itemset(s) from tree conditioned on items (aboverm_real_mrent_18, aboverm_real_mrent_00)
# 0 itemset(s) from tree conditioned on items (aboverm_real_mrent_18, aboverm_real_mrent_00, aboverm_real_mrent_12)
# 0 itemset(s) from tree conditioned on items (aboverm_real_mrent_18, aboverm_real_mrent_00, aboverm_per_col_00)
# 3 itemset(s) from tree conditioned on items (aboverm_real_mrent_18, aboverm_per_col_90)
# 0 itemset(s) from tree conditioned on items (aboverm_real_mrent_18, aboverm_per_col_90, aboverm_per_col_00)
# 1 itemset(s) from tree conditioned on items (aboverm_real_mrent_18, aboverm_per_col_90, aboverm_real_mrent_12)
# 0 itemset(s) from tree conditioned on items (aboverm_real_mrent_18, aboverm_per_col_90, aboverm_real_mrent_00)
# 4 itemset(s) from tree conditioned on items (aboverm_real_mrent_18, aboverm_real_mhval_00)
# 0 itemset(s) from tree conditioned on items (aboverm_real_mrent_18, aboverm_real_mhval_00, aboverm_real_mrent_12)
# 0 itemset(s) from tree conditioned on items (aboverm_real_mrent_18, aboverm_real_mhval_00, aboverm_per_col_00)
# 1 itemset(s) from tree conditioned on items (aboverm_real_mrent_18, aboverm_real_mhval_00, aboverm_real_mrent_00)
# 1 itemset(s) from tree conditioned on items (aboverm_real_mrent_18, aboverm_real_mhval_00, aboverm_per_col_90)
# 6 itemset(s) from tree conditioned on items (aboverm_per_col_18)
# 0 itemset(s) from tree conditioned on items (aboverm_per_col_18, aboverm_per_col_00)
# 1 itemset(s) from tree conditioned on items (aboverm_per_col_18, aboverm_per_col_90)
# 2 itemset(s) from tree conditioned on items (aboverm_per_col_18, aboverm_real_mhval_00)
# 0 itemset(s) from tree conditioned on items (aboverm_per_col_18, aboverm_real_mhval_00, aboverm_per_col_00)
# 1 itemset(s) from tree conditioned on items (aboverm_per_col_18, aboverm_real_mhval_00, aboverm_per_col_90)
# 3 itemset(s) from tree conditioned on items (aboverm_per_col_18, aboverm_real_mrent_12)
# 0 itemset(s) from tree conditioned on items (aboverm_per_col_18, aboverm_real_mrent_12, aboverm_per_col_00)
# 1 itemset(s) from tree conditioned on items (aboverm_per_col_18, aboverm_real_mrent_12, aboverm_per_col_90)
# 1 itemset(s) from tree conditioned on items (aboverm_per_col_18, aboverm_real_mrent_12, aboverm_real_mhval_00)
# 4 itemset(s) from tree conditioned on items (aboverm_per_col_18, aboverm_real_mrent_18)
# 0 itemset(s) from tree conditioned on items (aboverm_per_col_18, aboverm_real_mrent_18, aboverm_per_col_00)
# 1 itemset(s) from tree conditioned on items (aboverm_per_col_18, aboverm_real_mrent_18, aboverm_per_col_90)
# 2 itemset(s) from tree conditioned on items (aboverm_per_col_18, aboverm_real_mrent_18, aboverm_real_mrent_12)
# 0 itemset(s) from tree conditioned on items (aboverm_per_col_18, aboverm_real_mrent_18, aboverm_real_mrent_12, aboverm_per_col_00)
# 1 itemset(s) from tree conditioned on items (aboverm_per_col_18, aboverm_real_mrent_18, aboverm_real_mrent_12, aboverm_per_col_90)
# 1 itemset(s) from tree conditioned on items (aboverm_per_col_18, aboverm_real_mrent_18, aboverm_real_mhval_00)
# 5 itemset(s) from tree conditioned on items (aboverm_per_col_18, aboverm_real_mrent_00)
# 0 itemset(s) from tree conditioned on items (aboverm_per_col_18, aboverm_real_mrent_00, aboverm_per_col_00)
# 1 itemset(s) from tree conditioned on items (aboverm_per_col_18, aboverm_real_mrent_00, aboverm_per_col_90)
# 2 itemset(s) from tree conditioned on items (aboverm_per_col_18, aboverm_real_mrent_00, aboverm_real_mhval_00)
# 0 itemset(s) from tree conditioned on items (aboverm_per_col_18, aboverm_real_mrent_00, aboverm_real_mhval_00, aboverm_per_col_00)
# 1 itemset(s) from tree conditioned on items (aboverm_per_col_18, aboverm_real_mrent_00, aboverm_real_mhval_00, aboverm_per_col_90)
# 0 itemset(s) from tree conditioned on items (aboverm_per_col_18, aboverm_real_mrent_00, aboverm_real_mrent_12)
# 0 itemset(s) from tree conditioned on items (aboverm_per_col_18, aboverm_real_mrent_00, aboverm_real_mrent_18)
# 7 itemset(s) from tree conditioned on items (dp_PChRent)
# 0 itemset(s) from tree conditioned on items (dp_PChRent, aboverm_per_col_00)
# 1 itemset(s) from tree conditioned on items (dp_PChRent, aboverm_per_col_90)
# 2 itemset(s) from tree conditioned on items (dp_PChRent, aboverm_per_col_18)
# 0 itemset(s) from tree conditioned on items (dp_PChRent, aboverm_per_col_18, aboverm_per_col_00)
# 1 itemset(s) from tree conditioned on items (dp_PChRent, aboverm_per_col_18, aboverm_per_col_90)
# 3 itemset(s) from tree conditioned on items (dp_PChRent, aboverm_real_mrent_18)
# 0 itemset(s) from tree conditioned on items (dp_PChRent, aboverm_real_mrent_18, aboverm_per_col_00)
# 0 itemset(s) from tree conditioned on items (dp_PChRent, aboverm_real_mrent_18, aboverm_per_col_18)
# 0 itemset(s) from tree conditioned on items (dp_PChRent, aboverm_real_mrent_18, aboverm_per_col_90)
# 2 itemset(s) from tree conditioned on items (dp_PChRent, aboverm_real_mhval_00)
# 0 itemset(s) from tree conditioned on items (dp_PChRent, aboverm_real_mhval_00, aboverm_per_col_00)
# 0 itemset(s) from tree conditioned on items (dp_PChRent, aboverm_real_mhval_00, aboverm_per_col_90)
# 1 itemset(s) from tree conditioned on items (dp_PChRent, aboverm_real_mrent_12)
# 0 itemset(s) from tree conditioned on items (dp_PChRent, aboverm_real_mrent_00)
# 4 itemset(s) from tree conditioned on items (house_increase)
# 0 itemset(s) from tree conditioned on items (house_increase, aboverm_real_mrent_00)
# 0 itemset(s) from tree conditioned on items (house_increase, aboverm_real_mhval_00)
# 0 itemset(s) from tree conditioned on items (house_increase, aboverm_real_mrent_12)
# 0 itemset(s) from tree conditioned on items (house_increase, aboverm_per_col_00)
# 8 itemset(s) from tree conditioned on items (aboverm_real_mhval_18)
# 0 itemset(s) from tree conditioned on items (aboverm_real_mhval_18, aboverm_per_col_00)
# 1 itemset(s) from tree conditioned on items (aboverm_real_mhval_18, aboverm_per_col_90)
# 2 itemset(s) from tree conditioned on items (aboverm_real_mhval_18, aboverm_per_col_18)
# 0 itemset(s) from tree conditioned on items (aboverm_real_mhval_18, aboverm_per_col_18, aboverm_per_col_00)
# 1 itemset(s) from tree conditioned on items (aboverm_real_mhval_18, aboverm_per_col_18, aboverm_per_col_90)
# 3 itemset(s) from tree conditioned on items (aboverm_real_mhval_18, aboverm_real_mhval_00)
# 0 itemset(s) from tree conditioned on items (aboverm_real_mhval_18, aboverm_real_mhval_00, aboverm_per_col_00)
# 1 itemset(s) from tree conditioned on items (aboverm_real_mhval_18, aboverm_real_mhval_00, aboverm_per_col_90)
# 2 itemset(s) from tree conditioned on items (aboverm_real_mhval_18, aboverm_real_mhval_00, aboverm_per_col_18)
# 0 itemset(s) from tree conditioned on items (aboverm_real_mhval_18, aboverm_real_mhval_00, aboverm_per_col_18, aboverm_per_col_00)
# 1 itemset(s) from tree conditioned on items (aboverm_real_mhval_18, aboverm_real_mhval_00, aboverm_per_col_18, aboverm_per_col_90)
# 4 itemset(s) from tree conditioned on items (aboverm_real_mhval_18, aboverm_real_mrent_12)
# 0 itemset(s) from tree conditioned on items (aboverm_real_mhval_18, aboverm_real_mrent_12, aboverm_per_col_00)
# 1 itemset(s) from tree conditioned on items (aboverm_real_mhval_18, aboverm_real_mrent_12, aboverm_per_col_18)
# 1 itemset(s) from tree conditioned on items (aboverm_real_mhval_18, aboverm_real_mrent_12, aboverm_per_col_90)
# 0 itemset(s) from tree conditioned on items (aboverm_real_mhval_18, aboverm_real_mrent_12, aboverm_real_mhval_00)
# 4 itemset(s) from tree conditioned on items (aboverm_real_mhval_18, aboverm_real_mrent_18)
# 0 itemset(s) from tree conditioned on items (aboverm_real_mhval_18, aboverm_real_mrent_18, aboverm_per_col_00)
# 1 itemset(s) from tree conditioned on items (aboverm_real_mhval_18, aboverm_real_mrent_18, aboverm_per_col_18)
# 1 itemset(s) from tree conditioned on items (aboverm_real_mhval_18, aboverm_real_mrent_18, aboverm_per_col_90)
# 0 itemset(s) from tree conditioned on items (aboverm_real_mhval_18, aboverm_real_mrent_18, aboverm_real_mrent_12)
# 2 itemset(s) from tree conditioned on items (aboverm_real_mhval_18, aboverm_real_mrent_00)
# 0 itemset(s) from tree conditioned on items (aboverm_real_mhval_18, aboverm_real_mrent_00, aboverm_real_mhval_00)
# 0 itemset(s) from tree conditioned on items (aboverm_real_mhval_18, aboverm_real_mrent_00, aboverm_per_col_00)
# 1 itemset(s) from tree conditioned on items (aboverm_real_mhval_18, dp_PChRent)
# 2 itemset(s) from tree conditioned on items (aboverm_real_mhval_90)
# 0 itemset(s) from tree conditioned on items (aboverm_real_mhval_90, aboverm_real_mhval_00)
# 0 itemset(s) from tree conditioned on items (aboverm_real_mhval_90, aboverm_real_mrent_00)
# 1 itemset(s) from tree conditioned on items (aboverm_real_mrent_90)
# 7 itemset(s) from tree conditioned on items (high_pdmt_medhhinc_00)
# 0 itemset(s) from tree conditioned on items (high_pdmt_medhhinc_00, aboverm_real_mrent_12)
# 0 itemset(s) from tree conditioned on items (high_pdmt_medhhinc_00, aboverm_per_col_00)
# 0 itemset(s) from tree conditioned on items (high_pdmt_medhhinc_00, aboverm_real_mhval_00)
# 0 itemset(s) from tree conditioned on items (high_pdmt_medhhinc_00, aboverm_per_col_18)
# 0 itemset(s) from tree conditioned on items (high_pdmt_medhhinc_00, aboverm_per_col_90)
# 0 itemset(s) from tree conditioned on items (high_pdmt_medhhinc_00, aboverm_real_mrent_00)
# 0 itemset(s) from tree conditioned on items (high_pdmt_medhhinc_00, aboverm_real_mrent_18)
# 0 itemset(s) from tree conditioned on items (hotmarket_18)

# %%
import pickle 

filehandler = open("{}/data/freqitems_{}_{}".format(customized_path_to_homework, gent_class, file_name), 'wb') 
pickle.dump(frequent_itemsets, filehandler)

# %%
import pickle 
filehandler = open("{}/data/freqitems_{}_{}".format(customized_path_to_homework, gent_class, file_name), 'rb') 
frequent_itemsets = pickle.load(filehandler)

# %%
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=confidence_cut)
rules.head(10)
# Out:
#                                       antecedents  ... conviction
# 0                         (aboverm_real_mrent_00)  ...   1.748997
# 1                         (aboverm_real_mrent_12)  ...   1.743145
# 2                            (aboverm_per_col_00)  ...   1.441612
# 3                         (aboverm_real_mrent_12)  ...   1.417078
# 4                         (aboverm_real_mrent_00)  ...   1.303214
# 5                            (aboverm_per_col_00)  ...   1.317653
# 6     (aboverm_real_mrent_00, aboverm_per_col_00)  ...   2.236786
# 7  (aboverm_real_mrent_00, aboverm_real_mrent_12)  ...   1.532770
# 8     (aboverm_per_col_00, aboverm_real_mrent_12)  ...   1.934333
# 9                         (aboverm_real_mhval_00)  ...   2.050073
#
# [10 rows x 9 columns]

# %%
# save association rules
import pickle 

filehandler = open("{}/data/assocrules_{}_{}".format(customized_path_to_homework, gent_class, file_name), 'wb') 
pickle.dump(rules, filehandler)

# %%
#load association rules 
import pickle 
filehandler = open("{}/data/assocrules_{}_{}".format(customized_path_to_homework, gent_class, file_name), 'rb') 
rules = pickle.load(filehandler)

# %%
rules.head(10)
# Out:
#                                       antecedents  ... conviction
# 0                         (aboverm_real_mrent_00)  ...   1.748997
# 1                         (aboverm_real_mrent_12)  ...   1.743145
# 2                            (aboverm_per_col_00)  ...   1.441612
# 3                         (aboverm_real_mrent_12)  ...   1.417078
# 4                         (aboverm_real_mrent_00)  ...   1.303214
# 5                            (aboverm_per_col_00)  ...   1.317653
# 6     (aboverm_real_mrent_00, aboverm_per_col_00)  ...   2.236786
# 7  (aboverm_real_mrent_00, aboverm_real_mrent_12)  ...   1.532770
# 8     (aboverm_per_col_00, aboverm_real_mrent_12)  ...   1.934333
# 9                         (aboverm_real_mhval_00)  ...   2.050073
#
# [10 rows x 9 columns]

# %%
rules[ (rules['lift'] >= lift_cut) &
       (rules['conviction'] >= conviction_cut) ]
# Out:
#                  antecedents              consequents  ...  leverage  conviction
# 0    (aboverm_real_mrent_00)  (aboverm_real_mrent_12)  ...  0.067035    1.748997
# 1    (aboverm_real_mrent_12)  (aboverm_real_mrent_00)  ...  0.067035    1.743145
# 2       (aboverm_per_col_00)  (aboverm_real_mrent_12)  ...  0.047616    1.441612
# 3    (aboverm_real_mrent_12)     (aboverm_per_col_00)  ...  0.047616    1.417078
# 4    (aboverm_real_mrent_00)     (aboverm_per_col_00)  ...  0.037608    1.303214
# ..                       ...                      ...  ...       ...         ...
# 713  (high_pdmt_medhhinc_00)  (aboverm_real_mhval_00)  ...  0.081923    2.614556
# 714  (high_pdmt_medhhinc_00)     (aboverm_per_col_18)  ...  0.094670    2.840221
# 715  (high_pdmt_medhhinc_00)     (aboverm_per_col_90)  ...  0.084447    2.597735
# 716  (high_pdmt_medhhinc_00)  (aboverm_real_mrent_00)  ...  0.072815    2.307901
# 717  (high_pdmt_medhhinc_00)  (aboverm_real_mrent_18)  ...  0.087176    2.527201
#
# [717 rows x 9 columns]

# %%
rules.nlargest(100, ['conviction', 'lift', 'confidence', 'support'])
# Out:
#                                            antecedents  ... conviction
# 697     (aboverm_real_mrent_00, aboverm_real_mhval_18)  ...  29.695090
# 597  (aboverm_real_mhval_00, aboverm_per_col_90, ab...  ...  25.564784
# 526  (aboverm_per_col_90, aboverm_real_mhval_18, ab...  ...  23.699789
# 283  (aboverm_real_mrent_18, aboverm_per_col_90, ab...  ...  18.598309
# 321  (aboverm_real_mrent_18, aboverm_per_col_90, ab...  ...  17.573996
# ..                                                 ...  ...        ...
# 396  (aboverm_real_mrent_00, aboverm_per_col_18, ab...  ...   5.335157
# 252  (aboverm_real_mhval_00, aboverm_per_col_00, ab...  ...   5.251753
# 161  (aboverm_real_mhval_00, aboverm_real_mrent_00,...  ...   5.251586
# 539     (aboverm_real_mhval_00, aboverm_real_mhval_18)  ...   5.147992
# 310  (aboverm_real_mrent_18, aboverm_real_mrent_12,...  ...   5.141649
#
# [100 rows x 9 columns]
