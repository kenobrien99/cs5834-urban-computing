# %% [markdown]
# **CS 5834, Fall 2020: Intro to Urban Computing Project - STUCCO analysis for Gentrification using San Franciso Data Set**

# %% [markdown]
# ### Imports and Mount File Directories

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
# modify "customized_path_to_homework", path of folder in drive, where you project is stored
customized_path_to_homework = "/content/drive/My Drive/cs5834/urbcomp_fall2020/project"
file_name = "SanFrancisco_typology_output.csv"

sys.path.append(customized_path_to_homework)

# %%
# %cd $customized_path_to_homework/data
# Out:
# /content/drive/My Drive/cs5834/urbcomp_fall2020/project/data

# %%
import os, sys
import pandas as pd
import numpy as np
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
import datetime
import warnings

# %%
"""
sys.path.insert(0,'../')
# %load_ext autoreload
# %autoreload 2
import nyctaxi_helpers
warnings.filterwarnings('ignore')
"""
# Out:
# "\nsys.path.insert(0,'../')\n%load_ext autoreload\n%autoreload 2\nimport nyctaxi_helpers\nwarnings.filterwarnings('ignore')\n"

# %%
#pip install --upgrade mlxtend

# %%
#ref https://pbpython.com/market-basket-analysis.html


#may need to install mlxtend package - pip install mlxtend in console
import pandas as pd
# #from mlxtend.frequent_patterns import apriori
# from mlxtend.frequent_patterns import fpgrowth
# from mlxtend.frequent_patterns import association_rules

# %%
# !wget -nc https://raw.githubusercontent.com/parsahosseini/contrast/master/stucco.py
# Out:
# File ‘stucco.py’ already there; not retrieving.

# %% [markdown]
# # **Process Urban Displacement Model Data for Gentrificaiton**

# %% [markdown]
# Reference: https://www.urbandisplacement.org/open-source-project

# %% [markdown]
# Based on the work https://ww2.arb.ca.gov/sites/default/files/classic//research/apr/past/13-310.pdf?_ga=2.269282425.968981409.1605209194-851335111.1605209194
#
# **Developing a New
# Methodology for Analyzing
# Potential Displacement**
#
# University of California, Berkeley
#
# Principal Investigator:
# Karen Chapple
#
# https://ww3.arb.ca.gov/research/single-project.php?row_id=65188

# %% [markdown]
# ## **Obtain the Data**
#
# Data can be found at https://github.com/urban-displacement/displacement-typologies/blob/main/data/outputs/typologies/LosAngeles_typology_output.csv

# %%
download_file = ("https://raw.githubusercontent.com/urban-displacement/displacement-typologies/main/data/outputs/typologies/{}".format(file_name))

# %%
#!wget -nc $download_file

# %%
## Process Data - if data file already processed then can start at Associaton Rules section
# get the Data File

df = pd.read_csv("https://raw.githubusercontent.com/urban-displacement/displacement-typologies/main/data/outputs/typologies/{}".format(file_name), index_col=0)
#df = pd.read_csv("{}/data/{}".format(customized_path_to_homework, file_name), index_col=0)

# sneak peak in the data
df.head(10)
# Out:
#    pop_18  white_18   hh_18   hinc_18  ...  LISD  double_counted  typology   typ_cat
# 0  2772.0    1388.0  1108.0   55125.0  ...     1             1.0       1.0  ['LISD']
# 1  4127.0    2874.0  1550.0  100202.0  ...     0             1.0       6.0  ['SMMI']
# 2   722.0     396.0    37.0    6953.0  ...     0             1.0       3.0   ['ARG']
# 3  5070.0    3335.0  2045.0   40733.0  ...     1             1.0       1.0  ['LISD']
# 4  3338.0    1900.0  1628.0   33194.0  ...     0             1.0       2.0    ['OD']
# 5  4626.0    1591.0  2057.0   27663.0  ...     1             1.0       1.0  ['LISD']
# 6  2450.0    2123.0   929.0   54745.0  ...     1             1.0       1.0  ['LISD']
# 7  5908.0    4764.0  2692.0   94853.0  ...     0             1.0       7.0   ['ARE']
# 8  3471.0    2451.0  1574.0   60870.0  ...     0             1.0       2.0    ['OD']
# 9  2691.0    2230.0  1176.0  122000.0  ...     0             1.0       7.0   ['ARE']
#
# [10 rows x 305 columns]

# %%
df.columns
# Out:
# Index(['pop_18', 'white_18', 'hh_18', 'hinc_18', 'mhval_18', 'mhval_18_se',
#        'mrent_18', 'mrent_18_se', 'total_25_18', 'total_25_col_bd_18',
#        ...
#        'BE', 'SMMI', 'ARG', 'EOG', 'OD', 'OD_loss', 'LISD', 'double_counted',
#        'typology', 'typ_cat'],
#       dtype='object', length=305)

# %%
"""
# create a working copy of the data to process
df2 = df.copy()

#removed  'inc_cat_medhhinc_encoded18', 'inc_cat_medhhinc_encoded00',
df2 = df2[[ 'inc80_18',
 'inc120_18',
 'inc80_00',
 'inc120_00',
 'inc80_90',
 'low_80120_18',
 'mod_80120_18',
 'high_80120_18',
 'low_pdmt_medhhinc_18',
 'high_pdmt_medhhinc_18',
 'mod_pdmt_medhhinc_18',
 'mix_low_medhhinc_18',
 'mix_mod_medhhinc_18',
 'mix_high_medhhinc_18',

 'low_80120_00',
 'mod_80120_00',
 'high_80120_00',
 'low_pdmt_medhhinc_00',
 'high_pdmt_medhhinc_00',
 'mod_pdmt_medhhinc_00',
 'mix_low_medhhinc_00',
 'mix_mod_medhhinc_00',
 'mix_high_medhhinc_00',

 'per_all_li_90',
 'per_all_li_00',
 'per_all_li_18',
 'per_nonwhite_90',
 'per_nonwhite_00',
 'per_nonwhite_18',
 'per_rent_90',
 'per_rent_00',
 'per_rent_18',
 'per_col_90',
 'per_col_00',
 'per_col_18',
 'per_units_pre50_18',
 'per_limove_18',
 'per_limove_12',
 'lmh_flag_category',
 'pctch_real_mhval_00_18',
 'pctch_real_mrent_12_18',
 'rent_decrease',
 'rent_marginal',
 'rent_increase',
 'rent_rapid_increase',
 'house_decrease',
 'house_marginal',
 'house_increase',
 'house_rapid_increase',
 'tot_decrease',
 'tot_marginal',
 'tot_increase',
 'tot_rapid_increase',
 'change_flag_category',
 'per_ch_zillow_12_18',
 'ab_50pct_ch',
 'ab_90percentile_ch',
 'rent_50pct_ch',
 'rent_90percentile_ch',
 'hv_abrm_ch',
 'rent_abrm_ch',
 'pctch_real_mhval_90_00',
 'pctch_real_mrent_90_00',
 'pctch_real_hinc_90_00',
 'pctch_real_mrent_00_18',
 'pctch_real_hinc_00_18',
 'ch_per_col_90_00',
 'ch_per_col_00_18',
 'ch_per_limove_12_18',
 'aboverm_per_all_li_90',
 'aboverm_per_all_li_00',
 'aboverm_per_all_li_18',
 'aboverm_per_nonwhite_18',
 'aboverm_per_nonwhite_90',
 'aboverm_per_nonwhite_00',
 'aboverm_per_rent_90',
 'aboverm_per_rent_00',
 'aboverm_per_rent_18',
 'aboverm_per_col_90',
 'aboverm_per_col_00',
 'aboverm_per_col_18',
 'aboverm_real_mrent_90',
 'aboverm_real_mrent_00',
 'aboverm_real_mrent_12',
 'aboverm_real_mrent_18',
 'aboverm_real_mhval_90',
 'aboverm_real_mhval_00',
 'aboverm_real_mhval_18',
 'aboverm_pctch_real_mhval_00_18',
 'aboverm_pctch_real_mrent_00_18',
 'aboverm_pctch_real_mrent_12_18',
 'aboverm_pctch_real_mhval_90_00',
 'aboverm_pctch_real_mrent_90_00',
 'lostli_00',
 'lostli_18',
 'aboverm_pctch_real_hinc_90_00',
 'aboverm_pctch_real_hinc_00_18',
 'aboverm_ch_per_col_90_00',
 'aboverm_ch_per_col_00_18',
 'aboverm_per_units_pre50_18',
 'GEOID',
 'rail',
 'presence_ph_LIHTC',
 'hotmarket_00',
 'hotmarket_18',
 'dp_PChRent',
 'dp_RentGap',
 'dense',
 'typology']]


# drop rows which dont have a gentrification category
df2.dropna(subset=['typology'], inplace=True)
df2 = df2.set_index('GEOID')

#fill the nas
df2.fillna(0.0, inplace=True)


df2.head(10)
"""
# Out:
# "\n# create a working copy of the data to process\ndf2 = df.copy()\n\n#removed  'inc_cat_medhhinc_encoded18', 'inc_cat_medhhinc_encoded00',\ndf2 = df2[[ 'inc80_18',\n 'inc120_18',\n 'inc80_00',\n 'inc120_00',\n 'inc80_90',\n 'low_80120_18',\n 'mod_80120_18',\n 'high_80120_18',\n 'low_pdmt_medhhinc_18',\n 'high_pdmt_medhhinc_18',\n 'mod_pdmt_medhhinc_18',\n 'mix_low_medhhinc_18',\n 'mix_mod_medhhinc_18',\n 'mix_high_medhhinc_18',\n\n 'low_80120_00',\n 'mod_80120_00',\n 'high_80120_00',\n 'low_pdmt_medhhinc_00',\n 'high_pdmt_medhhinc_00',\n 'mod_pdmt_medhhinc_00',\n 'mix_low_medhhinc_00',\n 'mix_mod_medhhinc_00',\n 'mix_high_medhhinc_00',\n\n 'per_all_li_90',\n 'per_all_li_00',\n 'per_all_li_18',\n 'per_nonwhite_90',\n 'per_nonwhite_00',\n 'per_nonwhite_18',\n 'per_rent_90',\n 'per_rent_00',\n 'per_rent_18',\n 'per_col_90',\n 'per_col_00',\n 'per_col_18',\n 'per_units_pre50_18',\n 'per_limove_18',\n 'per_limove_12',\n 'lmh_flag_category',\n 'pctch_real_mhval_00_18',\n 'pctch_real_mrent_12_18',\n 'rent_decrease',\n 'rent_marginal',\n 'rent_increase',\n 'rent_rapid_increase',\n 'house_decrease',\n 'house_marginal',\n 'house_increase',\n 'house_rapid_increase',\n 'tot_decrease',\n 'tot_marginal',\n 'tot_increase',\n 'tot_rapid_increase',\n 'change_flag_category',\n 'per_ch_zillow_12_18',\n 'ab_50pct_ch',\n 'ab_90percentile_ch',\n 'rent_50pct_ch',\n 'rent_90percentile_ch',\n 'hv_abrm_ch',\n 'rent_abrm_ch',\n 'pctch_real_mhval_90_00',\n 'pctch_real_mrent_90_00',\n 'pctch_real_hinc_90_00',\n 'pctch_real_mrent_00_18',\n 'pctch_real_hinc_00_18',\n 'ch_per_col_90_00',\n 'ch_per_col_00_18',\n 'ch_per_limove_12_18',\n 'aboverm_per_all_li_90',\n 'aboverm_per_all_li_00',\n 'aboverm_per_all_li_18',\n 'aboverm_per_nonwhite_18',\n 'aboverm_per_nonwhite_90',\n 'aboverm_per_nonwhite_00',\n 'aboverm_per_rent_90',\n 'aboverm_per_rent_00',\n 'aboverm_per_rent_18',\n 'aboverm_per_col_90',\n 'aboverm_per_col_00',\n 'aboverm_per_col_18',\n 'aboverm_real_mrent_90',\n 'aboverm_real_mrent_00',\n 'aboverm_real_mrent_12',\n 'aboverm_real_mrent_18',\n 'aboverm_real_mhval_90',\n 'aboverm_real_mhval_00',\n 'aboverm_real_mhval_18',\n 'aboverm_pctch_real_mhval_00_18',\n 'aboverm_pctch_real_mrent_00_18',\n 'aboverm_pctch_real_mrent_12_18',\n 'aboverm_pctch_real_mhval_90_00',\n 'aboverm_pctch_real_mrent_90_00',\n 'lostli_00',\n 'lostli_18',\n 'aboverm_pctch_real_hinc_90_00',\n 'aboverm_pctch_real_hinc_00_18',\n 'aboverm_ch_per_col_90_00',\n 'aboverm_ch_per_col_00_18',\n 'aboverm_per_units_pre50_18',\n 'GEOID',\n 'rail',\n 'presence_ph_LIHTC',\n 'hotmarket_00',\n 'hotmarket_18',\n 'dp_PChRent',\n 'dp_RentGap',\n 'dense',\n 'typology']]\n\n\n# drop rows which dont have a gentrification category\ndf2.dropna(subset=['typology'], inplace=True)\ndf2 = df2.set_index('GEOID')\n\n#fill the nas\ndf2.fillna(0.0, inplace=True)\n\n\ndf2.head(10)\n"

# %%
# create a working copy of the data to process
df2 = df.copy()

"""
removed  'inc_cat_medhhinc_encoded18', 'inc_cat_medhhinc_encoded00', 
'inc80_18',
 'inc120_18',
 'inc80_00',
 'inc120_00',
 'inc80_90',
  'per_col_90',
 'per_col_00',
 'per_col_18',
  'tot_decrease',
 'tot_marginal',
 'tot_increase',
 'tot_rapid_increase',
  'pctch_real_mhval_90_00',
 'pctch_real_mrent_90_00',
 'pctch_real_mrent_00_18',
 'per_units_pre50_18',
  
"""

df2.head(10)
df2 = df2[[ 

 'low_80120_18',
 'mod_80120_18',
 'high_80120_18',
 'low_pdmt_medhhinc_18',
 'high_pdmt_medhhinc_18',
 'mod_pdmt_medhhinc_18',
 'mix_low_medhhinc_18',
 'mix_mod_medhhinc_18',
 'mix_high_medhhinc_18',

 'low_80120_00',
 'mod_80120_00',
 'high_80120_00',
 'low_pdmt_medhhinc_00',
 'high_pdmt_medhhinc_00',
 'mod_pdmt_medhhinc_00',
 'mix_low_medhhinc_00',
 'mix_mod_medhhinc_00',
 'mix_high_medhhinc_00',

 'per_all_li_90',
 'per_all_li_00',
 'per_all_li_18',
 'per_nonwhite_90',
 'per_nonwhite_00',
 'per_nonwhite_18',
 'per_rent_90',
 'per_rent_00',
 'per_rent_18',

 
 'per_limove_18',
 'per_limove_12',
 'lmh_flag_category',
 'pctch_real_mhval_00_18',
 'pctch_real_mrent_12_18',
 'rent_decrease',
 'rent_marginal',
 'rent_increase',
 'rent_rapid_increase',
 'house_decrease',
 'house_marginal',
 'house_increase',
 'house_rapid_increase',

 'change_flag_category',
 'per_ch_zillow_12_18',
 'ab_50pct_ch',
 'ab_90percentile_ch',
 'rent_50pct_ch',
 'rent_90percentile_ch',
 'hv_abrm_ch',
 'rent_abrm_ch',

 'pctch_real_hinc_90_00',
 
 'pctch_real_hinc_00_18',
 'ch_per_col_90_00',
 'ch_per_col_00_18',
 'ch_per_limove_12_18',
 'aboverm_per_all_li_90',
 'aboverm_per_all_li_00',
 'aboverm_per_all_li_18',
 'aboverm_per_nonwhite_18',
 'aboverm_per_nonwhite_90',
 'aboverm_per_nonwhite_00',
 'aboverm_per_rent_90',
 'aboverm_per_rent_00',
 'aboverm_per_rent_18',
 'aboverm_per_col_90',
 'aboverm_per_col_00',
 'aboverm_per_col_18',
 'aboverm_real_mrent_90',
 'aboverm_real_mrent_00',
 'aboverm_real_mrent_12',
 'aboverm_real_mrent_18',
 'aboverm_real_mhval_90',
 'aboverm_real_mhval_00',
 'aboverm_real_mhval_18',
 'aboverm_pctch_real_mhval_00_18',
 'aboverm_pctch_real_mrent_00_18',
 'aboverm_pctch_real_mrent_12_18',
 'aboverm_pctch_real_mhval_90_00',
 'aboverm_pctch_real_mrent_90_00',
 'lostli_00',
 'lostli_18',
 'aboverm_pctch_real_hinc_90_00',
 'aboverm_pctch_real_hinc_00_18',
 'aboverm_ch_per_col_90_00',
 'aboverm_ch_per_col_00_18',
 'aboverm_per_units_pre50_18',
 'GEOID',
 'rail',
 'presence_ph_LIHTC',
 'hotmarket_00',
 'hotmarket_18',
 'dp_PChRent',
 'dp_RentGap',
 'dense',
 'typology']]

# drop rows which dont have a gentrification category
df2.dropna(subset=['typology'], inplace=True)
df2 = df2.set_index('GEOID')

#fill the nas
df2.fillna(0.0, inplace=True)


df2.head(10)
# Out:
#             low_80120_18  mod_80120_18  ...  dense  typology
# GEOID                                   ...
# 6055200202      0.656685      0.119309  ...      0       1.0
# 6055200400      0.321536      0.220092  ...      0       6.0
# 6055200900      0.810811      0.189189  ...      0       3.0
# 6067006101      0.748241      0.084786  ...      0       1.0
# 6067006102      0.764552      0.110582  ...      0       2.0
# 6067006900      0.857817      0.053220  ...      0       1.0
# 6067008137      0.632070      0.176806  ...      0       1.0
# 6067008210      0.382446      0.165303  ...      0       7.0
# 6067008404      0.553044      0.192073  ...      0       2.0
# 6067008702      0.236779      0.157911  ...      0       7.0
#
# [10 rows x 92 columns]

# %% [markdown]
# ### Convert select continous variables to categorical and one hot encode

# %%
# # convert already dummy variables from float to int
# dummy_var_list = ['hotmarket_00', 'hotmarket_18', 'low_pdmt_medhhinc_00', 'high_pdmt_medhhinc_00', 'mod_pdmt_medhhinc_00',
#                   'mix_low_medhhinc_00', 'mix_mod_medhhinc_00',  'mix_high_medhhinc_00', 'low_pdmt_medhhinc_18', 'high_pdmt_medhhinc_18',
#                   'mod_pdmt_medhhinc_18', 'mix_low_medhhinc_18', 'mix_mod_medhhinc_18', 'mix_high_medhhinc_18', 'presence_ph_LIHTC',
#                   'typology']
# for dummycol in dummy_var_list:
#   df2.loc[:,(dummycol)] = df2[dummycol].astype(int, copy=False)

# %%
# use float variables to represent each categorical variable by dividing into quartiles
def convert_percents_to_dummy_vars(X):

    columns = X.columns

    bin_labels_4 = ['VL', 'L', 'H',  'VH']


    for i in range(0, len(columns)):
        if X[columns[i]].dtype=='float64':
          print("Processing: " + columns[i])

          X[columns[i]] = X[columns[i]].fillna(0)
          cat_label = "{}_cat".format(columns[i])
          dummy_label = "{}_dummy".format(columns[i])
          X[cat_label] = pd.qcut(X[columns[i]], 
                                 4,
                              precision=5,
                              duplicates = 'drop',
                              labels=bin_labels_4)
          X = pd.get_dummies(X, columns=[cat_label], prefix=[dummy_label])
          X = X.drop([columns[i]], axis=1)

    return X

# %%
# check if categorical then convert to dummy using label and onehot encoding
def convert_categorical_to_dummy_vars(X):

    from sklearn.preprocessing import LabelEncoder
    from sklearn.preprocessing import OneHotEncoder    

    columns = X.columns
    indices = X.index
    new_columns = []
    encoded_x = None

    for i in range(0, len(columns)):
        if X[columns[i]].dtype=='O':
          print("Processing: " + columns[i])


          label_encoder = LabelEncoder()
          le = label_encoder.fit(X[columns[i]].apply(str))
          for class_ in le.classes_:
              new_columns.append("{}_{}".format(columns[i],class_))
              
          feature = le.transform(X[columns[i]].apply(str))
          feature = feature.reshape(X.shape[0], 1)
          onehot_encoder = OneHotEncoder(sparse=False)
          onehot_encoder.fit(feature)
          feature = onehot_encoder.transform(feature)
          if encoded_x is None:
              encoded_x = feature
          else:
              encoded_x = np.concatenate((encoded_x, feature), axis=1)
          X = X.drop(columns[i], axis=1)
    new_columns.extend(X.columns)

    X = pd.DataFrame(np.concatenate((encoded_x,X),axis=1),index=indices,columns=new_columns)
    
    return X

# %% [markdown]
# ### Convert Percentage (floats) to Quartiles and Dummy Variables

# %%
# # process and save data all converted to one hot encoding
# df2 = convert_percents_to_dummy_vars(df2)

# %%
# df2 = convert_categorical_to_dummy_vars(df2)

# %% [markdown]
# iii. Save the dataset as a CSV file. The first line of the CSV file should be the attribute
# names as described in the previous question.

# %%
# df2.to_csv("{}/data/processed_{}".format(customized_path_to_homework, file_name))

# %% [markdown]
# # **STUCCO Rule Calculations**

# %%
# load already processed data 
# df3 = pd.read_csv("{}/data/processed_{}".format(customized_path_to_homework, file_name), index_col=0)
# df3 = df3.astype(int)

# %%
confidence_cut = 0.8
lift_cut = 1.0
conviction_cut = 0.8
support_cut = 0.65

# %%
#ref: https://www.ics.uci.edu/~pazzani/Publications/stucco.pdf
#ref: https://github.com/parsahosseini/contrast/blob/master/README.md

# %%
from stucco import ContrastSetLearner
learner = ContrastSetLearner(df2, group_feature='typology')
# Out:
# INFO:root:User-defined feature is 'typology'
# INFO:root:Data dimensions: 2,064 x 92
# INFO:root:Reading object features (n=3)
# INFO:root:Reading numeric features (n=89)
# INFO:root:34 features lack value; dropping
# INFO:root:New data dimensions: 2,064 x 58
# INFO:root:Record count (pre-index): 2,064
# INFO:root:Record count (index): 2,062

# %%
# derive 3-length combinations of a rule and enumerate their abundance.
learner.learn(max_length=3)
# Out:
# INFO:root:Enumerating 2,062 item-sets, i
# INFO:root:i=0; n(matrix)=0
# INFO:root:i=200; n(matrix)=362,974
# INFO:root:i=400; n(matrix)=387,283
# INFO:root:i=600; n(matrix)=391,371
# INFO:root:i=800; n(matrix)=445,257
# INFO:root:i=1000; n(matrix)=450,811
# INFO:root:i=1200; n(matrix)=454,184
# INFO:root:i=1400; n(matrix)=455,046
# INFO:root:i=1600; n(matrix)=456,332
# INFO:root:i=1800; n(matrix)=456,643
# INFO:root:i=2000; n(matrix)=463,106
# INFO:root:463,415 contingency matrices made
# INFO:root:i=0 matrix not-rules enumerated
# INFO:root:i=2500 matrix not-rules enumerated
# INFO:root:i=5000 matrix not-rules enumerated
# INFO:root:i=7500 matrix not-rules enumerated
# INFO:root:i=10000 matrix not-rules enumerated
# INFO:root:i=12500 matrix not-rules enumerated
# INFO:root:i=15000 matrix not-rules enumerated
# INFO:root:i=17500 matrix not-rules enumerated
# INFO:root:i=20000 matrix not-rules enumerated
# INFO:root:i=22500 matrix not-rules enumerated
# INFO:root:i=25000 matrix not-rules enumerated
# INFO:root:i=27500 matrix not-rules enumerated
# INFO:root:i=30000 matrix not-rules enumerated
# INFO:root:i=32500 matrix not-rules enumerated
# INFO:root:i=35000 matrix not-rules enumerated
# INFO:root:i=37500 matrix not-rules enumerated
# INFO:root:i=40000 matrix not-rules enumerated
# INFO:root:i=42500 matrix not-rules enumerated
# INFO:root:i=45000 matrix not-rules enumerated
# INFO:root:i=47500 matrix not-rules enumerated
# INFO:root:i=50000 matrix not-rules enumerated
# INFO:root:i=52500 matrix not-rules enumerated
# INFO:root:i=55000 matrix not-rules enumerated
# INFO:root:i=57500 matrix not-rules enumerated
# INFO:root:i=60000 matrix not-rules enumerated
# INFO:root:i=62500 matrix not-rules enumerated
# INFO:root:i=65000 matrix not-rules enumerated
# INFO:root:i=67500 matrix not-rules enumerated
# INFO:root:i=70000 matrix not-rules enumerated
# INFO:root:i=72500 matrix not-rules enumerated
# INFO:root:i=75000 matrix not-rules enumerated
# INFO:root:i=77500 matrix not-rules enumerated
# INFO:root:i=80000 matrix not-rules enumerated
# INFO:root:i=82500 matrix not-rules enumerated
# INFO:root:i=85000 matrix not-rules enumerated
# INFO:root:i=87500 matrix not-rules enumerated
# INFO:root:i=90000 matrix not-rules enumerated
# INFO:root:i=92500 matrix not-rules enumerated
# INFO:root:i=95000 matrix not-rules enumerated
# INFO:root:i=97500 matrix not-rules enumerated
# INFO:root:i=100000 matrix not-rules enumerated
# INFO:root:i=102500 matrix not-rules enumerated
# INFO:root:i=105000 matrix not-rules enumerated
# INFO:root:i=107500 matrix not-rules enumerated
# INFO:root:i=110000 matrix not-rules enumerated
# INFO:root:i=112500 matrix not-rules enumerated
# INFO:root:i=115000 matrix not-rules enumerated
# INFO:root:i=117500 matrix not-rules enumerated
# INFO:root:i=120000 matrix not-rules enumerated
# INFO:root:i=122500 matrix not-rules enumerated
# INFO:root:i=125000 matrix not-rules enumerated
# INFO:root:i=127500 matrix not-rules enumerated
# INFO:root:i=130000 matrix not-rules enumerated
# INFO:root:i=132500 matrix not-rules enumerated
# INFO:root:i=135000 matrix not-rules enumerated
# INFO:root:i=137500 matrix not-rules enumerated
# INFO:root:i=140000 matrix not-rules enumerated
# INFO:root:i=142500 matrix not-rules enumerated
# INFO:root:i=145000 matrix not-rules enumerated
# INFO:root:i=147500 matrix not-rules enumerated
# INFO:root:i=150000 matrix not-rules enumerated
# INFO:root:i=152500 matrix not-rules enumerated
# INFO:root:i=155000 matrix not-rules enumerated
# INFO:root:i=157500 matrix not-rules enumerated
# INFO:root:i=160000 matrix not-rules enumerated
# INFO:root:i=162500 matrix not-rules enumerated
# INFO:root:i=165000 matrix not-rules enumerated
# INFO:root:i=167500 matrix not-rules enumerated
# INFO:root:i=170000 matrix not-rules enumerated
# INFO:root:i=172500 matrix not-rules enumerated
# INFO:root:i=175000 matrix not-rules enumerated
# INFO:root:i=177500 matrix not-rules enumerated
# INFO:root:i=180000 matrix not-rules enumerated
# INFO:root:i=182500 matrix not-rules enumerated
# INFO:root:i=185000 matrix not-rules enumerated
# INFO:root:i=187500 matrix not-rules enumerated
# INFO:root:i=190000 matrix not-rules enumerated
# INFO:root:i=192500 matrix not-rules enumerated
# INFO:root:i=195000 matrix not-rules enumerated
# INFO:root:i=197500 matrix not-rules enumerated
# INFO:root:i=200000 matrix not-rules enumerated
# INFO:root:i=202500 matrix not-rules enumerated
# INFO:root:i=205000 matrix not-rules enumerated
# INFO:root:i=207500 matrix not-rules enumerated
# INFO:root:i=210000 matrix not-rules enumerated
# INFO:root:i=212500 matrix not-rules enumerated
# INFO:root:i=215000 matrix not-rules enumerated
# INFO:root:i=217500 matrix not-rules enumerated
# INFO:root:i=220000 matrix not-rules enumerated
# INFO:root:i=222500 matrix not-rules enumerated
# INFO:root:i=225000 matrix not-rules enumerated
# INFO:root:i=227500 matrix not-rules enumerated
# INFO:root:i=230000 matrix not-rules enumerated
# INFO:root:i=232500 matrix not-rules enumerated
# INFO:root:i=235000 matrix not-rules enumerated
# INFO:root:i=237500 matrix not-rules enumerated
# INFO:root:i=240000 matrix not-rules enumerated
# INFO:root:i=242500 matrix not-rules enumerated
# INFO:root:i=245000 matrix not-rules enumerated
# INFO:root:i=247500 matrix not-rules enumerated
# INFO:root:i=250000 matrix not-rules enumerated
# INFO:root:i=252500 matrix not-rules enumerated
# INFO:root:i=255000 matrix not-rules enumerated
# INFO:root:i=257500 matrix not-rules enumerated
# INFO:root:i=260000 matrix not-rules enumerated
# INFO:root:i=262500 matrix not-rules enumerated
# INFO:root:i=265000 matrix not-rules enumerated
# INFO:root:i=267500 matrix not-rules enumerated
# INFO:root:i=270000 matrix not-rules enumerated
# INFO:root:i=272500 matrix not-rules enumerated
# INFO:root:i=275000 matrix not-rules enumerated
# INFO:root:i=277500 matrix not-rules enumerated
# INFO:root:i=280000 matrix not-rules enumerated
# INFO:root:i=282500 matrix not-rules enumerated
# INFO:root:i=285000 matrix not-rules enumerated
# INFO:root:i=287500 matrix not-rules enumerated
# INFO:root:i=290000 matrix not-rules enumerated
# INFO:root:i=292500 matrix not-rules enumerated
# INFO:root:i=295000 matrix not-rules enumerated
# INFO:root:i=297500 matrix not-rules enumerated
# INFO:root:i=300000 matrix not-rules enumerated
# INFO:root:i=302500 matrix not-rules enumerated
# INFO:root:i=305000 matrix not-rules enumerated
# INFO:root:i=307500 matrix not-rules enumerated
# INFO:root:i=310000 matrix not-rules enumerated
# INFO:root:i=312500 matrix not-rules enumerated
# INFO:root:i=315000 matrix not-rules enumerated
# INFO:root:i=317500 matrix not-rules enumerated
# INFO:root:i=320000 matrix not-rules enumerated
# INFO:root:i=322500 matrix not-rules enumerated
# INFO:root:i=325000 matrix not-rules enumerated
# INFO:root:i=327500 matrix not-rules enumerated
# INFO:root:i=330000 matrix not-rules enumerated
# INFO:root:i=332500 matrix not-rules enumerated
# INFO:root:i=335000 matrix not-rules enumerated
# INFO:root:i=337500 matrix not-rules enumerated
# INFO:root:i=340000 matrix not-rules enumerated
# INFO:root:i=342500 matrix not-rules enumerated
# INFO:root:i=345000 matrix not-rules enumerated
# INFO:root:i=347500 matrix not-rules enumerated
# INFO:root:i=350000 matrix not-rules enumerated
# INFO:root:i=352500 matrix not-rules enumerated
# INFO:root:i=355000 matrix not-rules enumerated
# INFO:root:i=357500 matrix not-rules enumerated
# INFO:root:i=360000 matrix not-rules enumerated
# INFO:root:i=362500 matrix not-rules enumerated
# INFO:root:i=365000 matrix not-rules enumerated
# INFO:root:i=367500 matrix not-rules enumerated
# INFO:root:i=370000 matrix not-rules enumerated
# INFO:root:i=372500 matrix not-rules enumerated
# INFO:root:i=375000 matrix not-rules enumerated
# INFO:root:i=377500 matrix not-rules enumerated
# INFO:root:i=380000 matrix not-rules enumerated
# INFO:root:i=382500 matrix not-rules enumerated
# INFO:root:i=385000 matrix not-rules enumerated
# INFO:root:i=387500 matrix not-rules enumerated
# INFO:root:i=390000 matrix not-rules enumerated
# INFO:root:i=392500 matrix not-rules enumerated
# INFO:root:i=395000 matrix not-rules enumerated
# INFO:root:i=397500 matrix not-rules enumerated
# INFO:root:i=400000 matrix not-rules enumerated
# INFO:root:i=402500 matrix not-rules enumerated
# INFO:root:i=405000 matrix not-rules enumerated
# INFO:root:i=407500 matrix not-rules enumerated
# INFO:root:i=410000 matrix not-rules enumerated
# INFO:root:i=412500 matrix not-rules enumerated
# INFO:root:i=415000 matrix not-rules enumerated
# INFO:root:i=417500 matrix not-rules enumerated
# INFO:root:i=420000 matrix not-rules enumerated
# INFO:root:i=422500 matrix not-rules enumerated
# INFO:root:i=425000 matrix not-rules enumerated
# INFO:root:i=427500 matrix not-rules enumerated
# INFO:root:i=430000 matrix not-rules enumerated
# INFO:root:i=432500 matrix not-rules enumerated
# INFO:root:i=435000 matrix not-rules enumerated
# INFO:root:i=437500 matrix not-rules enumerated
# INFO:root:i=440000 matrix not-rules enumerated
# INFO:root:i=442500 matrix not-rules enumerated
# INFO:root:i=445000 matrix not-rules enumerated
# INFO:root:i=447500 matrix not-rules enumerated
# INFO:root:i=450000 matrix not-rules enumerated
# INFO:root:i=452500 matrix not-rules enumerated
# INFO:root:i=455000 matrix not-rules enumerated
# INFO:root:i=457500 matrix not-rules enumerated
# INFO:root:i=460000 matrix not-rules enumerated
# INFO:root:i=462500 matrix not-rules enumerated
# 463415

# %%
output = learner.score(min_lift=3)
# Out:
# Streaming output truncated to the last 5000 lines.
# INFO:root:399067 / 463415: {'rule': ('high_80120_00=>(0.5639943680683175, 1.0)', 'pctch_real_mrent_12_18=>(0.2164448712672062, 3.1496504993958303)', 'aboverm_per_units_pre50_18=>0'), 'group': 'typology=>9.0', 'lift': 3.3524659863945576}
# INFO:root:399069 / 463415: {'rule': ('high_80120_00=>(0.5639943680683175, 1.0)', 'pctch_real_mrent_12_18=>(0.2164448712672062, 3.1496504993958303)', 'hotmarket_00=>1.0'), 'group': 'typology=>9.0', 'lift': 3.5963758872207503}
# INFO:root:399070 / 463415: {'rule': ('high_80120_00=>(0.5639943680683175, 1.0)', 'pctch_real_mrent_12_18=>(0.2164448712672062, 3.1496504993958303)', 'dp_RentGap=>0'), 'group': 'typology=>9.0', 'lift': 3.133221446067314}
# INFO:root:399074 / 463415: {'rule': ('high_80120_00=>(0.5639943680683175, 1.0)', 'house_increase=>1', 'hv_abrm_ch=>1'), 'group': 'typology=>7.0', 'lift': 3.0665937670858394}
# INFO:root:399077 / 463415: {'rule': ('high_80120_00=>(0.5639943680683175, 1.0)', 'house_increase=>1', 'pctch_real_hinc_00_18=>(-0.04848044320668265, 0.19889357457847068)'), 'group': 'typology=>9.0', 'lift': 3.7266112266112263}
# INFO:root:399084 / 463415: {'rule': ('high_80120_00=>(0.5639943680683175, 1.0)', 'house_increase=>1', 'aboverm_per_nonwhite_18=>1'), 'group': 'typology=>7.0', 'lift': 3.2770471464019852}
# INFO:root:399085 / 463415: {'rule': ('high_80120_00=>(0.5639943680683175, 1.0)', 'house_increase=>1', 'aboverm_per_nonwhite_90=>1'), 'group': 'typology=>7.0', 'lift': 3.058333333333333}
# INFO:root:399086 / 463415: {'rule': ('high_80120_00=>(0.5639943680683175, 1.0)', 'house_increase=>1', 'aboverm_per_nonwhite_00=>1'), 'group': 'typology=>7.0', 'lift': 3.110797237915883}
# INFO:root:399093 / 463415: {'rule': ('high_80120_00=>(0.5639943680683175, 1.0)', 'house_increase=>1', 'aboverm_real_mrent_90=>0'), 'group': 'typology=>7.0', 'lift': 3.8207934336525313}
# INFO:root:399101 / 463415: {'rule': ('high_80120_00=>(0.5639943680683175, 1.0)', 'house_increase=>1', 'aboverm_ch_per_col_90_00=>1'), 'group': 'typology=>7.0', 'lift': 3.467466787439613}
# INFO:root:399101 / 463415: {'rule': ('high_80120_00=>(0.5639943680683175, 1.0)', 'house_increase=>1', 'aboverm_ch_per_col_90_00=>1'), 'group': 'typology=>9.0', 'lift': 3.516304347826087}
# INFO:root:399110 / 463415: {'rule': ('high_80120_00=>(0.5639943680683175, 1.0)', 'house_rapid_increase=>0', 'pctch_real_hinc_00_18=>(-0.04848044320668265, 0.19889357457847068)'), 'group': 'typology=>9.0', 'lift': 3.4459848637063826}
# INFO:root:399122 / 463415: {'rule': ('high_80120_00=>(0.5639943680683175, 1.0)', 'change_flag_category=>ch_rapid_increase', 'aboverm_per_all_li_90=>1'), 'group': 'typology=>6.0', 'lift': 4.503787878787878}
# INFO:root:399170 / 463415: {'rule': ('high_80120_00=>(0.5639943680683175, 1.0)', 'hv_abrm_ch=>1', 'ch_per_col_00_18=>(0.14730804093336136, 0.5292914867076665)'), 'group': 'typology=>9.0', 'lift': 4.282442748091603}
# INFO:root:399192 / 463415: {'rule': ('high_80120_00=>(0.5639943680683175, 1.0)', 'hv_abrm_ch=>1', 'aboverm_ch_per_col_90_00=>1'), 'group': 'typology=>9.0', 'lift': 3.1989247311827955}
# INFO:root:399193 / 463415: {'rule': ('high_80120_00=>(0.5639943680683175, 1.0)', 'hv_abrm_ch=>1', 'aboverm_ch_per_col_00_18=>1'), 'group': 'typology=>9.0', 'lift': 3.040462427745665}
# INFO:root:399198 / 463415: {'rule': ('high_80120_00=>(0.5639943680683175, 1.0)', 'rent_abrm_ch=>1', 'pctch_real_hinc_00_18=>(-0.04848044320668265, 0.19889357457847068)'), 'group': 'typology=>9.0', 'lift': 3.813614852566436}
# INFO:root:399199 / 463415: {'rule': ('high_80120_00=>(0.5639943680683175, 1.0)', 'rent_abrm_ch=>1', 'ch_per_col_00_18=>(0.14730804093336136, 0.5292914867076665)'), 'group': 'typology=>9.0', 'lift': 3.8044444444444445}
# INFO:root:399216 / 463415: {'rule': ('high_80120_00=>(0.5639943680683175, 1.0)', 'pctch_real_hinc_00_18=>(-0.04848044320668265, 0.19889357457847068)', 'aboverm_per_all_li_00=>0'), 'group': 'typology=>9.0', 'lift': 3.619217081850534}
# INFO:root:399217 / 463415: {'rule': ('high_80120_00=>(0.5639943680683175, 1.0)', 'pctch_real_hinc_00_18=>(-0.04848044320668265, 0.19889357457847068)', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>9.0', 'lift': 3.590747330960854}
# INFO:root:399224 / 463415: {'rule': ('high_80120_00=>(0.5639943680683175, 1.0)', 'pctch_real_hinc_00_18=>(-0.04848044320668265, 0.19889357457847068)', 'aboverm_per_col_90=>1'), 'group': 'typology=>9.0', 'lift': 3.5650406504065044}
# INFO:root:399225 / 463415: {'rule': ('high_80120_00=>(0.5639943680683175, 1.0)', 'pctch_real_hinc_00_18=>(-0.04848044320668265, 0.19889357457847068)', 'aboverm_per_col_00=>1'), 'group': 'typology=>9.0', 'lift': 3.5879999999999996}
# INFO:root:399226 / 463415: {'rule': ('high_80120_00=>(0.5639943680683175, 1.0)', 'pctch_real_hinc_00_18=>(-0.04848044320668265, 0.19889357457847068)', 'aboverm_per_col_18=>1'), 'group': 'typology=>9.0', 'lift': 3.57429718875502}
# INFO:root:399228 / 463415: {'rule': ('high_80120_00=>(0.5639943680683175, 1.0)', 'pctch_real_hinc_00_18=>(-0.04848044320668265, 0.19889357457847068)', 'aboverm_real_mrent_00=>1'), 'group': 'typology=>9.0', 'lift': 3.3565031982942433}
# INFO:root:399229 / 463415: {'rule': ('high_80120_00=>(0.5639943680683175, 1.0)', 'pctch_real_hinc_00_18=>(-0.04848044320668265, 0.19889357457847068)', 'aboverm_real_mrent_12=>1'), 'group': 'typology=>9.0', 'lift': 3.6865079365079367}
# INFO:root:399230 / 463415: {'rule': ('high_80120_00=>(0.5639943680683175, 1.0)', 'pctch_real_hinc_00_18=>(-0.04848044320668265, 0.19889357457847068)', 'aboverm_real_mrent_18=>1'), 'group': 'typology=>9.0', 'lift': 3.6422328621371025}
# INFO:root:399231 / 463415: {'rule': ('high_80120_00=>(0.5639943680683175, 1.0)', 'pctch_real_hinc_00_18=>(-0.04848044320668265, 0.19889357457847068)', 'aboverm_real_mhval_90=>1'), 'group': 'typology=>9.0', 'lift': 3.5107228915662656}
# INFO:root:399232 / 463415: {'rule': ('high_80120_00=>(0.5639943680683175, 1.0)', 'pctch_real_hinc_00_18=>(-0.04848044320668265, 0.19889357457847068)', 'aboverm_real_mhval_00=>1'), 'group': 'typology=>9.0', 'lift': 3.3157967222145706}
# INFO:root:399233 / 463415: {'rule': ('high_80120_00=>(0.5639943680683175, 1.0)', 'pctch_real_hinc_00_18=>(-0.04848044320668265, 0.19889357457847068)', 'aboverm_real_mhval_18=>1'), 'group': 'typology=>9.0', 'lift': 3.4732824427480917}
# INFO:root:399234 / 463415: {'rule': ('high_80120_00=>(0.5639943680683175, 1.0)', 'pctch_real_hinc_00_18=>(-0.04848044320668265, 0.19889357457847068)', 'aboverm_pctch_real_mrent_12_18=>1'), 'group': 'typology=>9.0', 'lift': 3.8672560975609755}
# INFO:root:399236 / 463415: {'rule': ('high_80120_00=>(0.5639943680683175, 1.0)', 'pctch_real_hinc_00_18=>(-0.04848044320668265, 0.19889357457847068)', 'aboverm_ch_per_col_00_18=>1'), 'group': 'typology=>9.0', 'lift': 4.164948453608248}
# INFO:root:399239 / 463415: {'rule': ('high_80120_00=>(0.5639943680683175, 1.0)', 'pctch_real_hinc_00_18=>(-0.04848044320668265, 0.19889357457847068)', 'hotmarket_00=>1.0'), 'group': 'typology=>9.0', 'lift': 3.9547058823529415}
# INFO:root:399240 / 463415: {'rule': ('high_80120_00=>(0.5639943680683175, 1.0)', 'pctch_real_hinc_00_18=>(-0.04848044320668265, 0.19889357457847068)', 'dp_RentGap=>0'), 'group': 'typology=>9.0', 'lift': 3.6917960088691797}
# INFO:root:399242 / 463415: {'rule': ('high_80120_00=>(0.5639943680683175, 1.0)', 'ch_per_col_90_00=>(0.05092707934146701, 0.545358933776489)', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>9.0', 'lift': 3.481818181818182}
# INFO:root:399244 / 463415: {'rule': ('high_80120_00=>(0.5639943680683175, 1.0)', 'ch_per_col_90_00=>(0.05092707934146701, 0.545358933776489)', 'aboverm_real_mhval_90=>1'), 'group': 'typology=>9.0', 'lift': 3.8033472803347284}
# INFO:root:399245 / 463415: {'rule': ('high_80120_00=>(0.5639943680683175, 1.0)', 'ch_per_col_90_00=>(0.05092707934146701, 0.545358933776489)', 'aboverm_real_mhval_00=>1'), 'group': 'typology=>9.0', 'lift': 3.8167938931297707}
# INFO:root:399246 / 463415: {'rule': ('high_80120_00=>(0.5639943680683175, 1.0)', 'ch_per_col_90_00=>(0.05092707934146701, 0.545358933776489)', 'aboverm_real_mhval_18=>1'), 'group': 'typology=>9.0', 'lift': 3.6073825503355708}
# INFO:root:399249 / 463415: {'rule': ('high_80120_00=>(0.5639943680683175, 1.0)', 'ch_per_col_00_18=>(0.14730804093336136, 0.5292914867076665)', 'aboverm_per_all_li_00=>0'), 'group': 'typology=>9.0', 'lift': 3.504854368932039}
# INFO:root:399250 / 463415: {'rule': ('high_80120_00=>(0.5639943680683175, 1.0)', 'ch_per_col_00_18=>(0.14730804093336136, 0.5292914867076665)', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>9.0', 'lift': 3.7012987012987013}
# INFO:root:399257 / 463415: {'rule': ('high_80120_00=>(0.5639943680683175, 1.0)', 'ch_per_col_00_18=>(0.14730804093336136, 0.5292914867076665)', 'aboverm_per_col_90=>1'), 'group': 'typology=>9.0', 'lift': 3.5683453237410077}
# INFO:root:399258 / 463415: {'rule': ('high_80120_00=>(0.5639943680683175, 1.0)', 'ch_per_col_00_18=>(0.14730804093336136, 0.5292914867076665)', 'aboverm_per_col_00=>1'), 'group': 'typology=>9.0', 'lift': 3.638297872340426}
# INFO:root:399259 / 463415: {'rule': ('high_80120_00=>(0.5639943680683175, 1.0)', 'ch_per_col_00_18=>(0.14730804093336136, 0.5292914867076665)', 'aboverm_per_col_18=>1'), 'group': 'typology=>9.0', 'lift': 3.6666666666666674}
# INFO:root:399261 / 463415: {'rule': ('high_80120_00=>(0.5639943680683175, 1.0)', 'ch_per_col_00_18=>(0.14730804093336136, 0.5292914867076665)', 'aboverm_real_mrent_00=>1'), 'group': 'typology=>9.0', 'lift': 3.479087452471483}
# INFO:root:399262 / 463415: {'rule': ('high_80120_00=>(0.5639943680683175, 1.0)', 'ch_per_col_00_18=>(0.14730804093336136, 0.5292914867076665)', 'aboverm_real_mrent_12=>1'), 'group': 'typology=>9.0', 'lift': 3.646428571428572}
# INFO:root:399263 / 463415: {'rule': ('high_80120_00=>(0.5639943680683175, 1.0)', 'ch_per_col_00_18=>(0.14730804093336136, 0.5292914867076665)', 'aboverm_real_mrent_18=>1'), 'group': 'typology=>9.0', 'lift': 3.6920415224913494}
# INFO:root:399264 / 463415: {'rule': ('high_80120_00=>(0.5639943680683175, 1.0)', 'ch_per_col_00_18=>(0.14730804093336136, 0.5292914867076665)', 'aboverm_real_mhval_90=>1'), 'group': 'typology=>9.0', 'lift': 3.4886363636363633}
# INFO:root:399265 / 463415: {'rule': ('high_80120_00=>(0.5639943680683175, 1.0)', 'ch_per_col_00_18=>(0.14730804093336136, 0.5292914867076665)', 'aboverm_real_mhval_00=>1'), 'group': 'typology=>9.0', 'lift': 3.50709219858156}
# INFO:root:399266 / 463415: {'rule': ('high_80120_00=>(0.5639943680683175, 1.0)', 'ch_per_col_00_18=>(0.14730804093336136, 0.5292914867076665)', 'aboverm_real_mhval_18=>1'), 'group': 'typology=>9.0', 'lift': 3.600682593856656}
# INFO:root:399267 / 463415: {'rule': ('high_80120_00=>(0.5639943680683175, 1.0)', 'ch_per_col_00_18=>(0.14730804093336136, 0.5292914867076665)', 'aboverm_pctch_real_mrent_12_18=>1'), 'group': 'typology=>9.0', 'lift': 3.8488888888888892}
# INFO:root:399269 / 463415: {'rule': ('high_80120_00=>(0.5639943680683175, 1.0)', 'ch_per_col_00_18=>(0.14730804093336136, 0.5292914867076665)', 'aboverm_ch_per_col_00_18=>1'), 'group': 'typology=>9.0', 'lift': 3.7451612903225806}
# INFO:root:399272 / 463415: {'rule': ('high_80120_00=>(0.5639943680683175, 1.0)', 'ch_per_col_00_18=>(0.14730804093336136, 0.5292914867076665)', 'hotmarket_00=>1.0'), 'group': 'typology=>9.0', 'lift': 3.9802955665024626}
# INFO:root:399273 / 463415: {'rule': ('high_80120_00=>(0.5639943680683175, 1.0)', 'ch_per_col_00_18=>(0.14730804093336136, 0.5292914867076665)', 'dp_RentGap=>0'), 'group': 'typology=>9.0', 'lift': 3.6283185840707963}
# INFO:root:399333 / 463415: {'rule': ('high_80120_00=>(0.5639943680683175, 1.0)', 'aboverm_per_nonwhite_00=>1', 'aboverm_per_col_18=>1'), 'group': 'typology=>9.0', 'lift': 3.0738255033557045}
# INFO:root:399397 / 463415: {'rule': ('high_80120_00=>(0.5639943680683175, 1.0)', 'aboverm_real_mhval_90=>1', 'aboverm_ch_per_col_90_00=>1'), 'group': 'typology=>9.0', 'lift': 3.2277580071174374}
# INFO:root:399405 / 463415: {'rule': ('high_80120_00=>(0.5639943680683175, 1.0)', 'aboverm_real_mhval_00=>1', 'aboverm_ch_per_col_90_00=>1'), 'group': 'typology=>9.0', 'lift': 3.2115384615384612}
# INFO:root:399412 / 463415: {'rule': ('high_80120_00=>(0.5639943680683175, 1.0)', 'aboverm_real_mhval_18=>1', 'aboverm_ch_per_col_90_00=>1'), 'group': 'typology=>9.0', 'lift': 3.074074074074074}
# INFO:root:399459 / 463415: {'rule': ('per_all_li_90=>(0.16361799531892668, 0.2995041574505646)', 'per_all_li_18=>(0.0, 0.31703225175887484)', 'change_flag_category=>ch_rapid_increase'), 'group': 'typology=>6.0', 'lift': 3.1611526807247543}
# INFO:root:399520 / 463415: {'rule': ('per_all_li_90=>(0.16361799531892668, 0.2995041574505646)', 'house_increase=>1', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>7.0', 'lift': 3.5126582278481018}
# INFO:root:399521 / 463415: {'rule': ('per_all_li_90=>(0.16361799531892668, 0.2995041574505646)', 'house_rapid_increase=>0', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>7.0', 'lift': 3.153374233128835}
# INFO:root:399576 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'per_all_li_18=>(0.0, 0.31703225175887484)', 'per_limove_18=>(0.04591681062269298, 0.3711912604646169)'), 'group': 'typology=>9.0', 'lift': 4.049382716049383}
# INFO:root:399577 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'per_all_li_18=>(0.0, 0.31703225175887484)', 'per_limove_12=>(0.0, 0.3834065643589453)'), 'group': 'typology=>9.0', 'lift': 4.0}
# INFO:root:399580 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'per_all_li_18=>(0.0, 0.31703225175887484)', 'pctch_real_mrent_12_18=>(0.2164448712672062, 3.1496504993958303)'), 'group': 'typology=>9.0', 'lift': 4.138513513513513}
# INFO:root:399581 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'per_all_li_18=>(0.0, 0.31703225175887484)', 'house_increase=>1'), 'group': 'typology=>9.0', 'lift': 3.177083333333333}
# INFO:root:399585 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'per_all_li_18=>(0.0, 0.31703225175887484)', 'hv_abrm_ch=>1'), 'group': 'typology=>9.0', 'lift': 3.389830508474576}
# INFO:root:399589 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'per_all_li_18=>(0.0, 0.31703225175887484)', 'ch_per_col_90_00=>(0.05092707934146701, 0.545358933776489)'), 'group': 'typology=>9.0', 'lift': 4.4498141263940525}
# INFO:root:399612 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'per_all_li_18=>(0.0, 0.31703225175887484)', 'aboverm_ch_per_col_90_00=>1'), 'group': 'typology=>9.0', 'lift': 3.7882736156351786}
# INFO:root:399613 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'per_all_li_18=>(0.0, 0.31703225175887484)', 'aboverm_ch_per_col_00_18=>1'), 'group': 'typology=>9.0', 'lift': 3.3372434017595305}
# INFO:root:399614 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'per_all_li_18=>(0.0, 0.31703225175887484)', 'aboverm_per_units_pre50_18=>0'), 'group': 'typology=>9.0', 'lift': 3.136904761904762}
# INFO:root:399648 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'per_rent_90=>(0.2829228930760002, 0.4976911024130292)', 'change_flag_category=>ch_rapid_increase'), 'group': 'typology=>6.0', 'lift': 3.316888888888889}
# INFO:root:399691 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'per_limove_18=>(0.04591681062269298, 0.3711912604646169)', 'pctch_real_mrent_12_18=>(0.2164448712672062, 3.1496504993958303)'), 'group': 'typology=>9.0', 'lift': 4.821563342318059}
# INFO:root:399697 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'per_limove_18=>(0.04591681062269298, 0.3711912604646169)', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>9.0', 'lift': 3.4033149171270716}
# INFO:root:399699 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'per_limove_18=>(0.04591681062269298, 0.3711912604646169)', 'aboverm_real_mrent_18=>1'), 'group': 'typology=>9.0', 'lift': 3.3798230867755366}
# INFO:root:399700 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'per_limove_18=>(0.04591681062269298, 0.3711912604646169)', 'aboverm_real_mhval_90=>1'), 'group': 'typology=>9.0', 'lift': 3.395833333333333}
# INFO:root:399701 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'per_limove_18=>(0.04591681062269298, 0.3711912604646169)', 'aboverm_real_mhval_00=>1'), 'group': 'typology=>9.0', 'lift': 3.3737704918032785}
# INFO:root:399702 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'per_limove_18=>(0.04591681062269298, 0.3711912604646169)', 'aboverm_real_mhval_18=>1'), 'group': 'typology=>9.0', 'lift': 3.372307692307692}
# INFO:root:399704 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'per_limove_12=>(0.0, 0.3834065643589453)', 'pctch_real_mrent_12_18=>(0.2164448712672062, 3.1496504993958303)'), 'group': 'typology=>9.0', 'lift': 4.759154929577464}
# INFO:root:399705 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'per_limove_12=>(0.0, 0.3834065643589453)', 'house_increase=>1'), 'group': 'typology=>9.0', 'lift': 3.672174840085287}
# INFO:root:399712 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'per_limove_12=>(0.0, 0.3834065643589453)', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>9.0', 'lift': 3.278215223097113}
# INFO:root:399718 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'per_limove_12=>(0.0, 0.3834065643589453)', 'aboverm_real_mrent_00=>1'), 'group': 'typology=>9.0', 'lift': 3.3430420711974107}
# INFO:root:399719 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'per_limove_12=>(0.0, 0.3834065643589453)', 'aboverm_real_mrent_12=>1'), 'group': 'typology=>9.0', 'lift': 3.3603351955307263}
# INFO:root:399720 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'per_limove_12=>(0.0, 0.3834065643589453)', 'aboverm_real_mrent_18=>1'), 'group': 'typology=>9.0', 'lift': 3.2939560439560442}
# INFO:root:399721 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'per_limove_12=>(0.0, 0.3834065643589453)', 'aboverm_real_mhval_90=>1'), 'group': 'typology=>9.0', 'lift': 3.3537414965986394}
# INFO:root:399722 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'per_limove_12=>(0.0, 0.3834065643589453)', 'aboverm_real_mhval_00=>1'), 'group': 'typology=>9.0', 'lift': 3.2626582278481013}
# INFO:root:399723 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'per_limove_12=>(0.0, 0.3834065643589453)', 'aboverm_real_mhval_18=>1'), 'group': 'typology=>9.0', 'lift': 3.248520710059172}
# INFO:root:399725 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'per_limove_12=>(0.0, 0.3834065643589453)', 'dp_RentGap=>0'), 'group': 'typology=>9.0', 'lift': 3.2237474262182566}
# INFO:root:399726 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'lmh_flag_category=>aff_mix_mod', 'pctch_real_mrent_12_18=>(0.2164448712672062, 3.1496504993958303)'), 'group': 'typology=>6.0', 'lift': 3.050609184629803}
# INFO:root:399740 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'pctch_real_mrent_12_18=>(0.2164448712672062, 3.1496504993958303)', 'house_increase=>1'), 'group': 'typology=>9.0', 'lift': 3.858148243801653}
# INFO:root:399741 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'pctch_real_mrent_12_18=>(0.2164448712672062, 3.1496504993958303)', 'house_rapid_increase=>0'), 'group': 'typology=>9.0', 'lift': 3.5582539007953375}
# INFO:root:399744 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'pctch_real_mrent_12_18=>(0.2164448712672062, 3.1496504993958303)', 'hv_abrm_ch=>1'), 'group': 'typology=>9.0', 'lift': 3.503221564760026}
# INFO:root:399745 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'pctch_real_mrent_12_18=>(0.2164448712672062, 3.1496504993958303)', 'rent_abrm_ch=>1'), 'group': 'typology=>9.0', 'lift': 3.2206339801510886}
# INFO:root:399749 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'pctch_real_mrent_12_18=>(0.2164448712672062, 3.1496504993958303)', 'ch_per_col_00_18=>(0.14730804093336136, 0.5292914867076665)'), 'group': 'typology=>9.0', 'lift': 5.446192801591608}
# INFO:root:399752 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'pctch_real_mrent_12_18=>(0.2164448712672062, 3.1496504993958303)', 'aboverm_per_all_li_00=>0'), 'group': 'typology=>9.0', 'lift': 3.3488372093023258}
# INFO:root:399753 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'pctch_real_mrent_12_18=>(0.2164448712672062, 3.1496504993958303)', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>9.0', 'lift': 3.4024024024024024}
# INFO:root:399760 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'pctch_real_mrent_12_18=>(0.2164448712672062, 3.1496504993958303)', 'aboverm_per_col_90=>1'), 'group': 'typology=>9.0', 'lift': 3.272445820433437}
# INFO:root:399761 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'pctch_real_mrent_12_18=>(0.2164448712672062, 3.1496504993958303)', 'aboverm_per_col_00=>1'), 'group': 'typology=>9.0', 'lift': 3.299504842983104}
# INFO:root:399762 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'pctch_real_mrent_12_18=>(0.2164448712672062, 3.1496504993958303)', 'aboverm_per_col_18=>1'), 'group': 'typology=>9.0', 'lift': 3.304186026501463}
# INFO:root:399764 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'pctch_real_mrent_12_18=>(0.2164448712672062, 3.1496504993958303)', 'aboverm_real_mrent_00=>1'), 'group': 'typology=>9.0', 'lift': 3.35594675826535}
# INFO:root:399765 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'pctch_real_mrent_12_18=>(0.2164448712672062, 3.1496504993958303)', 'aboverm_real_mrent_12=>1'), 'group': 'typology=>9.0', 'lift': 3.4081632653061225}
# INFO:root:399766 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'pctch_real_mrent_12_18=>(0.2164448712672062, 3.1496504993958303)', 'aboverm_real_mrent_18=>1'), 'group': 'typology=>9.0', 'lift': 3.3830755232029115}
# INFO:root:399767 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'pctch_real_mrent_12_18=>(0.2164448712672062, 3.1496504993958303)', 'aboverm_real_mhval_90=>1'), 'group': 'typology=>9.0', 'lift': 3.4113207547169813}
# INFO:root:399768 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'pctch_real_mrent_12_18=>(0.2164448712672062, 3.1496504993958303)', 'aboverm_real_mhval_00=>1'), 'group': 'typology=>9.0', 'lift': 3.341296928327645}
# INFO:root:399769 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'pctch_real_mrent_12_18=>(0.2164448712672062, 3.1496504993958303)', 'aboverm_real_mhval_18=>1'), 'group': 'typology=>9.0', 'lift': 3.2626582278481013}
# INFO:root:399770 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'pctch_real_mrent_12_18=>(0.2164448712672062, 3.1496504993958303)', 'aboverm_pctch_real_mrent_12_18=>1'), 'group': 'typology=>9.0', 'lift': 3.263960894682269}
# INFO:root:399771 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'pctch_real_mrent_12_18=>(0.2164448712672062, 3.1496504993958303)', 'aboverm_ch_per_col_90_00=>1'), 'group': 'typology=>9.0', 'lift': 4.383396086087481}
# INFO:root:399772 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'pctch_real_mrent_12_18=>(0.2164448712672062, 3.1496504993958303)', 'aboverm_ch_per_col_00_18=>1'), 'group': 'typology=>9.0', 'lift': 4.222222222222222}
# INFO:root:399773 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'pctch_real_mrent_12_18=>(0.2164448712672062, 3.1496504993958303)', 'aboverm_per_units_pre50_18=>0'), 'group': 'typology=>9.0', 'lift': 3.435856001436395}
# INFO:root:399775 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'pctch_real_mrent_12_18=>(0.2164448712672062, 3.1496504993958303)', 'hotmarket_00=>1.0'), 'group': 'typology=>9.0', 'lift': 3.7211022222222216}
# INFO:root:399776 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'pctch_real_mrent_12_18=>(0.2164448712672062, 3.1496504993958303)', 'dp_RentGap=>0'), 'group': 'typology=>9.0', 'lift': 3.174523330458944}
# INFO:root:399779 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'house_increase=>1', 'pctch_real_hinc_00_18=>(-0.04848044320668265, 0.19889357457847068)'), 'group': 'typology=>9.0', 'lift': 3.720959507657878}
# INFO:root:399780 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'house_increase=>1', 'ch_per_col_00_18=>(0.14730804093336136, 0.5292914867076665)'), 'group': 'typology=>9.0', 'lift': 3.8907415165479686}
# INFO:root:399791 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'house_rapid_increase=>0', 'pctch_real_hinc_00_18=>(-0.04848044320668265, 0.19889357457847068)'), 'group': 'typology=>9.0', 'lift': 3.4982113373692902}
# INFO:root:399792 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'house_rapid_increase=>0', 'ch_per_col_00_18=>(0.14730804093336136, 0.5292914867076665)'), 'group': 'typology=>9.0', 'lift': 3.5581561977549563}
# INFO:root:399798 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'change_flag_category=>ch_rapid_increase', 'ch_per_col_00_18=>(0.14730804093336136, 0.5292914867076665)'), 'group': 'typology=>9.0', 'lift': 3.0224215246636774}
# INFO:root:399817 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'hv_abrm_ch=>1', 'ch_per_col_00_18=>(0.14730804093336136, 0.5292914867076665)'), 'group': 'typology=>9.0', 'lift': 4.334712398238356}
# INFO:root:399820 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'hv_abrm_ch=>1', 'aboverm_ch_per_col_00_18=>1'), 'group': 'typology=>9.0', 'lift': 3.089820359281437}
# INFO:root:399821 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'rent_abrm_ch=>1', 'pctch_real_hinc_00_18=>(-0.04848044320668265, 0.19889357457847068)'), 'group': 'typology=>9.0', 'lift': 3.809644670050762}
# INFO:root:399832 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'pctch_real_hinc_00_18=>(-0.04848044320668265, 0.19889357457847068)', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>9.0', 'lift': 3.5992647058823533}
# INFO:root:399839 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'pctch_real_hinc_00_18=>(-0.04848044320668265, 0.19889357457847068)', 'aboverm_per_col_90=>1'), 'group': 'typology=>9.0', 'lift': 3.6266094420600856}
# INFO:root:399840 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'pctch_real_hinc_00_18=>(-0.04848044320668265, 0.19889357457847068)', 'aboverm_per_col_00=>1'), 'group': 'typology=>9.0', 'lift': 3.6125}
# INFO:root:399841 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'pctch_real_hinc_00_18=>(-0.04848044320668265, 0.19889357457847068)', 'aboverm_per_col_18=>1'), 'group': 'typology=>9.0', 'lift': 3.588235294117647}
# INFO:root:399842 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'pctch_real_hinc_00_18=>(-0.04848044320668265, 0.19889357457847068)', 'aboverm_real_mrent_00=>1'), 'group': 'typology=>9.0', 'lift': 3.372315386878493}
# INFO:root:399843 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'pctch_real_hinc_00_18=>(-0.04848044320668265, 0.19889357457847068)', 'aboverm_real_mrent_12=>1'), 'group': 'typology=>9.0', 'lift': 3.7246963562753033}
# INFO:root:399844 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'pctch_real_hinc_00_18=>(-0.04848044320668265, 0.19889357457847068)', 'aboverm_real_mrent_18=>1'), 'group': 'typology=>9.0', 'lift': 3.624803149606299}
# INFO:root:399845 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'pctch_real_hinc_00_18=>(-0.04848044320668265, 0.19889357457847068)', 'aboverm_real_mhval_90=>1'), 'group': 'typology=>9.0', 'lift': 3.592436974789916}
# INFO:root:399846 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'pctch_real_hinc_00_18=>(-0.04848044320668265, 0.19889357457847068)', 'aboverm_real_mhval_00=>1'), 'group': 'typology=>9.0', 'lift': 3.363966501148744}
# INFO:root:399847 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'pctch_real_hinc_00_18=>(-0.04848044320668265, 0.19889357457847068)', 'aboverm_real_mhval_18=>1'), 'group': 'typology=>9.0', 'lift': 3.5}
# INFO:root:399848 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'pctch_real_hinc_00_18=>(-0.04848044320668265, 0.19889357457847068)', 'aboverm_pctch_real_mrent_12_18=>1'), 'group': 'typology=>9.0', 'lift': 3.8643494897959183}
# INFO:root:399850 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'pctch_real_hinc_00_18=>(-0.04848044320668265, 0.19889357457847068)', 'aboverm_ch_per_col_00_18=>1'), 'group': 'typology=>9.0', 'lift': 4.228260869565217}
# INFO:root:399852 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'pctch_real_hinc_00_18=>(-0.04848044320668265, 0.19889357457847068)', 'dp_RentGap=>0'), 'group': 'typology=>9.0', 'lift': 3.683424589347934}
# INFO:root:399854 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'ch_per_col_90_00=>(0.05092707934146701, 0.545358933776489)', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>9.0', 'lift': 3.536507936507937}
# INFO:root:399855 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'ch_per_col_90_00=>(0.05092707934146701, 0.545358933776489)', 'aboverm_real_mhval_90=>1'), 'group': 'typology=>9.0', 'lift': 3.945945945945946}
# INFO:root:399856 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'ch_per_col_90_00=>(0.05092707934146701, 0.545358933776489)', 'aboverm_real_mhval_00=>1'), 'group': 'typology=>9.0', 'lift': 3.946502057613168}
# INFO:root:399857 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'ch_per_col_90_00=>(0.05092707934146701, 0.545358933776489)', 'aboverm_real_mhval_18=>1'), 'group': 'typology=>9.0', 'lift': 3.6845878136200723}
# INFO:root:399860 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'ch_per_col_00_18=>(0.14730804093336136, 0.5292914867076665)', 'aboverm_per_all_li_00=>0'), 'group': 'typology=>9.0', 'lift': 3.6450511945392488}
# INFO:root:399861 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'ch_per_col_00_18=>(0.14730804093336136, 0.5292914867076665)', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>9.0', 'lift': 3.780068728522337}
# INFO:root:399868 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'ch_per_col_00_18=>(0.14730804093336136, 0.5292914867076665)', 'aboverm_per_col_90=>1'), 'group': 'typology=>9.0', 'lift': 3.6542753112520563}
# INFO:root:399870 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'ch_per_col_00_18=>(0.14730804093336136, 0.5292914867076665)', 'aboverm_per_col_18=>1'), 'group': 'typology=>9.0', 'lift': 3.6963955162484567}
# INFO:root:399872 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'ch_per_col_00_18=>(0.14730804093336136, 0.5292914867076665)', 'aboverm_real_mrent_00=>1'), 'group': 'typology=>9.0', 'lift': 3.6129032258064515}
# INFO:root:399873 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'ch_per_col_00_18=>(0.14730804093336136, 0.5292914867076665)', 'aboverm_real_mrent_12=>1'), 'group': 'typology=>9.0', 'lift': 3.7669172932330826}
# INFO:root:399874 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'ch_per_col_00_18=>(0.14730804093336136, 0.5292914867076665)', 'aboverm_real_mrent_18=>1'), 'group': 'typology=>9.0', 'lift': 3.7608695652173916}
# INFO:root:399875 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'ch_per_col_00_18=>(0.14730804093336136, 0.5292914867076665)', 'aboverm_real_mhval_90=>1'), 'group': 'typology=>9.0', 'lift': 3.5894308943089435}
# INFO:root:399876 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'ch_per_col_00_18=>(0.14730804093336136, 0.5292914867076665)', 'aboverm_real_mhval_00=>1'), 'group': 'typology=>9.0', 'lift': 3.5855513307984794}
# INFO:root:399880 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'ch_per_col_00_18=>(0.14730804093336136, 0.5292914867076665)', 'aboverm_ch_per_col_00_18=>1'), 'group': 'typology=>9.0', 'lift': 3.825938566552901}
# INFO:root:399883 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'ch_per_col_00_18=>(0.14730804093336136, 0.5292914867076665)', 'hotmarket_00=>1.0'), 'group': 'typology=>9.0', 'lift': 4.0932642487046635}
# INFO:root:399884 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'ch_per_col_00_18=>(0.14730804093336136, 0.5292914867076665)', 'dp_RentGap=>0'), 'group': 'typology=>9.0', 'lift': 3.7493387409627927}
# INFO:root:399913 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'aboverm_per_all_li_18=>0', 'aboverm_ch_per_col_90_00=>1'), 'group': 'typology=>9.0', 'lift': 3.0752089136490253}
# INFO:root:399953 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'aboverm_real_mhval_90=>1', 'aboverm_ch_per_col_90_00=>1'), 'group': 'typology=>9.0', 'lift': 3.3513513513513513}
# INFO:root:399958 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'aboverm_real_mhval_00=>1', 'aboverm_ch_per_col_90_00=>1'), 'group': 'typology=>9.0', 'lift': 3.3391608391608387}
# INFO:root:399963 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'aboverm_real_mhval_18=>1', 'aboverm_ch_per_col_90_00=>1'), 'group': 'typology=>9.0', 'lift': 3.186335403726708}
# INFO:root:400028 / 463415: {'rule': ('per_all_li_18=>(0.0, 0.31703225175887484)', 'per_nonwhite_00=>(0.5773725439835624, 0.9902912621359224)', 'change_flag_category=>ch_rapid_increase'), 'group': 'typology=>6.0', 'lift': 3.688392857142857}
# INFO:root:400073 / 463415: {'rule': ('per_all_li_18=>(0.0, 0.31703225175887484)', 'per_nonwhite_18=>(0.7047619047619047, 0.9977610746841516)', 'change_flag_category=>ch_rapid_increase'), 'group': 'typology=>6.0', 'lift': 3.185657998423956}
# INFO:root:400117 / 463415: {'rule': ('per_all_li_18=>(0.0, 0.31703225175887484)', 'per_rent_90=>(0.2829228930760002, 0.4976911024130292)', 'change_flag_category=>ch_rapid_increase'), 'group': 'typology=>6.0', 'lift': 3.2932100959829365}
# INFO:root:400202 / 463415: {'rule': ('per_all_li_18=>(0.0, 0.31703225175887484)', 'per_rent_18=>(0.3015783540022548, 0.5273297491039427)', 'change_flag_category=>ch_rapid_increase'), 'group': 'typology=>6.0', 'lift': 3.602597402597403}
# INFO:root:400241 / 463415: {'rule': ('per_all_li_18=>(0.0, 0.31703225175887484)', 'per_limove_18=>(0.04591681062269298, 0.3711912604646169)', 'house_increase=>1'), 'group': 'typology=>9.0', 'lift': 3.8263157894736843}
# INFO:root:400242 / 463415: {'rule': ('per_all_li_18=>(0.0, 0.31703225175887484)', 'per_limove_18=>(0.04591681062269298, 0.3711912604646169)', 'house_rapid_increase=>0'), 'group': 'typology=>9.0', 'lift': 3.4720812182741114}
# INFO:root:400246 / 463415: {'rule': ('per_all_li_18=>(0.0, 0.31703225175887484)', 'per_limove_18=>(0.04591681062269298, 0.3711912604646169)', 'rent_abrm_ch=>1'), 'group': 'typology=>9.0', 'lift': 3.3084415584415585}
# INFO:root:400253 / 463415: {'rule': ('per_all_li_18=>(0.0, 0.31703225175887484)', 'per_limove_18=>(0.04591681062269298, 0.3711912604646169)', 'aboverm_per_all_li_00=>0'), 'group': 'typology=>9.0', 'lift': 3.1457286432160805}
# INFO:root:400254 / 463415: {'rule': ('per_all_li_18=>(0.0, 0.31703225175887484)', 'per_limove_18=>(0.04591681062269298, 0.3711912604646169)', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>9.0', 'lift': 3.1694117647058824}
# INFO:root:400261 / 463415: {'rule': ('per_all_li_18=>(0.0, 0.31703225175887484)', 'per_limove_18=>(0.04591681062269298, 0.3711912604646169)', 'aboverm_per_col_90=>1'), 'group': 'typology=>9.0', 'lift': 3.1561643835616437}
# INFO:root:400262 / 463415: {'rule': ('per_all_li_18=>(0.0, 0.31703225175887484)', 'per_limove_18=>(0.04591681062269298, 0.3711912604646169)', 'aboverm_per_col_00=>1'), 'group': 'typology=>9.0', 'lift': 3.154046997389034}
# INFO:root:400263 / 463415: {'rule': ('per_all_li_18=>(0.0, 0.31703225175887484)', 'per_limove_18=>(0.04591681062269298, 0.3711912604646169)', 'aboverm_per_col_18=>1'), 'group': 'typology=>9.0', 'lift': 3.162025316455696}
# INFO:root:400265 / 463415: {'rule': ('per_all_li_18=>(0.0, 0.31703225175887484)', 'per_limove_18=>(0.04591681062269298, 0.3711912604646169)', 'aboverm_real_mrent_00=>1'), 'group': 'typology=>9.0', 'lift': 3.231707317073171}
# INFO:root:400266 / 463415: {'rule': ('per_all_li_18=>(0.0, 0.31703225175887484)', 'per_limove_18=>(0.04591681062269298, 0.3711912604646169)', 'aboverm_real_mrent_12=>1'), 'group': 'typology=>9.0', 'lift': 3.1679586563307494}
# INFO:root:400267 / 463415: {'rule': ('per_all_li_18=>(0.0, 0.31703225175887484)', 'per_limove_18=>(0.04591681062269298, 0.3711912604646169)', 'aboverm_real_mrent_18=>1'), 'group': 'typology=>9.0', 'lift': 3.167082294264339}
# INFO:root:400268 / 463415: {'rule': ('per_all_li_18=>(0.0, 0.31703225175887484)', 'per_limove_18=>(0.04591681062269298, 0.3711912604646169)', 'aboverm_real_mhval_90=>1'), 'group': 'typology=>9.0', 'lift': 3.2282282282282284}
# INFO:root:400269 / 463415: {'rule': ('per_all_li_18=>(0.0, 0.31703225175887484)', 'per_limove_18=>(0.04591681062269298, 0.3711912604646169)', 'aboverm_real_mhval_00=>1'), 'group': 'typology=>9.0', 'lift': 3.201133144475921}
# INFO:root:400270 / 463415: {'rule': ('per_all_li_18=>(0.0, 0.31703225175887484)', 'per_limove_18=>(0.04591681062269298, 0.3711912604646169)', 'aboverm_real_mhval_18=>1'), 'group': 'typology=>9.0', 'lift': 3.1761658031088085}
# INFO:root:400271 / 463415: {'rule': ('per_all_li_18=>(0.0, 0.31703225175887484)', 'per_limove_18=>(0.04591681062269298, 0.3711912604646169)', 'aboverm_pctch_real_mrent_12_18=>1'), 'group': 'typology=>9.0', 'lift': 3.3474025974025974}
# INFO:root:400273 / 463415: {'rule': ('per_all_li_18=>(0.0, 0.31703225175887484)', 'per_limove_18=>(0.04591681062269298, 0.3711912604646169)', 'aboverm_ch_per_col_00_18=>1'), 'group': 'typology=>9.0', 'lift': 3.572755417956656}
# INFO:root:400276 / 463415: {'rule': ('per_all_li_18=>(0.0, 0.31703225175887484)', 'per_limove_18=>(0.04591681062269298, 0.3711912604646169)', 'hotmarket_00=>1.0'), 'group': 'typology=>9.0', 'lift': 3.3623188405797104}
# INFO:root:400277 / 463415: {'rule': ('per_all_li_18=>(0.0, 0.31703225175887484)', 'per_limove_18=>(0.04591681062269298, 0.3711912604646169)', 'dp_RentGap=>0'), 'group': 'typology=>9.0', 'lift': 3.0854430379746836}
# INFO:root:400280 / 463415: {'rule': ('per_all_li_18=>(0.0, 0.31703225175887484)', 'per_limove_12=>(0.0, 0.3834065643589453)', 'pctch_real_mrent_12_18=>(0.2164448712672062, 3.1496504993958303)'), 'group': 'typology=>9.0', 'lift': 4.6000000000000005}
# INFO:root:400281 / 463415: {'rule': ('per_all_li_18=>(0.0, 0.31703225175887484)', 'per_limove_12=>(0.0, 0.3834065643589453)', 'house_increase=>1'), 'group': 'typology=>9.0', 'lift': 3.822916666666667}
# INFO:root:400282 / 463415: {'rule': ('per_all_li_18=>(0.0, 0.31703225175887484)', 'per_limove_12=>(0.0, 0.3834065643589453)', 'house_rapid_increase=>0'), 'group': 'typology=>9.0', 'lift': 3.4450000000000003}
# INFO:root:400285 / 463415: {'rule': ('per_all_li_18=>(0.0, 0.31703225175887484)', 'per_limove_12=>(0.0, 0.3834065643589453)', 'hv_abrm_ch=>1'), 'group': 'typology=>9.0', 'lift': 3.605263157894737}
# INFO:root:400286 / 463415: {'rule': ('per_all_li_18=>(0.0, 0.31703225175887484)', 'per_limove_12=>(0.0, 0.3834065643589453)', 'rent_abrm_ch=>1'), 'group': 'typology=>9.0', 'lift': 3.236065573770492}
# INFO:root:400293 / 463415: {'rule': ('per_all_li_18=>(0.0, 0.31703225175887484)', 'per_limove_12=>(0.0, 0.3834065643589453)', 'aboverm_per_all_li_00=>0'), 'group': 'typology=>9.0', 'lift': 3.162907268170426}
# INFO:root:400294 / 463415: {'rule': ('per_all_li_18=>(0.0, 0.31703225175887484)', 'per_limove_12=>(0.0, 0.3834065643589453)', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>9.0', 'lift': 3.1725768321513}
# INFO:root:400301 / 463415: {'rule': ('per_all_li_18=>(0.0, 0.31703225175887484)', 'per_limove_12=>(0.0, 0.3834065643589453)', 'aboverm_per_col_90=>1'), 'group': 'typology=>9.0', 'lift': 3.188888888888889}
# INFO:root:400302 / 463415: {'rule': ('per_all_li_18=>(0.0, 0.31703225175887484)', 'per_limove_12=>(0.0, 0.3834065643589453)', 'aboverm_per_col_00=>1'), 'group': 'typology=>9.0', 'lift': 3.2129380053908356}
# INFO:root:400303 / 463415: {'rule': ('per_all_li_18=>(0.0, 0.31703225175887484)', 'per_limove_12=>(0.0, 0.3834065643589453)', 'aboverm_per_col_18=>1'), 'group': 'typology=>9.0', 'lift': 3.1752577319587627}
# INFO:root:400305 / 463415: {'rule': ('per_all_li_18=>(0.0, 0.31703225175887484)', 'per_limove_12=>(0.0, 0.3834065643589453)', 'aboverm_real_mrent_00=>1'), 'group': 'typology=>9.0', 'lift': 3.2415902140672785}
# INFO:root:400306 / 463415: {'rule': ('per_all_li_18=>(0.0, 0.31703225175887484)', 'per_limove_12=>(0.0, 0.3834065643589453)', 'aboverm_real_mrent_12=>1'), 'group': 'typology=>9.0', 'lift': 3.2216494845360826}
# INFO:root:400307 / 463415: {'rule': ('per_all_li_18=>(0.0, 0.31703225175887484)', 'per_limove_12=>(0.0, 0.3834065643589453)', 'aboverm_real_mrent_18=>1'), 'group': 'typology=>9.0', 'lift': 3.1889168765743072}
# INFO:root:400308 / 463415: {'rule': ('per_all_li_18=>(0.0, 0.31703225175887484)', 'per_limove_12=>(0.0, 0.3834065643589453)', 'aboverm_real_mhval_90=>1'), 'group': 'typology=>9.0', 'lift': 3.264615384615385}
# INFO:root:400309 / 463415: {'rule': ('per_all_li_18=>(0.0, 0.31703225175887484)', 'per_limove_12=>(0.0, 0.3834065643589453)', 'aboverm_real_mhval_00=>1'), 'group': 'typology=>9.0', 'lift': 3.189655172413793}
# INFO:root:400310 / 463415: {'rule': ('per_all_li_18=>(0.0, 0.31703225175887484)', 'per_limove_12=>(0.0, 0.3834065643589453)', 'aboverm_real_mhval_18=>1'), 'group': 'typology=>9.0', 'lift': 3.1653543307086616}
# INFO:root:400311 / 463415: {'rule': ('per_all_li_18=>(0.0, 0.31703225175887484)', 'per_limove_12=>(0.0, 0.3834065643589453)', 'aboverm_pctch_real_mrent_12_18=>1'), 'group': 'typology=>9.0', 'lift': 3.2861842105263155}
# INFO:root:400313 / 463415: {'rule': ('per_all_li_18=>(0.0, 0.31703225175887484)', 'per_limove_12=>(0.0, 0.3834065643589453)', 'aboverm_ch_per_col_00_18=>1'), 'group': 'typology=>9.0', 'lift': 3.55205047318612}
# INFO:root:400316 / 463415: {'rule': ('per_all_li_18=>(0.0, 0.31703225175887484)', 'per_limove_12=>(0.0, 0.3834065643589453)', 'hotmarket_00=>1.0'), 'group': 'typology=>9.0', 'lift': 3.3574007220216604}
# INFO:root:400317 / 463415: {'rule': ('per_all_li_18=>(0.0, 0.31703225175887484)', 'per_limove_12=>(0.0, 0.3834065643589453)', 'dp_RentGap=>0'), 'group': 'typology=>9.0', 'lift': 3.10828025477707}
# INFO:root:400360 / 463415: {'rule': ('per_all_li_18=>(0.0, 0.31703225175887484)', 'pctch_real_mhval_00_18=>(0.3924460233531615, 0.6706967687359844)', 'change_flag_category=>ch_rapid_increase'), 'group': 'typology=>9.0', 'lift': 3.1351351351351346}
# INFO:root:400399 / 463415: {'rule': ('per_all_li_18=>(0.0, 0.31703225175887484)', 'pctch_real_mrent_12_18=>(0.2164448712672062, 3.1496504993958303)', 'hv_abrm_ch=>1'), 'group': 'typology=>9.0', 'lift': 3.4}
# INFO:root:400400 / 463415: {'rule': ('per_all_li_18=>(0.0, 0.31703225175887484)', 'pctch_real_mrent_12_18=>(0.2164448712672062, 3.1496504993958303)', 'rent_abrm_ch=>1'), 'group': 'typology=>9.0', 'lift': 3.1488250652741514}
# INFO:root:400407 / 463415: {'rule': ('per_all_li_18=>(0.0, 0.31703225175887484)', 'pctch_real_mrent_12_18=>(0.2164448712672062, 3.1496504993958303)', 'aboverm_per_all_li_00=>0'), 'group': 'typology=>9.0', 'lift': 3.219101123595506}
# INFO:root:400408 / 463415: {'rule': ('per_all_li_18=>(0.0, 0.31703225175887484)', 'pctch_real_mrent_12_18=>(0.2164448712672062, 3.1496504993958303)', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>9.0', 'lift': 3.2219321148825064}
# INFO:root:400415 / 463415: {'rule': ('per_all_li_18=>(0.0, 0.31703225175887484)', 'pctch_real_mrent_12_18=>(0.2164448712672062, 3.1496504993958303)', 'aboverm_per_col_90=>1'), 'group': 'typology=>9.0', 'lift': 3.19375}
# INFO:root:400416 / 463415: {'rule': ('per_all_li_18=>(0.0, 0.31703225175887484)', 'pctch_real_mrent_12_18=>(0.2164448712672062, 3.1496504993958303)', 'aboverm_per_col_00=>1'), 'group': 'typology=>9.0', 'lift': 3.1904761904761902}
# INFO:root:400417 / 463415: {'rule': ('per_all_li_18=>(0.0, 0.31703225175887484)', 'pctch_real_mrent_12_18=>(0.2164448712672062, 3.1496504993958303)', 'aboverm_per_col_18=>1'), 'group': 'typology=>9.0', 'lift': 3.2238372093023258}
# INFO:root:400419 / 463415: {'rule': ('per_all_li_18=>(0.0, 0.31703225175887484)', 'pctch_real_mrent_12_18=>(0.2164448712672062, 3.1496504993958303)', 'aboverm_real_mrent_00=>1'), 'group': 'typology=>9.0', 'lift': 3.2540192926045015}
# INFO:root:400420 / 463415: {'rule': ('per_all_li_18=>(0.0, 0.31703225175887484)', 'pctch_real_mrent_12_18=>(0.2164448712672062, 3.1496504993958303)', 'aboverm_real_mrent_12=>1'), 'group': 'typology=>9.0', 'lift': 3.1646706586826348}
# INFO:root:400421 / 463415: {'rule': ('per_all_li_18=>(0.0, 0.31703225175887484)', 'pctch_real_mrent_12_18=>(0.2164448712672062, 3.1496504993958303)', 'aboverm_real_mrent_18=>1'), 'group': 'typology=>9.0', 'lift': 3.2593582887700534}
# INFO:root:400422 / 463415: {'rule': ('per_all_li_18=>(0.0, 0.31703225175887484)', 'pctch_real_mrent_12_18=>(0.2164448712672062, 3.1496504993958303)', 'aboverm_real_mhval_90=>1'), 'group': 'typology=>9.0', 'lift': 3.323232323232323}
# INFO:root:400423 / 463415: {'rule': ('per_all_li_18=>(0.0, 0.31703225175887484)', 'pctch_real_mrent_12_18=>(0.2164448712672062, 3.1496504993958303)', 'aboverm_real_mhval_00=>1'), 'group': 'typology=>9.0', 'lift': 3.2699386503067482}
# INFO:root:400424 / 463415: {'rule': ('per_all_li_18=>(0.0, 0.31703225175887484)', 'pctch_real_mrent_12_18=>(0.2164448712672062, 3.1496504993958303)', 'aboverm_real_mhval_18=>1'), 'group': 'typology=>9.0', 'lift': 3.151098901098901}
# INFO:root:400425 / 463415: {'rule': ('per_all_li_18=>(0.0, 0.31703225175887484)', 'pctch_real_mrent_12_18=>(0.2164448712672062, 3.1496504993958303)', 'aboverm_pctch_real_mrent_12_18=>1'), 'group': 'typology=>9.0', 'lift': 3.195822454308094}
# INFO:root:400426 / 463415: {'rule': ('per_all_li_18=>(0.0, 0.31703225175887484)', 'pctch_real_mrent_12_18=>(0.2164448712672062, 3.1496504993958303)', 'aboverm_ch_per_col_90_00=>1'), 'group': 'typology=>9.0', 'lift': 4.171428571428572}
# INFO:root:400427 / 463415: {'rule': ('per_all_li_18=>(0.0, 0.31703225175887484)', 'pctch_real_mrent_12_18=>(0.2164448712672062, 3.1496504993958303)', 'aboverm_ch_per_col_00_18=>1'), 'group': 'typology=>9.0', 'lift': 3.859848484848485}
# INFO:root:400428 / 463415: {'rule': ('per_all_li_18=>(0.0, 0.31703225175887484)', 'pctch_real_mrent_12_18=>(0.2164448712672062, 3.1496504993958303)', 'aboverm_per_units_pre50_18=>0'), 'group': 'typology=>9.0', 'lift': 3.417021276595745}
# INFO:root:400430 / 463415: {'rule': ('per_all_li_18=>(0.0, 0.31703225175887484)', 'pctch_real_mrent_12_18=>(0.2164448712672062, 3.1496504993958303)', 'hotmarket_00=>1.0'), 'group': 'typology=>9.0', 'lift': 3.5959183673469384}
# INFO:root:400431 / 463415: {'rule': ('per_all_li_18=>(0.0, 0.31703225175887484)', 'pctch_real_mrent_12_18=>(0.2164448712672062, 3.1496504993958303)', 'dp_RentGap=>0'), 'group': 'typology=>9.0', 'lift': 3.0532915360501565}
# INFO:root:400435 / 463415: {'rule': ('per_all_li_18=>(0.0, 0.31703225175887484)', 'house_increase=>1', 'hv_abrm_ch=>1'), 'group': 'typology=>9.0', 'lift': 3.564516129032258}
# INFO:root:400438 / 463415: {'rule': ('per_all_li_18=>(0.0, 0.31703225175887484)', 'house_increase=>1', 'pctch_real_hinc_00_18=>(-0.04848044320668265, 0.19889357457847068)'), 'group': 'typology=>9.0', 'lift': 3.9306358381502893}
# INFO:root:400440 / 463415: {'rule': ('per_all_li_18=>(0.0, 0.31703225175887484)', 'house_increase=>1', 'ch_per_col_00_18=>(0.14730804093336136, 0.5292914867076665)'), 'group': 'typology=>9.0', 'lift': 3.803468208092485}
# INFO:root:400446 / 463415: {'rule': ('per_all_li_18=>(0.0, 0.31703225175887484)', 'house_increase=>1', 'aboverm_per_nonwhite_90=>1'), 'group': 'typology=>7.0', 'lift': 3.4747474747474745}
# INFO:root:400462 / 463415: {'rule': ('per_all_li_18=>(0.0, 0.31703225175887484)', 'house_increase=>1', 'aboverm_ch_per_col_90_00=>1'), 'group': 'typology=>9.0', 'lift': 3.7083333333333335}
# ...
# INFO:root:458354 / 463415: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'aboverm_real_mrent_00=>1', 'aboverm_real_mhval_18=>1'), 'group': 'typology=>9.0', 'lift': 9.5}
# INFO:root:458356 / 463415: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'aboverm_real_mrent_00=>1', 'aboverm_ch_per_col_90_00=>0'), 'group': 'typology=>9.0', 'lift': 6.3076923076923075}
# INFO:root:458359 / 463415: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'aboverm_real_mrent_00=>1', 'presence_ph_LIHTC=>False'), 'group': 'typology=>9.0', 'lift': 6.096385542168675}
# INFO:root:458360 / 463415: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'aboverm_real_mrent_00=>1', 'hotmarket_00=>1.0'), 'group': 'typology=>9.0', 'lift': 8.117647058823529}
# INFO:root:458363 / 463415: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'aboverm_real_mrent_12=>1', 'aboverm_ch_per_col_90_00=>0'), 'group': 'typology=>9.0', 'lift': 8.702702702702704}
# INFO:root:458366 / 463415: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'aboverm_real_mrent_18=>1', 'aboverm_ch_per_col_90_00=>0'), 'group': 'typology=>9.0', 'lift': 7.6923076923076925}
# INFO:root:458369 / 463415: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'aboverm_real_mhval_90=>1', 'aboverm_ch_per_col_90_00=>0'), 'group': 'typology=>9.0', 'lift': 5.75}
# INFO:root:458372 / 463415: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'aboverm_real_mhval_00=>1', 'aboverm_ch_per_col_90_00=>0'), 'group': 'typology=>9.0', 'lift': 5.9399999999999995}
# INFO:root:458375 / 463415: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'aboverm_real_mhval_18=>1', 'aboverm_ch_per_col_90_00=>0'), 'group': 'typology=>9.0', 'lift': 6.4750000000000005}
# INFO:root:458385 / 463415: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'aboverm_ch_per_col_90_00=>0', 'presence_ph_LIHTC=>False'), 'group': 'typology=>9.0', 'lift': 5.840000000000001}
# INFO:root:458686 / 463415: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'aboverm_per_all_li_90=>0', 'dp_RentGap=>0'), 'group': 'typology=>9.0', 'lift': 8.6}
# INFO:root:458690 / 463415: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'aboverm_per_all_li_00=>0', 'dp_RentGap=>0'), 'group': 'typology=>9.0', 'lift': 8.817073170731707}
# INFO:root:458698 / 463415: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'aboverm_per_nonwhite_90=>0', 'dp_RentGap=>0'), 'group': 'typology=>9.0', 'lift': 8.826086956521738}
# INFO:root:458706 / 463415: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'aboverm_per_rent_90=>0', 'dp_RentGap=>0'), 'group': 'typology=>9.0', 'lift': 9.063291139240507}
# INFO:root:458714 / 463415: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'aboverm_per_rent_18=>0', 'dp_RentGap=>0'), 'group': 'typology=>9.0', 'lift': 8.963414634146341}
# INFO:root:458718 / 463415: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'aboverm_per_col_90=>1', 'dp_RentGap=>0'), 'group': 'typology=>9.0', 'lift': 8.049382716049383}
# INFO:root:458722 / 463415: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'aboverm_per_col_00=>1', 'dp_RentGap=>0'), 'group': 'typology=>9.0', 'lift': 7.98780487804878}
# INFO:root:458728 / 463415: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'aboverm_real_mrent_90=>1', 'dp_RentGap=>0'), 'group': 'typology=>9.0', 'lift': 8.232876712328766}
# INFO:root:458732 / 463415: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'aboverm_real_mrent_00=>1', 'dp_RentGap=>0'), 'group': 'typology=>9.0', 'lift': 8.166666666666666}
# INFO:root:458753 / 463415: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'aboverm_per_units_pre50_18=>0', 'presence_ph_LIHTC=>False'), 'group': 'typology=>9.0', 'lift': 8.872340425531917}
# INFO:root:459427 / 463415: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'rent_abrm_ch=>1', 'aboverm_per_all_li_90=>0'), 'group': 'typology=>9.0', 'lift': 8.461538461538462}
# INFO:root:459428 / 463415: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'rent_abrm_ch=>1', 'aboverm_per_all_li_00=>0'), 'group': 'typology=>9.0', 'lift': 9.128205128205128}
# INFO:root:459429 / 463415: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'rent_abrm_ch=>1', 'aboverm_per_nonwhite_90=>0'), 'group': 'typology=>9.0', 'lift': 8.923076923076923}
# INFO:root:459430 / 463415: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'rent_abrm_ch=>1', 'aboverm_per_nonwhite_00=>0'), 'group': 'typology=>9.0', 'lift': 9.694915254237287}
# INFO:root:459431 / 463415: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'rent_abrm_ch=>1', 'aboverm_per_rent_90=>0'), 'group': 'typology=>9.0', 'lift': 8.169014084507042}
# INFO:root:459432 / 463415: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'rent_abrm_ch=>1', 'aboverm_per_rent_00=>0'), 'group': 'typology=>9.0', 'lift': 8.055555555555555}
# INFO:root:459433 / 463415: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'rent_abrm_ch=>1', 'aboverm_per_rent_18=>0'), 'group': 'typology=>9.0', 'lift': 8.164383561643836}
# INFO:root:459434 / 463415: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'rent_abrm_ch=>1', 'aboverm_per_col_90=>1'), 'group': 'typology=>9.0', 'lift': 8.794871794871796}
# INFO:root:459435 / 463415: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'rent_abrm_ch=>1', 'aboverm_per_col_00=>1'), 'group': 'typology=>9.0', 'lift': 9.205128205128204}
# INFO:root:459436 / 463415: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'rent_abrm_ch=>1', 'aboverm_real_mrent_90=>1'), 'group': 'typology=>9.0', 'lift': 9.426470588235293}
# INFO:root:459449 / 463415: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'aboverm_per_all_li_90=>0', 'aboverm_pctch_real_mrent_12_18=>1'), 'group': 'typology=>9.0', 'lift': 8.64102564102564}
# INFO:root:459450 / 463415: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'aboverm_per_all_li_00=>0', 'aboverm_pctch_real_mrent_12_18=>1'), 'group': 'typology=>9.0', 'lift': 9.282051282051283}
# INFO:root:459451 / 463415: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'aboverm_per_nonwhite_90=>0', 'aboverm_pctch_real_mrent_12_18=>1'), 'group': 'typology=>9.0', 'lift': 9.153846153846153}
# INFO:root:459453 / 463415: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'aboverm_per_rent_90=>0', 'aboverm_pctch_real_mrent_12_18=>1'), 'group': 'typology=>9.0', 'lift': 8.380281690140846}
# INFO:root:459454 / 463415: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'aboverm_per_rent_00=>0', 'aboverm_pctch_real_mrent_12_18=>1'), 'group': 'typology=>9.0', 'lift': 8.23611111111111}
# INFO:root:459455 / 463415: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'aboverm_per_rent_18=>0', 'aboverm_pctch_real_mrent_12_18=>1'), 'group': 'typology=>9.0', 'lift': 8.356164383561644}
# INFO:root:459456 / 463415: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'aboverm_per_col_90=>1', 'aboverm_pctch_real_mrent_12_18=>1'), 'group': 'typology=>9.0', 'lift': 8.923076923076923}
# INFO:root:459457 / 463415: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'aboverm_per_col_00=>1', 'aboverm_pctch_real_mrent_12_18=>1'), 'group': 'typology=>9.0', 'lift': 9.35897435897436}
# INFO:root:459465 / 463415: {'rule': ('low_80120_18=>(0.0, 0.31703225175887484)', 'lmh_flag_category=>aff_predominantly_HI', 'change_flag_category=>ch_rapid_increase'), 'group': 'typology=>9.0', 'lift': 8.41025641025641}
# INFO:root:459467 / 463415: {'rule': ('mod_80120_18=>(0.0, 0.13899855886002244)', 'lmh_flag_category=>aff_predominantly_HI', 'change_flag_category=>ch_rapid_increase'), 'group': 'typology=>9.0', 'lift': 7.4375}
# INFO:root:459469 / 463415: {'rule': ('high_80120_18=>(0.5114549772564095, 1.0)', 'lmh_flag_category=>aff_predominantly_HI', 'change_flag_category=>ch_rapid_increase'), 'group': 'typology=>9.0', 'lift': 8.5}
# INFO:root:459471 / 463415: {'rule': ('low_80120_00=>(0.0, 0.25691207599591875)', 'lmh_flag_category=>aff_predominantly_HI', 'change_flag_category=>ch_rapid_increase'), 'group': 'typology=>9.0', 'lift': 7.893333333333333}
# INFO:root:459473 / 463415: {'rule': ('mod_80120_00=>(0.0, 0.15833002643919428)', 'lmh_flag_category=>aff_predominantly_HI', 'change_flag_category=>ch_rapid_increase'), 'group': 'typology=>9.0', 'lift': 7.960000000000001}
# INFO:root:459475 / 463415: {'rule': ('high_80120_00=>(0.5639943680683175, 1.0)', 'lmh_flag_category=>aff_predominantly_HI', 'change_flag_category=>ch_rapid_increase'), 'group': 'typology=>9.0', 'lift': 7.922077922077921}
# INFO:root:459477 / 463415: {'rule': ('per_all_li_90=>(0.0, 0.1634784911133197)', 'lmh_flag_category=>aff_predominantly_HI', 'change_flag_category=>ch_rapid_increase'), 'group': 'typology=>9.0', 'lift': 7.675324675324675}
# INFO:root:459479 / 463415: {'rule': ('per_all_li_00=>(0.0, 0.25691207599591875)', 'lmh_flag_category=>aff_predominantly_HI', 'change_flag_category=>ch_rapid_increase'), 'group': 'typology=>9.0', 'lift': 7.893333333333333}
# INFO:root:459481 / 463415: {'rule': ('per_all_li_18=>(0.0, 0.31703225175887484)', 'lmh_flag_category=>aff_predominantly_HI', 'change_flag_category=>ch_rapid_increase'), 'group': 'typology=>9.0', 'lift': 8.41025641025641}
# INFO:root:459489 / 463415: {'rule': ('per_rent_90=>(0.0, 0.2821738420165493)', 'lmh_flag_category=>aff_predominantly_HI', 'change_flag_category=>ch_rapid_increase'), 'group': 'typology=>9.0', 'lift': 8.53968253968254}
# INFO:root:459491 / 463415: {'rule': ('per_rent_00=>(0.022388215222427225, 0.2718393922951709)', 'lmh_flag_category=>aff_predominantly_HI', 'change_flag_category=>ch_rapid_increase'), 'group': 'typology=>9.0', 'lift': 8.029411764705882}
# INFO:root:459493 / 463415: {'rule': ('per_rent_18=>(0.0, 0.30114942528735633)', 'lmh_flag_category=>aff_predominantly_HI', 'change_flag_category=>ch_rapid_increase'), 'group': 'typology=>9.0', 'lift': 8.098591549295774}
# INFO:root:459499 / 463415: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'pctch_real_mhval_00_18=>(-inf, 0.39189796836038093)', 'change_flag_category=>ch_rapid_increase'), 'group': 'typology=>9.0', 'lift': 6.7250000000000005}
# INFO:root:459534 / 463415: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'pctch_real_mrent_12_18=>(0.2164448712672062, 3.1496504993958303)', 'presence_ph_LIHTC=>False'), 'group': 'typology=>9.0', 'lift': 7.9315068493150696}
# INFO:root:459541 / 463415: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'change_flag_category=>ch_rapid_increase', 'rent_abrm_ch=>1'), 'group': 'typology=>9.0', 'lift': 7.213483146067417}
# INFO:root:459547 / 463415: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'change_flag_category=>ch_rapid_increase', 'aboverm_per_all_li_90=>0'), 'group': 'typology=>9.0', 'lift': 6.012820512820513}
# INFO:root:459548 / 463415: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'change_flag_category=>ch_rapid_increase', 'aboverm_per_all_li_00=>0'), 'group': 'typology=>9.0', 'lift': 6.461538461538462}
# INFO:root:459549 / 463415: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'change_flag_category=>ch_rapid_increase', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>9.0', 'lift': 7.089743589743589}
# INFO:root:459550 / 463415: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'change_flag_category=>ch_rapid_increase', 'aboverm_per_nonwhite_18=>0'), 'group': 'typology=>9.0', 'lift': 7.137931034482757}
# INFO:root:459551 / 463415: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'change_flag_category=>ch_rapid_increase', 'aboverm_per_nonwhite_90=>0'), 'group': 'typology=>9.0', 'lift': 6.21875}
# INFO:root:459552 / 463415: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'change_flag_category=>ch_rapid_increase', 'aboverm_per_nonwhite_00=>0'), 'group': 'typology=>9.0', 'lift': 6.6440677966101696}
# INFO:root:459553 / 463415: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'change_flag_category=>ch_rapid_increase', 'aboverm_per_rent_90=>0'), 'group': 'typology=>9.0', 'lift': 6.289855072463768}
# INFO:root:459554 / 463415: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'change_flag_category=>ch_rapid_increase', 'aboverm_per_rent_00=>0'), 'group': 'typology=>9.0', 'lift': 6.114285714285715}
# INFO:root:459555 / 463415: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'change_flag_category=>ch_rapid_increase', 'aboverm_per_rent_18=>0'), 'group': 'typology=>9.0', 'lift': 6.095890410958904}
# INFO:root:459556 / 463415: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'change_flag_category=>ch_rapid_increase', 'aboverm_per_col_90=>1'), 'group': 'typology=>9.0', 'lift': 6.256410256410256}
# INFO:root:459557 / 463415: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'change_flag_category=>ch_rapid_increase', 'aboverm_per_col_00=>1'), 'group': 'typology=>9.0', 'lift': 6.666666666666667}
# INFO:root:459558 / 463415: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'change_flag_category=>ch_rapid_increase', 'aboverm_per_col_18=>1'), 'group': 'typology=>9.0', 'lift': 7.051282051282052}
# INFO:root:459559 / 463415: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'change_flag_category=>ch_rapid_increase', 'aboverm_real_mrent_90=>1'), 'group': 'typology=>9.0', 'lift': 5.955223880597015}
# INFO:root:459560 / 463415: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'change_flag_category=>ch_rapid_increase', 'aboverm_real_mrent_00=>1'), 'group': 'typology=>9.0', 'lift': 6.015151515151516}
# INFO:root:459561 / 463415: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'change_flag_category=>ch_rapid_increase', 'aboverm_real_mrent_12=>1'), 'group': 'typology=>9.0', 'lift': 6.45945945945946}
# INFO:root:459562 / 463415: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'change_flag_category=>ch_rapid_increase', 'aboverm_real_mrent_18=>1'), 'group': 'typology=>9.0', 'lift': 7.350649350649351}
# INFO:root:459563 / 463415: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'change_flag_category=>ch_rapid_increase', 'aboverm_real_mhval_90=>1'), 'group': 'typology=>9.0', 'lift': 6.3561643835616435}
# INFO:root:459564 / 463415: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'change_flag_category=>ch_rapid_increase', 'aboverm_real_mhval_00=>1'), 'group': 'typology=>9.0', 'lift': 6.6}
# INFO:root:459565 / 463415: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'change_flag_category=>ch_rapid_increase', 'aboverm_real_mhval_18=>1'), 'group': 'typology=>9.0', 'lift': 7.23076923076923}
# INFO:root:459566 / 463415: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'change_flag_category=>ch_rapid_increase', 'aboverm_pctch_real_mrent_12_18=>1'), 'group': 'typology=>9.0', 'lift': 7.337078651685394}
# INFO:root:459567 / 463415: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'change_flag_category=>ch_rapid_increase', 'aboverm_ch_per_col_90_00=>0'), 'group': 'typology=>9.0', 'lift': 5.634146341463414}
# INFO:root:459568 / 463415: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'change_flag_category=>ch_rapid_increase', 'aboverm_ch_per_col_00_18=>1'), 'group': 'typology=>9.0', 'lift': 8.253521126760564}
# INFO:root:459570 / 463415: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'change_flag_category=>ch_rapid_increase', 'presence_ph_LIHTC=>False'), 'group': 'typology=>9.0', 'lift': 4.500000000000001}
# INFO:root:459571 / 463415: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'change_flag_category=>ch_rapid_increase', 'hotmarket_00=>1.0'), 'group': 'typology=>9.0', 'lift': 6.323943661971831}
# INFO:root:459572 / 463415: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'change_flag_category=>ch_rapid_increase', 'dp_RentGap=>0'), 'group': 'typology=>9.0', 'lift': 5.690476190476191}
# INFO:root:459862 / 463415: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'change_flag_category=>ch_rapid_increase', 'hv_abrm_ch=>0'), 'group': 'typology=>9.0', 'lift': 6.945454545454544}
# INFO:root:459971 / 463415: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'change_flag_category=>ch_rapid_increase', 'aboverm_per_units_pre50_18=>0'), 'group': 'typology=>9.0', 'lift': 6.298245614035088}

# %%
output.to_csv("{}/data/stucco/stucco_{}".format(customized_path_to_homework, file_name))

# %% [markdown]
# ###  Rule Metrics

# %% [markdown]
# **Rules with high Lift and Confidence**

# %% [markdown]
# ref: http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.150.6616&rep=rep1&type=pdf
#
# Confidence ranges from 0 to 1. Confidence is an estimate of Pr(C | A), the
# probability of observing C given A. After obtaining a rule set, one can immediatly
# use confidence as a basis for classifying one new case x. Of all the rules that
# apply to x (i.e., the rules whose antecedent is true in x), we choose the one
# with highest confidence. This loosely follows the optimal Bayes classifier

# %% [markdown]
# ref: http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.150.6616&rep=rep1&type=pdf
#
# Conviction is another measure proposed in [4] to tackle some of the weaknesses of confidence and lift. Unlike lift, conviction is sensitive to rule direction
# (conv(A → C) 6= conv(C → A)). Conviction is somewhat inspired in the logical
# definition of implication and attempts to measure the degree of implication of
# a rule. Conviction is infinite for logical implications (confidence 1), and is 1 if
# A and C are independent

# %% [markdown]
# ref: http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.150.6616&rep=rep1&type=pdf
#
# Lift measures how far from independence are A and C. It ranges within
# [0, +∞[. Values close to 1 imply that A and C are independent and the rule
# is not interesting.
