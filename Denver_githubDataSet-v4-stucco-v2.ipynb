# %% [markdown]
# **CS 5834, Fall 2020: Intro to Urban Computing Project - STUCCO analysis for Gentrification using Denver Data Set**

# %% [markdown]
# ### Imports and Mount File Directories

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
# modify "customized_path_to_homework", path of folder in drive, where you project is stored
customized_path_to_homework = "/content/drive/My Drive/cs5834/urbcomp_fall2020/project"
file_name = "Denver_typology_output.csv"

sys.path.append(customized_path_to_homework)

# %%
# %cd $customized_path_to_homework/data
# Out:
# /content/drive/My Drive/cs5834/urbcomp_fall2020/project/data

# %%
import os, sys
import pandas as pd
import numpy as np
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
import datetime
import warnings

# %%
"""
sys.path.insert(0,'../')
# %load_ext autoreload
# %autoreload 2
import nyctaxi_helpers
warnings.filterwarnings('ignore')
"""
# Out:
# "\nsys.path.insert(0,'../')\n%load_ext autoreload\n%autoreload 2\nimport nyctaxi_helpers\nwarnings.filterwarnings('ignore')\n"

# %%
#pip install --upgrade mlxtend

# %%
#ref https://pbpython.com/market-basket-analysis.html


#may need to install mlxtend package - pip install mlxtend in console
import pandas as pd
# #from mlxtend.frequent_patterns import apriori
# from mlxtend.frequent_patterns import fpgrowth
# from mlxtend.frequent_patterns import association_rules

# %%
# !wget -nc https://raw.githubusercontent.com/parsahosseini/contrast/master/stucco.py
# Out:
# File ‘stucco.py’ already there; not retrieving.

# %% [markdown]
# # **Process Urban Displacement Model Data for Gentrificaiton**

# %% [markdown]
# Reference: https://www.urbandisplacement.org/open-source-project

# %% [markdown]
# Based on the work https://ww2.arb.ca.gov/sites/default/files/classic//research/apr/past/13-310.pdf?_ga=2.269282425.968981409.1605209194-851335111.1605209194
#
# **Developing a New
# Methodology for Analyzing
# Potential Displacement**
#
# University of California, Berkeley
#
# Principal Investigator:
# Karen Chapple
#
# https://ww3.arb.ca.gov/research/single-project.php?row_id=65188

# %% [markdown]
# ## **Obtain the Data**
#
# Data can be found at https://github.com/urban-displacement/displacement-typologies/blob/main/data/outputs/typologies/LosAngeles_typology_output.csv

# %%
download_file = ("https://raw.githubusercontent.com/urban-displacement/displacement-typologies/main/data/outputs/typologies/{}".format(file_name))

# %%
#!wget -nc $download_file

# %%
## Process Data - if data file already processed then can start at Associaton Rules section
# get the Data File

df = pd.read_csv("https://raw.githubusercontent.com/urban-displacement/displacement-typologies/main/data/outputs/typologies/{}".format(file_name), index_col=0)
#df = pd.read_csv("{}/data/{}".format(customized_path_to_homework, file_name), index_col=0)

# sneak peak in the data
df.head(10)
# Out:
#    pop_18  white_18   hh_18  hinc_18  ...  LISD  double_counted  typology   typ_cat
# 0  3850.0    1619.0  1618.0  55541.0  ...     1             1.0       1.0  ['LISD']
# 1  3165.0    1994.0  1859.0  62664.0  ...     0             1.0       6.0  ['SMMI']
# 2  1462.0     182.0   465.0   9766.0  ...     0             1.0       3.0   ['ARG']
# 3  6276.0    1176.0  1897.0  56042.0  ...     0             1.0       3.0   ['ARG']
# 4  6654.0    1654.0  1977.0  43594.0  ...     0             1.0       3.0   ['ARG']
# 5  2652.0     961.0  1009.0  55568.0  ...     0             1.0       2.0    ['OD']
# 6  5428.0    1127.0  1727.0  53180.0  ...     1             1.0       1.0  ['LISD']
# 7  4076.0    1151.0  1446.0  42474.0  ...     0             1.0       3.0   ['ARG']
# 8  4945.0    1103.0  1539.0  45840.0  ...     0             1.0       3.0   ['ARG']
# 9  4253.0    3134.0  2637.0  65408.0  ...     0             1.0       6.0  ['SMMI']
#
# [10 rows x 305 columns]

# %%
df.columns
# Out:
# Index(['pop_18', 'white_18', 'hh_18', 'hinc_18', 'mhval_18', 'mhval_18_se',
#        'mrent_18', 'mrent_18_se', 'total_25_18', 'total_25_col_bd_18',
#        ...
#        'BE', 'SMMI', 'ARG', 'EOG', 'OD', 'OD_loss', 'LISD', 'double_counted',
#        'typology', 'typ_cat'],
#       dtype='object', length=305)

# %%
"""
# create a working copy of the data to process
df2 = df.copy()

#removed  'inc_cat_medhhinc_encoded18', 'inc_cat_medhhinc_encoded00',
df2 = df2[[ 'inc80_18',
 'inc120_18',
 'inc80_00',
 'inc120_00',
 'inc80_90',
 'low_80120_18',
 'mod_80120_18',
 'high_80120_18',
 'low_pdmt_medhhinc_18',
 'high_pdmt_medhhinc_18',
 'mod_pdmt_medhhinc_18',
 'mix_low_medhhinc_18',
 'mix_mod_medhhinc_18',
 'mix_high_medhhinc_18',

 'low_80120_00',
 'mod_80120_00',
 'high_80120_00',
 'low_pdmt_medhhinc_00',
 'high_pdmt_medhhinc_00',
 'mod_pdmt_medhhinc_00',
 'mix_low_medhhinc_00',
 'mix_mod_medhhinc_00',
 'mix_high_medhhinc_00',

 'per_all_li_90',
 'per_all_li_00',
 'per_all_li_18',
 'per_nonwhite_90',
 'per_nonwhite_00',
 'per_nonwhite_18',
 'per_rent_90',
 'per_rent_00',
 'per_rent_18',
 'per_col_90',
 'per_col_00',
 'per_col_18',
 'per_units_pre50_18',
 'per_limove_18',
 'per_limove_12',
 'lmh_flag_category',
 'pctch_real_mhval_00_18',
 'pctch_real_mrent_12_18',
 'rent_decrease',
 'rent_marginal',
 'rent_increase',
 'rent_rapid_increase',
 'house_decrease',
 'house_marginal',
 'house_increase',
 'house_rapid_increase',
 'tot_decrease',
 'tot_marginal',
 'tot_increase',
 'tot_rapid_increase',
 'change_flag_category',
 'per_ch_zillow_12_18',
 'ab_50pct_ch',
 'ab_90percentile_ch',
 'rent_50pct_ch',
 'rent_90percentile_ch',
 'hv_abrm_ch',
 'rent_abrm_ch',
 'pctch_real_mhval_90_00',
 'pctch_real_mrent_90_00',
 'pctch_real_hinc_90_00',
 'pctch_real_mrent_00_18',
 'pctch_real_hinc_00_18',
 'ch_per_col_90_00',
 'ch_per_col_00_18',
 'ch_per_limove_12_18',
 'aboverm_per_all_li_90',
 'aboverm_per_all_li_00',
 'aboverm_per_all_li_18',
 'aboverm_per_nonwhite_18',
 'aboverm_per_nonwhite_90',
 'aboverm_per_nonwhite_00',
 'aboverm_per_rent_90',
 'aboverm_per_rent_00',
 'aboverm_per_rent_18',
 'aboverm_per_col_90',
 'aboverm_per_col_00',
 'aboverm_per_col_18',
 'aboverm_real_mrent_90',
 'aboverm_real_mrent_00',
 'aboverm_real_mrent_12',
 'aboverm_real_mrent_18',
 'aboverm_real_mhval_90',
 'aboverm_real_mhval_00',
 'aboverm_real_mhval_18',
 'aboverm_pctch_real_mhval_00_18',
 'aboverm_pctch_real_mrent_00_18',
 'aboverm_pctch_real_mrent_12_18',
 'aboverm_pctch_real_mhval_90_00',
 'aboverm_pctch_real_mrent_90_00',
 'lostli_00',
 'lostli_18',
 'aboverm_pctch_real_hinc_90_00',
 'aboverm_pctch_real_hinc_00_18',
 'aboverm_ch_per_col_90_00',
 'aboverm_ch_per_col_00_18',
 'aboverm_per_units_pre50_18',
 'GEOID',
 'rail',
 'presence_ph_LIHTC',
 'hotmarket_00',
 'hotmarket_18',
 'dp_PChRent',
 'dp_RentGap',
 'dense',
 'typology']]


# drop rows which dont have a gentrification category
df2.dropna(subset=['typology'], inplace=True)
df2 = df2.set_index('GEOID')

#fill the nas
df2.fillna(0.0, inplace=True)


df2.head(10)
"""
# Out:
# "\n# create a working copy of the data to process\ndf2 = df.copy()\n\n#removed  'inc_cat_medhhinc_encoded18', 'inc_cat_medhhinc_encoded00',\ndf2 = df2[[ 'inc80_18',\n 'inc120_18',\n 'inc80_00',\n 'inc120_00',\n 'inc80_90',\n 'low_80120_18',\n 'mod_80120_18',\n 'high_80120_18',\n 'low_pdmt_medhhinc_18',\n 'high_pdmt_medhhinc_18',\n 'mod_pdmt_medhhinc_18',\n 'mix_low_medhhinc_18',\n 'mix_mod_medhhinc_18',\n 'mix_high_medhhinc_18',\n\n 'low_80120_00',\n 'mod_80120_00',\n 'high_80120_00',\n 'low_pdmt_medhhinc_00',\n 'high_pdmt_medhhinc_00',\n 'mod_pdmt_medhhinc_00',\n 'mix_low_medhhinc_00',\n 'mix_mod_medhhinc_00',\n 'mix_high_medhhinc_00',\n\n 'per_all_li_90',\n 'per_all_li_00',\n 'per_all_li_18',\n 'per_nonwhite_90',\n 'per_nonwhite_00',\n 'per_nonwhite_18',\n 'per_rent_90',\n 'per_rent_00',\n 'per_rent_18',\n 'per_col_90',\n 'per_col_00',\n 'per_col_18',\n 'per_units_pre50_18',\n 'per_limove_18',\n 'per_limove_12',\n 'lmh_flag_category',\n 'pctch_real_mhval_00_18',\n 'pctch_real_mrent_12_18',\n 'rent_decrease',\n 'rent_marginal',\n 'rent_increase',\n 'rent_rapid_increase',\n 'house_decrease',\n 'house_marginal',\n 'house_increase',\n 'house_rapid_increase',\n 'tot_decrease',\n 'tot_marginal',\n 'tot_increase',\n 'tot_rapid_increase',\n 'change_flag_category',\n 'per_ch_zillow_12_18',\n 'ab_50pct_ch',\n 'ab_90percentile_ch',\n 'rent_50pct_ch',\n 'rent_90percentile_ch',\n 'hv_abrm_ch',\n 'rent_abrm_ch',\n 'pctch_real_mhval_90_00',\n 'pctch_real_mrent_90_00',\n 'pctch_real_hinc_90_00',\n 'pctch_real_mrent_00_18',\n 'pctch_real_hinc_00_18',\n 'ch_per_col_90_00',\n 'ch_per_col_00_18',\n 'ch_per_limove_12_18',\n 'aboverm_per_all_li_90',\n 'aboverm_per_all_li_00',\n 'aboverm_per_all_li_18',\n 'aboverm_per_nonwhite_18',\n 'aboverm_per_nonwhite_90',\n 'aboverm_per_nonwhite_00',\n 'aboverm_per_rent_90',\n 'aboverm_per_rent_00',\n 'aboverm_per_rent_18',\n 'aboverm_per_col_90',\n 'aboverm_per_col_00',\n 'aboverm_per_col_18',\n 'aboverm_real_mrent_90',\n 'aboverm_real_mrent_00',\n 'aboverm_real_mrent_12',\n 'aboverm_real_mrent_18',\n 'aboverm_real_mhval_90',\n 'aboverm_real_mhval_00',\n 'aboverm_real_mhval_18',\n 'aboverm_pctch_real_mhval_00_18',\n 'aboverm_pctch_real_mrent_00_18',\n 'aboverm_pctch_real_mrent_12_18',\n 'aboverm_pctch_real_mhval_90_00',\n 'aboverm_pctch_real_mrent_90_00',\n 'lostli_00',\n 'lostli_18',\n 'aboverm_pctch_real_hinc_90_00',\n 'aboverm_pctch_real_hinc_00_18',\n 'aboverm_ch_per_col_90_00',\n 'aboverm_ch_per_col_00_18',\n 'aboverm_per_units_pre50_18',\n 'GEOID',\n 'rail',\n 'presence_ph_LIHTC',\n 'hotmarket_00',\n 'hotmarket_18',\n 'dp_PChRent',\n 'dp_RentGap',\n 'dense',\n 'typology']]\n\n\n# drop rows which dont have a gentrification category\ndf2.dropna(subset=['typology'], inplace=True)\ndf2 = df2.set_index('GEOID')\n\n#fill the nas\ndf2.fillna(0.0, inplace=True)\n\n\ndf2.head(10)\n"

# %%
# create a working copy of the data to process
df2 = df.copy()

"""
removed  'inc_cat_medhhinc_encoded18', 'inc_cat_medhhinc_encoded00', 
'inc80_18',
 'inc120_18',
 'inc80_00',
 'inc120_00',
 'inc80_90',
  'per_col_90',
 'per_col_00',
 'per_col_18',
  'tot_decrease',
 'tot_marginal',
 'tot_increase',
 'tot_rapid_increase',
  'pctch_real_mhval_90_00',
 'pctch_real_mrent_90_00',
 'pctch_real_mrent_00_18',
 'per_units_pre50_18',
  
"""

df2.head(10)
df2 = df2[[ 

 'low_80120_18',
 'mod_80120_18',
 'high_80120_18',
 'low_pdmt_medhhinc_18',
 'high_pdmt_medhhinc_18',
 'mod_pdmt_medhhinc_18',
 'mix_low_medhhinc_18',
 'mix_mod_medhhinc_18',
 'mix_high_medhhinc_18',

 'low_80120_00',
 'mod_80120_00',
 'high_80120_00',
 'low_pdmt_medhhinc_00',
 'high_pdmt_medhhinc_00',
 'mod_pdmt_medhhinc_00',
 'mix_low_medhhinc_00',
 'mix_mod_medhhinc_00',
 'mix_high_medhhinc_00',

 'per_all_li_90',
 'per_all_li_00',
 'per_all_li_18',
 'per_nonwhite_90',
 'per_nonwhite_00',
 'per_nonwhite_18',
 'per_rent_90',
 'per_rent_00',
 'per_rent_18',

 
 'per_limove_18',
 'per_limove_12',
 'lmh_flag_category',
 'pctch_real_mhval_00_18',
 'pctch_real_mrent_12_18',
 'rent_decrease',
 'rent_marginal',
 'rent_increase',
 'rent_rapid_increase',
 'house_decrease',
 'house_marginal',
 'house_increase',
 'house_rapid_increase',

 'change_flag_category',
 'per_ch_zillow_12_18',
 'ab_50pct_ch',
 'ab_90percentile_ch',
 'rent_50pct_ch',
 'rent_90percentile_ch',
 'hv_abrm_ch',
 'rent_abrm_ch',

 'pctch_real_hinc_90_00',
 
 'pctch_real_hinc_00_18',
 'ch_per_col_90_00',
 'ch_per_col_00_18',
 'ch_per_limove_12_18',
 'aboverm_per_all_li_90',
 'aboverm_per_all_li_00',
 'aboverm_per_all_li_18',
 'aboverm_per_nonwhite_18',
 'aboverm_per_nonwhite_90',
 'aboverm_per_nonwhite_00',
 'aboverm_per_rent_90',
 'aboverm_per_rent_00',
 'aboverm_per_rent_18',
 'aboverm_per_col_90',
 'aboverm_per_col_00',
 'aboverm_per_col_18',
 'aboverm_real_mrent_90',
 'aboverm_real_mrent_00',
 'aboverm_real_mrent_12',
 'aboverm_real_mrent_18',
 'aboverm_real_mhval_90',
 'aboverm_real_mhval_00',
 'aboverm_real_mhval_18',
 'aboverm_pctch_real_mhval_00_18',
 'aboverm_pctch_real_mrent_00_18',
 'aboverm_pctch_real_mrent_12_18',
 'aboverm_pctch_real_mhval_90_00',
 'aboverm_pctch_real_mrent_90_00',
 'lostli_00',
 'lostli_18',
 'aboverm_pctch_real_hinc_90_00',
 'aboverm_pctch_real_hinc_00_18',
 'aboverm_ch_per_col_90_00',
 'aboverm_ch_per_col_00_18',
 'aboverm_per_units_pre50_18',
 'GEOID',
 'rail',
 'presence_ph_LIHTC',
 'hotmarket_00',
 'hotmarket_18',
 'dp_PChRent',
 'dp_RentGap',
 'dense',
 'typology']]

# drop rows which dont have a gentrification category
df2.dropna(subset=['typology'], inplace=True)
df2 = df2.set_index('GEOID')

#fill the nas
df2.fillna(0.0, inplace=True)


df2.head(10)
# Out:
#             low_80120_18  mod_80120_18  ...  dense  typology
# GEOID                                   ...
# 8031000201      0.538912      0.198657  ...      0       1.0
# 8031000600      0.495830      0.142011  ...      0       6.0
# 8031000800      0.980645      0.000000  ...      0       3.0
# 8031000902      0.578164      0.202530  ...      0       3.0
# 8031000903      0.700942      0.165850  ...      0       3.0
# 8031001101      0.540785      0.125722  ...      0       2.0
# 8031001301      0.575720      0.230259  ...      0       1.0
# 8031001302      0.728506      0.142227  ...      0       3.0
# 8031001402      0.674258      0.152525  ...      0       3.0
# 8031001702      0.475096      0.122383  ...      0       6.0
#
# [10 rows x 92 columns]

# %% [markdown]
# ### Convert select continous variables to categorical and one hot encode

# %%
# # convert already dummy variables from float to int
# dummy_var_list = ['hotmarket_00', 'hotmarket_18', 'low_pdmt_medhhinc_00', 'high_pdmt_medhhinc_00', 'mod_pdmt_medhhinc_00',
#                   'mix_low_medhhinc_00', 'mix_mod_medhhinc_00',  'mix_high_medhhinc_00', 'low_pdmt_medhhinc_18', 'high_pdmt_medhhinc_18',
#                   'mod_pdmt_medhhinc_18', 'mix_low_medhhinc_18', 'mix_mod_medhhinc_18', 'mix_high_medhhinc_18', 'presence_ph_LIHTC',
#                   'typology']
# for dummycol in dummy_var_list:
#   df2.loc[:,(dummycol)] = df2[dummycol].astype(int, copy=False)

# %%
# use float variables to represent each categorical variable by dividing into quartiles
def convert_percents_to_dummy_vars(X):

    columns = X.columns

    bin_labels_4 = ['VL', 'L', 'H',  'VH']


    for i in range(0, len(columns)):
        if X[columns[i]].dtype=='float64':
          print("Processing: " + columns[i])

          X[columns[i]] = X[columns[i]].fillna(0)
          cat_label = "{}_cat".format(columns[i])
          dummy_label = "{}_dummy".format(columns[i])
          X[cat_label] = pd.qcut(X[columns[i]], 
                                 4,
                              precision=5,
                              duplicates = 'drop',
                              labels=bin_labels_4)
          X = pd.get_dummies(X, columns=[cat_label], prefix=[dummy_label])
          X = X.drop([columns[i]], axis=1)

    return X

# %%
# check if categorical then convert to dummy using label and onehot encoding
def convert_categorical_to_dummy_vars(X):

    from sklearn.preprocessing import LabelEncoder
    from sklearn.preprocessing import OneHotEncoder    

    columns = X.columns
    indices = X.index
    new_columns = []
    encoded_x = None

    for i in range(0, len(columns)):
        if X[columns[i]].dtype=='O':
          print("Processing: " + columns[i])


          label_encoder = LabelEncoder()
          le = label_encoder.fit(X[columns[i]].apply(str))
          for class_ in le.classes_:
              new_columns.append("{}_{}".format(columns[i],class_))
              
          feature = le.transform(X[columns[i]].apply(str))
          feature = feature.reshape(X.shape[0], 1)
          onehot_encoder = OneHotEncoder(sparse=False)
          onehot_encoder.fit(feature)
          feature = onehot_encoder.transform(feature)
          if encoded_x is None:
              encoded_x = feature
          else:
              encoded_x = np.concatenate((encoded_x, feature), axis=1)
          X = X.drop(columns[i], axis=1)
    new_columns.extend(X.columns)

    X = pd.DataFrame(np.concatenate((encoded_x,X),axis=1),index=indices,columns=new_columns)
    
    return X

# %% [markdown]
# ### Convert Percentage (floats) to Quartiles and Dummy Variables

# %%
# # process and save data all converted to one hot encoding
# df2 = convert_percents_to_dummy_vars(df2)

# %%
# df2 = convert_categorical_to_dummy_vars(df2)

# %% [markdown]
# iii. Save the dataset as a CSV file. The first line of the CSV file should be the attribute
# names as described in the previous question.

# %%
# df2.to_csv("{}/data/processed_{}".format(customized_path_to_homework, file_name))

# %% [markdown]
# # **STUCCO Rule Calculations**

# %%
# load already processed data 
# df3 = pd.read_csv("{}/data/processed_{}".format(customized_path_to_homework, file_name), index_col=0)
# df3 = df3.astype(int)

# %%
confidence_cut = 0.8
lift_cut = 1.0
conviction_cut = 0.8
support_cut = 0.65

# %%
#ref: https://www.ics.uci.edu/~pazzani/Publications/stucco.pdf
#ref: https://github.com/parsahosseini/contrast/blob/master/README.md

# %%
from stucco import ContrastSetLearner
learner = ContrastSetLearner(df2, group_feature='typology')
# Out:
# INFO:root:User-defined feature is 'typology'
# INFO:root:Data dimensions: 640 x 92
# INFO:root:Reading object features (n=3)
# INFO:root:Reading numeric features (n=89)
# INFO:root:32 features lack value; dropping
# INFO:root:New data dimensions: 640 x 60
# INFO:root:Record count (pre-index): 640
# INFO:root:Record count (index): 640

# %%
# derive 3-length combinations of a rule and enumerate their abundance.
learner.learn(max_length=3)
# Out:
# INFO:root:Enumerating 640 item-sets, i
# INFO:root:i=0; n(matrix)=0
# INFO:root:i=200; n(matrix)=350,696
# INFO:root:i=400; n(matrix)=472,011
# INFO:root:i=600; n(matrix)=478,254
# INFO:root:487,050 contingency matrices made
# INFO:root:i=0 matrix not-rules enumerated
# INFO:root:i=2500 matrix not-rules enumerated
# INFO:root:i=5000 matrix not-rules enumerated
# INFO:root:i=7500 matrix not-rules enumerated
# INFO:root:i=10000 matrix not-rules enumerated
# INFO:root:i=12500 matrix not-rules enumerated
# INFO:root:i=15000 matrix not-rules enumerated
# INFO:root:i=17500 matrix not-rules enumerated
# INFO:root:i=20000 matrix not-rules enumerated
# INFO:root:i=22500 matrix not-rules enumerated
# INFO:root:i=25000 matrix not-rules enumerated
# INFO:root:i=27500 matrix not-rules enumerated
# INFO:root:i=30000 matrix not-rules enumerated
# INFO:root:i=32500 matrix not-rules enumerated
# INFO:root:i=35000 matrix not-rules enumerated
# INFO:root:i=37500 matrix not-rules enumerated
# INFO:root:i=40000 matrix not-rules enumerated
# INFO:root:i=42500 matrix not-rules enumerated
# INFO:root:i=45000 matrix not-rules enumerated
# INFO:root:i=47500 matrix not-rules enumerated
# INFO:root:i=50000 matrix not-rules enumerated
# INFO:root:i=52500 matrix not-rules enumerated
# INFO:root:i=55000 matrix not-rules enumerated
# INFO:root:i=57500 matrix not-rules enumerated
# INFO:root:i=60000 matrix not-rules enumerated
# INFO:root:i=62500 matrix not-rules enumerated
# INFO:root:i=65000 matrix not-rules enumerated
# INFO:root:i=67500 matrix not-rules enumerated
# INFO:root:i=70000 matrix not-rules enumerated
# INFO:root:i=72500 matrix not-rules enumerated
# INFO:root:i=75000 matrix not-rules enumerated
# INFO:root:i=77500 matrix not-rules enumerated
# INFO:root:i=80000 matrix not-rules enumerated
# INFO:root:i=82500 matrix not-rules enumerated
# INFO:root:i=85000 matrix not-rules enumerated
# INFO:root:i=87500 matrix not-rules enumerated
# INFO:root:i=90000 matrix not-rules enumerated
# INFO:root:i=92500 matrix not-rules enumerated
# INFO:root:i=95000 matrix not-rules enumerated
# INFO:root:i=97500 matrix not-rules enumerated
# INFO:root:i=100000 matrix not-rules enumerated
# INFO:root:i=102500 matrix not-rules enumerated
# INFO:root:i=105000 matrix not-rules enumerated
# INFO:root:i=107500 matrix not-rules enumerated
# INFO:root:i=110000 matrix not-rules enumerated
# INFO:root:i=112500 matrix not-rules enumerated
# INFO:root:i=115000 matrix not-rules enumerated
# INFO:root:i=117500 matrix not-rules enumerated
# INFO:root:i=120000 matrix not-rules enumerated
# INFO:root:i=122500 matrix not-rules enumerated
# INFO:root:i=125000 matrix not-rules enumerated
# INFO:root:i=127500 matrix not-rules enumerated
# INFO:root:i=130000 matrix not-rules enumerated
# INFO:root:i=132500 matrix not-rules enumerated
# INFO:root:i=135000 matrix not-rules enumerated
# INFO:root:i=137500 matrix not-rules enumerated
# INFO:root:i=140000 matrix not-rules enumerated
# INFO:root:i=142500 matrix not-rules enumerated
# INFO:root:i=145000 matrix not-rules enumerated
# INFO:root:i=147500 matrix not-rules enumerated
# INFO:root:i=150000 matrix not-rules enumerated
# INFO:root:i=152500 matrix not-rules enumerated
# INFO:root:i=155000 matrix not-rules enumerated
# INFO:root:i=157500 matrix not-rules enumerated
# INFO:root:i=160000 matrix not-rules enumerated
# INFO:root:i=162500 matrix not-rules enumerated
# INFO:root:i=165000 matrix not-rules enumerated
# INFO:root:i=167500 matrix not-rules enumerated
# INFO:root:i=170000 matrix not-rules enumerated
# INFO:root:i=172500 matrix not-rules enumerated
# INFO:root:i=175000 matrix not-rules enumerated
# INFO:root:i=177500 matrix not-rules enumerated
# INFO:root:i=180000 matrix not-rules enumerated
# INFO:root:i=182500 matrix not-rules enumerated
# INFO:root:i=185000 matrix not-rules enumerated
# INFO:root:i=187500 matrix not-rules enumerated
# INFO:root:i=190000 matrix not-rules enumerated
# INFO:root:i=192500 matrix not-rules enumerated
# INFO:root:i=195000 matrix not-rules enumerated
# INFO:root:i=197500 matrix not-rules enumerated
# INFO:root:i=200000 matrix not-rules enumerated
# INFO:root:i=202500 matrix not-rules enumerated
# INFO:root:i=205000 matrix not-rules enumerated
# INFO:root:i=207500 matrix not-rules enumerated
# INFO:root:i=210000 matrix not-rules enumerated
# INFO:root:i=212500 matrix not-rules enumerated
# INFO:root:i=215000 matrix not-rules enumerated
# INFO:root:i=217500 matrix not-rules enumerated
# INFO:root:i=220000 matrix not-rules enumerated
# INFO:root:i=222500 matrix not-rules enumerated
# INFO:root:i=225000 matrix not-rules enumerated
# INFO:root:i=227500 matrix not-rules enumerated
# INFO:root:i=230000 matrix not-rules enumerated
# INFO:root:i=232500 matrix not-rules enumerated
# INFO:root:i=235000 matrix not-rules enumerated
# INFO:root:i=237500 matrix not-rules enumerated
# INFO:root:i=240000 matrix not-rules enumerated
# INFO:root:i=242500 matrix not-rules enumerated
# INFO:root:i=245000 matrix not-rules enumerated
# INFO:root:i=247500 matrix not-rules enumerated
# INFO:root:i=250000 matrix not-rules enumerated
# INFO:root:i=252500 matrix not-rules enumerated
# INFO:root:i=255000 matrix not-rules enumerated
# INFO:root:i=257500 matrix not-rules enumerated
# INFO:root:i=260000 matrix not-rules enumerated
# INFO:root:i=262500 matrix not-rules enumerated
# INFO:root:i=265000 matrix not-rules enumerated
# INFO:root:i=267500 matrix not-rules enumerated
# INFO:root:i=270000 matrix not-rules enumerated
# INFO:root:i=272500 matrix not-rules enumerated
# INFO:root:i=275000 matrix not-rules enumerated
# INFO:root:i=277500 matrix not-rules enumerated
# INFO:root:i=280000 matrix not-rules enumerated
# INFO:root:i=282500 matrix not-rules enumerated
# INFO:root:i=285000 matrix not-rules enumerated
# INFO:root:i=287500 matrix not-rules enumerated
# INFO:root:i=290000 matrix not-rules enumerated
# INFO:root:i=292500 matrix not-rules enumerated
# INFO:root:i=295000 matrix not-rules enumerated
# INFO:root:i=297500 matrix not-rules enumerated
# INFO:root:i=300000 matrix not-rules enumerated
# INFO:root:i=302500 matrix not-rules enumerated
# INFO:root:i=305000 matrix not-rules enumerated
# INFO:root:i=307500 matrix not-rules enumerated
# INFO:root:i=310000 matrix not-rules enumerated
# INFO:root:i=312500 matrix not-rules enumerated
# INFO:root:i=315000 matrix not-rules enumerated
# INFO:root:i=317500 matrix not-rules enumerated
# INFO:root:i=320000 matrix not-rules enumerated
# INFO:root:i=322500 matrix not-rules enumerated
# INFO:root:i=325000 matrix not-rules enumerated
# INFO:root:i=327500 matrix not-rules enumerated
# INFO:root:i=330000 matrix not-rules enumerated
# INFO:root:i=332500 matrix not-rules enumerated
# INFO:root:i=335000 matrix not-rules enumerated
# INFO:root:i=337500 matrix not-rules enumerated
# INFO:root:i=340000 matrix not-rules enumerated
# INFO:root:i=342500 matrix not-rules enumerated
# INFO:root:i=345000 matrix not-rules enumerated
# INFO:root:i=347500 matrix not-rules enumerated
# INFO:root:i=350000 matrix not-rules enumerated
# INFO:root:i=352500 matrix not-rules enumerated
# INFO:root:i=355000 matrix not-rules enumerated
# INFO:root:i=357500 matrix not-rules enumerated
# INFO:root:i=360000 matrix not-rules enumerated
# INFO:root:i=362500 matrix not-rules enumerated
# INFO:root:i=365000 matrix not-rules enumerated
# INFO:root:i=367500 matrix not-rules enumerated
# INFO:root:i=370000 matrix not-rules enumerated
# INFO:root:i=372500 matrix not-rules enumerated
# INFO:root:i=375000 matrix not-rules enumerated
# INFO:root:i=377500 matrix not-rules enumerated
# INFO:root:i=380000 matrix not-rules enumerated
# INFO:root:i=382500 matrix not-rules enumerated
# INFO:root:i=385000 matrix not-rules enumerated
# INFO:root:i=387500 matrix not-rules enumerated
# INFO:root:i=390000 matrix not-rules enumerated
# INFO:root:i=392500 matrix not-rules enumerated
# INFO:root:i=395000 matrix not-rules enumerated
# INFO:root:i=397500 matrix not-rules enumerated
# INFO:root:i=400000 matrix not-rules enumerated
# INFO:root:i=402500 matrix not-rules enumerated
# INFO:root:i=405000 matrix not-rules enumerated
# INFO:root:i=407500 matrix not-rules enumerated
# INFO:root:i=410000 matrix not-rules enumerated
# INFO:root:i=412500 matrix not-rules enumerated
# INFO:root:i=415000 matrix not-rules enumerated
# INFO:root:i=417500 matrix not-rules enumerated
# INFO:root:i=420000 matrix not-rules enumerated
# INFO:root:i=422500 matrix not-rules enumerated
# INFO:root:i=425000 matrix not-rules enumerated
# INFO:root:i=427500 matrix not-rules enumerated
# INFO:root:i=430000 matrix not-rules enumerated
# INFO:root:i=432500 matrix not-rules enumerated
# INFO:root:i=435000 matrix not-rules enumerated
# INFO:root:i=437500 matrix not-rules enumerated
# INFO:root:i=440000 matrix not-rules enumerated
# INFO:root:i=442500 matrix not-rules enumerated
# INFO:root:i=445000 matrix not-rules enumerated
# INFO:root:i=447500 matrix not-rules enumerated
# INFO:root:i=450000 matrix not-rules enumerated
# INFO:root:i=452500 matrix not-rules enumerated
# INFO:root:i=455000 matrix not-rules enumerated
# INFO:root:i=457500 matrix not-rules enumerated
# INFO:root:i=460000 matrix not-rules enumerated
# INFO:root:i=462500 matrix not-rules enumerated
# INFO:root:i=465000 matrix not-rules enumerated
# INFO:root:i=467500 matrix not-rules enumerated
# INFO:root:i=470000 matrix not-rules enumerated
# INFO:root:i=472500 matrix not-rules enumerated
# INFO:root:i=475000 matrix not-rules enumerated
# INFO:root:i=477500 matrix not-rules enumerated
# INFO:root:i=480000 matrix not-rules enumerated
# INFO:root:i=482500 matrix not-rules enumerated
# INFO:root:i=485000 matrix not-rules enumerated
# 487050

# %%
output = learner.score(min_lift=3)
# Out:
# Streaming output truncated to the last 5000 lines.
# INFO:root:409768 / 487050: {'rule': ('low_80120_18=>(0.07232608288405527, 0.3215360644184264)', 'house_increase=>1', 'pctch_real_hinc_00_18=>(-0.6266114855221789, -0.13736163169161475)'), 'group': 'typology=>7.0', 'lift': 4.716117216117216}
# INFO:root:409770 / 487050: {'rule': ('low_80120_18=>(0.07232608288405527, 0.3215360644184264)', 'house_increase=>1', 'ch_per_col_00_18=>(0.05787243444569822, 0.12150076642224615)'), 'group': 'typology=>7.0', 'lift': 3.592945128779395}
# INFO:root:409771 / 487050: {'rule': ('low_80120_18=>(0.07232608288405527, 0.3215360644184264)', 'house_increase=>1', 'ch_per_limove_12_18=>(0.017369500761109102, 0.4913001657356805)'), 'group': 'typology=>7.0', 'lift': 4.885620915032679}
# INFO:root:409788 / 487050: {'rule': ('low_80120_18=>(0.07232608288405527, 0.3215360644184264)', 'house_increase=>1', 'aboverm_real_mhval_90=>1'), 'group': 'typology=>7.0', 'lift': 3.191176470588236}
# INFO:root:409800 / 487050: {'rule': ('low_80120_18=>(0.07232608288405527, 0.3215360644184264)', 'house_rapid_increase=>0', 'per_ch_zillow_12_18=>(0.3111943220753792, 0.5673345024112231)'), 'group': 'typology=>7.0', 'lift': 3.900000000000001}
# INFO:root:409803 / 487050: {'rule': ('low_80120_18=>(0.07232608288405527, 0.3215360644184264)', 'house_rapid_increase=>0', 'pctch_real_hinc_90_00=>(0.12704621728576854, 0.7209308673501899)'), 'group': 'typology=>7.0', 'lift': 4.625}
# INFO:root:409813 / 487050: {'rule': ('low_80120_18=>(0.07232608288405527, 0.3215360644184264)', 'change_flag_category=>ch_rapid_increase', 'pctch_real_hinc_00_18=>(-0.6266114855221789, -0.13736163169161475)'), 'group': 'typology=>6.0', 'lift': 3.6704545454545454}
# INFO:root:409821 / 487050: {'rule': ('low_80120_18=>(0.07232608288405527, 0.3215360644184264)', 'per_ch_zillow_12_18=>(0.3111943220753792, 0.5673345024112231)', 'aboverm_pctch_real_mrent_12_18=>1'), 'group': 'typology=>6.0', 'lift': 3.1200000000000006}
# INFO:root:409853 / 487050: {'rule': ('low_80120_18=>(0.07232608288405527, 0.3215360644184264)', 'pctch_real_hinc_00_18=>(-0.6266114855221789, -0.13736163169161475)', 'hotmarket_18=>1.0'), 'group': 'typology=>6.0', 'lift': 3.0617283950617287}
# INFO:root:409855 / 487050: {'rule': ('low_80120_18=>(0.07232608288405527, 0.3215360644184264)', 'ch_per_col_90_00=>(0.05177264696896694, 0.3491158849333221)', 'aboverm_pctch_real_mrent_12_18=>1'), 'group': 'typology=>6.0', 'lift': 3.0724137931034483}
# INFO:root:409894 / 487050: {'rule': ('mod_80120_18=>(0.0, 0.15438325056590113)', 'low_80120_00=>(0.012114658689864893, 0.2087531503779575)', 'house_increase=>1'), 'group': 'typology=>7.0', 'lift': 3.6842592592592593}
# INFO:root:409895 / 487050: {'rule': ('mod_80120_18=>(0.0, 0.15438325056590113)', 'mod_80120_00=>(0.02209108324534564, 0.16737512770269564)', 'house_increase=>1'), 'group': 'typology=>7.0', 'lift': 3.3358024691358024}
# INFO:root:409896 / 487050: {'rule': ('mod_80120_18=>(0.0, 0.15438325056590113)', 'high_80120_00=>(0.6083022121341034, 0.9657942580647896)', 'house_increase=>1'), 'group': 'typology=>7.0', 'lift': 3.6858974358974357}
# INFO:root:409897 / 487050: {'rule': ('mod_80120_18=>(0.0, 0.15438325056590113)', 'per_all_li_00=>(0.012114658689864893, 0.2087531503779575)', 'house_increase=>1'), 'group': 'typology=>7.0', 'lift': 3.6842592592592593}
# INFO:root:409900 / 487050: {'rule': ('mod_80120_18=>(0.0, 0.15438325056590113)', 'per_rent_00=>(0.010430247718383313, 0.15727321524422974)', 'house_increase=>1'), 'group': 'typology=>7.0', 'lift': 3.9911764705882353}
# INFO:root:409926 / 487050: {'rule': ('high_80120_18=>(0.4946016860547764, 0.8502280114527071)', 'per_rent_00=>(0.010430247718383313, 0.15727321524422974)', 'house_increase=>1'), 'group': 'typology=>7.0', 'lift': 3.087976539589443}
# INFO:root:409927 / 487050: {'rule': ('high_80120_18=>(0.4946016860547764, 0.8502280114527071)', 'per_rent_18=>(0.0, 0.20769789397240376)', 'house_increase=>1'), 'group': 'typology=>7.0', 'lift': 3.136363636363636}
# INFO:root:409945 / 487050: {'rule': ('high_80120_18=>(0.4946016860547764, 0.8502280114527071)', 'per_limove_12=>(0.053000817706700114, 0.4268800157689047)', 'house_increase=>1'), 'group': 'typology=>7.0', 'lift': 3.5219141323792487}
# INFO:root:409950 / 487050: {'rule': ('high_80120_18=>(0.4946016860547764, 0.8502280114527071)', 'pctch_real_mhval_00_18=>(0.17462453281149493, 0.4181848671050583)', 'aboverm_per_all_li_90=>0'), 'group': 'typology=>7.0', 'lift': 3.1504360465116275}
# INFO:root:409955 / 487050: {'rule': ('high_80120_18=>(0.4946016860547764, 0.8502280114527071)', 'pctch_real_mrent_12_18=>(0.2446214871588005, 3.0397287747111066)', 'aboverm_per_all_li_90=>0'), 'group': 'typology=>6.0', 'lift': 3.3181818181818183}
# INFO:root:409960 / 487050: {'rule': ('high_80120_18=>(0.4946016860547764, 0.8502280114527071)', 'house_increase=>1', 'pctch_real_hinc_00_18=>(-0.6266114855221789, -0.13736163169161475)'), 'group': 'typology=>7.0', 'lift': 4.988247863247863}
# INFO:root:409961 / 487050: {'rule': ('high_80120_18=>(0.4946016860547764, 0.8502280114527071)', 'house_increase=>1', 'ch_per_col_00_18=>(0.05787243444569822, 0.12150076642224615)'), 'group': 'typology=>7.0', 'lift': 3.6444444444444444}
# INFO:root:409962 / 487050: {'rule': ('high_80120_18=>(0.4946016860547764, 0.8502280114527071)', 'house_increase=>1', 'ch_per_limove_12_18=>(0.017369500761109102, 0.4913001657356805)'), 'group': 'typology=>7.0', 'lift': 4.987500000000001}
# INFO:root:409969 / 487050: {'rule': ('high_80120_18=>(0.4946016860547764, 0.8502280114527071)', 'house_increase=>1', 'aboverm_real_mhval_90=>1'), 'group': 'typology=>7.0', 'lift': 3.09375}
# INFO:root:409972 / 487050: {'rule': ('high_80120_18=>(0.4946016860547764, 0.8502280114527071)', 'house_rapid_increase=>0', 'per_ch_zillow_12_18=>(0.3111943220753792, 0.5673345024112231)'), 'group': 'typology=>7.0', 'lift': 3.6727272727272724}
# INFO:root:409973 / 487050: {'rule': ('high_80120_18=>(0.4946016860547764, 0.8502280114527071)', 'house_rapid_increase=>0', 'pctch_real_hinc_90_00=>(0.12704621728576854, 0.7209308673501899)'), 'group': 'typology=>7.0', 'lift': 4.384615384615385}
# INFO:root:409978 / 487050: {'rule': ('high_80120_18=>(0.4946016860547764, 0.8502280114527071)', 'change_flag_category=>ch_rapid_increase', 'pctch_real_hinc_00_18=>(-0.6266114855221789, -0.13736163169161475)'), 'group': 'typology=>6.0', 'lift': 3.789473684210526}
# INFO:root:409986 / 487050: {'rule': ('high_80120_18=>(0.4946016860547764, 0.8502280114527071)', 'per_ch_zillow_12_18=>(0.3111943220753792, 0.5673345024112231)', 'aboverm_pctch_real_mrent_12_18=>1'), 'group': 'typology=>6.0', 'lift': 3.1386224934612024}
# INFO:root:410008 / 487050: {'rule': ('high_80120_18=>(0.4946016860547764, 0.8502280114527071)', 'pctch_real_hinc_00_18=>(-0.6266114855221789, -0.13736163169161475)', 'hotmarket_18=>1.0'), 'group': 'typology=>6.0', 'lift': 3.0617283950617287}
# INFO:root:410033 / 487050: {'rule': ('low_80120_00=>(0.012114658689864893, 0.2087531503779575)', 'per_nonwhite_90=>(0.0, 0.08502289077828651)', 'house_increase=>1'), 'group': 'typology=>7.0', 'lift': 3.2733074361820202}
# INFO:root:410037 / 487050: {'rule': ('low_80120_00=>(0.012114658689864893, 0.2087531503779575)', 'per_nonwhite_00=>(0.0321456235476375, 0.12919166960818915)', 'house_increase=>1'), 'group': 'typology=>7.0', 'lift': 3.0877192982456134}
# INFO:root:410038 / 487050: {'rule': ('low_80120_00=>(0.012114658689864893, 0.2087531503779575)', 'per_nonwhite_18=>(0.03097345132743368, 0.18758389261744968)', 'house_increase=>1'), 'group': 'typology=>7.0', 'lift': 3.1544474393530995}
# INFO:root:410049 / 487050: {'rule': ('low_80120_00=>(0.012114658689864893, 0.2087531503779575)', 'per_limove_18=>(0.5334746153711671, 0.940992690153764)', 'change_flag_category=>ch_rapid_increase'), 'group': 'typology=>6.0', 'lift': 4.788461538461538}
# INFO:root:410062 / 487050: {'rule': ('low_80120_00=>(0.012114658689864893, 0.2087531503779575)', 'per_limove_18=>(0.5334746153711671, 0.940992690153764)', 'hotmarket_18=>1.0'), 'group': 'typology=>6.0', 'lift': 3.6083916083916083}
# INFO:root:410063 / 487050: {'rule': ('low_80120_00=>(0.012114658689864893, 0.2087531503779575)', 'per_limove_12=>(0.053000817706700114, 0.4268800157689047)', 'house_increase=>1'), 'group': 'typology=>7.0', 'lift': 3.280086848635236}
# INFO:root:410069 / 487050: {'rule': ('low_80120_00=>(0.012114658689864893, 0.2087531503779575)', 'pctch_real_mhval_00_18=>(0.17462453281149493, 0.4181848671050583)', 'house_increase=>1'), 'group': 'typology=>7.0', 'lift': 3.425936768149883}
# INFO:root:410070 / 487050: {'rule': ('low_80120_00=>(0.012114658689864893, 0.2087531503779575)', 'pctch_real_mhval_00_18=>(0.17462453281149493, 0.4181848671050583)', 'house_rapid_increase=>0'), 'group': 'typology=>7.0', 'lift': 3.2786885245901645}
# INFO:root:410074 / 487050: {'rule': ('low_80120_00=>(0.012114658689864893, 0.2087531503779575)', 'pctch_real_mhval_00_18=>(0.17462453281149493, 0.4181848671050583)', 'aboverm_per_all_li_90=>0'), 'group': 'typology=>7.0', 'lift': 3.0365432098765432}
# INFO:root:410079 / 487050: {'rule': ('low_80120_00=>(0.012114658689864893, 0.2087531503779575)', 'pctch_real_mhval_00_18=>(0.17462453281149493, 0.4181848671050583)', 'aboverm_ch_per_col_00_18=>0'), 'group': 'typology=>7.0', 'lift': 3.0475}
# INFO:root:410084 / 487050: {'rule': ('low_80120_00=>(0.012114658689864893, 0.2087531503779575)', 'pctch_real_mrent_12_18=>(0.2446214871588005, 3.0397287747111066)', 'ch_per_col_90_00=>(0.05177264696896694, 0.3491158849333221)'), 'group': 'typology=>6.0', 'lift': 3.372043010752688}
# INFO:root:410089 / 487050: {'rule': ('low_80120_00=>(0.012114658689864893, 0.2087531503779575)', 'pctch_real_mrent_12_18=>(0.2446214871588005, 3.0397287747111066)', 'aboverm_pctch_real_mhval_90_00=>1'), 'group': 'typology=>6.0', 'lift': 3.028549676437001}
# INFO:root:410093 / 487050: {'rule': ('low_80120_00=>(0.012114658689864893, 0.2087531503779575)', 'house_increase=>1', 'per_ch_zillow_12_18=>(0.3111943220753792, 0.5673345024112231)'), 'group': 'typology=>7.0', 'lift': 4.102127659574468}
# INFO:root:410097 / 487050: {'rule': ('low_80120_00=>(0.012114658689864893, 0.2087531503779575)', 'house_increase=>1', 'pctch_real_hinc_00_18=>(-0.6266114855221789, -0.13736163169161475)'), 'group': 'typology=>7.0', 'lift': 3.7928118393234667}
# INFO:root:410098 / 487050: {'rule': ('low_80120_00=>(0.012114658689864893, 0.2087531503779575)', 'house_increase=>1', 'ch_per_col_90_00=>(0.05177264696896694, 0.3491158849333221)'), 'group': 'typology=>7.0', 'lift': 3.2597904026475457}
# INFO:root:410099 / 487050: {'rule': ('low_80120_00=>(0.012114658689864893, 0.2087531503779575)', 'house_increase=>1', 'ch_per_col_00_18=>(0.05787243444569822, 0.12150076642224615)'), 'group': 'typology=>7.0', 'lift': 3.525606469002695}
# INFO:root:410100 / 487050: {'rule': ('low_80120_00=>(0.012114658689864893, 0.2087531503779575)', 'house_increase=>1', 'ch_per_limove_12_18=>(0.017369500761109102, 0.4913001657356805)'), 'group': 'typology=>7.0', 'lift': 4.0884520884520885}
# INFO:root:410129 / 487050: {'rule': ('low_80120_00=>(0.012114658689864893, 0.2087531503779575)', 'house_rapid_increase=>0', 'per_ch_zillow_12_18=>(0.3111943220753792, 0.5673345024112231)'), 'group': 'typology=>7.0', 'lift': 3.8867924528301883}
# INFO:root:410132 / 487050: {'rule': ('low_80120_00=>(0.012114658689864893, 0.2087531503779575)', 'house_rapid_increase=>0', 'pctch_real_hinc_90_00=>(0.12704621728576854, 0.7209308673501899)'), 'group': 'typology=>7.0', 'lift': 4.111111111111111}
# INFO:root:410142 / 487050: {'rule': ('low_80120_00=>(0.012114658689864893, 0.2087531503779575)', 'change_flag_category=>ch_rapid_increase', 'pctch_real_hinc_00_18=>(-0.6266114855221789, -0.13736163169161475)'), 'group': 'typology=>6.0', 'lift': 3.2804487179487185}
# INFO:root:410176 / 487050: {'rule': ('low_80120_00=>(0.012114658689864893, 0.2087531503779575)', 'pctch_real_hinc_00_18=>(-0.6266114855221789, -0.13736163169161475)', 'aboverm_per_rent_90=>0'), 'group': 'typology=>7.0', 'lift': 3.007432818753574}
# INFO:root:410213 / 487050: {'rule': ('low_80120_00=>(0.012114658689864893, 0.2087531503779575)', 'aboverm_real_mhval_90=>1', 'aboverm_pctch_real_mhval_90_00=>1'), 'group': 'typology=>7.0', 'lift': 3.461538461538462}
# INFO:root:410228 / 487050: {'rule': ('mod_80120_00=>(0.02209108324534564, 0.16737512770269564)', 'per_nonwhite_90=>(0.0, 0.08502289077828651)', 'house_increase=>1'), 'group': 'typology=>7.0', 'lift': 3.119155354449472}
# INFO:root:410230 / 487050: {'rule': ('mod_80120_00=>(0.02209108324534564, 0.16737512770269564)', 'per_nonwhite_00=>(0.0321456235476375, 0.12919166960818915)', 'house_increase=>1'), 'group': 'typology=>7.0', 'lift': 3.0246913580246915}
# INFO:root:410236 / 487050: {'rule': ('mod_80120_00=>(0.02209108324534564, 0.16737512770269564)', 'per_rent_00=>(0.010430247718383313, 0.15727321524422974)', 'house_increase=>1'), 'group': 'typology=>7.0', 'lift': 3.223443223443223}
# INFO:root:410237 / 487050: {'rule': ('mod_80120_00=>(0.02209108324534564, 0.16737512770269564)', 'per_rent_18=>(0.0, 0.20769789397240376)', 'house_increase=>1'), 'group': 'typology=>7.0', 'lift': 3.2791777188328917}
# INFO:root:410240 / 487050: {'rule': ('mod_80120_00=>(0.02209108324534564, 0.16737512770269564)', 'per_limove_12=>(0.053000817706700114, 0.4268800157689047)', 'house_increase=>1'), 'group': 'typology=>7.0', 'lift': 3.3990000000000005}
# INFO:root:410244 / 487050: {'rule': ('mod_80120_00=>(0.02209108324534564, 0.16737512770269564)', 'pctch_real_mrent_12_18=>(0.2446214871588005, 3.0397287747111066)', 'per_ch_zillow_12_18=>(0.3111943220753792, 0.5673345024112231)'), 'group': 'typology=>6.0', 'lift': 3.0296874999999996}
# INFO:root:410245 / 487050: {'rule': ('mod_80120_00=>(0.02209108324534564, 0.16737512770269564)', 'pctch_real_mrent_12_18=>(0.2446214871588005, 3.0397287747111066)', 'aboverm_per_all_li_90=>0'), 'group': 'typology=>6.0', 'lift': 3.1619897959183674}
# INFO:root:410246 / 487050: {'rule': ('mod_80120_00=>(0.02209108324534564, 0.16737512770269564)', 'house_increase=>1', 'per_ch_zillow_12_18=>(0.3111943220753792, 0.5673345024112231)'), 'group': 'typology=>7.0', 'lift': 3.767077267637178}
# INFO:root:410247 / 487050: {'rule': ('mod_80120_00=>(0.02209108324534564, 0.16737512770269564)', 'house_increase=>1', 'ch_per_col_00_18=>(0.05787243444569822, 0.12150076642224615)'), 'group': 'typology=>7.0', 'lift': 3.8872180451127827}
# INFO:root:410271 / 487050: {'rule': ('high_80120_00=>(0.6083022121341034, 0.9657942580647896)', 'per_nonwhite_90=>(0.0, 0.08502289077828651)', 'house_increase=>1'), 'group': 'typology=>7.0', 'lift': 3.20230607966457}
# INFO:root:410275 / 487050: {'rule': ('high_80120_00=>(0.6083022121341034, 0.9657942580647896)', 'per_nonwhite_00=>(0.0321456235476375, 0.12919166960818915)', 'house_increase=>1'), 'group': 'typology=>7.0', 'lift': 3.0720209515495416}
# INFO:root:410276 / 487050: {'rule': ('high_80120_00=>(0.6083022121341034, 0.9657942580647896)', 'per_nonwhite_18=>(0.03097345132743368, 0.18758389261744968)', 'house_increase=>1'), 'group': 'typology=>7.0', 'lift': 3.088484848484849}
# INFO:root:410283 / 487050: {'rule': ('high_80120_00=>(0.6083022121341034, 0.9657942580647896)', 'per_rent_18=>(0.0, 0.20769789397240376)', 'house_increase=>1'), 'group': 'typology=>7.0', 'lift': 3.0351916376306622}
# INFO:root:410287 / 487050: {'rule': ('high_80120_00=>(0.6083022121341034, 0.9657942580647896)', 'per_limove_18=>(0.5334746153711671, 0.940992690153764)', 'change_flag_category=>ch_rapid_increase'), 'group': 'typology=>6.0', 'lift': 4.7521008403361344}
# INFO:root:410300 / 487050: {'rule': ('high_80120_00=>(0.6083022121341034, 0.9657942580647896)', 'per_limove_18=>(0.5334746153711671, 0.940992690153764)', 'hotmarket_18=>1.0'), 'group': 'typology=>6.0', 'lift': 3.520833333333333}
# INFO:root:410301 / 487050: {'rule': ('high_80120_00=>(0.6083022121341034, 0.9657942580647896)', 'per_limove_12=>(0.053000817706700114, 0.4268800157689047)', 'house_increase=>1'), 'group': 'typology=>7.0', 'lift': 3.366343258614921}
# INFO:root:410307 / 487050: {'rule': ('high_80120_00=>(0.6083022121341034, 0.9657942580647896)', 'pctch_real_mhval_00_18=>(0.17462453281149493, 0.4181848671050583)', 'house_increase=>1'), 'group': 'typology=>7.0', 'lift': 3.50679012345679}
# INFO:root:410308 / 487050: {'rule': ('high_80120_00=>(0.6083022121341034, 0.9657942580647896)', 'pctch_real_mhval_00_18=>(0.17462453281149493, 0.4181848671050583)', 'house_rapid_increase=>0'), 'group': 'typology=>7.0', 'lift': 3.333333333333333}
# INFO:root:410320 / 487050: {'rule': ('high_80120_00=>(0.6083022121341034, 0.9657942580647896)', 'pctch_real_mrent_12_18=>(0.2446214871588005, 3.0397287747111066)', 'per_ch_zillow_12_18=>(0.3111943220753792, 0.5673345024112231)'), 'group': 'typology=>6.0', 'lift': 3.0860445205479445}
# INFO:root:410322 / 487050: {'rule': ('high_80120_00=>(0.6083022121341034, 0.9657942580647896)', 'pctch_real_mrent_12_18=>(0.2446214871588005, 3.0397287747111066)', 'ch_per_col_90_00=>(0.05177264696896694, 0.3491158849333221)'), 'group': 'typology=>6.0', 'lift': 3.308531746031746}
# INFO:root:410331 / 487050: {'rule': ('high_80120_00=>(0.6083022121341034, 0.9657942580647896)', 'house_increase=>1', 'per_ch_zillow_12_18=>(0.3111943220753792, 0.5673345024112231)'), 'group': 'typology=>7.0', 'lift': 4.006802721088435}
# INFO:root:410335 / 487050: {'rule': ('high_80120_00=>(0.6083022121341034, 0.9657942580647896)', 'house_increase=>1', 'pctch_real_hinc_00_18=>(-0.6266114855221789, -0.13736163169161475)'), 'group': 'typology=>7.0', 'lift': 3.969627243442246}
# INFO:root:410336 / 487050: {'rule': ('high_80120_00=>(0.6083022121341034, 0.9657942580647896)', 'house_increase=>1', 'ch_per_col_90_00=>(0.05177264696896694, 0.3491158849333221)'), 'group': 'typology=>7.0', 'lift': 3.2715419501133782}
# INFO:root:410337 / 487050: {'rule': ('high_80120_00=>(0.6083022121341034, 0.9657942580647896)', 'house_increase=>1', 'ch_per_col_00_18=>(0.05787243444569822, 0.12150076642224615)'), 'group': 'typology=>7.0', 'lift': 3.638461538461539}
# INFO:root:410338 / 487050: {'rule': ('high_80120_00=>(0.6083022121341034, 0.9657942580647896)', 'house_increase=>1', 'ch_per_limove_12_18=>(0.017369500761109102, 0.4913001657356805)'), 'group': 'typology=>7.0', 'lift': 4.2272727272727275}
# INFO:root:410367 / 487050: {'rule': ('high_80120_00=>(0.6083022121341034, 0.9657942580647896)', 'house_rapid_increase=>0', 'per_ch_zillow_12_18=>(0.3111943220753792, 0.5673345024112231)'), 'group': 'typology=>7.0', 'lift': 3.6896551724137936}
# INFO:root:410370 / 487050: {'rule': ('high_80120_00=>(0.6083022121341034, 0.9657942580647896)', 'house_rapid_increase=>0', 'pctch_real_hinc_90_00=>(0.12704621728576854, 0.7209308673501899)'), 'group': 'typology=>7.0', 'lift': 4.033333333333333}
# INFO:root:410380 / 487050: {'rule': ('high_80120_00=>(0.6083022121341034, 0.9657942580647896)', 'change_flag_category=>ch_rapid_increase', 'pctch_real_hinc_00_18=>(-0.6266114855221789, -0.13736163169161475)'), 'group': 'typology=>6.0', 'lift': 3.4434782608695653}
# INFO:root:410461 / 487050: {'rule': ('high_pdmt_medhhinc_00=>1.0', 'per_all_li_90=>(0.07589807755288536, 0.2187093814914599)', 'house_increase=>1'), 'group': 'typology=>7.0', 'lift': 4.317857142857142}
# INFO:root:410476 / 487050: {'rule': ('high_pdmt_medhhinc_00=>1.0', 'per_limove_18=>(0.5334746153711671, 0.940992690153764)', 'house_increase=>1'), 'group': 'typology=>7.0', 'lift': 4.595959595959595}
# INFO:root:410477 / 487050: {'rule': ('high_pdmt_medhhinc_00=>1.0', 'per_limove_18=>(0.5334746153711671, 0.940992690153764)', 'change_flag_category=>ch_rapid_increase'), 'group': 'typology=>6.0', 'lift': 3.055555555555556}
# INFO:root:410491 / 487050: {'rule': ('high_pdmt_medhhinc_00=>1.0', 'per_limove_12=>(0.053000817706700114, 0.4268800157689047)', 'house_increase=>1'), 'group': 'typology=>7.0', 'lift': 3.041396789636723}
# INFO:root:410501 / 487050: {'rule': ('high_pdmt_medhhinc_00=>1.0', 'pctch_real_mrent_12_18=>(0.2446214871588005, 3.0397287747111066)', 'per_ch_zillow_12_18=>(0.3111943220753792, 0.5673345024112231)'), 'group': 'typology=>6.0', 'lift': 3.280423280423281}
# INFO:root:410503 / 487050: {'rule': ('high_pdmt_medhhinc_00=>1.0', 'house_increase=>1', 'per_ch_zillow_12_18=>(0.3111943220753792, 0.5673345024112231)'), 'group': 'typology=>7.0', 'lift': 3.6666666666666665}
# INFO:root:410504 / 487050: {'rule': ('high_pdmt_medhhinc_00=>1.0', 'house_increase=>1', 'pctch_real_hinc_90_00=>(0.12704621728576854, 0.7209308673501899)'), 'group': 'typology=>7.0', 'lift': 3.689440993788819}
# INFO:root:410505 / 487050: {'rule': ('high_pdmt_medhhinc_00=>1.0', 'house_increase=>1', 'pctch_real_hinc_00_18=>(-0.6266114855221789, -0.13736163169161475)'), 'group': 'typology=>7.0', 'lift': 3.188856494978944}
# INFO:root:410506 / 487050: {'rule': ('high_pdmt_medhhinc_00=>1.0', 'house_increase=>1', 'ch_per_col_00_18=>(0.05787243444569822, 0.12150076642224615)'), 'group': 'typology=>7.0', 'lift': 3.246022031823745}
# INFO:root:410507 / 487050: {'rule': ('high_pdmt_medhhinc_00=>1.0', 'house_increase=>1', 'ch_per_limove_12_18=>(0.017369500761109102, 0.4913001657356805)'), 'group': 'typology=>7.0', 'lift': 3.6274509803921564}
# INFO:root:410517 / 487050: {'rule': ('high_pdmt_medhhinc_00=>1.0', 'house_rapid_increase=>0', 'per_ch_zillow_12_18=>(0.3111943220753792, 0.5673345024112231)'), 'group': 'typology=>7.0', 'lift': 3.171875}
# INFO:root:410518 / 487050: {'rule': ('high_pdmt_medhhinc_00=>1.0', 'house_rapid_increase=>0', 'pctch_real_hinc_90_00=>(0.12704621728576854, 0.7209308673501899)'), 'group': 'typology=>7.0', 'lift': 3.114285714285714}
# INFO:root:410569 / 487050: {'rule': ('per_all_li_90=>(0.07589807755288536, 0.2187093814914599)', 'per_rent_18=>(0.0, 0.20769789397240376)', 'house_increase=>1'), 'group': 'typology=>7.0', 'lift': 5.251231527093596}
# INFO:root:410575 / 487050: {'rule': ('per_all_li_90=>(0.07589807755288536, 0.2187093814914599)', 'house_increase=>1', 'aboverm_per_all_li_00=>0'), 'group': 'typology=>7.0', 'lift': 3.521350546176763}
# INFO:root:410576 / 487050: {'rule': ('per_all_li_90=>(0.07589807755288536, 0.2187093814914599)', 'house_increase=>1', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>7.0', 'lift': 3.473958333333334}
# INFO:root:410578 / 487050: {'rule': ('per_all_li_90=>(0.07589807755288536, 0.2187093814914599)', 'per_ch_zillow_12_18=>(0.3111943220753792, 0.5673345024112231)', 'rent_abrm_ch=>1'), 'group': 'typology=>6.0', 'lift': 3.4159090909090906}
# INFO:root:410584 / 487050: {'rule': ('per_all_li_90=>(0.07589807755288536, 0.2187093814914599)', 'per_ch_zillow_12_18=>(0.3111943220753792, 0.5673345024112231)', 'hotmarket_18=>1.0'), 'group': 'typology=>6.0', 'lift': 4.0313852813852815}
# INFO:root:410589 / 487050: {'rule': ('per_all_li_00=>(0.012114658689864893, 0.2087531503779575)', 'per_nonwhite_90=>(0.0, 0.08502289077828651)', 'house_increase=>1'), 'group': 'typology=>7.0', 'lift': 3.2733074361820202}
# INFO:root:410593 / 487050: {'rule': ('per_all_li_00=>(0.012114658689864893, 0.2087531503779575)', 'per_nonwhite_00=>(0.0321456235476375, 0.12919166960818915)', 'house_increase=>1'), 'group': 'typology=>7.0', 'lift': 3.0877192982456134}
# INFO:root:410594 / 487050: {'rule': ('per_all_li_00=>(0.012114658689864893, 0.2087531503779575)', 'per_nonwhite_18=>(0.03097345132743368, 0.18758389261744968)', 'house_increase=>1'), 'group': 'typology=>7.0', 'lift': 3.1544474393530995}
# INFO:root:410605 / 487050: {'rule': ('per_all_li_00=>(0.012114658689864893, 0.2087531503779575)', 'per_limove_18=>(0.5334746153711671, 0.940992690153764)', 'change_flag_category=>ch_rapid_increase'), 'group': 'typology=>6.0', 'lift': 4.788461538461538}
# INFO:root:410618 / 487050: {'rule': ('per_all_li_00=>(0.012114658689864893, 0.2087531503779575)', 'per_limove_18=>(0.5334746153711671, 0.940992690153764)', 'hotmarket_18=>1.0'), 'group': 'typology=>6.0', 'lift': 3.6083916083916083}
# INFO:root:410619 / 487050: {'rule': ('per_all_li_00=>(0.012114658689864893, 0.2087531503779575)', 'per_limove_12=>(0.053000817706700114, 0.4268800157689047)', 'house_increase=>1'), 'group': 'typology=>7.0', 'lift': 3.280086848635236}
# INFO:root:410625 / 487050: {'rule': ('per_all_li_00=>(0.012114658689864893, 0.2087531503779575)', 'pctch_real_mhval_00_18=>(0.17462453281149493, 0.4181848671050583)', 'house_increase=>1'), 'group': 'typology=>7.0', 'lift': 3.425936768149883}
# INFO:root:410626 / 487050: {'rule': ('per_all_li_00=>(0.012114658689864893, 0.2087531503779575)', 'pctch_real_mhval_00_18=>(0.17462453281149493, 0.4181848671050583)', 'house_rapid_increase=>0'), 'group': 'typology=>7.0', 'lift': 3.2786885245901645}
# INFO:root:410630 / 487050: {'rule': ('per_all_li_00=>(0.012114658689864893, 0.2087531503779575)', 'pctch_real_mhval_00_18=>(0.17462453281149493, 0.4181848671050583)', 'aboverm_per_all_li_90=>0'), 'group': 'typology=>7.0', 'lift': 3.0365432098765432}
# INFO:root:410635 / 487050: {'rule': ('per_all_li_00=>(0.012114658689864893, 0.2087531503779575)', 'pctch_real_mhval_00_18=>(0.17462453281149493, 0.4181848671050583)', 'aboverm_ch_per_col_00_18=>0'), 'group': 'typology=>7.0', 'lift': 3.0475}
# INFO:root:410640 / 487050: {'rule': ('per_all_li_00=>(0.012114658689864893, 0.2087531503779575)', 'pctch_real_mrent_12_18=>(0.2446214871588005, 3.0397287747111066)', 'ch_per_col_90_00=>(0.05177264696896694, 0.3491158849333221)'), 'group': 'typology=>6.0', 'lift': 3.372043010752688}
# INFO:root:410645 / 487050: {'rule': ('per_all_li_00=>(0.012114658689864893, 0.2087531503779575)', 'pctch_real_mrent_12_18=>(0.2446214871588005, 3.0397287747111066)', 'aboverm_pctch_real_mhval_90_00=>1'), 'group': 'typology=>6.0', 'lift': 3.028549676437001}
# INFO:root:410649 / 487050: {'rule': ('per_all_li_00=>(0.012114658689864893, 0.2087531503779575)', 'house_increase=>1', 'per_ch_zillow_12_18=>(0.3111943220753792, 0.5673345024112231)'), 'group': 'typology=>7.0', 'lift': 4.102127659574468}
# INFO:root:410653 / 487050: {'rule': ('per_all_li_00=>(0.012114658689864893, 0.2087531503779575)', 'house_increase=>1', 'pctch_real_hinc_00_18=>(-0.6266114855221789, -0.13736163169161475)'), 'group': 'typology=>7.0', 'lift': 3.7928118393234667}
# INFO:root:410654 / 487050: {'rule': ('per_all_li_00=>(0.012114658689864893, 0.2087531503779575)', 'house_increase=>1', 'ch_per_col_90_00=>(0.05177264696896694, 0.3491158849333221)'), 'group': 'typology=>7.0', 'lift': 3.2597904026475457}
# INFO:root:410655 / 487050: {'rule': ('per_all_li_00=>(0.012114658689864893, 0.2087531503779575)', 'house_increase=>1', 'ch_per_col_00_18=>(0.05787243444569822, 0.12150076642224615)'), 'group': 'typology=>7.0', 'lift': 3.525606469002695}
# INFO:root:410656 / 487050: {'rule': ('per_all_li_00=>(0.012114658689864893, 0.2087531503779575)', 'house_increase=>1', 'ch_per_limove_12_18=>(0.017369500761109102, 0.4913001657356805)'), 'group': 'typology=>7.0', 'lift': 4.0884520884520885}
# INFO:root:410685 / 487050: {'rule': ('per_all_li_00=>(0.012114658689864893, 0.2087531503779575)', 'house_rapid_increase=>0', 'per_ch_zillow_12_18=>(0.3111943220753792, 0.5673345024112231)'), 'group': 'typology=>7.0', 'lift': 3.8867924528301883}
# INFO:root:410688 / 487050: {'rule': ('per_all_li_00=>(0.012114658689864893, 0.2087531503779575)', 'house_rapid_increase=>0', 'pctch_real_hinc_90_00=>(0.12704621728576854, 0.7209308673501899)'), 'group': 'typology=>7.0', 'lift': 4.111111111111111}
# INFO:root:410698 / 487050: {'rule': ('per_all_li_00=>(0.012114658689864893, 0.2087531503779575)', 'change_flag_category=>ch_rapid_increase', 'pctch_real_hinc_00_18=>(-0.6266114855221789, -0.13736163169161475)'), 'group': 'typology=>6.0', 'lift': 3.2804487179487185}
# INFO:root:410732 / 487050: {'rule': ('per_all_li_00=>(0.012114658689864893, 0.2087531503779575)', 'pctch_real_hinc_00_18=>(-0.6266114855221789, -0.13736163169161475)', 'aboverm_per_rent_90=>0'), 'group': 'typology=>7.0', 'lift': 3.007432818753574}
# INFO:root:410769 / 487050: {'rule': ('per_all_li_00=>(0.012114658689864893, 0.2087531503779575)', 'aboverm_real_mhval_90=>1', 'aboverm_pctch_real_mhval_90_00=>1'), 'group': 'typology=>7.0', 'lift': 3.461538461538462}
# INFO:root:410780 / 487050: {'rule': ('per_all_li_18=>(0.07232608288405527, 0.3215360644184264)', 'per_nonwhite_90=>(0.0, 0.08502289077828651)', 'house_increase=>1'), 'group': 'typology=>7.0', 'lift': 3.28125}
# INFO:root:410781 / 487050: {'rule': ('per_all_li_18=>(0.07232608288405527, 0.3215360644184264)', 'per_nonwhite_90=>(0.0, 0.08502289077828651)', 'house_rapid_increase=>0'), 'group': 'typology=>7.0', 'lift': 3.014084507042254}
# INFO:root:410784 / 487050: {'rule': ('per_all_li_18=>(0.07232608288405527, 0.3215360644184264)', 'per_nonwhite_00=>(0.0321456235476375, 0.12919166960818915)', 'house_increase=>1'), 'group': 'typology=>7.0', 'lift': 3.128247197156139}
# INFO:root:410785 / 487050: {'rule': ('per_all_li_18=>(0.07232608288405527, 0.3215360644184264)', 'per_nonwhite_18=>(0.03097345132743368, 0.18758389261744968)', 'house_increase=>1'), 'group': 'typology=>7.0', 'lift': 3.1699196326062}
# INFO:root:410791 / 487050: {'rule': ('per_all_li_18=>(0.07232608288405527, 0.3215360644184264)', 'per_rent_00=>(0.010430247718383313, 0.15727321524422974)', 'house_increase=>1'), 'group': 'typology=>7.0', 'lift': 3.0237367379967632}
# INFO:root:410792 / 487050: {'rule': ('per_all_li_18=>(0.07232608288405527, 0.3215360644184264)', 'per_rent_18=>(0.0, 0.20769789397240376)', 'house_increase=>1'), 'group': 'typology=>7.0', 'lift': 3.076086956521739}
# INFO:root:410796 / 487050: {'rule': ('per_all_li_18=>(0.07232608288405527, 0.3215360644184264)', 'per_limove_18=>(0.5334746153711671, 0.940992690153764)', 'change_flag_category=>ch_rapid_increase'), 'group': 'typology=>6.0', 'lift': 5.500000000000001}
# INFO:root:410810 / 487050: {'rule': ('per_all_li_18=>(0.07232608288405527, 0.3215360644184264)', 'per_limove_12=>(0.053000817706700114, 0.4268800157689047)', 'house_increase=>1'), 'group': 'typology=>7.0', 'lift': 3.4868312757201645}
# INFO:root:410816 / 487050: {'rule': ('per_all_li_18=>(0.07232608288405527, 0.3215360644184264)', 'pctch_real_mhval_00_18=>(0.17462453281149493, 0.4181848671050583)', 'house_increase=>1'), 'group': 'typology=>7.0', 'lift': 3.4433198380566803}
# INFO:root:410817 / 487050: {'rule': ('per_all_li_18=>(0.07232608288405527, 0.3215360644184264)', 'pctch_real_mhval_00_18=>(0.17462453281149493, 0.4181848671050583)', 'house_rapid_increase=>0'), 'group': 'typology=>7.0', 'lift': 3.350877192982456}
# INFO:root:410821 / 487050: {'rule': ('per_all_li_18=>(0.07232608288405527, 0.3215360644184264)', 'pctch_real_mhval_00_18=>(0.17462453281149493, 0.4181848671050583)', 'aboverm_per_all_li_90=>0'), 'group': 'typology=>7.0', 'lift': 3.0170132325141776}
# INFO:root:410831 / 487050: {'rule': ('per_all_li_18=>(0.07232608288405527, 0.3215360644184264)', 'pctch_real_mrent_12_18=>(0.2446214871588005, 3.0397287747111066)', 'ch_per_col_90_00=>(0.05177264696896694, 0.3491158849333221)'), 'group': 'typology=>6.0', 'lift': 3.2953281423804226}
# INFO:root:410832 / 487050: {'rule': ('per_all_li_18=>(0.07232608288405527, 0.3215360644184264)', 'pctch_real_mrent_12_18=>(0.2446214871588005, 3.0397287747111066)', 'aboverm_per_all_li_90=>0'), 'group': 'typology=>6.0', 'lift': 3.1701275045537343}
# INFO:root:410833 / 487050: {'rule': ('per_all_li_18=>(0.07232608288405527, 0.3215360644184264)', 'pctch_real_mrent_12_18=>(0.2446214871588005, 3.0397287747111066)', 'aboverm_real_mrent_90=>0'), 'group': 'typology=>6.0', 'lift': 3.0769230769230775}
# INFO:root:410836 / 487050: {'rule': ('per_all_li_18=>(0.07232608288405527, 0.3215360644184264)', 'pctch_real_mrent_12_18=>(0.2446214871588005, 3.0397287747111066)', 'aboverm_pctch_real_mhval_90_00=>1'), 'group': 'typology=>6.0', 'lift': 3.164983164983165}
# INFO:root:410844 / 487050: {'rule': ('per_all_li_18=>(0.07232608288405527, 0.3215360644184264)', 'house_increase=>1', 'pctch_real_hinc_00_18=>(-0.6266114855221789, -0.13736163169161475)'), 'group': 'typology=>7.0', 'lift': 4.716117216117216}
# INFO:root:410846 / 487050: {'rule': ('per_all_li_18=>(0.07232608288405527, 0.3215360644184264)', 'house_increase=>1', 'ch_per_col_00_18=>(0.05787243444569822, 0.12150076642224615)'), 'group': 'typology=>7.0', 'lift': 3.592945128779395}
# INFO:root:410847 / 487050: {'rule': ('per_all_li_18=>(0.07232608288405527, 0.3215360644184264)', 'house_increase=>1', 'ch_per_limove_12_18=>(0.017369500761109102, 0.4913001657356805)'), 'group': 'typology=>7.0', 'lift': 4.885620915032679}
# INFO:root:410864 / 487050: {'rule': ('per_all_li_18=>(0.07232608288405527, 0.3215360644184264)', 'house_increase=>1', 'aboverm_real_mhval_90=>1'), 'group': 'typology=>7.0', 'lift': 3.191176470588236}
# INFO:root:410876 / 487050: {'rule': ('per_all_li_18=>(0.07232608288405527, 0.3215360644184264)', 'house_rapid_increase=>0', 'per_ch_zillow_12_18=>(0.3111943220753792, 0.5673345024112231)'), 'group': 'typology=>7.0', 'lift': 3.900000000000001}
# INFO:root:410879 / 487050: {'rule': ('per_all_li_18=>(0.07232608288405527, 0.3215360644184264)', 'house_rapid_increase=>0', 'pctch_real_hinc_90_00=>(0.12704621728576854, 0.7209308673501899)'), 'group': 'typology=>7.0', 'lift': 4.625}
# INFO:root:410889 / 487050: {'rule': ('per_all_li_18=>(0.07232608288405527, 0.3215360644184264)', 'change_flag_category=>ch_rapid_increase', 'pctch_real_hinc_00_18=>(-0.6266114855221789, -0.13736163169161475)'), 'group': 'typology=>6.0', 'lift': 3.6704545454545454}
# INFO:root:410897 / 487050: {'rule': ('per_all_li_18=>(0.07232608288405527, 0.3215360644184264)', 'per_ch_zillow_12_18=>(0.3111943220753792, 0.5673345024112231)', 'aboverm_pctch_real_mrent_12_18=>1'), 'group': 'typology=>6.0', 'lift': 3.1200000000000006}
# INFO:root:410929 / 487050: {'rule': ('per_all_li_18=>(0.07232608288405527, 0.3215360644184264)', 'pctch_real_hinc_00_18=>(-0.6266114855221789, -0.13736163169161475)', 'hotmarket_18=>1.0'), 'group': 'typology=>6.0', 'lift': 3.0617283950617287}
# INFO:root:410931 / 487050: {'rule': ('per_all_li_18=>(0.07232608288405527, 0.3215360644184264)', 'ch_per_col_90_00=>(0.05177264696896694, 0.3491158849333221)', 'aboverm_pctch_real_mrent_12_18=>1'), 'group': 'typology=>6.0', 'lift': 3.0724137931034483}
# INFO:root:410971 / 487050: {'rule': ('per_nonwhite_90=>(0.0, 0.08502289077828651)', 'per_rent_90=>(0.0, 0.21823529411764706)', 'house_increase=>1'), 'group': 'typology=>7.0', 'lift': 3.0641641204714096}
# INFO:root:410974 / 487050: {'rule': ('per_nonwhite_90=>(0.0, 0.08502289077828651)', 'per_rent_00=>(0.010430247718383313, 0.15727321524422974)', 'house_increase=>1'), 'group': 'typology=>7.0', 'lift': 3.443195266272189}
# INFO:root:410977 / 487050: {'rule': ('per_nonwhite_90=>(0.0, 0.08502289077828651)', 'per_rent_18=>(0.0, 0.20769789397240376)', 'house_increase=>1'), 'group': 'typology=>7.0', 'lift': 3.3998842592592595}
# INFO:root:410978 / 487050: {'rule': ('per_nonwhite_90=>(0.0, 0.08502289077828651)', 'per_rent_18=>(0.0, 0.20769789397240376)', 'house_rapid_increase=>0'), 'group': 'typology=>7.0', 'lift': 3.0277777777777777}
# INFO:root:411017 / 487050: {'rule': ('per_nonwhite_90=>(0.0, 0.08502289077828651)', 'aboverm_real_mhval_90=>1', 'aboverm_pctch_real_mhval_90_00=>1'), 'group': 'typology=>7.0', 'lift': 3.2954545454545454}
# INFO:root:411019 / 487050: {'rule': ('per_nonwhite_00=>(0.0321456235476375, 0.12919166960818915)', 'per_rent_00=>(0.010430247718383313, 0.15727321524422974)', 'house_increase=>1'), 'group': 'typology=>7.0', 'lift': 3.327886710239651}
# INFO:root:411020 / 487050: {'rule': ('per_nonwhite_00=>(0.0321456235476375, 0.12919166960818915)', 'per_rent_18=>(0.0, 0.20769789397240376)', 'house_increase=>1'), 'group': 'typology=>7.0', 'lift': 3.24223602484472}
# INFO:root:411030 / 487050: {'rule': ('per_nonwhite_00=>(0.0321456235476375, 0.12919166960818915)', 'pctch_real_mrent_12_18=>(0.2446214871588005, 3.0397287747111066)', 'per_ch_zillow_12_18=>(0.3111943220753792, 0.5673345024112231)'), 'group': 'typology=>6.0', 'lift': 3.3225404732254047}
# INFO:root:411032 / 487050: {'rule': ('per_nonwhite_00=>(0.0321456235476375, 0.12919166960818915)', 'pctch_real_mrent_12_18=>(0.2446214871588005, 3.0397287747111066)', 'aboverm_per_all_li_90=>0'), 'group': 'typology=>6.0', 'lift': 3.171630094043887}
# INFO:root:411044 / 487050: {'rule': ('per_nonwhite_00=>(0.0321456235476375, 0.12919166960818915)', 'aboverm_real_mhval_90=>1', 'aboverm_pctch_real_mhval_90_00=>1'), 'group': 'typology=>7.0', 'lift': 3.4924731182795696}
# INFO:root:411046 / 487050: {'rule': ('per_nonwhite_18=>(0.03097345132743368, 0.18758389261744968)', 'per_rent_90=>(0.0, 0.21823529411764706)', 'house_increase=>1'), 'group': 'typology=>7.0', 'lift': 3.005333333333333}
# INFO:root:411048 / 487050: {'rule': ('per_nonwhite_18=>(0.03097345132743368, 0.18758389261744968)', 'per_rent_00=>(0.010430247718383313, 0.15727321524422974)', 'house_increase=>1'), 'group': 'typology=>7.0', 'lift': 3.4435483870967745}
# INFO:root:411049 / 487050: {'rule': ('per_nonwhite_18=>(0.03097345132743368, 0.18758389261744968)', 'per_rent_18=>(0.0, 0.20769789397240376)', 'house_increase=>1'), 'group': 'typology=>7.0', 'lift': 3.2549019607843137}
# INFO:root:411056 / 487050: {'rule': ('per_nonwhite_18=>(0.03097345132743368, 0.18758389261744968)', 'pctch_real_mhval_00_18=>(0.17462453281149493, 0.4181848671050583)', 'aboverm_per_all_li_90=>0'), 'group': 'typology=>7.0', 'lift': 3.017676767676767}
# INFO:root:411060 / 487050: {'rule': ('per_nonwhite_18=>(0.03097345132743368, 0.18758389261744968)', 'pctch_real_mrent_12_18=>(0.2446214871588005, 3.0397287747111066)', 'aboverm_per_all_li_90=>0'), 'group': 'typology=>6.0', 'lift': 3.5466448445171848}
# INFO:root:411083 / 487050: {'rule': ('per_rent_90=>(0.0, 0.21823529411764706)', 'per_limove_18=>(0.5334746153711671, 0.940992690153764)', 'change_flag_category=>ch_rapid_increase'), 'group': 'typology=>6.0', 'lift': 4.1911764705882355}
# INFO:root:411103 / 487050: {'rule': ('per_rent_90=>(0.0, 0.21823529411764706)', 'per_limove_18=>(0.5334746153711671, 0.940992690153764)', 'hotmarket_18=>1.0'), 'group': 'typology=>6.0', 'lift': 3.112121212121212}
# INFO:root:411106 / 487050: {'rule': ('per_rent_90=>(0.0, 0.21823529411764706)', 'pctch_real_mhval_00_18=>(0.17462453281149493, 0.4181848671050583)', 'house_increase=>1'), 'group': 'typology=>7.0', 'lift': 3.215087132967295}
# INFO:root:411107 / 487050: {'rule': ('per_rent_90=>(0.0, 0.21823529411764706)', 'pctch_real_mhval_00_18=>(0.17462453281149493, 0.4181848671050583)', 'house_rapid_increase=>0'), 'group': 'typology=>7.0', 'lift': 3.014084507042254}
# INFO:root:411115 / 487050: {'rule': ('per_rent_90=>(0.0, 0.21823529411764706)', 'pctch_real_mhval_00_18=>(0.17462453281149493, 0.4181848671050583)', 'aboverm_ch_per_col_00_18=>0'), 'group': 'typology=>7.0', 'lift': 3.007662835249042}
# INFO:root:411118 / 487050: {'rule': ('per_rent_90=>(0.0, 0.21823529411764706)', 'pctch_real_mrent_12_18=>(0.2446214871588005, 3.0397287747111066)', 'per_ch_zillow_12_18=>(0.3111943220753792, 0.5673345024112231)'), 'group': 'typology=>6.0', 'lift': 3.428571428571429}
# INFO:root:411120 / 487050: {'rule': ('per_rent_90=>(0.0, 0.21823529411764706)', 'pctch_real_mrent_12_18=>(0.2446214871588005, 3.0397287747111066)', 'ch_per_col_90_00=>(0.05177264696896694, 0.3491158849333221)'), 'group': 'typology=>6.0', 'lift': 3.6690307328605205}
# INFO:root:411125 / 487050: {'rule': ('per_rent_90=>(0.0, 0.21823529411764706)', 'pctch_real_mrent_12_18=>(0.2446214871588005, 3.0397287747111066)', 'aboverm_pctch_real_mhval_90_00=>1'), 'group': 'typology=>6.0', 'lift': 3.0852380952380947}
# INFO:root:411128 / 487050: {'rule': ('per_rent_90=>(0.0, 0.21823529411764706)', 'house_increase=>1', 'per_ch_zillow_12_18=>(0.3111943220753792, 0.5673345024112231)'), 'group': 'typology=>7.0', 'lift': 4.195064629847238}
# INFO:root:411140 / 487050: {'rule': ('per_rent_90=>(0.0, 0.21823529411764706)', 'house_rapid_increase=>0', 'per_ch_zillow_12_18=>(0.3111943220753792, 0.5673345024112231)'), 'group': 'typology=>7.0', 'lift': 3.7636363636363637}
# INFO:root:411151 / 487050: {'rule': ('per_rent_90=>(0.0, 0.21823529411764706)', 'change_flag_category=>ch_rapid_increase', 'pctch_real_hinc_00_18=>(-0.6266114855221789, -0.13736163169161475)'), 'group': 'typology=>6.0', 'lift': 3.1015384615384614}
# INFO:root:411159 / 487050: {'rule': ('per_rent_90=>(0.0, 0.21823529411764706)', 'per_ch_zillow_12_18=>(0.3111943220753792, 0.5673345024112231)', 'aboverm_pctch_real_mrent_12_18=>1'), 'group': 'typology=>6.0', 'lift': 3.0401427297056203}
# INFO:root:411172 / 487050: {'rule': ('per_rent_90=>(0.0, 0.21823529411764706)', 'pctch_real_hinc_00_18=>(-0.6266114855221789, -0.13736163169161475)', 'aboverm_per_all_li_00=>0'), 'group': 'typology=>7.0', 'lift': 3.024462564862861}
# INFO:root:411184 / 487050: {'rule': ('per_rent_90=>(0.0, 0.21823529411764706)', 'ch_per_col_90_00=>(0.05177264696896694, 0.3491158849333221)', 'aboverm_pctch_real_mrent_12_18=>1'), 'group': 'typology=>6.0', 'lift': 3.188571428571428}
# INFO:root:411209 / 487050: {'rule': ('per_rent_90=>(0.0, 0.21823529411764706)', 'aboverm_real_mhval_90=>1', 'aboverm_pctch_real_mhval_90_00=>1'), 'group': 'typology=>7.0', 'lift': 3.3464052287581696}
# INFO:root:411228 / 487050: {'rule': ('per_rent_00=>(0.010430247718383313, 0.15727321524422974)', 'pctch_real_mhval_00_18=>(0.17462453281149493, 0.4181848671050583)', 'house_increase=>1'), 'group': 'typology=>7.0', 'lift': 3.631995477671001}
# INFO:root:411229 / 487050: {'rule': ('per_rent_00=>(0.010430247718383313, 0.15727321524422974)', 'pctch_real_mhval_00_18=>(0.17462453281149493, 0.4181848671050583)', 'house_rapid_increase=>0'), 'group': 'typology=>7.0', 'lift': 3.4918032786885242}
# INFO:root:411233 / 487050: {'rule': ('per_rent_00=>(0.010430247718383313, 0.15727321524422974)', 'pctch_real_mhval_00_18=>(0.17462453281149493, 0.4181848671050583)', 'aboverm_per_all_li_90=>0'), 'group': 'typology=>7.0', 'lift': 3.2280000000000006}
# INFO:root:411238 / 487050: {'rule': ('per_rent_00=>(0.010430247718383313, 0.15727321524422974)', 'pctch_real_mhval_00_18=>(0.17462453281149493, 0.4181848671050583)', 'aboverm_ch_per_col_00_18=>0'), 'group': 'typology=>7.0', 'lift': 3.1640625000000004}
# INFO:root:411243 / 487050: {'rule': ('per_rent_00=>(0.010430247718383313, 0.15727321524422974)', 'pctch_real_mrent_12_18=>(0.2446214871588005, 3.0397287747111066)', 'ch_per_col_90_00=>(0.05177264696896694, 0.3491158849333221)'), 'group': 'typology=>6.0', 'lift': 3.3822115384615383}
# INFO:root:411244 / 487050: {'rule': ('per_rent_00=>(0.010430247718383313, 0.15727321524422974)', 'pctch_real_mrent_12_18=>(0.2446214871588005, 3.0397287747111066)', 'aboverm_per_all_li_90=>0'), 'group': 'typology=>6.0', 'lift': 3.06}
# INFO:root:411251 / 487050: {'rule': ('per_rent_00=>(0.010430247718383313, 0.15727321524422974)', 'house_increase=>1', 'per_ch_zillow_12_18=>(0.3111943220753792, 0.5673345024112231)'), 'group': 'typology=>7.0', 'lift': 4.7291021671826625}
# INFO:root:411254 / 487050: {'rule': ('per_rent_00=>(0.010430247718383313, 0.15727321524422974)', 'house_increase=>1', 'ch_per_col_90_00=>(0.05177264696896694, 0.3491158849333221)'), 'group': 'typology=>7.0', 'lift': 3.5179704016913314}
# INFO:root:411268 / 487050: {'rule': ('per_rent_00=>(0.010430247718383313, 0.15727321524422974)', 'house_increase=>1', 'aboverm_pctch_real_mhval_90_00=>1'), 'group': 'typology=>7.0', 'lift': 3.1015981735159817}
# INFO:root:411276 / 487050: {'rule': ('per_rent_00=>(0.010430247718383313, 0.15727321524422974)', 'change_flag_category=>ch_rapid_increase', 'pctch_real_hinc_00_18=>(-0.6266114855221789, -0.13736163169161475)'), 'group': 'typology=>6.0', 'lift': 3.154150197628459}
# INFO:root:411282 / 487050: {'rule': ('per_rent_00=>(0.010430247718383313, 0.15727321524422974)', 'per_ch_zillow_12_18=>(0.3111943220753792, 0.5673345024112231)', 'aboverm_pctch_real_mrent_12_18=>1'), 'group': 'typology=>6.0', 'lift': 3.1152291105121295}
# INFO:root:411303 / 487050: {'rule': ('per_rent_00=>(0.010430247718383313, 0.15727321524422974)', 'ch_per_col_90_00=>(0.05177264696896694, 0.3491158849333221)', 'aboverm_pctch_real_mrent_12_18=>1'), 'group': 'typology=>6.0', 'lift': 3.2447916666666665}
# INFO:root:411321 / 487050: {'rule': ('per_rent_00=>(0.010430247718383313, 0.15727321524422974)', 'aboverm_real_mhval_90=>1', 'aboverm_pctch_real_mhval_90_00=>1'), 'group': 'typology=>7.0', 'lift': 4.041666666666666}
# INFO:root:411334 / 487050: {'rule': ('per_rent_18=>(0.0, 0.20769789397240376)', 'per_limove_12=>(0.053000817706700114, 0.4268800157689047)', 'house_increase=>1'), 'group': 'typology=>7.0', 'lift': 3.693295865114411}
# INFO:root:411337 / 487050: {'rule': ('per_rent_18=>(0.0, 0.20769789397240376)', 'pctch_real_mhval_00_18=>(0.17462453281149493, 0.4181848671050583)', 'house_increase=>1'), 'group': 'typology=>7.0', 'lift': 3.470540758676352}
# INFO:root:411338 / 487050: {'rule': ('per_rent_18=>(0.0, 0.20769789397240376)', 'pctch_real_mhval_00_18=>(0.17462453281149493, 0.4181848671050583)', 'house_rapid_increase=>0'), 'group': 'typology=>7.0', 'lift': 3.3333333333333335}
# INFO:root:411342 / 487050: {'rule': ('per_rent_18=>(0.0, 0.20769789397240376)', 'pctch_real_mhval_00_18=>(0.17462453281149493, 0.4181848671050583)', 'aboverm_per_all_li_90=>0'), 'group': 'typology=>7.0', 'lift': 3.24748490945674}
# INFO:root:411353 / 487050: {'rule': ('per_rent_18=>(0.0, 0.20769789397240376)', 'pctch_real_mrent_12_18=>(0.2446214871588005, 3.0397287747111066)', 'aboverm_per_all_li_90=>0'), 'group': 'typology=>6.0', 'lift': 3.1152204836415365}
# INFO:root:411354 / 487050: {'rule': ('per_rent_18=>(0.0, 0.20769789397240376)', 'pctch_real_mrent_12_18=>(0.2446214871588005, 3.0397287747111066)', 'aboverm_pctch_real_mhval_90_00=>1'), 'group': 'typology=>6.0', 'lift': 3.1034482758620685}
# INFO:root:411357 / 487050: {'rule': ('per_rent_18=>(0.0, 0.20769789397240376)', 'house_increase=>1', 'per_ch_zillow_12_18=>(0.3111943220753792, 0.5673345024112231)'), 'group': 'typology=>7.0', 'lift': 4.959663865546219}
# INFO:root:411361 / 487050: {'rule': ('per_rent_18=>(0.0, 0.20769789397240376)', 'house_increase=>1', 'pctch_real_hinc_00_18=>(-0.6266114855221789, -0.13736163169161475)'), 'group': 'typology=>7.0', 'lift': 4.819327731092437}
# INFO:root:411362 / 487050: {'rule': ('per_rent_18=>(0.0, 0.20769789397240376)', 'house_increase=>1', 'ch_per_col_90_00=>(0.05177264696896694, 0.3491158849333221)'), 'group': 'typology=>7.0', 'lift': 3.541666666666667}
# INFO:root:411363 / 487050: {'rule': ('per_rent_18=>(0.0, 0.20769789397240376)', 'house_increase=>1', 'ch_per_col_00_18=>(0.05787243444569822, 0.12150076642224615)'), 'group': 'typology=>7.0', 'lift': 3.837674418604651}
# INFO:root:411364 / 487050: {'rule': ('per_rent_18=>(0.0, 0.20769789397240376)', 'house_increase=>1', 'ch_per_limove_12_18=>(0.017369500761109102, 0.4913001657356805)'), 'group': 'typology=>7.0', 'lift': 4.810207336523127}
# INFO:root:411385 / 487050: {'rule': ('per_rent_18=>(0.0, 0.20769789397240376)', 'house_increase=>1', 'aboverm_pctch_real_mhval_90_00=>1'), 'group': 'typology=>7.0', 'lift': 3.202797202797203}
# INFO:root:411398 / 487050: {'rule': ('per_rent_18=>(0.0, 0.20769789397240376)', 'change_flag_category=>ch_rapid_increase', 'pctch_real_hinc_00_18=>(-0.6266114855221789, -0.13736163169161475)'), 'group': 'typology=>6.0', 'lift': 4.04296875}
# INFO:root:411420 / 487050: {'rule': ('per_rent_18=>(0.0, 0.20769789397240376)', 'pctch_real_hinc_00_18=>(-0.6266114855221789, -0.13736163169161475)', 'hotmarket_18=>1.0'), 'group': 'typology=>6.0', 'lift': 3.1836734693877555}
# INFO:root:411422 / 487050: {'rule': ('per_rent_18=>(0.0, 0.20769789397240376)', 'ch_per_col_90_00=>(0.05177264696896694, 0.3491158849333221)', 'aboverm_pctch_real_mrent_12_18=>1'), 'group': 'typology=>6.0', 'lift': 3.3655172413793104}
# INFO:root:411424 / 487050: {'rule': ('per_rent_18=>(0.0, 0.20769789397240376)', 'ch_per_col_90_00=>(0.05177264696896694, 0.3491158849333221)', 'hotmarket_18=>1.0'), 'group': 'typology=>6.0', 'lift': 3.08989898989899}
# INFO:root:411432 / 487050: {'rule': ('per_rent_18=>(0.0, 0.20769789397240376)', 'aboverm_real_mhval_90=>1', 'aboverm_pctch_real_mhval_90_00=>1'), 'group': 'typology=>7.0', 'lift': 3.576923076923077}
# ...
# INFO:root:476588 / 487050: {'rule': ('high_80120_18=>(0.4946016860547764, 0.8502280114527071)', 'change_flag_category=>ch_increase', 'aboverm_per_col_18=>0'), 'group': 'typology=>7.0', 'lift': 7.666666666666667}
# INFO:root:476589 / 487050: {'rule': ('high_80120_18=>(0.4946016860547764, 0.8502280114527071)', 'change_flag_category=>ch_increase', 'aboverm_real_mhval_18=>0'), 'group': 'typology=>7.0', 'lift': 7.466666666666667}
# INFO:root:476594 / 487050: {'rule': ('high_80120_18=>(0.4946016860547764, 0.8502280114527071)', 'aboverm_real_mhval_18=>0', 'hotmarket_18=>0.0'), 'group': 'typology=>7.0', 'lift': 5.9444444444444455}
# INFO:root:476595 / 487050: {'rule': ('low_80120_00=>(0.012114658689864893, 0.2087531503779575)', 'change_flag_category=>ch_increase', 'aboverm_per_col_18=>0'), 'group': 'typology=>7.0', 'lift': 5.0}
# INFO:root:476596 / 487050: {'rule': ('low_80120_00=>(0.012114658689864893, 0.2087531503779575)', 'change_flag_category=>ch_increase', 'aboverm_real_mhval_18=>0'), 'group': 'typology=>7.0', 'lift': 4.545454545454546}
# INFO:root:476597 / 487050: {'rule': ('low_80120_00=>(0.012114658689864893, 0.2087531503779575)', 'aboverm_real_mhval_18=>0', 'hotmarket_18=>0.0'), 'group': 'typology=>7.0', 'lift': 4.303030303030303}
# INFO:root:476599 / 487050: {'rule': ('high_80120_00=>(0.6083022121341034, 0.9657942580647896)', 'change_flag_category=>ch_increase', 'aboverm_per_col_18=>0'), 'group': 'typology=>7.0', 'lift': 5.359999999999999}
# INFO:root:476600 / 487050: {'rule': ('high_80120_00=>(0.6083022121341034, 0.9657942580647896)', 'change_flag_category=>ch_increase', 'aboverm_real_mhval_18=>0'), 'group': 'typology=>7.0', 'lift': 5.115384615384616}
# INFO:root:476601 / 487050: {'rule': ('high_80120_00=>(0.6083022121341034, 0.9657942580647896)', 'aboverm_real_mhval_18=>0', 'hotmarket_18=>0.0'), 'group': 'typology=>7.0', 'lift': 4.62962962962963}
# INFO:root:476602 / 487050: {'rule': ('high_pdmt_medhhinc_00=>1.0', 'change_flag_category=>ch_increase', 'aboverm_per_col_18=>0'), 'group': 'typology=>7.0', 'lift': 3.621621621621621}
# INFO:root:476603 / 487050: {'rule': ('high_pdmt_medhhinc_00=>1.0', 'change_flag_category=>ch_increase', 'aboverm_real_mhval_18=>0'), 'group': 'typology=>7.0', 'lift': 3.35}
# INFO:root:476604 / 487050: {'rule': ('per_all_li_00=>(0.012114658689864893, 0.2087531503779575)', 'change_flag_category=>ch_increase', 'aboverm_per_col_18=>0'), 'group': 'typology=>7.0', 'lift': 5.0}
# INFO:root:476605 / 487050: {'rule': ('per_all_li_00=>(0.012114658689864893, 0.2087531503779575)', 'change_flag_category=>ch_increase', 'aboverm_real_mhval_18=>0'), 'group': 'typology=>7.0', 'lift': 4.545454545454546}
# INFO:root:476606 / 487050: {'rule': ('per_all_li_00=>(0.012114658689864893, 0.2087531503779575)', 'aboverm_real_mhval_18=>0', 'hotmarket_18=>0.0'), 'group': 'typology=>7.0', 'lift': 4.303030303030303}
# INFO:root:476609 / 487050: {'rule': ('per_all_li_18=>(0.07232608288405527, 0.3215360644184264)', 'change_flag_category=>ch_increase', 'aboverm_per_col_18=>0'), 'group': 'typology=>7.0', 'lift': 7.0}
# INFO:root:476610 / 487050: {'rule': ('per_all_li_18=>(0.07232608288405527, 0.3215360644184264)', 'change_flag_category=>ch_increase', 'aboverm_real_mhval_18=>0'), 'group': 'typology=>7.0', 'lift': 5.904761904761905}
# INFO:root:476614 / 487050: {'rule': ('per_all_li_18=>(0.07232608288405527, 0.3215360644184264)', 'aboverm_real_mhval_18=>0', 'hotmarket_18=>0.0'), 'group': 'typology=>7.0', 'lift': 5.0}
# INFO:root:476689 / 487050: {'rule': ('high_80120_00=>(0.6083022121341034, 0.9657942580647896)', 'per_nonwhite_00=>(0.12954186413902058, 0.2697947214076246)', 'aboverm_per_col_00=>0'), 'group': 'typology=>7.0', 'lift': 3.041666666666667}
# INFO:root:476702 / 487050: {'rule': ('low_80120_00=>(0.012114658689864893, 0.2087531503779575)', 'mod_80120_00=>(0.1674134023874015, 0.2166693073316064)', 'change_flag_category=>ch_increase'), 'group': 'typology=>7.0', 'lift': 7.583333333333334}
# INFO:root:476707 / 487050: {'rule': ('mod_80120_00=>(0.1674134023874015, 0.2166693073316064)', 'high_80120_00=>(0.6083022121341034, 0.9657942580647896)', 'change_flag_category=>ch_increase'), 'group': 'typology=>7.0', 'lift': 8.428571428571429}
# INFO:root:476708 / 487050: {'rule': ('mod_80120_00=>(0.1674134023874015, 0.2166693073316064)', 'high_pdmt_medhhinc_00=>1.0', 'change_flag_category=>ch_increase'), 'group': 'typology=>7.0', 'lift': 5.303030303030303}
# INFO:root:476709 / 487050: {'rule': ('mod_80120_00=>(0.1674134023874015, 0.2166693073316064)', 'per_all_li_00=>(0.012114658689864893, 0.2087531503779575)', 'change_flag_category=>ch_increase'), 'group': 'typology=>7.0', 'lift': 7.583333333333334}
# INFO:root:476712 / 487050: {'rule': ('mod_80120_00=>(0.1674134023874015, 0.2166693073316064)', 'change_flag_category=>ch_increase', 'hv_abrm_ch=>0'), 'group': 'typology=>7.0', 'lift': 6.9523809523809526}
# INFO:root:476713 / 487050: {'rule': ('mod_80120_00=>(0.1674134023874015, 0.2166693073316064)', 'change_flag_category=>ch_increase', 'aboverm_per_all_li_00=>0'), 'group': 'typology=>7.0', 'lift': 4.526315789473684}
# INFO:root:476730 / 487050: {'rule': ('high_80120_00=>(0.3695231792066057, 0.6071075915927819)', 'high_pdmt_medhhinc_00=>1.0', 'change_flag_category=>ch_increase'), 'group': 'typology=>7.0', 'lift': 7.714285714285715}
# INFO:root:476732 / 487050: {'rule': ('high_80120_00=>(0.3695231792066057, 0.6071075915927819)', 'change_flag_category=>ch_increase', 'aboverm_per_all_li_00=>0'), 'group': 'typology=>7.0', 'lift': 4.641025641025641}
# INFO:root:476924 / 487050: {'rule': ('mod_80120_00=>(0.21691021962996973, 0.3394610010898204)', 'change_flag_category=>ch_increase', 'aboverm_per_all_li_00=>0'), 'group': 'typology=>7.0', 'lift': 6.0}
# INFO:root:476944 / 487050: {'rule': ('low_80120_18=>(0.07232608288405527, 0.3215360644184264)', 'mod_80120_18=>(0.20557119174997251, 0.3537495526330947)', 'change_flag_category=>ch_increase'), 'group': 'typology=>7.0', 'lift': 9.142857142857142}
# INFO:root:476947 / 487050: {'rule': ('mod_80120_18=>(0.20557119174997251, 0.3537495526330947)', 'low_80120_00=>(0.012114658689864893, 0.2087531503779575)', 'change_flag_category=>ch_increase'), 'group': 'typology=>7.0', 'lift': 6.71875}
# INFO:root:476950 / 487050: {'rule': ('mod_80120_18=>(0.20557119174997251, 0.3537495526330947)', 'high_80120_00=>(0.6083022121341034, 0.9657942580647896)', 'change_flag_category=>ch_increase'), 'group': 'typology=>7.0', 'lift': 7.178571428571428}
# INFO:root:476951 / 487050: {'rule': ('mod_80120_18=>(0.20557119174997251, 0.3537495526330947)', 'high_pdmt_medhhinc_00=>1.0', 'change_flag_category=>ch_increase'), 'group': 'typology=>7.0', 'lift': 5.324324324324325}
# INFO:root:476952 / 487050: {'rule': ('mod_80120_18=>(0.20557119174997251, 0.3537495526330947)', 'per_all_li_90=>(4.399743375458728e-05, 0.0728616821733332)', 'change_flag_category=>ch_increase'), 'group': 'typology=>7.0', 'lift': 6.628571428571429}
# INFO:root:476953 / 487050: {'rule': ('mod_80120_18=>(0.20557119174997251, 0.3537495526330947)', 'per_all_li_00=>(0.012114658689864893, 0.2087531503779575)', 'change_flag_category=>ch_increase'), 'group': 'typology=>7.0', 'lift': 6.71875}
# INFO:root:476954 / 487050: {'rule': ('mod_80120_18=>(0.20557119174997251, 0.3537495526330947)', 'per_all_li_18=>(0.07232608288405527, 0.3215360644184264)', 'change_flag_category=>ch_increase'), 'group': 'typology=>7.0', 'lift': 9.142857142857142}
# INFO:root:476956 / 487050: {'rule': ('mod_80120_18=>(0.20557119174997251, 0.3537495526330947)', 'change_flag_category=>ch_increase', 'aboverm_per_all_li_00=>0'), 'group': 'typology=>7.0', 'lift': 4.391304347826087}
# INFO:root:476957 / 487050: {'rule': ('mod_80120_18=>(0.20557119174997251, 0.3537495526330947)', 'change_flag_category=>ch_increase', 'aboverm_per_col_00=>1'), 'group': 'typology=>7.0', 'lift': 6.611111111111111}
# INFO:root:476958 / 487050: {'rule': ('mod_80120_18=>(0.20557119174997251, 0.3537495526330947)', 'change_flag_category=>ch_increase', 'aboverm_real_mhval_18=>1'), 'group': 'typology=>7.0', 'lift': 8.818181818181818}
# INFO:root:476959 / 487050: {'rule': ('high_80120_18=>(0.29652503841801536, 0.4943985737048728)', 'low_80120_00=>(0.012114658689864893, 0.2087531503779575)', 'change_flag_category=>ch_increase'), 'group': 'typology=>7.0', 'lift': 6.7857142857142865}
# INFO:root:476961 / 487050: {'rule': ('high_80120_18=>(0.29652503841801536, 0.4943985737048728)', 'high_80120_00=>(0.6083022121341034, 0.9657942580647896)', 'change_flag_category=>ch_increase'), 'group': 'typology=>7.0', 'lift': 8.0}
# INFO:root:476963 / 487050: {'rule': ('high_80120_18=>(0.29652503841801536, 0.4943985737048728)', 'high_80120_00=>(0.6083022121341034, 0.9657942580647896)', 'hotmarket_18=>0.0'), 'group': 'typology=>7.0', 'lift': 8.6}
# INFO:root:476964 / 487050: {'rule': ('high_80120_18=>(0.29652503841801536, 0.4943985737048728)', 'high_pdmt_medhhinc_00=>1.0', 'change_flag_category=>ch_increase'), 'group': 'typology=>7.0', 'lift': 4.717948717948718}
# INFO:root:476965 / 487050: {'rule': ('high_80120_18=>(0.29652503841801536, 0.4943985737048728)', 'per_all_li_00=>(0.012114658689864893, 0.2087531503779575)', 'change_flag_category=>ch_increase'), 'group': 'typology=>7.0', 'lift': 6.7857142857142865}
# INFO:root:476969 / 487050: {'rule': ('high_80120_18=>(0.29652503841801536, 0.4943985737048728)', 'change_flag_category=>ch_increase', 'aboverm_per_all_li_00=>0'), 'group': 'typology=>7.0', 'lift': 3.6226415094339623}
# INFO:root:476970 / 487050: {'rule': ('high_80120_18=>(0.29652503841801536, 0.4943985737048728)', 'lmh_flag_category=>aff_predominantly_MI', 'change_flag_category=>ch_increase'), 'group': 'typology=>7.0', 'lift': 8.3125}
# INFO:root:476973 / 487050: {'rule': ('per_all_li_90=>(4.399743375458728e-05, 0.0728616821733332)', 'change_flag_category=>ch_increase', 'aboverm_per_rent_00=>1'), 'group': 'typology=>7.0', 'lift': 8.090909090909092}
# INFO:root:477168 / 487050: {'rule': ('per_nonwhite_18=>(0.3700854700854701, 0.9230569274759552)', 'change_flag_category=>ch_increase', 'aboverm_per_all_li_00=>0'), 'group': 'typology=>7.0', 'lift': 7.250000000000001}
# INFO:root:477170 / 487050: {'rule': ('per_nonwhite_18=>(0.3700854700854701, 0.9230569274759552)', 'aboverm_per_all_li_00=>0', 'hotmarket_18=>0.0'), 'group': 'typology=>7.0', 'lift': 7.2631578947368425}
# INFO:root:477172 / 487050: {'rule': ('change_flag_category=>ch_increase', 'aboverm_per_all_li_00=>0', 'aboverm_real_mhval_00=>0'), 'group': 'typology=>7.0', 'lift': 5.631578947368421}
# INFO:root:477173 / 487050: {'rule': ('change_flag_category=>ch_increase', 'aboverm_per_all_li_18=>0', 'aboverm_real_mhval_00=>0'), 'group': 'typology=>7.0', 'lift': 7.727272727272726}
# INFO:root:477174 / 487050: {'rule': ('aboverm_per_all_li_00=>0', 'aboverm_real_mhval_00=>0', 'hotmarket_18=>0.0'), 'group': 'typology=>7.0', 'lift': 4.904761904761905}
# INFO:root:477243 / 487050: {'rule': ('low_80120_18=>(0.321618738222016, 0.4896157527993907)', 'low_80120_00=>(0.012114658689864893, 0.2087531503779575)', 'change_flag_category=>ch_increase'), 'group': 'typology=>7.0', 'lift': 7.625}
# INFO:root:477246 / 487050: {'rule': ('low_80120_18=>(0.321618738222016, 0.4896157527993907)', 'high_80120_00=>(0.6083022121341034, 0.9657942580647896)', 'change_flag_category=>ch_increase'), 'group': 'typology=>7.0', 'lift': 9.210526315789474}
# INFO:root:477247 / 487050: {'rule': ('low_80120_18=>(0.321618738222016, 0.4896157527993907)', 'high_80120_00=>(0.6083022121341034, 0.9657942580647896)', 'hotmarket_18=>0.0'), 'group': 'typology=>7.0', 'lift': 9.941176470588236}
# INFO:root:477248 / 487050: {'rule': ('low_80120_18=>(0.321618738222016, 0.4896157527993907)', 'high_pdmt_medhhinc_00=>1.0', 'change_flag_category=>ch_increase'), 'group': 'typology=>7.0', 'lift': 5.2}
# INFO:root:477249 / 487050: {'rule': ('low_80120_18=>(0.321618738222016, 0.4896157527993907)', 'per_all_li_00=>(0.012114658689864893, 0.2087531503779575)', 'change_flag_category=>ch_increase'), 'group': 'typology=>7.0', 'lift': 7.625}
# INFO:root:477251 / 487050: {'rule': ('low_80120_18=>(0.321618738222016, 0.4896157527993907)', 'lmh_flag_category=>aff_mix_mod', 'change_flag_category=>ch_increase'), 'group': 'typology=>7.0', 'lift': 3.4901960784313726}
# INFO:root:477253 / 487050: {'rule': ('low_80120_18=>(0.321618738222016, 0.4896157527993907)', 'change_flag_category=>ch_increase', 'aboverm_per_all_li_00=>0'), 'group': 'typology=>7.0', 'lift': 3.823529411764706}
# INFO:root:477259 / 487050: {'rule': ('low_80120_00=>(0.012114658689864893, 0.2087531503779575)', 'per_all_li_18=>(0.321618738222016, 0.4896157527993907)', 'change_flag_category=>ch_increase'), 'group': 'typology=>7.0', 'lift': 7.625}
# INFO:root:477270 / 487050: {'rule': ('high_80120_00=>(0.6083022121341034, 0.9657942580647896)', 'per_all_li_18=>(0.321618738222016, 0.4896157527993907)', 'change_flag_category=>ch_increase'), 'group': 'typology=>7.0', 'lift': 9.210526315789474}
# INFO:root:477271 / 487050: {'rule': ('high_80120_00=>(0.6083022121341034, 0.9657942580647896)', 'per_all_li_18=>(0.321618738222016, 0.4896157527993907)', 'hotmarket_18=>0.0'), 'group': 'typology=>7.0', 'lift': 9.941176470588236}
# INFO:root:477279 / 487050: {'rule': ('high_pdmt_medhhinc_00=>1.0', 'per_all_li_18=>(0.321618738222016, 0.4896157527993907)', 'change_flag_category=>ch_increase'), 'group': 'typology=>7.0', 'lift': 5.2}
# INFO:root:477281 / 487050: {'rule': ('high_pdmt_medhhinc_00=>1.0', 'change_flag_category=>ch_increase', 'aboverm_per_all_li_18=>1'), 'group': 'typology=>7.0', 'lift': 4.0}
# INFO:root:477282 / 487050: {'rule': ('high_pdmt_medhhinc_00=>1.0', 'aboverm_per_all_li_18=>1', 'hotmarket_18=>0.0'), 'group': 'typology=>7.0', 'lift': 3.642857142857143}
# INFO:root:477284 / 487050: {'rule': ('per_all_li_90=>(4.399743375458728e-05, 0.0728616821733332)', 'change_flag_category=>ch_increase', 'aboverm_per_rent_18=>1'), 'group': 'typology=>7.0', 'lift': 7.3076923076923075}
# INFO:root:477286 / 487050: {'rule': ('per_all_li_00=>(0.012114658689864893, 0.2087531503779575)', 'per_all_li_18=>(0.321618738222016, 0.4896157527993907)', 'change_flag_category=>ch_increase'), 'group': 'typology=>7.0', 'lift': 7.625}
# INFO:root:477296 / 487050: {'rule': ('per_all_li_18=>(0.321618738222016, 0.4896157527993907)', 'lmh_flag_category=>aff_mix_mod', 'change_flag_category=>ch_increase'), 'group': 'typology=>7.0', 'lift': 3.4901960784313726}
# INFO:root:477298 / 487050: {'rule': ('per_all_li_18=>(0.321618738222016, 0.4896157527993907)', 'change_flag_category=>ch_increase', 'aboverm_per_all_li_00=>0'), 'group': 'typology=>7.0', 'lift': 3.823529411764706}
# INFO:root:477304 / 487050: {'rule': ('low_80120_18=>(0.321618738222016, 0.4896157527993907)', 'per_limove_18=>(0.3877966444004181, 0.5313058144518821)', 'change_flag_category=>ch_increase'), 'group': 'typology=>7.0', 'lift': 8.25925925925926}
# INFO:root:477308 / 487050: {'rule': ('per_all_li_18=>(0.321618738222016, 0.4896157527993907)', 'per_limove_18=>(0.3877966444004181, 0.5313058144518821)', 'change_flag_category=>ch_increase'), 'group': 'typology=>7.0', 'lift': 8.25925925925926}
# INFO:root:477309 / 487050: {'rule': ('low_80120_18=>(0.321618738222016, 0.4896157527993907)', 'per_nonwhite_90=>(0.08535090407600354, 0.1785434812593425)', 'change_flag_category=>ch_increase'), 'group': 'typology=>7.0', 'lift': 5.8}
# INFO:root:477310 / 487050: {'rule': ('low_80120_18=>(0.321618738222016, 0.4896157527993907)', 'per_limove_12=>(0.5923751141142446, 0.9251455275118912)', 'change_flag_category=>ch_increase'), 'group': 'typology=>7.0', 'lift': 8.458333333333334}
# INFO:root:477320 / 487050: {'rule': ('per_all_li_18=>(0.321618738222016, 0.4896157527993907)', 'per_nonwhite_90=>(0.08535090407600354, 0.1785434812593425)', 'change_flag_category=>ch_increase'), 'group': 'typology=>7.0', 'lift': 5.8}
# INFO:root:477321 / 487050: {'rule': ('per_all_li_18=>(0.321618738222016, 0.4896157527993907)', 'per_limove_12=>(0.5923751141142446, 0.9251455275118912)', 'change_flag_category=>ch_increase'), 'group': 'typology=>7.0', 'lift': 8.458333333333334}

# %%
output.to_csv("{}/data/stucco/stucco_{}".format(customized_path_to_homework, file_name))

# %% [markdown]
# ###  Rule Metrics

# %% [markdown]
# **Rules with high Lift and Confidence**

# %% [markdown]
# ref: http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.150.6616&rep=rep1&type=pdf
#
# Confidence ranges from 0 to 1. Confidence is an estimate of Pr(C | A), the
# probability of observing C given A. After obtaining a rule set, one can immediatly
# use confidence as a basis for classifying one new case x. Of all the rules that
# apply to x (i.e., the rules whose antecedent is true in x), we choose the one
# with highest confidence. This loosely follows the optimal Bayes classifier

# %% [markdown]
# ref: http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.150.6616&rep=rep1&type=pdf
#
# Conviction is another measure proposed in [4] to tackle some of the weaknesses of confidence and lift. Unlike lift, conviction is sensitive to rule direction
# (conv(A → C) 6= conv(C → A)). Conviction is somewhat inspired in the logical
# definition of implication and attempts to measure the degree of implication of
# a rule. Conviction is infinite for logical implications (confidence 1), and is 1 if
# A and C are independent

# %% [markdown]
# ref: http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.150.6616&rep=rep1&type=pdf
#
# Lift measures how far from independence are A and C. It ranges within
# [0, +∞[. Values close to 1 imply that A and C are independent and the rule
# is not interesting.
