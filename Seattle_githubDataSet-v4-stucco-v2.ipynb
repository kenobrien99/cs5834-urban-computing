# %% [markdown]
# **CS 5834, Fall 2020: Intro to Urban Computing Project - STUCCO analysis for Gentrification using Seattle Data Set**

# %% [markdown]
# ### Imports and Mount File Directories

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
# modify "customized_path_to_homework", path of folder in drive, where you project is stored
customized_path_to_homework = "/content/drive/My Drive/cs5834/urbcomp_fall2020/project"
file_name = "Seattle_typology_output.csv"

sys.path.append(customized_path_to_homework)

# %%
# %cd $customized_path_to_homework/data
# Out:
# /content/drive/My Drive/cs5834/urbcomp_fall2020/project/data

# %%
import os, sys
import pandas as pd
import numpy as np
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
import datetime
import warnings

# %%
"""
sys.path.insert(0,'../')
# %load_ext autoreload
# %autoreload 2
import nyctaxi_helpers
warnings.filterwarnings('ignore')
"""
# Out:
# "\nsys.path.insert(0,'../')\n%load_ext autoreload\n%autoreload 2\nimport nyctaxi_helpers\nwarnings.filterwarnings('ignore')\n"

# %%
#pip install --upgrade mlxtend

# %%
#ref https://pbpython.com/market-basket-analysis.html


#may need to install mlxtend package - pip install mlxtend in console
import pandas as pd
# #from mlxtend.frequent_patterns import apriori
# from mlxtend.frequent_patterns import fpgrowth
# from mlxtend.frequent_patterns import association_rules

# %%
# !wget -nc https://raw.githubusercontent.com/parsahosseini/contrast/master/stucco.py
# Out:
# File ‘stucco.py’ already there; not retrieving.

# %% [markdown]
# # **Process Urban Displacement Model Data for Gentrificaiton**

# %% [markdown]
# Reference: https://www.urbandisplacement.org/open-source-project

# %% [markdown]
# Based on the work https://ww2.arb.ca.gov/sites/default/files/classic//research/apr/past/13-310.pdf?_ga=2.269282425.968981409.1605209194-851335111.1605209194
#
# **Developing a New
# Methodology for Analyzing
# Potential Displacement**
#
# University of California, Berkeley
#
# Principal Investigator:
# Karen Chapple
#
# https://ww3.arb.ca.gov/research/single-project.php?row_id=65188

# %% [markdown]
# ## **Obtain the Data**
#
# Data can be found at https://github.com/urban-displacement/displacement-typologies/blob/main/data/outputs/typologies/LosAngeles_typology_output.csv

# %%
download_file = ("https://raw.githubusercontent.com/urban-displacement/displacement-typologies/main/data/outputs/typologies/{}".format(file_name))

# %%
#!wget -nc $download_file

# %%
## Process Data - if data file already processed then can start at Associaton Rules section
# get the Data File

df = pd.read_csv("https://raw.githubusercontent.com/urban-displacement/displacement-typologies/main/data/outputs/typologies/{}".format(file_name), index_col=0)
#df = pd.read_csv("{}/data/{}".format(customized_path_to_homework, file_name), index_col=0)

# sneak peak in the data
df.head(10)
# Out:
#    pop_18  white_18   hh_18   hinc_18  ...  LISD  double_counted  typology   typ_cat
# 0  3089.0    2722.0  1109.0  122125.0  ...     0             1.0       7.0   ['ARE']
# 1  5717.0    4602.0  2139.0   72821.0  ...     0             1.0       7.0   ['ARE']
# 2  5373.0    3444.0  1954.0  152222.0  ...     0             1.0       6.0  ['SMMI']
# 3  2587.0    2214.0   929.0   86635.0  ...     0             1.0       7.0   ['ARE']
# 4  4916.0    3637.0  1837.0  100586.0  ...     0             1.0       7.0   ['ARE']
# 5  4309.0    3944.0  1723.0   74255.0  ...     0             1.0       7.0   ['ARE']
# 6  7413.0    3925.0  2542.0   60714.0  ...     0             1.0       2.0    ['OD']
# 7  3292.0    1454.0  1172.0   52240.0  ...     1             1.0       1.0  ['LISD']
# 8  5044.0    3857.0  1827.0   78027.0  ...     0             1.0       7.0   ['ARE']
# 9  5268.0    4372.0  1712.0   91200.0  ...     0             1.0       7.0   ['ARE']
#
# [10 rows x 305 columns]

# %%
df.columns
# Out:
# Index(['pop_18', 'white_18', 'hh_18', 'hinc_18', 'mhval_18', 'mhval_18_se',
#        'mrent_18', 'mrent_18_se', 'total_25_18', 'total_25_col_bd_18',
#        ...
#        'BE', 'SMMI', 'ARG', 'EOG', 'OD', 'OD_loss', 'LISD', 'double_counted',
#        'typology', 'typ_cat'],
#       dtype='object', length=305)

# %%
"""
# create a working copy of the data to process
df2 = df.copy()

#removed  'inc_cat_medhhinc_encoded18', 'inc_cat_medhhinc_encoded00',
df2 = df2[[ 'inc80_18',
 'inc120_18',
 'inc80_00',
 'inc120_00',
 'inc80_90',
 'low_80120_18',
 'mod_80120_18',
 'high_80120_18',
 'low_pdmt_medhhinc_18',
 'high_pdmt_medhhinc_18',
 'mod_pdmt_medhhinc_18',
 'mix_low_medhhinc_18',
 'mix_mod_medhhinc_18',
 'mix_high_medhhinc_18',

 'low_80120_00',
 'mod_80120_00',
 'high_80120_00',
 'low_pdmt_medhhinc_00',
 'high_pdmt_medhhinc_00',
 'mod_pdmt_medhhinc_00',
 'mix_low_medhhinc_00',
 'mix_mod_medhhinc_00',
 'mix_high_medhhinc_00',

 'per_all_li_90',
 'per_all_li_00',
 'per_all_li_18',
 'per_nonwhite_90',
 'per_nonwhite_00',
 'per_nonwhite_18',
 'per_rent_90',
 'per_rent_00',
 'per_rent_18',
 'per_col_90',
 'per_col_00',
 'per_col_18',
 'per_units_pre50_18',
 'per_limove_18',
 'per_limove_12',
 'lmh_flag_category',
 'pctch_real_mhval_00_18',
 'pctch_real_mrent_12_18',
 'rent_decrease',
 'rent_marginal',
 'rent_increase',
 'rent_rapid_increase',
 'house_decrease',
 'house_marginal',
 'house_increase',
 'house_rapid_increase',
 'tot_decrease',
 'tot_marginal',
 'tot_increase',
 'tot_rapid_increase',
 'change_flag_category',
 'per_ch_zillow_12_18',
 'ab_50pct_ch',
 'ab_90percentile_ch',
 'rent_50pct_ch',
 'rent_90percentile_ch',
 'hv_abrm_ch',
 'rent_abrm_ch',
 'pctch_real_mhval_90_00',
 'pctch_real_mrent_90_00',
 'pctch_real_hinc_90_00',
 'pctch_real_mrent_00_18',
 'pctch_real_hinc_00_18',
 'ch_per_col_90_00',
 'ch_per_col_00_18',
 'ch_per_limove_12_18',
 'aboverm_per_all_li_90',
 'aboverm_per_all_li_00',
 'aboverm_per_all_li_18',
 'aboverm_per_nonwhite_18',
 'aboverm_per_nonwhite_90',
 'aboverm_per_nonwhite_00',
 'aboverm_per_rent_90',
 'aboverm_per_rent_00',
 'aboverm_per_rent_18',
 'aboverm_per_col_90',
 'aboverm_per_col_00',
 'aboverm_per_col_18',
 'aboverm_real_mrent_90',
 'aboverm_real_mrent_00',
 'aboverm_real_mrent_12',
 'aboverm_real_mrent_18',
 'aboverm_real_mhval_90',
 'aboverm_real_mhval_00',
 'aboverm_real_mhval_18',
 'aboverm_pctch_real_mhval_00_18',
 'aboverm_pctch_real_mrent_00_18',
 'aboverm_pctch_real_mrent_12_18',
 'aboverm_pctch_real_mhval_90_00',
 'aboverm_pctch_real_mrent_90_00',
 'lostli_00',
 'lostli_18',
 'aboverm_pctch_real_hinc_90_00',
 'aboverm_pctch_real_hinc_00_18',
 'aboverm_ch_per_col_90_00',
 'aboverm_ch_per_col_00_18',
 'aboverm_per_units_pre50_18',
 'GEOID',
 'rail',
 'presence_ph_LIHTC',
 'hotmarket_00',
 'hotmarket_18',
 'dp_PChRent',
 'dp_RentGap',
 'dense',
 'typology']]


# drop rows which dont have a gentrification category
df2.dropna(subset=['typology'], inplace=True)
df2 = df2.set_index('GEOID')

#fill the nas
df2.fillna(0.0, inplace=True)


df2.head(10)
"""
# Out:
# "\n# create a working copy of the data to process\ndf2 = df.copy()\n\n#removed  'inc_cat_medhhinc_encoded18', 'inc_cat_medhhinc_encoded00',\ndf2 = df2[[ 'inc80_18',\n 'inc120_18',\n 'inc80_00',\n 'inc120_00',\n 'inc80_90',\n 'low_80120_18',\n 'mod_80120_18',\n 'high_80120_18',\n 'low_pdmt_medhhinc_18',\n 'high_pdmt_medhhinc_18',\n 'mod_pdmt_medhhinc_18',\n 'mix_low_medhhinc_18',\n 'mix_mod_medhhinc_18',\n 'mix_high_medhhinc_18',\n\n 'low_80120_00',\n 'mod_80120_00',\n 'high_80120_00',\n 'low_pdmt_medhhinc_00',\n 'high_pdmt_medhhinc_00',\n 'mod_pdmt_medhhinc_00',\n 'mix_low_medhhinc_00',\n 'mix_mod_medhhinc_00',\n 'mix_high_medhhinc_00',\n\n 'per_all_li_90',\n 'per_all_li_00',\n 'per_all_li_18',\n 'per_nonwhite_90',\n 'per_nonwhite_00',\n 'per_nonwhite_18',\n 'per_rent_90',\n 'per_rent_00',\n 'per_rent_18',\n 'per_col_90',\n 'per_col_00',\n 'per_col_18',\n 'per_units_pre50_18',\n 'per_limove_18',\n 'per_limove_12',\n 'lmh_flag_category',\n 'pctch_real_mhval_00_18',\n 'pctch_real_mrent_12_18',\n 'rent_decrease',\n 'rent_marginal',\n 'rent_increase',\n 'rent_rapid_increase',\n 'house_decrease',\n 'house_marginal',\n 'house_increase',\n 'house_rapid_increase',\n 'tot_decrease',\n 'tot_marginal',\n 'tot_increase',\n 'tot_rapid_increase',\n 'change_flag_category',\n 'per_ch_zillow_12_18',\n 'ab_50pct_ch',\n 'ab_90percentile_ch',\n 'rent_50pct_ch',\n 'rent_90percentile_ch',\n 'hv_abrm_ch',\n 'rent_abrm_ch',\n 'pctch_real_mhval_90_00',\n 'pctch_real_mrent_90_00',\n 'pctch_real_hinc_90_00',\n 'pctch_real_mrent_00_18',\n 'pctch_real_hinc_00_18',\n 'ch_per_col_90_00',\n 'ch_per_col_00_18',\n 'ch_per_limove_12_18',\n 'aboverm_per_all_li_90',\n 'aboverm_per_all_li_00',\n 'aboverm_per_all_li_18',\n 'aboverm_per_nonwhite_18',\n 'aboverm_per_nonwhite_90',\n 'aboverm_per_nonwhite_00',\n 'aboverm_per_rent_90',\n 'aboverm_per_rent_00',\n 'aboverm_per_rent_18',\n 'aboverm_per_col_90',\n 'aboverm_per_col_00',\n 'aboverm_per_col_18',\n 'aboverm_real_mrent_90',\n 'aboverm_real_mrent_00',\n 'aboverm_real_mrent_12',\n 'aboverm_real_mrent_18',\n 'aboverm_real_mhval_90',\n 'aboverm_real_mhval_00',\n 'aboverm_real_mhval_18',\n 'aboverm_pctch_real_mhval_00_18',\n 'aboverm_pctch_real_mrent_00_18',\n 'aboverm_pctch_real_mrent_12_18',\n 'aboverm_pctch_real_mhval_90_00',\n 'aboverm_pctch_real_mrent_90_00',\n 'lostli_00',\n 'lostli_18',\n 'aboverm_pctch_real_hinc_90_00',\n 'aboverm_pctch_real_hinc_00_18',\n 'aboverm_ch_per_col_90_00',\n 'aboverm_ch_per_col_00_18',\n 'aboverm_per_units_pre50_18',\n 'GEOID',\n 'rail',\n 'presence_ph_LIHTC',\n 'hotmarket_00',\n 'hotmarket_18',\n 'dp_PChRent',\n 'dp_RentGap',\n 'dense',\n 'typology']]\n\n\n# drop rows which dont have a gentrification category\ndf2.dropna(subset=['typology'], inplace=True)\ndf2 = df2.set_index('GEOID')\n\n#fill the nas\ndf2.fillna(0.0, inplace=True)\n\n\ndf2.head(10)\n"

# %%
# create a working copy of the data to process
df2 = df.copy()

"""
removed  'inc_cat_medhhinc_encoded18', 'inc_cat_medhhinc_encoded00', 
'inc80_18',
 'inc120_18',
 'inc80_00',
 'inc120_00',
 'inc80_90',
  'per_col_90',
 'per_col_00',
 'per_col_18',
  'tot_decrease',
 'tot_marginal',
 'tot_increase',
 'tot_rapid_increase',
  'pctch_real_mhval_90_00',
 'pctch_real_mrent_90_00',
 'pctch_real_mrent_00_18',
 'per_units_pre50_18',
  
"""

df2.head(10)
df2 = df2[[ 

 'low_80120_18',
 'mod_80120_18',
 'high_80120_18',
 'low_pdmt_medhhinc_18',
 'high_pdmt_medhhinc_18',
 'mod_pdmt_medhhinc_18',
 'mix_low_medhhinc_18',
 'mix_mod_medhhinc_18',
 'mix_high_medhhinc_18',

 'low_80120_00',
 'mod_80120_00',
 'high_80120_00',
 'low_pdmt_medhhinc_00',
 'high_pdmt_medhhinc_00',
 'mod_pdmt_medhhinc_00',
 'mix_low_medhhinc_00',
 'mix_mod_medhhinc_00',
 'mix_high_medhhinc_00',

 'per_all_li_90',
 'per_all_li_00',
 'per_all_li_18',
 'per_nonwhite_90',
 'per_nonwhite_00',
 'per_nonwhite_18',
 'per_rent_90',
 'per_rent_00',
 'per_rent_18',

 
 'per_limove_18',
 'per_limove_12',
 'lmh_flag_category',
 'pctch_real_mhval_00_18',
 'pctch_real_mrent_12_18',
 'rent_decrease',
 'rent_marginal',
 'rent_increase',
 'rent_rapid_increase',
 'house_decrease',
 'house_marginal',
 'house_increase',
 'house_rapid_increase',

 'change_flag_category',
 'per_ch_zillow_12_18',
 'ab_50pct_ch',
 'ab_90percentile_ch',
 'rent_50pct_ch',
 'rent_90percentile_ch',
 'hv_abrm_ch',
 'rent_abrm_ch',

 'pctch_real_hinc_90_00',
 
 'pctch_real_hinc_00_18',
 'ch_per_col_90_00',
 'ch_per_col_00_18',
 'ch_per_limove_12_18',
 'aboverm_per_all_li_90',
 'aboverm_per_all_li_00',
 'aboverm_per_all_li_18',
 'aboverm_per_nonwhite_18',
 'aboverm_per_nonwhite_90',
 'aboverm_per_nonwhite_00',
 'aboverm_per_rent_90',
 'aboverm_per_rent_00',
 'aboverm_per_rent_18',
 'aboverm_per_col_90',
 'aboverm_per_col_00',
 'aboverm_per_col_18',
 'aboverm_real_mrent_90',
 'aboverm_real_mrent_00',
 'aboverm_real_mrent_12',
 'aboverm_real_mrent_18',
 'aboverm_real_mhval_90',
 'aboverm_real_mhval_00',
 'aboverm_real_mhval_18',
 'aboverm_pctch_real_mhval_00_18',
 'aboverm_pctch_real_mrent_00_18',
 'aboverm_pctch_real_mrent_12_18',
 'aboverm_pctch_real_mhval_90_00',
 'aboverm_pctch_real_mrent_90_00',
 'lostli_00',
 'lostli_18',
 'aboverm_pctch_real_hinc_90_00',
 'aboverm_pctch_real_hinc_00_18',
 'aboverm_ch_per_col_90_00',
 'aboverm_ch_per_col_00_18',
 'aboverm_per_units_pre50_18',
 'GEOID',
 'rail',
 'presence_ph_LIHTC',
 'hotmarket_00',
 'hotmarket_18',
 'dp_PChRent',
 'dp_RentGap',
 'dense',
 'typology']]

# drop rows which dont have a gentrification category
df2.dropna(subset=['typology'], inplace=True)
df2 = df2.set_index('GEOID')

#fill the nas
df2.fillna(0.0, inplace=True)


df2.head(10)
# Out:
#              low_80120_18  mod_80120_18  ...  dense  typology
# GEOID                                    ...
# 53061052113      0.193854      0.217980  ...      0       7.0
# 53061052904      0.473768      0.232011  ...      0       7.0
# 53061042005      0.174057      0.132720  ...      0       6.0
# 53061052504      0.354614      0.300848  ...      0       7.0
# 53061051918      0.375988      0.124089  ...      0       7.0
# 53061053201      0.440755      0.189433  ...      0       7.0
# 53053062500      0.557999      0.198831  ...      0       2.0
# 53053063000      0.692757      0.144091  ...      0       1.0
# 53053071205      0.429005      0.208271  ...      0       7.0
# 53053070310      0.344225      0.231862  ...      0       7.0
#
# [10 rows x 92 columns]

# %% [markdown]
# ### Convert select continous variables to categorical and one hot encode

# %%
# # convert already dummy variables from float to int
# dummy_var_list = ['hotmarket_00', 'hotmarket_18', 'low_pdmt_medhhinc_00', 'high_pdmt_medhhinc_00', 'mod_pdmt_medhhinc_00',
#                   'mix_low_medhhinc_00', 'mix_mod_medhhinc_00',  'mix_high_medhhinc_00', 'low_pdmt_medhhinc_18', 'high_pdmt_medhhinc_18',
#                   'mod_pdmt_medhhinc_18', 'mix_low_medhhinc_18', 'mix_mod_medhhinc_18', 'mix_high_medhhinc_18', 'presence_ph_LIHTC',
#                   'typology']
# for dummycol in dummy_var_list:
#   df2.loc[:,(dummycol)] = df2[dummycol].astype(int, copy=False)

# %%
# use float variables to represent each categorical variable by dividing into quartiles
def convert_percents_to_dummy_vars(X):

    columns = X.columns

    bin_labels_4 = ['VL', 'L', 'H',  'VH']


    for i in range(0, len(columns)):
        if X[columns[i]].dtype=='float64':
          print("Processing: " + columns[i])

          X[columns[i]] = X[columns[i]].fillna(0)
          cat_label = "{}_cat".format(columns[i])
          dummy_label = "{}_dummy".format(columns[i])
          X[cat_label] = pd.qcut(X[columns[i]], 
                                 4,
                              precision=5,
                              duplicates = 'drop',
                              labels=bin_labels_4)
          X = pd.get_dummies(X, columns=[cat_label], prefix=[dummy_label])
          X = X.drop([columns[i]], axis=1)

    return X

# %%
# check if categorical then convert to dummy using label and onehot encoding
def convert_categorical_to_dummy_vars(X):

    from sklearn.preprocessing import LabelEncoder
    from sklearn.preprocessing import OneHotEncoder    

    columns = X.columns
    indices = X.index
    new_columns = []
    encoded_x = None

    for i in range(0, len(columns)):
        if X[columns[i]].dtype=='O':
          print("Processing: " + columns[i])


          label_encoder = LabelEncoder()
          le = label_encoder.fit(X[columns[i]].apply(str))
          for class_ in le.classes_:
              new_columns.append("{}_{}".format(columns[i],class_))
              
          feature = le.transform(X[columns[i]].apply(str))
          feature = feature.reshape(X.shape[0], 1)
          onehot_encoder = OneHotEncoder(sparse=False)
          onehot_encoder.fit(feature)
          feature = onehot_encoder.transform(feature)
          if encoded_x is None:
              encoded_x = feature
          else:
              encoded_x = np.concatenate((encoded_x, feature), axis=1)
          X = X.drop(columns[i], axis=1)
    new_columns.extend(X.columns)

    X = pd.DataFrame(np.concatenate((encoded_x,X),axis=1),index=indices,columns=new_columns)
    
    return X

# %% [markdown]
# ### Convert Percentage (floats) to Quartiles and Dummy Variables

# %%
# # process and save data all converted to one hot encoding
# df2 = convert_percents_to_dummy_vars(df2)

# %%
# df2 = convert_categorical_to_dummy_vars(df2)

# %% [markdown]
# iii. Save the dataset as a CSV file. The first line of the CSV file should be the attribute
# names as described in the previous question.

# %%
# df2.to_csv("{}/data/processed_{}".format(customized_path_to_homework, file_name))

# %% [markdown]
# # **STUCCO Rule Calculations**

# %%
# load already processed data 
# df3 = pd.read_csv("{}/data/processed_{}".format(customized_path_to_homework, file_name), index_col=0)
# df3 = df3.astype(int)

# %%
confidence_cut = 0.8
lift_cut = 1.0
conviction_cut = 0.8
support_cut = 0.65

# %%
#ref: https://www.ics.uci.edu/~pazzani/Publications/stucco.pdf
#ref: https://github.com/parsahosseini/contrast/blob/master/README.md

# %%
from stucco import ContrastSetLearner
learner = ContrastSetLearner(df2, group_feature='typology')
# Out:
# INFO:root:User-defined feature is 'typology'
# INFO:root:Data dimensions: 715 x 92
# INFO:root:Reading object features (n=3)
# INFO:root:Reading numeric features (n=89)
# INFO:root:27 features lack value; dropping
# INFO:root:New data dimensions: 715 x 65
# INFO:root:Record count (pre-index): 715
# INFO:root:Record count (index): 715

# %%
# derive 3-length combinations of a rule and enumerate their abundance.
learner.learn(max_length=3)
# Out:
# INFO:root:Enumerating 715 item-sets, i
# INFO:root:i=0; n(matrix)=0
# INFO:root:i=200; n(matrix)=450,388
# INFO:root:i=400; n(matrix)=582,999
# INFO:root:i=600; n(matrix)=589,612
# INFO:root:602,776 contingency matrices made
# INFO:root:i=0 matrix not-rules enumerated
# INFO:root:i=2500 matrix not-rules enumerated
# INFO:root:i=5000 matrix not-rules enumerated
# INFO:root:i=7500 matrix not-rules enumerated
# INFO:root:i=10000 matrix not-rules enumerated
# INFO:root:i=12500 matrix not-rules enumerated
# INFO:root:i=15000 matrix not-rules enumerated
# INFO:root:i=17500 matrix not-rules enumerated
# INFO:root:i=20000 matrix not-rules enumerated
# INFO:root:i=22500 matrix not-rules enumerated
# INFO:root:i=25000 matrix not-rules enumerated
# INFO:root:i=27500 matrix not-rules enumerated
# INFO:root:i=30000 matrix not-rules enumerated
# INFO:root:i=32500 matrix not-rules enumerated
# INFO:root:i=35000 matrix not-rules enumerated
# INFO:root:i=37500 matrix not-rules enumerated
# INFO:root:i=40000 matrix not-rules enumerated
# INFO:root:i=42500 matrix not-rules enumerated
# INFO:root:i=45000 matrix not-rules enumerated
# INFO:root:i=47500 matrix not-rules enumerated
# INFO:root:i=50000 matrix not-rules enumerated
# INFO:root:i=52500 matrix not-rules enumerated
# INFO:root:i=55000 matrix not-rules enumerated
# INFO:root:i=57500 matrix not-rules enumerated
# INFO:root:i=60000 matrix not-rules enumerated
# INFO:root:i=62500 matrix not-rules enumerated
# INFO:root:i=65000 matrix not-rules enumerated
# INFO:root:i=67500 matrix not-rules enumerated
# INFO:root:i=70000 matrix not-rules enumerated
# INFO:root:i=72500 matrix not-rules enumerated
# INFO:root:i=75000 matrix not-rules enumerated
# INFO:root:i=77500 matrix not-rules enumerated
# INFO:root:i=80000 matrix not-rules enumerated
# INFO:root:i=82500 matrix not-rules enumerated
# INFO:root:i=85000 matrix not-rules enumerated
# INFO:root:i=87500 matrix not-rules enumerated
# INFO:root:i=90000 matrix not-rules enumerated
# INFO:root:i=92500 matrix not-rules enumerated
# INFO:root:i=95000 matrix not-rules enumerated
# INFO:root:i=97500 matrix not-rules enumerated
# INFO:root:i=100000 matrix not-rules enumerated
# INFO:root:i=102500 matrix not-rules enumerated
# INFO:root:i=105000 matrix not-rules enumerated
# INFO:root:i=107500 matrix not-rules enumerated
# INFO:root:i=110000 matrix not-rules enumerated
# INFO:root:i=112500 matrix not-rules enumerated
# INFO:root:i=115000 matrix not-rules enumerated
# INFO:root:i=117500 matrix not-rules enumerated
# INFO:root:i=120000 matrix not-rules enumerated
# INFO:root:i=122500 matrix not-rules enumerated
# INFO:root:i=125000 matrix not-rules enumerated
# INFO:root:i=127500 matrix not-rules enumerated
# INFO:root:i=130000 matrix not-rules enumerated
# INFO:root:i=132500 matrix not-rules enumerated
# INFO:root:i=135000 matrix not-rules enumerated
# INFO:root:i=137500 matrix not-rules enumerated
# INFO:root:i=140000 matrix not-rules enumerated
# INFO:root:i=142500 matrix not-rules enumerated
# INFO:root:i=145000 matrix not-rules enumerated
# INFO:root:i=147500 matrix not-rules enumerated
# INFO:root:i=150000 matrix not-rules enumerated
# INFO:root:i=152500 matrix not-rules enumerated
# INFO:root:i=155000 matrix not-rules enumerated
# INFO:root:i=157500 matrix not-rules enumerated
# INFO:root:i=160000 matrix not-rules enumerated
# INFO:root:i=162500 matrix not-rules enumerated
# INFO:root:i=165000 matrix not-rules enumerated
# INFO:root:i=167500 matrix not-rules enumerated
# INFO:root:i=170000 matrix not-rules enumerated
# INFO:root:i=172500 matrix not-rules enumerated
# INFO:root:i=175000 matrix not-rules enumerated
# INFO:root:i=177500 matrix not-rules enumerated
# INFO:root:i=180000 matrix not-rules enumerated
# INFO:root:i=182500 matrix not-rules enumerated
# INFO:root:i=185000 matrix not-rules enumerated
# INFO:root:i=187500 matrix not-rules enumerated
# INFO:root:i=190000 matrix not-rules enumerated
# INFO:root:i=192500 matrix not-rules enumerated
# INFO:root:i=195000 matrix not-rules enumerated
# INFO:root:i=197500 matrix not-rules enumerated
# INFO:root:i=200000 matrix not-rules enumerated
# INFO:root:i=202500 matrix not-rules enumerated
# INFO:root:i=205000 matrix not-rules enumerated
# INFO:root:i=207500 matrix not-rules enumerated
# INFO:root:i=210000 matrix not-rules enumerated
# INFO:root:i=212500 matrix not-rules enumerated
# INFO:root:i=215000 matrix not-rules enumerated
# INFO:root:i=217500 matrix not-rules enumerated
# INFO:root:i=220000 matrix not-rules enumerated
# INFO:root:i=222500 matrix not-rules enumerated
# INFO:root:i=225000 matrix not-rules enumerated
# INFO:root:i=227500 matrix not-rules enumerated
# INFO:root:i=230000 matrix not-rules enumerated
# INFO:root:i=232500 matrix not-rules enumerated
# INFO:root:i=235000 matrix not-rules enumerated
# INFO:root:i=237500 matrix not-rules enumerated
# INFO:root:i=240000 matrix not-rules enumerated
# INFO:root:i=242500 matrix not-rules enumerated
# INFO:root:i=245000 matrix not-rules enumerated
# INFO:root:i=247500 matrix not-rules enumerated
# INFO:root:i=250000 matrix not-rules enumerated
# INFO:root:i=252500 matrix not-rules enumerated
# INFO:root:i=255000 matrix not-rules enumerated
# INFO:root:i=257500 matrix not-rules enumerated
# INFO:root:i=260000 matrix not-rules enumerated
# INFO:root:i=262500 matrix not-rules enumerated
# INFO:root:i=265000 matrix not-rules enumerated
# INFO:root:i=267500 matrix not-rules enumerated
# INFO:root:i=270000 matrix not-rules enumerated
# INFO:root:i=272500 matrix not-rules enumerated
# INFO:root:i=275000 matrix not-rules enumerated
# INFO:root:i=277500 matrix not-rules enumerated
# INFO:root:i=280000 matrix not-rules enumerated
# INFO:root:i=282500 matrix not-rules enumerated
# INFO:root:i=285000 matrix not-rules enumerated
# INFO:root:i=287500 matrix not-rules enumerated
# INFO:root:i=290000 matrix not-rules enumerated
# INFO:root:i=292500 matrix not-rules enumerated
# INFO:root:i=295000 matrix not-rules enumerated
# INFO:root:i=297500 matrix not-rules enumerated
# INFO:root:i=300000 matrix not-rules enumerated
# INFO:root:i=302500 matrix not-rules enumerated
# INFO:root:i=305000 matrix not-rules enumerated
# INFO:root:i=307500 matrix not-rules enumerated
# INFO:root:i=310000 matrix not-rules enumerated
# INFO:root:i=312500 matrix not-rules enumerated
# INFO:root:i=315000 matrix not-rules enumerated
# INFO:root:i=317500 matrix not-rules enumerated
# INFO:root:i=320000 matrix not-rules enumerated
# INFO:root:i=322500 matrix not-rules enumerated
# INFO:root:i=325000 matrix not-rules enumerated
# INFO:root:i=327500 matrix not-rules enumerated
# INFO:root:i=330000 matrix not-rules enumerated
# INFO:root:i=332500 matrix not-rules enumerated
# INFO:root:i=335000 matrix not-rules enumerated
# INFO:root:i=337500 matrix not-rules enumerated
# INFO:root:i=340000 matrix not-rules enumerated
# INFO:root:i=342500 matrix not-rules enumerated
# INFO:root:i=345000 matrix not-rules enumerated
# INFO:root:i=347500 matrix not-rules enumerated
# INFO:root:i=350000 matrix not-rules enumerated
# INFO:root:i=352500 matrix not-rules enumerated
# INFO:root:i=355000 matrix not-rules enumerated
# INFO:root:i=357500 matrix not-rules enumerated
# INFO:root:i=360000 matrix not-rules enumerated
# INFO:root:i=362500 matrix not-rules enumerated
# INFO:root:i=365000 matrix not-rules enumerated
# INFO:root:i=367500 matrix not-rules enumerated
# INFO:root:i=370000 matrix not-rules enumerated
# INFO:root:i=372500 matrix not-rules enumerated
# INFO:root:i=375000 matrix not-rules enumerated
# INFO:root:i=377500 matrix not-rules enumerated
# INFO:root:i=380000 matrix not-rules enumerated
# INFO:root:i=382500 matrix not-rules enumerated
# INFO:root:i=385000 matrix not-rules enumerated
# INFO:root:i=387500 matrix not-rules enumerated
# INFO:root:i=390000 matrix not-rules enumerated
# INFO:root:i=392500 matrix not-rules enumerated
# INFO:root:i=395000 matrix not-rules enumerated
# INFO:root:i=397500 matrix not-rules enumerated
# INFO:root:i=400000 matrix not-rules enumerated
# INFO:root:i=402500 matrix not-rules enumerated
# INFO:root:i=405000 matrix not-rules enumerated
# INFO:root:i=407500 matrix not-rules enumerated
# INFO:root:i=410000 matrix not-rules enumerated
# INFO:root:i=412500 matrix not-rules enumerated
# INFO:root:i=415000 matrix not-rules enumerated
# INFO:root:i=417500 matrix not-rules enumerated
# INFO:root:i=420000 matrix not-rules enumerated
# INFO:root:i=422500 matrix not-rules enumerated
# INFO:root:i=425000 matrix not-rules enumerated
# INFO:root:i=427500 matrix not-rules enumerated
# INFO:root:i=430000 matrix not-rules enumerated
# INFO:root:i=432500 matrix not-rules enumerated
# INFO:root:i=435000 matrix not-rules enumerated
# INFO:root:i=437500 matrix not-rules enumerated
# INFO:root:i=440000 matrix not-rules enumerated
# INFO:root:i=442500 matrix not-rules enumerated
# INFO:root:i=445000 matrix not-rules enumerated
# INFO:root:i=447500 matrix not-rules enumerated
# INFO:root:i=450000 matrix not-rules enumerated
# INFO:root:i=452500 matrix not-rules enumerated
# INFO:root:i=455000 matrix not-rules enumerated
# INFO:root:i=457500 matrix not-rules enumerated
# INFO:root:i=460000 matrix not-rules enumerated
# INFO:root:i=462500 matrix not-rules enumerated
# INFO:root:i=465000 matrix not-rules enumerated
# INFO:root:i=467500 matrix not-rules enumerated
# INFO:root:i=470000 matrix not-rules enumerated
# INFO:root:i=472500 matrix not-rules enumerated
# INFO:root:i=475000 matrix not-rules enumerated
# INFO:root:i=477500 matrix not-rules enumerated
# INFO:root:i=480000 matrix not-rules enumerated
# INFO:root:i=482500 matrix not-rules enumerated
# INFO:root:i=485000 matrix not-rules enumerated
# INFO:root:i=487500 matrix not-rules enumerated
# INFO:root:i=490000 matrix not-rules enumerated
# INFO:root:i=492500 matrix not-rules enumerated
# INFO:root:i=495000 matrix not-rules enumerated
# INFO:root:i=497500 matrix not-rules enumerated
# INFO:root:i=500000 matrix not-rules enumerated
# INFO:root:i=502500 matrix not-rules enumerated
# INFO:root:i=505000 matrix not-rules enumerated
# INFO:root:i=507500 matrix not-rules enumerated
# INFO:root:i=510000 matrix not-rules enumerated
# INFO:root:i=512500 matrix not-rules enumerated
# INFO:root:i=515000 matrix not-rules enumerated
# INFO:root:i=517500 matrix not-rules enumerated
# INFO:root:i=520000 matrix not-rules enumerated
# INFO:root:i=522500 matrix not-rules enumerated
# INFO:root:i=525000 matrix not-rules enumerated
# INFO:root:i=527500 matrix not-rules enumerated
# INFO:root:i=530000 matrix not-rules enumerated
# INFO:root:i=532500 matrix not-rules enumerated
# INFO:root:i=535000 matrix not-rules enumerated
# INFO:root:i=537500 matrix not-rules enumerated
# INFO:root:i=540000 matrix not-rules enumerated
# INFO:root:i=542500 matrix not-rules enumerated
# INFO:root:i=545000 matrix not-rules enumerated
# INFO:root:i=547500 matrix not-rules enumerated
# INFO:root:i=550000 matrix not-rules enumerated
# INFO:root:i=552500 matrix not-rules enumerated
# INFO:root:i=555000 matrix not-rules enumerated
# INFO:root:i=557500 matrix not-rules enumerated
# INFO:root:i=560000 matrix not-rules enumerated
# INFO:root:i=562500 matrix not-rules enumerated
# INFO:root:i=565000 matrix not-rules enumerated
# INFO:root:i=567500 matrix not-rules enumerated
# INFO:root:i=570000 matrix not-rules enumerated
# INFO:root:i=572500 matrix not-rules enumerated
# INFO:root:i=575000 matrix not-rules enumerated
# INFO:root:i=577500 matrix not-rules enumerated
# INFO:root:i=580000 matrix not-rules enumerated
# INFO:root:i=582500 matrix not-rules enumerated
# INFO:root:i=585000 matrix not-rules enumerated
# INFO:root:i=587500 matrix not-rules enumerated
# INFO:root:i=590000 matrix not-rules enumerated
# INFO:root:i=592500 matrix not-rules enumerated
# INFO:root:i=595000 matrix not-rules enumerated
# INFO:root:i=597500 matrix not-rules enumerated
# INFO:root:i=600000 matrix not-rules enumerated
# INFO:root:i=602500 matrix not-rules enumerated
# 602776

# %%
output = learner.score(min_lift=3)
# Out:
# Streaming output truncated to the last 5000 lines.
# INFO:root:483613 / 602776: {'rule': ('high_80120_18=>(0.3216243553845851, 0.4843013054269869)', 'ch_per_col_90_00=>(0.012715062985367176, 0.05757458090868189)', 'aboverm_real_mrent_12=>1'), 'group': 'typology=>7.0', 'lift': 3.395238095238095}
# INFO:root:483618 / 602776: {'rule': ('high_80120_18=>(0.3216243553845851, 0.4843013054269869)', 'ch_per_col_00_18=>(0.06572064969842584, 0.14347370267001552)', 'aboverm_real_mrent_12=>1'), 'group': 'typology=>7.0', 'lift': 3.709677419354839}
# INFO:root:483644 / 602776: {'rule': ('high_80120_18=>(0.3216243553845851, 0.4843013054269869)', 'aboverm_per_rent_18=>0', 'aboverm_real_mrent_18=>1'), 'group': 'typology=>6.0', 'lift': 3.073469387755102}
# INFO:root:483665 / 602776: {'rule': ('high_80120_18=>(0.3216243553845851, 0.4843013054269869)', 'aboverm_real_mrent_12=>1', 'aboverm_pctch_real_mhval_90_00=>1'), 'group': 'typology=>7.0', 'lift': 3.4079625292740046}
# INFO:root:483666 / 602776: {'rule': ('high_80120_18=>(0.3216243553845851, 0.4843013054269869)', 'aboverm_real_mrent_12=>1', 'aboverm_pctch_real_mrent_90_00=>1'), 'group': 'typology=>7.0', 'lift': 3.1014705882352946}
# INFO:root:483667 / 602776: {'rule': ('high_80120_18=>(0.3216243553845851, 0.4843013054269869)', 'aboverm_real_mrent_12=>1', 'aboverm_pctch_real_hinc_90_00=>1'), 'group': 'typology=>7.0', 'lift': 3.148075412411626}
# INFO:root:483677 / 602776: {'rule': ('high_80120_18=>(0.3216243553845851, 0.4843013054269869)', 'aboverm_real_mrent_18=>1', 'aboverm_pctch_real_mhval_90_00=>1'), 'group': 'typology=>7.0', 'lift': 3.288510638297872}
# INFO:root:483703 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'low_80120_00=>(0.022020173879551533, 0.2843729629892182)', 'mod_80120_00=>(0.22610194803672845, 0.38048699669616404)'), 'group': 'typology=>7.0', 'lift': 4.421052631578948}
# INFO:root:483725 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'mod_80120_00=>(0.22610194803672845, 0.38048699669616404)', 'per_all_li_00=>(0.022020173879551533, 0.2843729629892182)'), 'group': 'typology=>7.0', 'lift': 4.421052631578948}
# INFO:root:483738 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'mod_80120_00=>(0.22610194803672845, 0.38048699669616404)', 'house_increase=>1'), 'group': 'typology=>7.0', 'lift': 3.2608082706766917}
# INFO:root:483740 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'mod_80120_00=>(0.22610194803672845, 0.38048699669616404)', 'change_flag_category=>ch_increase'), 'group': 'typology=>7.0', 'lift': 4.527845036319613}
# INFO:root:483743 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'mod_80120_00=>(0.22610194803672845, 0.38048699669616404)', 'rent_abrm_ch=>0'), 'group': 'typology=>7.0', 'lift': 3.1681833501853727}
# INFO:root:483768 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'mod_80120_00=>(0.22610194803672845, 0.38048699669616404)', 'aboverm_pctch_real_mhval_00_18=>0'), 'group': 'typology=>7.0', 'lift': 3.134246575342466}
# INFO:root:483770 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'mod_80120_00=>(0.22610194803672845, 0.38048699669616404)', 'aboverm_pctch_real_mrent_12_18=>0'), 'group': 'typology=>7.0', 'lift': 3.1282467532467537}
# INFO:root:483813 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_all_li_90=>(0.11812490370661273, 0.2267444655558735)', 'house_increase=>1'), 'group': 'typology=>7.0', 'lift': 3.464387464387465}
# INFO:root:483814 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_all_li_90=>(0.11812490370661273, 0.2267444655558735)', 'house_rapid_increase=>0'), 'group': 'typology=>7.0', 'lift': 3.044776119402985}
# INFO:root:483815 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_all_li_90=>(0.11812490370661273, 0.2267444655558735)', 'change_flag_category=>ch_increase'), 'group': 'typology=>7.0', 'lift': 5.251704545454546}
# INFO:root:483825 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_all_li_90=>(0.11812490370661273, 0.2267444655558735)', 'aboverm_per_all_li_00=>0'), 'group': 'typology=>6.0', 'lift': 3.497607655502392}
# INFO:root:483838 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_all_li_90=>(0.11812490370661273, 0.2267444655558735)', 'aboverm_real_mrent_12=>1'), 'group': 'typology=>7.0', 'lift': 3.3526517222525976}
# INFO:root:483839 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_all_li_90=>(0.11812490370661273, 0.2267444655558735)', 'aboverm_real_mrent_18=>1'), 'group': 'typology=>6.0', 'lift': 3.1504292646509886}
# INFO:root:483843 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_all_li_90=>(0.11812490370661273, 0.2267444655558735)', 'aboverm_pctch_real_mhval_00_18=>0'), 'group': 'typology=>7.0', 'lift': 3.1330645161290325}
# INFO:root:483877 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_all_li_18=>(0.3184768593043761, 0.4653195664878133)', 'per_rent_00=>(0.028934935700710537, 0.2107141793614305)'), 'group': 'typology=>7.0', 'lift': 3.4202898550724643}
# INFO:root:483886 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_all_li_18=>(0.3184768593043761, 0.4653195664878133)', 'change_flag_category=>ch_increase'), 'group': 'typology=>7.0', 'lift': 3.9732352941176474}
# INFO:root:483921 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_nonwhite_90=>(0.0751708428246014, 0.1364178932593133)', 'pctch_real_mhval_00_18=>(-inf, 0.2648828995373518)'), 'group': 'typology=>7.0', 'lift': 4.639423076923076}
# INFO:root:483923 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_nonwhite_90=>(0.0751708428246014, 0.1364178932593133)', 'house_increase=>1'), 'group': 'typology=>7.0', 'lift': 4.2237174095878895}
# INFO:root:483924 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_nonwhite_90=>(0.0751708428246014, 0.1364178932593133)', 'house_rapid_increase=>0'), 'group': 'typology=>7.0', 'lift': 3.727272727272727}
# INFO:root:483925 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_nonwhite_90=>(0.0751708428246014, 0.1364178932593133)', 'change_flag_category=>ch_increase'), 'group': 'typology=>7.0', 'lift': 6.190092165898617}
# INFO:root:483928 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_nonwhite_90=>(0.0751708428246014, 0.1364178932593133)', 'rent_abrm_ch=>0'), 'group': 'typology=>7.0', 'lift': 3.7955865272938443}
# INFO:root:483935 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_nonwhite_90=>(0.0751708428246014, 0.1364178932593133)', 'aboverm_per_all_li_00=>0'), 'group': 'typology=>6.0', 'lift': 3.901515151515152}
# INFO:root:483947 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_nonwhite_90=>(0.0751708428246014, 0.1364178932593133)', 'aboverm_real_mrent_00=>1'), 'group': 'typology=>7.0', 'lift': 3.361581920903955}
# INFO:root:483949 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_nonwhite_90=>(0.0751708428246014, 0.1364178932593133)', 'aboverm_real_mrent_18=>1'), 'group': 'typology=>6.0', 'lift': 3.2692307692307687}
# INFO:root:483953 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_nonwhite_90=>(0.0751708428246014, 0.1364178932593133)', 'aboverm_pctch_real_mhval_00_18=>0'), 'group': 'typology=>7.0', 'lift': 3.5460829493087562}
# INFO:root:483955 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_nonwhite_90=>(0.0751708428246014, 0.1364178932593133)', 'aboverm_pctch_real_mrent_12_18=>0'), 'group': 'typology=>7.0', 'lift': 3.7735191637630665}
# INFO:root:483963 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_nonwhite_90=>(0.0751708428246014, 0.1364178932593133)', 'presence_ph_LIHTC=>False'), 'group': 'typology=>7.0', 'lift': 3.139705882352941}
# INFO:root:483975 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_nonwhite_00=>(0.143828666823399, 0.2578125)', 'house_increase=>1'), 'group': 'typology=>7.0', 'lift': 3.631578947368421}
# INFO:root:483976 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_nonwhite_00=>(0.143828666823399, 0.2578125)', 'house_rapid_increase=>0'), 'group': 'typology=>7.0', 'lift': 3.186440677966102}
# INFO:root:483977 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_nonwhite_00=>(0.143828666823399, 0.2578125)', 'change_flag_category=>ch_increase'), 'group': 'typology=>7.0', 'lift': 5.0304114490161}
# INFO:root:483980 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_nonwhite_00=>(0.143828666823399, 0.2578125)', 'rent_abrm_ch=>0'), 'group': 'typology=>7.0', 'lift': 3.2075471698113205}
# INFO:root:483987 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_nonwhite_00=>(0.143828666823399, 0.2578125)', 'aboverm_per_all_li_00=>0'), 'group': 'typology=>7.0', 'lift': 3.5381773399014778}
# INFO:root:484005 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_nonwhite_00=>(0.143828666823399, 0.2578125)', 'aboverm_pctch_real_mhval_00_18=>0'), 'group': 'typology=>7.0', 'lift': 3.111111111111111}
# INFO:root:484007 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_nonwhite_00=>(0.143828666823399, 0.2578125)', 'aboverm_pctch_real_mrent_12_18=>0'), 'group': 'typology=>7.0', 'lift': 3.1903945111492273}
# INFO:root:484026 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_nonwhite_18=>(0.4282479479196151, 0.9158447009443862)', 'house_increase=>1'), 'group': 'typology=>7.0', 'lift': 4.923273657289003}
# INFO:root:484027 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_nonwhite_18=>(0.4282479479196151, 0.9158447009443862)', 'house_rapid_increase=>0'), 'group': 'typology=>7.0', 'lift': 4.742857142857142}
# INFO:root:484028 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_nonwhite_18=>(0.4282479479196151, 0.9158447009443862)', 'change_flag_category=>ch_increase'), 'group': 'typology=>7.0', 'lift': 7.513333333333334}
# INFO:root:484037 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_nonwhite_18=>(0.4282479479196151, 0.9158447009443862)', 'aboverm_per_rent_18=>0'), 'group': 'typology=>7.0', 'lift': 3.010752688172043}
# INFO:root:484044 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_nonwhite_18=>(0.4282479479196151, 0.9158447009443862)', 'aboverm_pctch_real_mhval_00_18=>0'), 'group': 'typology=>7.0', 'lift': 4.600961538461538}
# INFO:root:484062 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_rent_90=>(0.2227880484846412, 0.4384572928444935)', 'house_increase=>1'), 'group': 'typology=>7.0', 'lift': 3.7508620689655174}
# INFO:root:484063 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_rent_90=>(0.2227880484846412, 0.4384572928444935)', 'house_rapid_increase=>0'), 'group': 'typology=>7.0', 'lift': 3.327868852459016}
# INFO:root:484064 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_rent_90=>(0.2227880484846412, 0.4384572928444935)', 'change_flag_category=>ch_increase'), 'group': 'typology=>7.0', 'lift': 5.490640952921158}
# INFO:root:484067 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_rent_90=>(0.2227880484846412, 0.4384572928444935)', 'rent_abrm_ch=>0'), 'group': 'typology=>7.0', 'lift': 3.600713012477718}
# INFO:root:484074 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_rent_90=>(0.2227880484846412, 0.4384572928444935)', 'aboverm_per_all_li_00=>0'), 'group': 'typology=>6.0', 'lift': 3.3105263157894735}
# INFO:root:484080 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_rent_90=>(0.2227880484846412, 0.4384572928444935)', 'aboverm_per_rent_00=>0'), 'group': 'typology=>7.0', 'lift': 3.5030864197530867}
# INFO:root:484081 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_rent_90=>(0.2227880484846412, 0.4384572928444935)', 'aboverm_per_rent_18=>0'), 'group': 'typology=>7.0', 'lift': 3.28798185941043}
# INFO:root:484087 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_rent_90=>(0.2227880484846412, 0.4384572928444935)', 'aboverm_real_mrent_12=>1'), 'group': 'typology=>7.0', 'lift': 3.5384615384615388}
# INFO:root:484088 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_rent_90=>(0.2227880484846412, 0.4384572928444935)', 'aboverm_real_mrent_18=>1'), 'group': 'typology=>6.0', 'lift': 3.0219298245614032}
# INFO:root:484092 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_rent_90=>(0.2227880484846412, 0.4384572928444935)', 'aboverm_pctch_real_mhval_00_18=>0'), 'group': 'typology=>7.0', 'lift': 3.2665639445300463}
# INFO:root:484094 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_rent_90=>(0.2227880484846412, 0.4384572928444935)', 'aboverm_pctch_real_mrent_12_18=>0'), 'group': 'typology=>7.0', 'lift': 3.541855203619909}
# INFO:root:484105 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_rent_00=>(0.028934935700710537, 0.2107141793614305)', 'per_rent_18=>(0.026881720430107527, 0.2373447946513849)'), 'group': 'typology=>7.0', 'lift': 3.5182724252491693}
# INFO:root:484116 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_rent_00=>(0.028934935700710537, 0.2107141793614305)', 'aboverm_real_mrent_90=>1'), 'group': 'typology=>7.0', 'lift': 3.4169960474308305}
# INFO:root:484121 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_rent_18=>(0.026881720430107527, 0.2373447946513849)', 'pctch_real_mhval_00_18=>(-inf, 0.2648828995373518)'), 'group': 'typology=>7.0', 'lift': 4.546026750590086}
# INFO:root:484122 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_rent_18=>(0.026881720430107527, 0.2373447946513849)', 'pctch_real_mrent_12_18=>(-435534.43002175493, 0.07563642349306425)'), 'group': 'typology=>7.0', 'lift': 4.70935960591133}
# INFO:root:484123 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_rent_18=>(0.026881720430107527, 0.2373447946513849)', 'house_increase=>1'), 'group': 'typology=>7.0', 'lift': 3.370907738095238}
# INFO:root:484125 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_rent_18=>(0.026881720430107527, 0.2373447946513849)', 'change_flag_category=>ch_increase'), 'group': 'typology=>7.0', 'lift': 4.822222222222223}
# INFO:root:484128 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_rent_18=>(0.026881720430107527, 0.2373447946513849)', 'rent_abrm_ch=>0'), 'group': 'typology=>7.0', 'lift': 3.3333333333333335}
# INFO:root:484130 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_rent_18=>(0.026881720430107527, 0.2373447946513849)', 'pctch_real_hinc_00_18=>(-0.6032483202443868, -0.023633286618103603)'), 'group': 'typology=>7.0', 'lift': 4.168421052631579}
# INFO:root:484135 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_rent_18=>(0.026881720430107527, 0.2373447946513849)', 'aboverm_per_all_li_00=>0'), 'group': 'typology=>7.0', 'lift': 3.384711779448622}
# INFO:root:484135 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_rent_18=>(0.026881720430107527, 0.2373447946513849)', 'aboverm_per_all_li_00=>0'), 'group': 'typology=>6.0', 'lift': 3.0082417582417587}
# INFO:root:484141 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_rent_18=>(0.026881720430107527, 0.2373447946513849)', 'aboverm_per_rent_00=>0'), 'group': 'typology=>7.0', 'lift': 3.0174365942028984}
# INFO:root:484146 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_rent_18=>(0.026881720430107527, 0.2373447946513849)', 'aboverm_real_mrent_90=>1'), 'group': 'typology=>7.0', 'lift': 3.389610389610389}
# INFO:root:484147 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_rent_18=>(0.026881720430107527, 0.2373447946513849)', 'aboverm_real_mrent_00=>1'), 'group': 'typology=>7.0', 'lift': 3.835388994307401}
# INFO:root:484149 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_rent_18=>(0.026881720430107527, 0.2373447946513849)', 'aboverm_real_mrent_18=>1'), 'group': 'typology=>6.0', 'lift': 4.265625}
# INFO:root:484153 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_rent_18=>(0.026881720430107527, 0.2373447946513849)', 'aboverm_pctch_real_mhval_00_18=>0'), 'group': 'typology=>7.0', 'lift': 3.193548387096774}
# INFO:root:484155 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_rent_18=>(0.026881720430107527, 0.2373447946513849)', 'aboverm_pctch_real_mrent_12_18=>0'), 'group': 'typology=>7.0', 'lift': 3.315972222222222}
# INFO:root:484157 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_rent_18=>(0.026881720430107527, 0.2373447946513849)', 'aboverm_pctch_real_mrent_90_00=>1'), 'group': 'typology=>7.0', 'lift': 3.7050000000000005}
# INFO:root:484162 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_rent_18=>(0.026881720430107527, 0.2373447946513849)', 'aboverm_per_units_pre50_18=>0'), 'group': 'typology=>7.0', 'lift': 3.4967213114754094}
# INFO:root:484164 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_rent_18=>(0.026881720430107527, 0.2373447946513849)', 'hotmarket_00=>1.0'), 'group': 'typology=>7.0', 'lift': 3.510000000000001}
# INFO:root:484165 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_rent_18=>(0.026881720430107527, 0.2373447946513849)', 'dp_RentGap=>0'), 'group': 'typology=>7.0', 'lift': 3.262599469496021}
# INFO:root:484181 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_limove_12=>(0.1063154004330476, 0.4415351408594652)', 'house_increase=>1'), 'group': 'typology=>7.0', 'lift': 3.836180124223602}
# INFO:root:484182 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_limove_12=>(0.1063154004330476, 0.4415351408594652)', 'house_rapid_increase=>0'), 'group': 'typology=>7.0', 'lift': 3.2978723404255317}
# INFO:root:484183 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_limove_12=>(0.1063154004330476, 0.4415351408594652)', 'change_flag_category=>ch_increase'), 'group': 'typology=>7.0', 'lift': 6.0034562211981575}
# INFO:root:484193 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_limove_12=>(0.1063154004330476, 0.4415351408594652)', 'aboverm_per_all_li_00=>0'), 'group': 'typology=>6.0', 'lift': 3.7992844364937386}
# INFO:root:484199 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_limove_12=>(0.1063154004330476, 0.4415351408594652)', 'aboverm_per_rent_00=>0'), 'group': 'typology=>6.0', 'lift': 3.5702479338842976}
# INFO:root:484200 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_limove_12=>(0.1063154004330476, 0.4415351408594652)', 'aboverm_per_rent_18=>0'), 'group': 'typology=>6.0', 'lift': 3.6444444444444444}
# INFO:root:484206 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_limove_12=>(0.1063154004330476, 0.4415351408594652)', 'aboverm_real_mrent_12=>1'), 'group': 'typology=>6.0', 'lift': 3.370570107858244}
# INFO:root:484207 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_limove_12=>(0.1063154004330476, 0.4415351408594652)', 'aboverm_real_mrent_18=>1'), 'group': 'typology=>6.0', 'lift': 3.5269320843091334}
# INFO:root:484211 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_limove_12=>(0.1063154004330476, 0.4415351408594652)', 'aboverm_pctch_real_mhval_00_18=>0'), 'group': 'typology=>7.0', 'lift': 3.2903726708074537}
# INFO:root:484226 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'lmh_flag_category=>aff_predominantly_MI', 'house_increase=>1'), 'group': 'typology=>7.0', 'lift': 5.275119617224881}
# INFO:root:484227 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'lmh_flag_category=>aff_predominantly_MI', 'house_rapid_increase=>0'), 'group': 'typology=>7.0', 'lift': 4.760869565217392}
# INFO:root:484228 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'lmh_flag_category=>aff_predominantly_MI', 'change_flag_category=>ch_increase'), 'group': 'typology=>7.0', 'lift': 7.126369612856098}
# INFO:root:484231 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'lmh_flag_category=>aff_predominantly_MI', 'rent_abrm_ch=>0'), 'group': 'typology=>7.0', 'lift': 4.349529780564263}
# INFO:root:484238 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'lmh_flag_category=>aff_predominantly_MI', 'aboverm_per_all_li_00=>0'), 'group': 'typology=>7.0', 'lift': 4.194014447884417}
# INFO:root:484250 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'lmh_flag_category=>aff_predominantly_MI', 'aboverm_real_mrent_00=>1'), 'group': 'typology=>7.0', 'lift': 4.4227642276422765}
# INFO:root:484252 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'lmh_flag_category=>aff_predominantly_MI', 'aboverm_real_mrent_18=>1'), 'group': 'typology=>7.0', 'lift': 3.0981932443047913}
# INFO:root:484256 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'lmh_flag_category=>aff_predominantly_MI', 'aboverm_pctch_real_mhval_00_18=>0'), 'group': 'typology=>7.0', 'lift': 4.800238521168755}
# INFO:root:484257 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'lmh_flag_category=>aff_predominantly_MI', 'aboverm_pctch_real_mrent_00_18=>0'), 'group': 'typology=>7.0', 'lift': 3.4444444444444446}
# INFO:root:484258 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'lmh_flag_category=>aff_predominantly_MI', 'aboverm_pctch_real_mrent_12_18=>0'), 'group': 'typology=>7.0', 'lift': 4.329937304075235}
# INFO:root:484262 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'lmh_flag_category=>aff_predominantly_MI', 'aboverm_pctch_real_hinc_00_18=>0'), 'group': 'typology=>7.0', 'lift': 3.317391304347826}
# INFO:root:484266 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'lmh_flag_category=>aff_predominantly_MI', 'presence_ph_LIHTC=>False'), 'group': 'typology=>7.0', 'lift': 3.6332179930795845}
# INFO:root:484277 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'pctch_real_mhval_00_18=>(-inf, 0.2648828995373518)', 'aboverm_real_mrent_90=>1'), 'group': 'typology=>7.0', 'lift': 3.0113636363636362}
# INFO:root:484287 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'pctch_real_mrent_12_18=>(-435534.43002175493, 0.07563642349306425)', 'aboverm_real_mrent_90=>1'), 'group': 'typology=>7.0', 'lift': 3.2380952380952377}
# INFO:root:484289 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'house_increase=>1', 'pctch_real_hinc_90_00=>(0.1205389287113354, 0.8888687812734251)'), 'group': 'typology=>7.0', 'lift': 4.514742014742014}
# INFO:root:484290 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'house_increase=>1', 'ch_per_col_90_00=>(0.012715062985367176, 0.05757458090868189)'), 'group': 'typology=>7.0', 'lift': 3.4366640440597953}
# INFO:root:484291 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'house_increase=>1', 'ch_per_col_00_18=>(0.06572064969842584, 0.14347370267001552)'), 'group': 'typology=>7.0', 'lift': 3.5406976744186047}
# INFO:root:484292 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'house_increase=>1', 'ch_per_limove_12_18=>(0.025471539194090453, 0.5315446818714793)'), 'group': 'typology=>7.0', 'lift': 3.601232811759128}
# INFO:root:484299 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'house_rapid_increase=>0', 'pctch_real_hinc_90_00=>(0.1205389287113354, 0.8888687812734251)'), 'group': 'typology=>7.0', 'lift': 4.0249999999999995}
# INFO:root:484300 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'house_rapid_increase=>0', 'ch_per_col_90_00=>(0.012715062985367176, 0.05757458090868189)'), 'group': 'typology=>7.0', 'lift': 3.106060606060606}
# INFO:root:484301 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'house_rapid_increase=>0', 'ch_per_col_00_18=>(0.06572064969842584, 0.14347370267001552)'), 'group': 'typology=>7.0', 'lift': 3.2656250000000004}
# INFO:root:484302 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'house_rapid_increase=>0', 'ch_per_limove_12_18=>(0.025471539194090453, 0.5315446818714793)'), 'group': 'typology=>7.0', 'lift': 3.4067796610169494}
# INFO:root:484309 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'change_flag_category=>ch_increase', 'pctch_real_hinc_90_00=>(0.1205389287113354, 0.8888687812734251)'), 'group': 'typology=>7.0', 'lift': 7.292727272727273}
# INFO:root:484310 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'change_flag_category=>ch_increase', 'ch_per_col_90_00=>(0.012715062985367176, 0.05757458090868189)'), 'group': 'typology=>7.0', 'lift': 5.0301136363636365}
# INFO:root:484311 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'change_flag_category=>ch_increase', 'ch_per_col_00_18=>(0.06572064969842584, 0.14347370267001552)'), 'group': 'typology=>7.0', 'lift': 5.266666666666666}
# INFO:root:484312 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'change_flag_category=>ch_increase', 'ch_per_limove_12_18=>(0.025471539194090453, 0.5315446818714793)'), 'group': 'typology=>7.0', 'lift': 5.2269013199245755}
# INFO:root:484313 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'change_flag_category=>ch_increase', 'aboverm_per_all_li_18=>1'), 'group': 'typology=>7.0', 'lift': 3.6192129629629632}
# INFO:root:484314 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'change_flag_category=>ch_increase', 'aboverm_per_col_90=>0'), 'group': 'typology=>7.0', 'lift': 3.436619718309859}
# INFO:root:484315 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'change_flag_category=>ch_increase', 'aboverm_per_col_00=>0'), 'group': 'typology=>7.0', 'lift': 3.269088213491475}
# INFO:root:484317 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'change_flag_category=>ch_increase', 'aboverm_real_mrent_90=>1'), 'group': 'typology=>7.0', 'lift': 3.574468085106383}
# INFO:root:484318 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'change_flag_category=>ch_increase', 'aboverm_real_mhval_00=>0'), 'group': 'typology=>7.0', 'lift': 3.5854350567465323}
# INFO:root:484341 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'rent_abrm_ch=>0', 'ch_per_col_00_18=>(0.06572064969842584, 0.14347370267001552)'), 'group': 'typology=>7.0', 'lift': 3.4109890109890113}
# INFO:root:484342 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'rent_abrm_ch=>0', 'ch_per_limove_12_18=>(0.025471539194090453, 0.5315446818714793)'), 'group': 'typology=>7.0', 'lift': 3.2231404958677685}
# INFO:root:484352 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'pctch_real_hinc_90_00=>(0.1205389287113354, 0.8888687812734251)', 'aboverm_per_all_li_00=>0'), 'group': 'typology=>6.0', 'lift': 3.5648912228057013}
# INFO:root:484384 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'ch_per_col_90_00=>(0.012715062985367176, 0.05757458090868189)', 'aboverm_per_all_li_00=>0'), 'group': 'typology=>7.0', 'lift': 3.0323660714285716}
# INFO:root:484390 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'ch_per_col_90_00=>(0.012715062985367176, 0.05757458090868189)', 'aboverm_per_rent_00=>0'), 'group': 'typology=>7.0', 'lift': 3.0223695111847553}
# INFO:root:484397 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'ch_per_col_90_00=>(0.012715062985367176, 0.05757458090868189)', 'aboverm_real_mrent_12=>1'), 'group': 'typology=>7.0', 'lift': 3.193548387096775}
# INFO:root:484402 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'ch_per_col_90_00=>(0.012715062985367176, 0.05757458090868189)', 'aboverm_pctch_real_mhval_00_18=>0'), 'group': 'typology=>7.0', 'lift': 3.281630937368643}
# INFO:root:484407 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'ch_per_col_90_00=>(0.012715062985367176, 0.05757458090868189)', 'aboverm_pctch_real_hinc_90_00=>1'), 'group': 'typology=>7.0', 'lift': 3.3171028606208157}
# INFO:root:484417 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'ch_per_col_00_18=>(0.06572064969842584, 0.14347370267001552)', 'aboverm_per_all_li_00=>0'), 'group': 'typology=>7.0', 'lift': 3.3562166285278416}
# INFO:root:484429 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'ch_per_col_00_18=>(0.06572064969842584, 0.14347370267001552)', 'aboverm_real_mrent_00=>1'), 'group': 'typology=>7.0', 'lift': 3.316937119675456}
# INFO:root:484430 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'ch_per_col_00_18=>(0.06572064969842584, 0.14347370267001552)', 'aboverm_real_mrent_12=>1'), 'group': 'typology=>7.0', 'lift': 3.49074074074074}
# INFO:root:484435 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'ch_per_col_00_18=>(0.06572064969842584, 0.14347370267001552)', 'aboverm_pctch_real_mhval_00_18=>0'), 'group': 'typology=>7.0', 'lift': 3.468057366362451}
# INFO:root:484437 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'ch_per_col_00_18=>(0.06572064969842584, 0.14347370267001552)', 'aboverm_pctch_real_mrent_12_18=>0'), 'group': 'typology=>7.0', 'lift': 3.393406593406593}
# INFO:root:484438 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'ch_per_col_00_18=>(0.06572064969842584, 0.14347370267001552)', 'aboverm_pctch_real_mhval_90_00=>1'), 'group': 'typology=>7.0', 'lift': 3.67741935483871}
# INFO:root:484439 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'ch_per_col_00_18=>(0.06572064969842584, 0.14347370267001552)', 'aboverm_pctch_real_mrent_90_00=>1'), 'group': 'typology=>7.0', 'lift': 3.4655061250805925}
# INFO:root:484446 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'ch_per_col_00_18=>(0.06572064969842584, 0.14347370267001552)', 'hotmarket_00=>1.0'), 'group': 'typology=>7.0', 'lift': 3.4531249999999996}
# INFO:root:484449 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'ch_per_limove_12_18=>(0.025471539194090453, 0.5315446818714793)', 'aboverm_per_rent_00=>0'), 'group': 'typology=>7.0', 'lift': 3.0632318501170963}
# INFO:root:484450 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'ch_per_limove_12_18=>(0.025471539194090453, 0.5315446818714793)', 'aboverm_per_rent_18=>0'), 'group': 'typology=>7.0', 'lift': 3.0255952380952387}
# INFO:root:484452 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'ch_per_limove_12_18=>(0.025471539194090453, 0.5315446818714793)', 'aboverm_real_mrent_00=>1'), 'group': 'typology=>7.0', 'lift': 3.004838709677419}
# INFO:root:484457 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'ch_per_limove_12_18=>(0.025471539194090453, 0.5315446818714793)', 'aboverm_pctch_real_mhval_00_18=>0'), 'group': 'typology=>7.0', 'lift': 3.4910714285714293}
# INFO:root:484459 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'ch_per_limove_12_18=>(0.025471539194090453, 0.5315446818714793)', 'aboverm_pctch_real_mrent_12_18=>0'), 'group': 'typology=>7.0', 'lift': 3.206611570247934}
# INFO:root:484461 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'ch_per_limove_12_18=>(0.025471539194090453, 0.5315446818714793)', 'aboverm_pctch_real_mrent_90_00=>1'), 'group': 'typology=>7.0', 'lift': 3.476280834914611}
# INFO:root:484467 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'ch_per_limove_12_18=>(0.025471539194090453, 0.5315446818714793)', 'hotmarket_00=>1.0'), 'group': 'typology=>7.0', 'lift': 3.3962264150943398}
# INFO:root:484711 / 602776: {'rule': ('low_80120_00=>(0.022020173879551533, 0.2843729629892182)', 'per_all_li_18=>(0.3184768593043761, 0.4653195664878133)', 'house_increase=>1'), 'group': 'typology=>7.0', 'lift': 5.222222222222222}
# INFO:root:484712 / 602776: {'rule': ('low_80120_00=>(0.022020173879551533, 0.2843729629892182)', 'per_all_li_18=>(0.3184768593043761, 0.4653195664878133)', 'house_rapid_increase=>0'), 'group': 'typology=>7.0', 'lift': 4.153846153846154}
# INFO:root:484713 / 602776: {'rule': ('low_80120_00=>(0.022020173879551533, 0.2843729629892182)', 'per_all_li_18=>(0.3184768593043761, 0.4653195664878133)', 'change_flag_category=>ch_increase'), 'group': 'typology=>7.0', 'lift': 7.0344827586206895}
# INFO:root:484715 / 602776: {'rule': ('low_80120_00=>(0.022020173879551533, 0.2843729629892182)', 'per_all_li_18=>(0.3184768593043761, 0.4653195664878133)', 'hv_abrm_ch=>0'), 'group': 'typology=>7.0', 'lift': 3.3347701149425286}
# INFO:root:484741 / 602776: {'rule': ('low_80120_00=>(0.022020173879551533, 0.2843729629892182)', 'per_all_li_18=>(0.3184768593043761, 0.4653195664878133)', 'aboverm_pctch_real_mhval_00_18=>0'), 'group': 'typology=>7.0', 'lift': 4.106100795755969}
# INFO:root:484742 / 602776: {'rule': ('low_80120_00=>(0.022020173879551533, 0.2843729629892182)', 'per_all_li_18=>(0.3184768593043761, 0.4653195664878133)', 'aboverm_pctch_real_mrent_00_18=>0'), 'group': 'typology=>7.0', 'lift': 3.6263736263736264}
# INFO:root:484903 / 602776: {'rule': ('low_80120_00=>(0.022020173879551533, 0.2843729629892182)', 'house_increase=>1', 'ch_per_col_90_00=>(0.012715062985367176, 0.05757458090868189)'), 'group': 'typology=>7.0', 'lift': 4.491754122938531}
# INFO:root:484904 / 602776: {'rule': ('low_80120_00=>(0.022020173879551533, 0.2843729629892182)', 'house_increase=>1', 'ch_per_col_00_18=>(0.06572064969842584, 0.14347370267001552)'), 'group': 'typology=>7.0', 'lift': 5.1447154471544705}
# INFO:root:484905 / 602776: {'rule': ('low_80120_00=>(0.022020173879551533, 0.2843729629892182)', 'house_increase=>1', 'aboverm_real_mhval_00=>0'), 'group': 'typology=>7.0', 'lift': 5.583333333333334}
# INFO:root:484907 / 602776: {'rule': ('low_80120_00=>(0.022020173879551533, 0.2843729629892182)', 'house_rapid_increase=>0', 'ch_per_col_90_00=>(0.012715062985367176, 0.05757458090868189)'), 'group': 'typology=>7.0', 'lift': 4.020833333333333}
# INFO:root:484908 / 602776: {'rule': ('low_80120_00=>(0.022020173879551533, 0.2843729629892182)', 'house_rapid_increase=>0', 'ch_per_col_00_18=>(0.06572064969842584, 0.14347370267001552)'), 'group': 'typology=>7.0', 'lift': 4.785714285714286}
# INFO:root:484909 / 602776: {'rule': ('low_80120_00=>(0.022020173879551533, 0.2843729629892182)', 'house_rapid_increase=>0', 'aboverm_real_mhval_00=>0'), 'group': 'typology=>7.0', 'lift': 4.846153846153847}
# INFO:root:484911 / 602776: {'rule': ('low_80120_00=>(0.022020173879551533, 0.2843729629892182)', 'change_flag_category=>ch_increase', 'ch_per_col_90_00=>(0.012715062985367176, 0.05757458090868189)'), 'group': 'typology=>7.0', 'lift': 7.4333333333333345}
# INFO:root:484912 / 602776: {'rule': ('low_80120_00=>(0.022020173879551533, 0.2843729629892182)', 'change_flag_category=>ch_increase', 'ch_per_col_00_18=>(0.06572064969842584, 0.14347370267001552)'), 'group': 'typology=>7.0', 'lift': 7.890606420927467}
# INFO:root:484913 / 602776: {'rule': ('low_80120_00=>(0.022020173879551533, 0.2843729629892182)', 'change_flag_category=>ch_increase', 'aboverm_real_mhval_00=>0'), 'group': 'typology=>7.0', 'lift': 7.8500000000000005}
# INFO:root:484969 / 602776: {'rule': ('low_80120_00=>(0.022020173879551533, 0.2843729629892182)', 'pctch_real_hinc_00_18=>(-0.6032483202443868, -0.023633286618103603)', 'aboverm_per_col_00=>0'), 'group': 'typology=>7.0', 'lift': 4.275}
# INFO:root:484992 / 602776: {'rule': ('low_80120_00=>(0.022020173879551533, 0.2843729629892182)', 'ch_per_col_90_00=>(0.012715062985367176, 0.05757458090868189)', 'aboverm_pctch_real_mhval_00_18=>0'), 'group': 'typology=>7.0', 'lift': 4.1269841269841265}
# INFO:root:485025 / 602776: {'rule': ('low_80120_00=>(0.022020173879551533, 0.2843729629892182)', 'ch_per_col_00_18=>(0.06572064969842584, 0.14347370267001552)', 'aboverm_pctch_real_mhval_00_18=>0'), 'group': 'typology=>7.0', 'lift': 5.283283283283284}
# INFO:root:485091 / 602776: {'rule': ('low_80120_00=>(0.022020173879551533, 0.2843729629892182)', 'aboverm_per_col_18=>0', 'aboverm_pctch_real_mhval_90_00=>1'), 'group': 'typology=>7.0', 'lift': 3.1883040935672513}
# INFO:root:485092 / 602776: {'rule': ('low_80120_00=>(0.022020173879551533, 0.2843729629892182)', 'aboverm_per_col_18=>0', 'aboverm_pctch_real_mrent_90_00=>1'), 'group': 'typology=>7.0', 'lift': 3.2600472813238777}
# INFO:root:485093 / 602776: {'rule': ('low_80120_00=>(0.022020173879551533, 0.2843729629892182)', 'aboverm_per_col_18=>0', 'aboverm_pctch_real_hinc_90_00=>1'), 'group': 'typology=>7.0', 'lift': 3.233108108108108}
# INFO:root:485095 / 602776: {'rule': ('low_80120_00=>(0.022020173879551533, 0.2843729629892182)', 'aboverm_per_col_18=>0', 'hotmarket_00=>1.0'), 'group': 'typology=>7.0', 'lift': 3.10474537037037}
# INFO:root:485111 / 602776: {'rule': ('low_80120_00=>(0.022020173879551533, 0.2843729629892182)', 'aboverm_real_mhval_00=>0', 'aboverm_pctch_real_mhval_00_18=>0'), 'group': 'typology=>7.0', 'lift': 4.638461538461539}
# INFO:root:485217 / 602776: {'rule': ('mod_80120_00=>(0.22610194803672845, 0.38048699669616404)', 'per_all_li_18=>(0.3184768593043761, 0.4653195664878133)', 'house_increase=>1'), 'group': 'typology=>7.0', 'lift': 3.9893617021276593}
# INFO:root:485218 / 602776: {'rule': ('mod_80120_00=>(0.22610194803672845, 0.38048699669616404)', 'per_all_li_18=>(0.3184768593043761, 0.4653195664878133)', 'house_rapid_increase=>0'), 'group': 'typology=>7.0', 'lift': 3.6190476190476186}
# INFO:root:485219 / 602776: {'rule': ('mod_80120_00=>(0.22610194803672845, 0.38048699669616404)', 'per_all_li_18=>(0.3184768593043761, 0.4653195664878133)', 'change_flag_category=>ch_increase'), 'group': 'typology=>7.0', 'lift': 5.5527572731220145}
# INFO:root:485222 / 602776: {'rule': ('mod_80120_00=>(0.22610194803672845, 0.38048699669616404)', 'per_all_li_18=>(0.3184768593043761, 0.4653195664878133)', 'rent_abrm_ch=>0'), 'group': 'typology=>7.0', 'lift': 3.3585365853658535}
# INFO:root:485247 / 602776: {'rule': ('mod_80120_00=>(0.22610194803672845, 0.38048699669616404)', 'per_all_li_18=>(0.3184768593043761, 0.4653195664878133)', 'aboverm_pctch_real_mhval_00_18=>0'), 'group': 'typology=>7.0', 'lift': 3.797669491525424}
# INFO:root:485249 / 602776: {'rule': ('mod_80120_00=>(0.22610194803672845, 0.38048699669616404)', 'per_all_li_18=>(0.3184768593043761, 0.4653195664878133)', 'aboverm_pctch_real_mrent_12_18=>0'), 'group': 'typology=>7.0', 'lift': 3.319672131147541}
# INFO:root:485294 / 602776: {'rule': ('high_80120_00=>(0.5052375693426361, 0.9212837624161008)', 'per_all_li_90=>(0.11812490370661273, 0.2267444655558735)', 'house_rapid_increase=>0'), 'group': 'typology=>7.0', 'lift': 5.166666666666667}
# INFO:root:485358 / 602776: {'rule': ('high_80120_00=>(0.5052375693426361, 0.9212837624161008)', 'per_all_li_18=>(0.3184768593043761, 0.4653195664878133)', 'house_increase=>1'), 'group': 'typology=>7.0', 'lift': 5.171428571428572}
# INFO:root:485359 / 602776: {'rule': ('high_80120_00=>(0.5052375693426361, 0.9212837624161008)', 'per_all_li_18=>(0.3184768593043761, 0.4653195664878133)', 'house_rapid_increase=>0'), 'group': 'typology=>7.0', 'lift': 4.162162162162162}
# INFO:root:485360 / 602776: {'rule': ('high_80120_00=>(0.5052375693426361, 0.9212837624161008)', 'per_all_li_18=>(0.3184768593043761, 0.4653195664878133)', 'change_flag_category=>ch_increase'), 'group': 'typology=>7.0', 'lift': 7.720000000000001}
# INFO:root:485388 / 602776: {'rule': ('high_80120_00=>(0.5052375693426361, 0.9212837624161008)', 'per_all_li_18=>(0.3184768593043761, 0.4653195664878133)', 'aboverm_pctch_real_mhval_00_18=>0'), 'group': 'typology=>7.0', 'lift': 4.066528066528067}
# INFO:root:485389 / 602776: {'rule': ('high_80120_00=>(0.5052375693426361, 0.9212837624161008)', 'per_all_li_18=>(0.3184768593043761, 0.4653195664878133)', 'aboverm_pctch_real_mrent_00_18=>0'), 'group': 'typology=>7.0', 'lift': 3.4645748987854255}
# INFO:root:485426 / 602776: {'rule': ('high_80120_00=>(0.5052375693426361, 0.9212837624161008)', 'per_nonwhite_00=>(0.143828666823399, 0.2578125)', 'house_increase=>1'), 'group': 'typology=>7.0', 'lift': 5.073170731707317}
# INFO:root:485427 / 602776: {'rule': ('high_80120_00=>(0.5052375693426361, 0.9212837624161008)', 'per_nonwhite_00=>(0.143828666823399, 0.2578125)', 'house_rapid_increase=>0'), 'group': 'typology=>7.0', 'lift': 4.325581395348838}
# INFO:root:485428 / 602776: {'rule': ('high_80120_00=>(0.5052375693426361, 0.9212837624161008)', 'per_nonwhite_00=>(0.143828666823399, 0.2578125)', 'change_flag_category=>ch_increase'), 'group': 'typology=>7.0', 'lift': 8.333333333333334}
# INFO:root:485456 / 602776: {'rule': ('high_80120_00=>(0.5052375693426361, 0.9212837624161008)', 'per_nonwhite_00=>(0.143828666823399, 0.2578125)', 'aboverm_pctch_real_mhval_00_18=>0'), 'group': 'typology=>7.0', 'lift': 4.203333333333333}
# INFO:root:485478 / 602776: {'rule': ('high_80120_00=>(0.5052375693426361, 0.9212837624161008)', 'per_nonwhite_18=>(0.4282479479196151, 0.9158447009443862)', 'house_rapid_increase=>0'), 'group': 'typology=>7.0', 'lift': 6.9}
# INFO:root:485507 / 602776: {'rule': ('high_80120_00=>(0.5052375693426361, 0.9212837624161008)', 'per_nonwhite_18=>(0.4282479479196151, 0.9158447009443862)', 'aboverm_pctch_real_mhval_00_18=>0'), 'group': 'typology=>7.0', 'lift': 6.066481994459833}
# INFO:root:485581 / 602776: {'rule': ('high_80120_00=>(0.5052375693426361, 0.9212837624161008)', 'lmh_flag_category=>aff_predominantly_MI', 'house_rapid_increase=>0'), 'group': 'typology=>7.0', 'lift': 7.2592592592592595}
# INFO:root:485610 / 602776: {'rule': ('high_80120_00=>(0.5052375693426361, 0.9212837624161008)', 'lmh_flag_category=>aff_predominantly_MI', 'aboverm_pctch_real_mhval_00_18=>0'), 'group': 'typology=>7.0', 'lift': 6.708333333333334}
# INFO:root:485627 / 602776: {'rule': ('high_80120_00=>(0.5052375693426361, 0.9212837624161008)', 'pctch_real_mhval_00_18=>(-inf, 0.2648828995373518)', 'aboverm_per_col_18=>0'), 'group': 'typology=>7.0', 'lift': 4.172972972972973}
# INFO:root:485638 / 602776: {'rule': ('high_80120_00=>(0.5052375693426361, 0.9212837624161008)', 'house_increase=>1', 'ch_per_col_90_00=>(0.012715062985367176, 0.05757458090868189)'), 'group': 'typology=>7.0', 'lift': 4.893658536585366}
# INFO:root:485639 / 602776: {'rule': ('high_80120_00=>(0.5052375693426361, 0.9212837624161008)', 'house_increase=>1', 'ch_per_col_00_18=>(0.06572064969842584, 0.14347370267001552)'), 'group': 'typology=>7.0', 'lift': 4.54040404040404}
# INFO:root:485641 / 602776: {'rule': ('high_80120_00=>(0.5052375693426361, 0.9212837624161008)', 'house_increase=>1', 'aboverm_per_col_18=>0'), 'group': 'typology=>7.0', 'lift': 4.475}
# INFO:root:485642 / 602776: {'rule': ('high_80120_00=>(0.5052375693426361, 0.9212837624161008)', 'house_increase=>1', 'aboverm_real_mrent_90=>1'), 'group': 'typology=>7.0', 'lift': 3.1089901477832513}
# INFO:root:485645 / 602776: {'rule': ('high_80120_00=>(0.5052375693426361, 0.9212837624161008)', 'house_rapid_increase=>0', 'ch_per_col_90_00=>(0.012715062985367176, 0.05757458090868189)'), 'group': 'typology=>7.0', 'lift': 4.452380952380952}
# INFO:root:485646 / 602776: {'rule': ('high_80120_00=>(0.5052375693426361, 0.9212837624161008)', 'house_rapid_increase=>0', 'ch_per_col_00_18=>(0.06572064969842584, 0.14347370267001552)'), 'group': 'typology=>7.0', 'lift': 4.204081632653062}
# INFO:root:485648 / 602776: {'rule': ('high_80120_00=>(0.5052375693426361, 0.9212837624161008)', 'house_rapid_increase=>0', 'aboverm_per_col_18=>0'), 'group': 'typology=>7.0', 'lift': 4.166666666666667}
# INFO:root:485652 / 602776: {'rule': ('high_80120_00=>(0.5052375693426361, 0.9212837624161008)', 'change_flag_category=>ch_increase', 'ch_per_col_90_00=>(0.012715062985367176, 0.05757458090868189)'), 'group': 'typology=>7.0', 'lift': 8.56}
# INFO:root:485653 / 602776: {'rule': ('high_80120_00=>(0.5052375693426361, 0.9212837624161008)', 'change_flag_category=>ch_increase', 'ch_per_col_00_18=>(0.06572064969842584, 0.14347370267001552)'), 'group': 'typology=>7.0', 'lift': 7.235351562500002}
# INFO:root:485655 / 602776: {'rule': ('high_80120_00=>(0.5052375693426361, 0.9212837624161008)', 'change_flag_category=>ch_increase', 'aboverm_per_col_18=>0'), 'group': 'typology=>7.0', 'lift': 5.696969696969696}
# INFO:root:485656 / 602776: {'rule': ('high_80120_00=>(0.5052375693426361, 0.9212837624161008)', 'change_flag_category=>ch_increase', 'aboverm_real_mrent_90=>1'), 'group': 'typology=>7.0', 'lift': 5.696551724137932}
# INFO:root:485676 / 602776: {'rule': ('high_80120_00=>(0.5052375693426361, 0.9212837624161008)', 'rent_abrm_ch=>0', 'aboverm_per_col_18=>0'), 'group': 'typology=>7.0', 'lift': 3.355714285714286}
# INFO:root:485721 / 602776: {'rule': ('high_80120_00=>(0.5052375693426361, 0.9212837624161008)', 'pctch_real_hinc_00_18=>(-0.6032483202443868, -0.023633286618103603)', 'aboverm_per_col_18=>0'), 'group': 'typology=>7.0', 'lift': 4.321839080459769}
# INFO:root:485745 / 602776: {'rule': ('high_80120_00=>(0.5052375693426361, 0.9212837624161008)', 'ch_per_col_90_00=>(0.012715062985367176, 0.05757458090868189)', 'aboverm_pctch_real_mhval_00_18=>0'), 'group': 'typology=>7.0', 'lift': 4.536324786324787}
# INFO:root:485778 / 602776: {'rule': ('high_80120_00=>(0.5052375693426361, 0.9212837624161008)', 'ch_per_col_00_18=>(0.06572064969842584, 0.14347370267001552)', 'aboverm_pctch_real_mhval_00_18=>0'), 'group': 'typology=>7.0', 'lift': 4.547727272727273}
# INFO:root:485878 / 602776: {'rule': ('high_80120_00=>(0.5052375693426361, 0.9212837624161008)', 'aboverm_per_col_18=>0', 'aboverm_pctch_real_mhval_00_18=>0'), 'group': 'typology=>7.0', 'lift': 4.159663865546219}
# INFO:root:485879 / 602776: {'rule': ('high_80120_00=>(0.5052375693426361, 0.9212837624161008)', 'aboverm_per_col_18=>0', 'aboverm_pctch_real_mrent_00_18=>0'), 'group': 'typology=>7.0', 'lift': 3.69073275862069}
# INFO:root:485880 / 602776: {'rule': ('high_80120_00=>(0.5052375693426361, 0.9212837624161008)', 'aboverm_per_col_18=>0', 'aboverm_pctch_real_mrent_12_18=>0'), 'group': 'typology=>7.0', 'lift': 3.3350000000000004}
# INFO:root:485884 / 602776: {'rule': ('high_80120_00=>(0.5052375693426361, 0.9212837624161008)', 'aboverm_per_col_18=>0', 'aboverm_pctch_real_hinc_00_18=>0'), 'group': 'typology=>7.0', 'lift': 3.1369047619047614}
# INFO:root:485889 / 602776: {'rule': ('high_80120_00=>(0.5052375693426361, 0.9212837624161008)', 'aboverm_per_col_18=>0', 'hotmarket_00=>1.0'), 'group': 'typology=>7.0', 'lift': 3.377477477477478}
# INFO:root:485994 / 602776: {'rule': ('per_all_li_90=>(0.11812490370661273, 0.2267444655558735)', 'per_all_li_18=>(0.3184768593043761, 0.4653195664878133)', 'house_increase=>1'), 'group': 'typology=>7.0', 'lift': 4.417297297297298}
# INFO:root:485995 / 602776: {'rule': ('per_all_li_90=>(0.11812490370661273, 0.2267444655558735)', 'per_all_li_18=>(0.3184768593043761, 0.4653195664878133)', 'house_rapid_increase=>0'), 'group': 'typology=>7.0', 'lift': 3.814814814814815}
# INFO:root:485996 / 602776: {'rule': ('per_all_li_90=>(0.11812490370661273, 0.2267444655558735)', 'per_all_li_18=>(0.3184768593043761, 0.4653195664878133)', 'change_flag_category=>ch_increase'), 'group': 'typology=>7.0', 'lift': 6.158552631578947}
# INFO:root:486024 / 602776: {'rule': ('per_all_li_90=>(0.11812490370661273, 0.2267444655558735)', 'per_all_li_18=>(0.3184768593043761, 0.4653195664878133)', 'aboverm_pctch_real_mhval_00_18=>0'), 'group': 'typology=>7.0', 'lift': 3.7975}
# INFO:root:486080 / 602776: {'rule': ('per_all_li_00=>(0.022020173879551533, 0.2843729629892182)', 'per_all_li_18=>(0.3184768593043761, 0.4653195664878133)', 'house_increase=>1'), 'group': 'typology=>7.0', 'lift': 5.222222222222222}
# INFO:root:486081 / 602776: {'rule': ('per_all_li_00=>(0.022020173879551533, 0.2843729629892182)', 'per_all_li_18=>(0.3184768593043761, 0.4653195664878133)', 'house_rapid_increase=>0'), 'group': 'typology=>7.0', 'lift': 4.153846153846154}
# INFO:root:486082 / 602776: {'rule': ('per_all_li_00=>(0.022020173879551533, 0.2843729629892182)', 'per_all_li_18=>(0.3184768593043761, 0.4653195664878133)', 'change_flag_category=>ch_increase'), 'group': 'typology=>7.0', 'lift': 7.0344827586206895}
# INFO:root:486084 / 602776: {'rule': ('per_all_li_00=>(0.022020173879551533, 0.2843729629892182)', 'per_all_li_18=>(0.3184768593043761, 0.4653195664878133)', 'hv_abrm_ch=>0'), 'group': 'typology=>7.0', 'lift': 3.3347701149425286}
# INFO:root:486110 / 602776: {'rule': ('per_all_li_00=>(0.022020173879551533, 0.2843729629892182)', 'per_all_li_18=>(0.3184768593043761, 0.4653195664878133)', 'aboverm_pctch_real_mhval_00_18=>0'), 'group': 'typology=>7.0', 'lift': 4.106100795755969}
# INFO:root:486111 / 602776: {'rule': ('per_all_li_00=>(0.022020173879551533, 0.2843729629892182)', 'per_all_li_18=>(0.3184768593043761, 0.4653195664878133)', 'aboverm_pctch_real_mrent_00_18=>0'), 'group': 'typology=>7.0', 'lift': 3.6263736263736264}
# INFO:root:486272 / 602776: {'rule': ('per_all_li_00=>(0.022020173879551533, 0.2843729629892182)', 'house_increase=>1', 'ch_per_col_90_00=>(0.012715062985367176, 0.05757458090868189)'), 'group': 'typology=>7.0', 'lift': 4.491754122938531}
# INFO:root:486273 / 602776: {'rule': ('per_all_li_00=>(0.022020173879551533, 0.2843729629892182)', 'house_increase=>1', 'ch_per_col_00_18=>(0.06572064969842584, 0.14347370267001552)'), 'group': 'typology=>7.0', 'lift': 5.1447154471544705}
# INFO:root:486274 / 602776: {'rule': ('per_all_li_00=>(0.022020173879551533, 0.2843729629892182)', 'house_increase=>1', 'aboverm_real_mhval_00=>0'), 'group': 'typology=>7.0', 'lift': 5.583333333333334}
# INFO:root:486276 / 602776: {'rule': ('per_all_li_00=>(0.022020173879551533, 0.2843729629892182)', 'house_rapid_increase=>0', 'ch_per_col_90_00=>(0.012715062985367176, 0.05757458090868189)'), 'group': 'typology=>7.0', 'lift': 4.020833333333333}
# INFO:root:486277 / 602776: {'rule': ('per_all_li_00=>(0.022020173879551533, 0.2843729629892182)', 'house_rapid_increase=>0', 'ch_per_col_00_18=>(0.06572064969842584, 0.14347370267001552)'), 'group': 'typology=>7.0', 'lift': 4.785714285714286}
# INFO:root:486278 / 602776: {'rule': ('per_all_li_00=>(0.022020173879551533, 0.2843729629892182)', 'house_rapid_increase=>0', 'aboverm_real_mhval_00=>0'), 'group': 'typology=>7.0', 'lift': 4.846153846153847}
# ...
# INFO:root:587654 / 602776: {'rule': ('per_all_li_90=>(0.0032204035886827746, 0.11807153568842745)', 'change_flag_category=>ch_increase', 'rent_abrm_ch=>1'), 'group': 'typology=>7.0', 'lift': 7.066666666666667}
# INFO:root:587655 / 602776: {'rule': ('per_all_li_90=>(0.0032204035886827746, 0.11807153568842745)', 'change_flag_category=>ch_increase', 'aboverm_pctch_real_mrent_12_18=>1'), 'group': 'typology=>7.0', 'lift': 7.133333333333335}
# INFO:root:587685 / 602776: {'rule': ('per_nonwhite_18=>(0.4282479479196151, 0.9158447009443862)', 'change_flag_category=>ch_increase', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>7.0', 'lift': 6.6875}
# INFO:root:587689 / 602776: {'rule': ('per_rent_90=>(0.0196078431372549, 0.2227613586237318)', 'change_flag_category=>ch_increase', 'per_ch_zillow_12_18=>(0.6533308984660336, 0.8467581563956498)'), 'group': 'typology=>7.0', 'lift': 7.250000000000001}
# INFO:root:587690 / 602776: {'rule': ('per_rent_90=>(0.0196078431372549, 0.2227613586237318)', 'change_flag_category=>ch_increase', 'rent_abrm_ch=>1'), 'group': 'typology=>7.0', 'lift': 8.0}
# INFO:root:587691 / 602776: {'rule': ('per_rent_90=>(0.0196078431372549, 0.2227613586237318)', 'change_flag_category=>ch_increase', 'aboverm_pctch_real_mrent_12_18=>1'), 'group': 'typology=>7.0', 'lift': 8.083333333333334}
# INFO:root:587692 / 602776: {'rule': ('per_rent_00=>(0.028934935700710537, 0.2107141793614305)', 'change_flag_category=>ch_increase', 'rent_abrm_ch=>1'), 'group': 'typology=>7.0', 'lift': 8.636363636363637}
# INFO:root:587693 / 602776: {'rule': ('per_rent_00=>(0.028934935700710537, 0.2107141793614305)', 'change_flag_category=>ch_increase', 'aboverm_pctch_real_mrent_12_18=>1'), 'group': 'typology=>7.0', 'lift': 8.727272727272728}
# INFO:root:587694 / 602776: {'rule': ('per_rent_18=>(0.026881720430107527, 0.2373447946513849)', 'change_flag_category=>ch_increase', 'rent_abrm_ch=>1'), 'group': 'typology=>7.0', 'lift': 7.071428571428572}
# INFO:root:587695 / 602776: {'rule': ('per_rent_18=>(0.026881720430107527, 0.2373447946513849)', 'change_flag_category=>ch_increase', 'aboverm_pctch_real_mrent_12_18=>1'), 'group': 'typology=>7.0', 'lift': 7.142857142857142}
# INFO:root:587696 / 602776: {'rule': ('per_limove_18=>(0.11696171071171073, 0.3870395963419219)', 'change_flag_category=>ch_increase', 'rent_abrm_ch=>1'), 'group': 'typology=>7.0', 'lift': 7.000000000000001}
# INFO:root:587697 / 602776: {'rule': ('per_limove_18=>(0.11696171071171073, 0.3870395963419219)', 'change_flag_category=>ch_increase', 'aboverm_pctch_real_mrent_12_18=>1'), 'group': 'typology=>7.0', 'lift': 7.071428571428572}
# INFO:root:587706 / 602776: {'rule': ('change_flag_category=>ch_increase', 'rent_abrm_ch=>1', 'aboverm_per_all_li_00=>0'), 'group': 'typology=>7.0', 'lift': 4.473684210526316}
# INFO:root:587707 / 602776: {'rule': ('change_flag_category=>ch_increase', 'rent_abrm_ch=>1', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>7.0', 'lift': 4.470588235294118}
# INFO:root:587708 / 602776: {'rule': ('change_flag_category=>ch_increase', 'rent_abrm_ch=>1', 'aboverm_per_rent_00=>0'), 'group': 'typology=>7.0', 'lift': 4.8235294117647065}
# INFO:root:587709 / 602776: {'rule': ('change_flag_category=>ch_increase', 'rent_abrm_ch=>1', 'aboverm_per_rent_18=>0'), 'group': 'typology=>7.0', 'lift': 4.611111111111112}
# INFO:root:587711 / 602776: {'rule': ('change_flag_category=>ch_increase', 'rent_abrm_ch=>1', 'aboverm_real_mrent_12=>1'), 'group': 'typology=>7.0', 'lift': 3.6842105263157894}
# INFO:root:587712 / 602776: {'rule': ('change_flag_category=>ch_increase', 'rent_abrm_ch=>1', 'aboverm_real_mrent_18=>1'), 'group': 'typology=>7.0', 'lift': 4.590909090909091}
# INFO:root:587713 / 602776: {'rule': ('change_flag_category=>ch_increase', 'rent_abrm_ch=>1', 'aboverm_real_mhval_18=>1'), 'group': 'typology=>7.0', 'lift': 5.769230769230769}
# INFO:root:587719 / 602776: {'rule': ('change_flag_category=>ch_increase', 'aboverm_per_all_li_00=>0', 'aboverm_pctch_real_mrent_12_18=>1'), 'group': 'typology=>7.0', 'lift': 4.722222222222222}
# INFO:root:587720 / 602776: {'rule': ('change_flag_category=>ch_increase', 'aboverm_per_all_li_18=>0', 'aboverm_pctch_real_mrent_12_18=>1'), 'group': 'typology=>7.0', 'lift': 4.750000000000001}
# INFO:root:587721 / 602776: {'rule': ('change_flag_category=>ch_increase', 'aboverm_per_nonwhite_18=>1', 'aboverm_real_mhval_18=>1'), 'group': 'typology=>7.0', 'lift': 5.846153846153846}
# INFO:root:587722 / 602776: {'rule': ('change_flag_category=>ch_increase', 'aboverm_per_rent_00=>0', 'aboverm_pctch_real_mrent_12_18=>1'), 'group': 'typology=>7.0', 'lift': 5.125}
# INFO:root:587723 / 602776: {'rule': ('change_flag_category=>ch_increase', 'aboverm_per_rent_18=>0', 'aboverm_pctch_real_mrent_12_18=>1'), 'group': 'typology=>7.0', 'lift': 4.88235294117647}
# INFO:root:587725 / 602776: {'rule': ('change_flag_category=>ch_increase', 'aboverm_real_mrent_12=>1', 'aboverm_pctch_real_mrent_12_18=>1'), 'group': 'typology=>7.0', 'lift': 3.8888888888888893}
# INFO:root:587726 / 602776: {'rule': ('change_flag_category=>ch_increase', 'aboverm_real_mrent_18=>1', 'aboverm_pctch_real_mrent_12_18=>1'), 'group': 'typology=>7.0', 'lift': 4.809523809523809}
# INFO:root:587727 / 602776: {'rule': ('change_flag_category=>ch_increase', 'aboverm_real_mhval_18=>1', 'aboverm_pctch_real_mrent_12_18=>1'), 'group': 'typology=>7.0', 'lift': 5.769230769230769}
# INFO:root:587751 / 602776: {'rule': ('change_flag_category=>ch_increase', 'pctch_real_hinc_90_00=>(0.1205389287113354, 0.8888687812734251)', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>7.0', 'lift': 6.952380952380953}
# INFO:root:587752 / 602776: {'rule': ('change_flag_category=>ch_increase', 'ch_per_col_00_18=>(-0.2260068230094192, 0.06571945564191707)', 'aboverm_real_mhval_18=>1'), 'group': 'typology=>7.0', 'lift': 7.0769230769230775}
# INFO:root:587774 / 602776: {'rule': ('high_80120_00=>(0.5052375693426361, 0.9212837624161008)', 'change_flag_category=>ch_increase', 'aboverm_per_rent_18=>1'), 'group': 'typology=>7.0', 'lift': 7.416666666666668}
# INFO:root:587802 / 602776: {'rule': ('lmh_flag_category=>aff_predominantly_MI', 'change_flag_category=>ch_increase', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>7.0', 'lift': 7.0740740740740735}
# INFO:root:587803 / 602776: {'rule': ('lmh_flag_category=>aff_predominantly_MI', 'change_flag_category=>ch_increase', 'aboverm_per_nonwhite_18=>0'), 'group': 'typology=>7.0', 'lift': 8.782608695652174}
# INFO:root:587819 / 602776: {'rule': ('change_flag_category=>ch_increase', 'aboverm_per_all_li_18=>0', 'aboverm_per_rent_18=>1'), 'group': 'typology=>7.0', 'lift': 4.0}
# INFO:root:587826 / 602776: {'rule': ('low_80120_00=>(0.022020173879551533, 0.2843729629892182)', 'change_flag_category=>ch_increase', 'presence_ph_LIHTC=>True'), 'group': 'typology=>7.0', 'lift': 8.2}
# INFO:root:587828 / 602776: {'rule': ('per_all_li_00=>(0.022020173879551533, 0.2843729629892182)', 'change_flag_category=>ch_increase', 'presence_ph_LIHTC=>True'), 'group': 'typology=>7.0', 'lift': 8.2}
# INFO:root:587836 / 602776: {'rule': ('change_flag_category=>ch_increase', 'aboverm_per_all_li_18=>0', 'presence_ph_LIHTC=>True'), 'group': 'typology=>7.0', 'lift': 5.062500000000001}
# INFO:root:587837 / 602776: {'rule': ('change_flag_category=>ch_increase', 'aboverm_per_col_00=>1', 'presence_ph_LIHTC=>True'), 'group': 'typology=>7.0', 'lift': 7.916666666666666}
# INFO:root:587839 / 602776: {'rule': ('change_flag_category=>ch_increase', 'aboverm_real_mhval_18=>1', 'presence_ph_LIHTC=>True'), 'group': 'typology=>7.0', 'lift': 7.23076923076923}
# INFO:root:587887 / 602776: {'rule': ('per_limove_18=>(0.5197935963893411, 0.9603569623714668)', 'change_flag_category=>ch_increase', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>7.0', 'lift': 7.666666666666667}
# INFO:root:587892 / 602776: {'rule': ('low_80120_18=>(0.07669565782499922, 0.31808813102906264)', 'change_flag_category=>ch_increase', 'aboverm_per_col_18=>0'), 'group': 'typology=>7.0', 'lift': 8.777777777777779}
# INFO:root:587896 / 602776: {'rule': ('per_all_li_18=>(0.07669565782499922, 0.31808813102906264)', 'change_flag_category=>ch_increase', 'aboverm_per_col_18=>0'), 'group': 'typology=>7.0', 'lift': 8.777777777777779}
# INFO:root:587916 / 602776: {'rule': ('mod_80120_00=>(0.22610194803672845, 0.38048699669616404)', 'change_flag_category=>ch_increase', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>7.0', 'lift': 5.392857142857142}
# INFO:root:587918 / 602776: {'rule': ('mod_80120_00=>(0.22610194803672845, 0.38048699669616404)', 'change_flag_category=>ch_increase', 'aboverm_real_mhval_18=>1'), 'group': 'typology=>7.0', 'lift': 8.636363636363637}
# INFO:root:587926 / 602776: {'rule': ('change_flag_category=>ch_increase', 'rent_abrm_ch=>1', 'aboverm_per_col_00=>1'), 'group': 'typology=>7.0', 'lift': 5.785714285714286}
# INFO:root:587927 / 602776: {'rule': ('change_flag_category=>ch_increase', 'aboverm_per_col_00=>1', 'aboverm_pctch_real_mrent_12_18=>1'), 'group': 'typology=>7.0', 'lift': 5.857142857142857}
# INFO:root:587938 / 602776: {'rule': ('per_limove_12=>(0.5650556003912895, 0.9893288723508056)', 'change_flag_category=>ch_increase', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>7.0', 'lift': 5.7272727272727275}
# INFO:root:588103 / 602776: {'rule': ('high_80120_00=>(0.5052375693426361, 0.9212837624161008)', 'change_flag_category=>ch_increase', 'aboverm_real_mrent_18=>0'), 'group': 'typology=>7.0', 'lift': 6.458333333333333}
# INFO:root:588119 / 602776: {'rule': ('mod_80120_18=>(0.1669205116562033, 0.2099594415914008)', 'change_flag_category=>ch_increase', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>7.0', 'lift': 5.433333333333334}
# INFO:root:588121 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'per_all_li_90=>(0.0032204035886827746, 0.11807153568842745)', 'change_flag_category=>ch_increase'), 'group': 'typology=>7.0', 'lift': 4.38}
# INFO:root:588137 / 602776: {'rule': ('high_80120_18=>(0.3216243553845851, 0.4843013054269869)', 'change_flag_category=>ch_increase', 'rent_abrm_ch=>1'), 'group': 'typology=>7.0', 'lift': 5.3809523809523805}
# INFO:root:588139 / 602776: {'rule': ('high_80120_18=>(0.3216243553845851, 0.4843013054269869)', 'change_flag_category=>ch_increase', 'aboverm_pctch_real_mrent_12_18=>1'), 'group': 'typology=>7.0', 'lift': 5.65}
# INFO:root:588140 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'change_flag_category=>ch_increase', 'rent_abrm_ch=>1'), 'group': 'typology=>7.0', 'lift': 4.111111111111111}
# INFO:root:588142 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'change_flag_category=>ch_increase', 'aboverm_pctch_real_mrent_12_18=>1'), 'group': 'typology=>7.0', 'lift': 4.269230769230769}
# INFO:root:588156 / 602776: {'rule': ('per_limove_12=>(0.5650556003912895, 0.9893288723508056)', 'change_flag_category=>ch_increase', 'aboverm_real_mhval_18=>1'), 'group': 'typology=>7.0', 'lift': 7.313609467455621}
# INFO:root:589304 / 602776: {'rule': ('change_flag_category=>ch_increase', 'aboverm_per_all_li_18=>0', 'aboverm_real_mhval_00=>0'), 'group': 'typology=>7.0', 'lift': 4.388888888888889}
# INFO:root:589333 / 602776: {'rule': ('low_80120_18=>(0.3184768593043761, 0.4653195664878133)', 'lmh_flag_category=>aff_mix_mod', 'change_flag_category=>ch_increase'), 'group': 'typology=>7.0', 'lift': 3.290909090909091}
# INFO:root:589334 / 602776: {'rule': ('low_80120_18=>(0.3184768593043761, 0.4653195664878133)', 'change_flag_category=>ch_increase', 'aboverm_per_all_li_90=>0'), 'group': 'typology=>7.0', 'lift': 3.6379310344827585}
# INFO:root:589337 / 602776: {'rule': ('per_all_li_18=>(0.3184768593043761, 0.4653195664878133)', 'lmh_flag_category=>aff_mix_mod', 'change_flag_category=>ch_increase'), 'group': 'typology=>7.0', 'lift': 3.290909090909091}
# INFO:root:589338 / 602776: {'rule': ('per_all_li_18=>(0.3184768593043761, 0.4653195664878133)', 'change_flag_category=>ch_increase', 'aboverm_per_all_li_90=>0'), 'group': 'typology=>7.0', 'lift': 3.6379310344827585}
# INFO:root:589341 / 602776: {'rule': ('low_80120_18=>(0.3184768593043761, 0.4653195664878133)', 'change_flag_category=>ch_increase', 'hv_abrm_ch=>1'), 'group': 'typology=>7.0', 'lift': 6.090909090909091}
# INFO:root:589343 / 602776: {'rule': ('mix_mod_medhhinc_18=>1.0', 'change_flag_category=>ch_increase', 'per_ch_zillow_12_18=>(0.850393919931492, 1.3120976781425138)'), 'group': 'typology=>7.0', 'lift': 9.133333333333333}
# INFO:root:589346 / 602776: {'rule': ('per_all_li_18=>(0.3184768593043761, 0.4653195664878133)', 'change_flag_category=>ch_increase', 'hv_abrm_ch=>1'), 'group': 'typology=>7.0', 'lift': 6.090909090909091}
# INFO:root:589351 / 602776: {'rule': ('low_80120_18=>(0.3184768593043761, 0.4653195664878133)', 'change_flag_category=>ch_increase', 'ch_per_limove_12_18=>(-0.09455467680910246, 0.02413793507243772)'), 'group': 'typology=>7.0', 'lift': 8.076923076923077}
# INFO:root:589352 / 602776: {'rule': ('per_all_li_18=>(0.3184768593043761, 0.4653195664878133)', 'change_flag_category=>ch_increase', 'ch_per_limove_12_18=>(-0.09455467680910246, 0.02413793507243772)'), 'group': 'typology=>7.0', 'lift': 8.076923076923077}
# INFO:root:589353 / 602776: {'rule': ('low_80120_18=>(0.3184768593043761, 0.4653195664878133)', 'per_all_li_90=>(0.0032204035886827746, 0.11807153568842745)', 'change_flag_category=>ch_increase'), 'group': 'typology=>7.0', 'lift': 6.757575757575758}
# INFO:root:589355 / 602776: {'rule': ('per_all_li_90=>(0.0032204035886827746, 0.11807153568842745)', 'per_all_li_18=>(0.3184768593043761, 0.4653195664878133)', 'change_flag_category=>ch_increase'), 'group': 'typology=>7.0', 'lift': 6.757575757575758}
# INFO:root:589357 / 602776: {'rule': ('low_80120_18=>(0.3184768593043761, 0.4653195664878133)', 'change_flag_category=>ch_increase', 'ch_per_col_90_00=>(-0.14848805945404348, 0.012268476342351536)'), 'group': 'typology=>7.0', 'lift': 6.944444444444445}
# INFO:root:589358 / 602776: {'rule': ('per_all_li_18=>(0.3184768593043761, 0.4653195664878133)', 'change_flag_category=>ch_increase', 'ch_per_col_90_00=>(-0.14848805945404348, 0.012268476342351536)'), 'group': 'typology=>7.0', 'lift': 6.944444444444445}
# INFO:root:589359 / 602776: {'rule': ('low_80120_18=>(0.3184768593043761, 0.4653195664878133)', 'pctch_real_mrent_12_18=>(0.07632987957531565, 0.22040645296459244)', 'change_flag_category=>ch_increase'), 'group': 'typology=>7.0', 'lift': 6.692307692307692}
# INFO:root:589370 / 602776: {'rule': ('per_all_li_18=>(0.3184768593043761, 0.4653195664878133)', 'pctch_real_mrent_12_18=>(0.07632987957531565, 0.22040645296459244)', 'change_flag_category=>ch_increase'), 'group': 'typology=>7.0', 'lift': 6.692307692307692}
# INFO:root:589374 / 602776: {'rule': ('low_80120_18=>(0.3184768593043761, 0.4653195664878133)', 'change_flag_category=>ch_increase', 'presence_ph_LIHTC=>True'), 'group': 'typology=>7.0', 'lift': 7.8}
# INFO:root:589375 / 602776: {'rule': ('per_all_li_18=>(0.3184768593043761, 0.4653195664878133)', 'change_flag_category=>ch_increase', 'presence_ph_LIHTC=>True'), 'group': 'typology=>7.0', 'lift': 7.8}
# INFO:root:589376 / 602776: {'rule': ('low_80120_18=>(0.3184768593043761, 0.4653195664878133)', 'change_flag_category=>ch_increase', 'rent_abrm_ch=>1'), 'group': 'typology=>7.0', 'lift': 5.449999999999999}
# INFO:root:589377 / 602776: {'rule': ('low_80120_18=>(0.3184768593043761, 0.4653195664878133)', 'change_flag_category=>ch_increase', 'aboverm_pctch_real_mrent_12_18=>1'), 'group': 'typology=>7.0', 'lift': 5.7368421052631575}
# INFO:root:589378 / 602776: {'rule': ('per_all_li_18=>(0.3184768593043761, 0.4653195664878133)', 'change_flag_category=>ch_increase', 'rent_abrm_ch=>1'), 'group': 'typology=>7.0', 'lift': 5.449999999999999}
# INFO:root:589379 / 602776: {'rule': ('per_all_li_18=>(0.3184768593043761, 0.4653195664878133)', 'change_flag_category=>ch_increase', 'aboverm_pctch_real_mrent_12_18=>1'), 'group': 'typology=>7.0', 'lift': 5.7368421052631575}
# INFO:root:591667 / 602776: {'rule': ('mix_mod_medhhinc_18=>0.0', 'lmh_flag_category=>aff_mix_high', 'aboverm_per_rent_18=>0'), 'group': 'typology=>9.0', 'lift': 9.928571428571429}

# %%
output.to_csv("{}/data/stucco/stucco_{}".format(customized_path_to_homework, file_name))

# %% [markdown]
# ###  Rule Metrics

# %% [markdown]
# **Rules with high Lift and Confidence**

# %% [markdown]
# ref: http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.150.6616&rep=rep1&type=pdf
#
# Confidence ranges from 0 to 1. Confidence is an estimate of Pr(C | A), the
# probability of observing C given A. After obtaining a rule set, one can immediatly
# use confidence as a basis for classifying one new case x. Of all the rules that
# apply to x (i.e., the rules whose antecedent is true in x), we choose the one
# with highest confidence. This loosely follows the optimal Bayes classifier

# %% [markdown]
# ref: http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.150.6616&rep=rep1&type=pdf
#
# Conviction is another measure proposed in [4] to tackle some of the weaknesses of confidence and lift. Unlike lift, conviction is sensitive to rule direction
# (conv(A → C) 6= conv(C → A)). Conviction is somewhat inspired in the logical
# definition of implication and attempts to measure the degree of implication of
# a rule. Conviction is infinite for logical implications (confidence 1), and is 1 if
# A and C are independent

# %% [markdown]
# ref: http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.150.6616&rep=rep1&type=pdf
#
# Lift measures how far from independence are A and C. It ranges within
# [0, +∞[. Values close to 1 imply that A and C are independent and the rule
# is not interesting.
