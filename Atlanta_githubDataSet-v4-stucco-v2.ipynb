# %% [markdown]
# **CS 5834, Fall 2020: Intro to Urban Computing Project - STUCCO analysis for Gentrification using Seattle Data Set**

# %% [markdown]
# ### Imports and Mount File Directories

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
# modify "customized_path_to_homework", path of folder in drive, where you project is stored
customized_path_to_homework = "/content/drive/My Drive/cs5834/urbcomp_fall2020/project"
file_name = "Atlanta_typology_output.csv"

sys.path.append(customized_path_to_homework)

# %%
# %cd $customized_path_to_homework/data
# Out:
# /content/drive/My Drive/cs5834/urbcomp_fall2020/project/data

# %%
import os, sys
import pandas as pd
import numpy as np
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
import datetime
import warnings

# %%
"""
sys.path.insert(0,'../')
# %load_ext autoreload
# %autoreload 2
import nyctaxi_helpers
warnings.filterwarnings('ignore')
"""
# Out:
# "\nsys.path.insert(0,'../')\n%load_ext autoreload\n%autoreload 2\nimport nyctaxi_helpers\nwarnings.filterwarnings('ignore')\n"

# %%
#pip install --upgrade mlxtend

# %%
#ref https://pbpython.com/market-basket-analysis.html


#may need to install mlxtend package - pip install mlxtend in console
import pandas as pd
# #from mlxtend.frequent_patterns import apriori
# from mlxtend.frequent_patterns import fpgrowth
# from mlxtend.frequent_patterns import association_rules

# %%
# !wget -nc https://raw.githubusercontent.com/parsahosseini/contrast/master/stucco.py
# Out:
# File ‘stucco.py’ already there; not retrieving.

# %% [markdown]
# # **Process Urban Displacement Model Data for Gentrificaiton**

# %% [markdown]
# Reference: https://www.urbandisplacement.org/open-source-project

# %% [markdown]
# Based on the work https://ww2.arb.ca.gov/sites/default/files/classic//research/apr/past/13-310.pdf?_ga=2.269282425.968981409.1605209194-851335111.1605209194
#
# **Developing a New
# Methodology for Analyzing
# Potential Displacement**
#
# University of California, Berkeley
#
# Principal Investigator:
# Karen Chapple
#
# https://ww3.arb.ca.gov/research/single-project.php?row_id=65188

# %% [markdown]
# ## **Obtain the Data**
#
# Data can be found at https://github.com/urban-displacement/displacement-typologies/blob/main/data/outputs/typologies/LosAngeles_typology_output.csv

# %%
download_file = ("https://raw.githubusercontent.com/urban-displacement/displacement-typologies/main/data/outputs/typologies/{}".format(file_name))

# %%
#!wget -nc $download_file

# %%
## Process Data - if data file already processed then can start at Associaton Rules section
# get the Data File

df = pd.read_csv("https://raw.githubusercontent.com/urban-displacement/displacement-typologies/main/data/outputs/typologies/{}".format(file_name), index_col=0)
#df = pd.read_csv("{}/data/{}".format(customized_path_to_homework, file_name), index_col=0)

# sneak peak in the data
df.head(10)
# Out:
#     pop_18  white_18   hh_18  hinc_18  ...  LISD  double_counted  typology   typ_cat
# 0   7183.0     380.0  2666.0  40397.0  ...     1             1.0       1.0  ['LISD']
# 1   6225.0     898.0  2148.0  31463.0  ...     0             1.0       3.0   ['ARG']
# 2   7827.0    1297.0  2023.0  34619.0  ...     0             1.0       3.0   ['ARG']
# 3   6116.0     680.0  1879.0  50029.0  ...     1             1.0       1.0  ['LISD']
# 4   7106.0     727.0  2387.0  49381.0  ...     1             1.0       1.0  ['LISD']
# 5   4554.0     145.0  1552.0  59583.0  ...     0             1.0       7.0   ['ARE']
# 6   3931.0     443.0  1224.0  48298.0  ...     1             1.0       1.0  ['LISD']
# 7   5366.0     407.0  1654.0  43172.0  ...     1             1.0       1.0  ['LISD']
# 8   3596.0    1034.0   967.0  44025.0  ...     0             1.0       3.0   ['ARG']
# 9  12430.0    1873.0  4060.0  62855.0  ...     0             1.0       7.0   ['ARE']
#
# [10 rows x 305 columns]

# %%
df.columns
# Out:
# Index(['pop_18', 'white_18', 'hh_18', 'hinc_18', 'mhval_18', 'mhval_18_se',
#        'mrent_18', 'mrent_18_se', 'total_25_18', 'total_25_col_bd_18',
#        ...
#        'BE', 'SMMI', 'ARG', 'EOG', 'OD', 'OD_loss', 'LISD', 'double_counted',
#        'typology', 'typ_cat'],
#       dtype='object', length=305)

# %%
"""
# create a working copy of the data to process
df2 = df.copy()

#removed  'inc_cat_medhhinc_encoded18', 'inc_cat_medhhinc_encoded00',
df2 = df2[[ 'inc80_18',
 'inc120_18',
 'inc80_00',
 'inc120_00',
 'inc80_90',
 'low_80120_18',
 'mod_80120_18',
 'high_80120_18',
 'low_pdmt_medhhinc_18',
 'high_pdmt_medhhinc_18',
 'mod_pdmt_medhhinc_18',
 'mix_low_medhhinc_18',
 'mix_mod_medhhinc_18',
 'mix_high_medhhinc_18',

 'low_80120_00',
 'mod_80120_00',
 'high_80120_00',
 'low_pdmt_medhhinc_00',
 'high_pdmt_medhhinc_00',
 'mod_pdmt_medhhinc_00',
 'mix_low_medhhinc_00',
 'mix_mod_medhhinc_00',
 'mix_high_medhhinc_00',

 'per_all_li_90',
 'per_all_li_00',
 'per_all_li_18',
 'per_nonwhite_90',
 'per_nonwhite_00',
 'per_nonwhite_18',
 'per_rent_90',
 'per_rent_00',
 'per_rent_18',
 'per_col_90',
 'per_col_00',
 'per_col_18',
 'per_units_pre50_18',
 'per_limove_18',
 'per_limove_12',
 'lmh_flag_category',
 'pctch_real_mhval_00_18',
 'pctch_real_mrent_12_18',
 'rent_decrease',
 'rent_marginal',
 'rent_increase',
 'rent_rapid_increase',
 'house_decrease',
 'house_marginal',
 'house_increase',
 'house_rapid_increase',
 'tot_decrease',
 'tot_marginal',
 'tot_increase',
 'tot_rapid_increase',
 'change_flag_category',
 'per_ch_zillow_12_18',
 'ab_50pct_ch',
 'ab_90percentile_ch',
 'rent_50pct_ch',
 'rent_90percentile_ch',
 'hv_abrm_ch',
 'rent_abrm_ch',
 'pctch_real_mhval_90_00',
 'pctch_real_mrent_90_00',
 'pctch_real_hinc_90_00',
 'pctch_real_mrent_00_18',
 'pctch_real_hinc_00_18',
 'ch_per_col_90_00',
 'ch_per_col_00_18',
 'ch_per_limove_12_18',
 'aboverm_per_all_li_90',
 'aboverm_per_all_li_00',
 'aboverm_per_all_li_18',
 'aboverm_per_nonwhite_18',
 'aboverm_per_nonwhite_90',
 'aboverm_per_nonwhite_00',
 'aboverm_per_rent_90',
 'aboverm_per_rent_00',
 'aboverm_per_rent_18',
 'aboverm_per_col_90',
 'aboverm_per_col_00',
 'aboverm_per_col_18',
 'aboverm_real_mrent_90',
 'aboverm_real_mrent_00',
 'aboverm_real_mrent_12',
 'aboverm_real_mrent_18',
 'aboverm_real_mhval_90',
 'aboverm_real_mhval_00',
 'aboverm_real_mhval_18',
 'aboverm_pctch_real_mhval_00_18',
 'aboverm_pctch_real_mrent_00_18',
 'aboverm_pctch_real_mrent_12_18',
 'aboverm_pctch_real_mhval_90_00',
 'aboverm_pctch_real_mrent_90_00',
 'lostli_00',
 'lostli_18',
 'aboverm_pctch_real_hinc_90_00',
 'aboverm_pctch_real_hinc_00_18',
 'aboverm_ch_per_col_90_00',
 'aboverm_ch_per_col_00_18',
 'aboverm_per_units_pre50_18',
 'GEOID',
 'rail',
 'presence_ph_LIHTC',
 'hotmarket_00',
 'hotmarket_18',
 'dp_PChRent',
 'dp_RentGap',
 'dense',
 'typology']]


# drop rows which dont have a gentrification category
df2.dropna(subset=['typology'], inplace=True)
df2 = df2.set_index('GEOID')

#fill the nas
df2.fillna(0.0, inplace=True)


df2.head(10)
"""
# Out:
# "\n# create a working copy of the data to process\ndf2 = df.copy()\n\n#removed  'inc_cat_medhhinc_encoded18', 'inc_cat_medhhinc_encoded00',\ndf2 = df2[[ 'inc80_18',\n 'inc120_18',\n 'inc80_00',\n 'inc120_00',\n 'inc80_90',\n 'low_80120_18',\n 'mod_80120_18',\n 'high_80120_18',\n 'low_pdmt_medhhinc_18',\n 'high_pdmt_medhhinc_18',\n 'mod_pdmt_medhhinc_18',\n 'mix_low_medhhinc_18',\n 'mix_mod_medhhinc_18',\n 'mix_high_medhhinc_18',\n\n 'low_80120_00',\n 'mod_80120_00',\n 'high_80120_00',\n 'low_pdmt_medhhinc_00',\n 'high_pdmt_medhhinc_00',\n 'mod_pdmt_medhhinc_00',\n 'mix_low_medhhinc_00',\n 'mix_mod_medhhinc_00',\n 'mix_high_medhhinc_00',\n\n 'per_all_li_90',\n 'per_all_li_00',\n 'per_all_li_18',\n 'per_nonwhite_90',\n 'per_nonwhite_00',\n 'per_nonwhite_18',\n 'per_rent_90',\n 'per_rent_00',\n 'per_rent_18',\n 'per_col_90',\n 'per_col_00',\n 'per_col_18',\n 'per_units_pre50_18',\n 'per_limove_18',\n 'per_limove_12',\n 'lmh_flag_category',\n 'pctch_real_mhval_00_18',\n 'pctch_real_mrent_12_18',\n 'rent_decrease',\n 'rent_marginal',\n 'rent_increase',\n 'rent_rapid_increase',\n 'house_decrease',\n 'house_marginal',\n 'house_increase',\n 'house_rapid_increase',\n 'tot_decrease',\n 'tot_marginal',\n 'tot_increase',\n 'tot_rapid_increase',\n 'change_flag_category',\n 'per_ch_zillow_12_18',\n 'ab_50pct_ch',\n 'ab_90percentile_ch',\n 'rent_50pct_ch',\n 'rent_90percentile_ch',\n 'hv_abrm_ch',\n 'rent_abrm_ch',\n 'pctch_real_mhval_90_00',\n 'pctch_real_mrent_90_00',\n 'pctch_real_hinc_90_00',\n 'pctch_real_mrent_00_18',\n 'pctch_real_hinc_00_18',\n 'ch_per_col_90_00',\n 'ch_per_col_00_18',\n 'ch_per_limove_12_18',\n 'aboverm_per_all_li_90',\n 'aboverm_per_all_li_00',\n 'aboverm_per_all_li_18',\n 'aboverm_per_nonwhite_18',\n 'aboverm_per_nonwhite_90',\n 'aboverm_per_nonwhite_00',\n 'aboverm_per_rent_90',\n 'aboverm_per_rent_00',\n 'aboverm_per_rent_18',\n 'aboverm_per_col_90',\n 'aboverm_per_col_00',\n 'aboverm_per_col_18',\n 'aboverm_real_mrent_90',\n 'aboverm_real_mrent_00',\n 'aboverm_real_mrent_12',\n 'aboverm_real_mrent_18',\n 'aboverm_real_mhval_90',\n 'aboverm_real_mhval_00',\n 'aboverm_real_mhval_18',\n 'aboverm_pctch_real_mhval_00_18',\n 'aboverm_pctch_real_mrent_00_18',\n 'aboverm_pctch_real_mrent_12_18',\n 'aboverm_pctch_real_mhval_90_00',\n 'aboverm_pctch_real_mrent_90_00',\n 'lostli_00',\n 'lostli_18',\n 'aboverm_pctch_real_hinc_90_00',\n 'aboverm_pctch_real_hinc_00_18',\n 'aboverm_ch_per_col_90_00',\n 'aboverm_ch_per_col_00_18',\n 'aboverm_per_units_pre50_18',\n 'GEOID',\n 'rail',\n 'presence_ph_LIHTC',\n 'hotmarket_00',\n 'hotmarket_18',\n 'dp_PChRent',\n 'dp_RentGap',\n 'dense',\n 'typology']]\n\n\n# drop rows which dont have a gentrification category\ndf2.dropna(subset=['typology'], inplace=True)\ndf2 = df2.set_index('GEOID')\n\n#fill the nas\ndf2.fillna(0.0, inplace=True)\n\n\ndf2.head(10)\n"

# %%
# create a working copy of the data to process
df2 = df.copy()

"""
removed  'inc_cat_medhhinc_encoded18', 'inc_cat_medhhinc_encoded00', 
'inc80_18',
 'inc120_18',
 'inc80_00',
 'inc120_00',
 'inc80_90',
  'per_col_90',
 'per_col_00',
 'per_col_18',
  'tot_decrease',
 'tot_marginal',
 'tot_increase',
 'tot_rapid_increase',
  'pctch_real_mhval_90_00',
 'pctch_real_mrent_90_00',
 'pctch_real_mrent_00_18',
 'per_units_pre50_18',
  
"""

df2.head(10)
df2 = df2[[ 

 'low_80120_18',
 'mod_80120_18',
 'high_80120_18',
 'low_pdmt_medhhinc_18',
 'high_pdmt_medhhinc_18',
 'mod_pdmt_medhhinc_18',
 'mix_low_medhhinc_18',
 'mix_mod_medhhinc_18',
 'mix_high_medhhinc_18',

 'low_80120_00',
 'mod_80120_00',
 'high_80120_00',
 'low_pdmt_medhhinc_00',
 'high_pdmt_medhhinc_00',
 'mod_pdmt_medhhinc_00',
 'mix_low_medhhinc_00',
 'mix_mod_medhhinc_00',
 'mix_high_medhhinc_00',

 'per_all_li_90',
 'per_all_li_00',
 'per_all_li_18',
 'per_nonwhite_90',
 'per_nonwhite_00',
 'per_nonwhite_18',
 'per_rent_90',
 'per_rent_00',
 'per_rent_18',

 
 'per_limove_18',
 'per_limove_12',
 'lmh_flag_category',
 'pctch_real_mhval_00_18',
 'pctch_real_mrent_12_18',
 'rent_decrease',
 'rent_marginal',
 'rent_increase',
 'rent_rapid_increase',
 'house_decrease',
 'house_marginal',
 'house_increase',
 'house_rapid_increase',

 'change_flag_category',
 'per_ch_zillow_12_18',
 'ab_50pct_ch',
 'ab_90percentile_ch',
 'rent_50pct_ch',
 'rent_90percentile_ch',
 'hv_abrm_ch',
 'rent_abrm_ch',

 'pctch_real_hinc_90_00',
 
 'pctch_real_hinc_00_18',
 'ch_per_col_90_00',
 'ch_per_col_00_18',
 'ch_per_limove_12_18',
 'aboverm_per_all_li_90',
 'aboverm_per_all_li_00',
 'aboverm_per_all_li_18',
 'aboverm_per_nonwhite_18',
 'aboverm_per_nonwhite_90',
 'aboverm_per_nonwhite_00',
 'aboverm_per_rent_90',
 'aboverm_per_rent_00',
 'aboverm_per_rent_18',
 'aboverm_per_col_90',
 'aboverm_per_col_00',
 'aboverm_per_col_18',
 'aboverm_real_mrent_90',
 'aboverm_real_mrent_00',
 'aboverm_real_mrent_12',
 'aboverm_real_mrent_18',
 'aboverm_real_mhval_90',
 'aboverm_real_mhval_00',
 'aboverm_real_mhval_18',
 'aboverm_pctch_real_mhval_00_18',
 'aboverm_pctch_real_mrent_00_18',
 'aboverm_pctch_real_mrent_12_18',
 'aboverm_pctch_real_mhval_90_00',
 'aboverm_pctch_real_mrent_90_00',
 'lostli_00',
 'lostli_18',
 'aboverm_pctch_real_hinc_90_00',
 'aboverm_pctch_real_hinc_00_18',
 'aboverm_ch_per_col_90_00',
 'aboverm_ch_per_col_00_18',
 'aboverm_per_units_pre50_18',
 'GEOID',
 'rail',
 'presence_ph_LIHTC',
 'hotmarket_00',
 'hotmarket_18',
 'dp_PChRent',
 'dp_RentGap',
 'dense',
 'typology']]

# drop rows which dont have a gentrification category
df2.dropna(subset=['typology'], inplace=True)
df2 = df2.set_index('GEOID')

#fill the nas
df2.fillna(0.0, inplace=True)


df2.head(10)
# Out:
#              low_80120_18  mod_80120_18  ...  dense  typology
# GEOID                                    ...
# 13063040515      0.633648      0.197877  ...      0       1.0
# 13063040611      0.702077      0.190240  ...      0       3.0
# 13063040612      0.690657      0.094531  ...      0       3.0
# 13063040409      0.527501      0.233772  ...      0       1.0
# 13063040410      0.537279      0.159060  ...      0       1.0
# 13063040509      0.438380      0.210569  ...      0       7.0
# 13063040407      0.588523      0.255260  ...      0       1.0
# 13063040518      0.620676      0.265977  ...      0       1.0
# 13063040606      0.576947      0.167285  ...      0       3.0
# 13063040608      0.364318      0.292797  ...      0       7.0
#
# [10 rows x 92 columns]

# %% [markdown]
# ### Convert select continous variables to categorical and one hot encode

# %%
# # convert already dummy variables from float to int
# dummy_var_list = ['hotmarket_00', 'hotmarket_18', 'low_pdmt_medhhinc_00', 'high_pdmt_medhhinc_00', 'mod_pdmt_medhhinc_00',
#                   'mix_low_medhhinc_00', 'mix_mod_medhhinc_00',  'mix_high_medhhinc_00', 'low_pdmt_medhhinc_18', 'high_pdmt_medhhinc_18',
#                   'mod_pdmt_medhhinc_18', 'mix_low_medhhinc_18', 'mix_mod_medhhinc_18', 'mix_high_medhhinc_18', 'presence_ph_LIHTC',
#                   'typology']
# for dummycol in dummy_var_list:
#   df2.loc[:,(dummycol)] = df2[dummycol].astype(int, copy=False)

# %%
# use float variables to represent each categorical variable by dividing into quartiles
def convert_percents_to_dummy_vars(X):

    columns = X.columns

    bin_labels_4 = ['VL', 'L', 'H',  'VH']


    for i in range(0, len(columns)):
        if X[columns[i]].dtype=='float64':
          print("Processing: " + columns[i])

          X[columns[i]] = X[columns[i]].fillna(0)
          cat_label = "{}_cat".format(columns[i])
          dummy_label = "{}_dummy".format(columns[i])
          X[cat_label] = pd.qcut(X[columns[i]], 
                                 4,
                              precision=5,
                              duplicates = 'drop',
                              labels=bin_labels_4)
          X = pd.get_dummies(X, columns=[cat_label], prefix=[dummy_label])
          X = X.drop([columns[i]], axis=1)

    return X

# %%
# check if categorical then convert to dummy using label and onehot encoding
def convert_categorical_to_dummy_vars(X):

    from sklearn.preprocessing import LabelEncoder
    from sklearn.preprocessing import OneHotEncoder    

    columns = X.columns
    indices = X.index
    new_columns = []
    encoded_x = None

    for i in range(0, len(columns)):
        if X[columns[i]].dtype=='O':
          print("Processing: " + columns[i])


          label_encoder = LabelEncoder()
          le = label_encoder.fit(X[columns[i]].apply(str))
          for class_ in le.classes_:
              new_columns.append("{}_{}".format(columns[i],class_))
              
          feature = le.transform(X[columns[i]].apply(str))
          feature = feature.reshape(X.shape[0], 1)
          onehot_encoder = OneHotEncoder(sparse=False)
          onehot_encoder.fit(feature)
          feature = onehot_encoder.transform(feature)
          if encoded_x is None:
              encoded_x = feature
          else:
              encoded_x = np.concatenate((encoded_x, feature), axis=1)
          X = X.drop(columns[i], axis=1)
    new_columns.extend(X.columns)

    X = pd.DataFrame(np.concatenate((encoded_x,X),axis=1),index=indices,columns=new_columns)
    
    return X

# %% [markdown]
# ### Convert Percentage (floats) to Quartiles and Dummy Variables

# %%
# # process and save data all converted to one hot encoding
# df2 = convert_percents_to_dummy_vars(df2)

# %%
# df2 = convert_categorical_to_dummy_vars(df2)

# %% [markdown]
# iii. Save the dataset as a CSV file. The first line of the CSV file should be the attribute
# names as described in the previous question.

# %%
# df2.to_csv("{}/data/processed_{}".format(customized_path_to_homework, file_name))

# %% [markdown]
# # **STUCCO Rule Calculations**

# %%
# load already processed data 
# df3 = pd.read_csv("{}/data/processed_{}".format(customized_path_to_homework, file_name), index_col=0)
# df3 = df3.astype(int)

# %%
confidence_cut = 0.8
lift_cut = 1.0
conviction_cut = 0.8
support_cut = 0.65

# %%
#ref: https://www.ics.uci.edu/~pazzani/Publications/stucco.pdf
#ref: https://github.com/parsahosseini/contrast/blob/master/README.md

# %%
from stucco import ContrastSetLearner
learner = ContrastSetLearner(df2, group_feature='typology')
# Out:
# INFO:root:User-defined feature is 'typology'
# INFO:root:Data dimensions: 733 x 92
# INFO:root:Reading object features (n=3)
# INFO:root:Reading numeric features (n=89)
# INFO:root:28 features lack value; dropping
# INFO:root:New data dimensions: 733 x 64
# INFO:root:Record count (pre-index): 733
# INFO:root:Record count (index): 733

# %%
# derive 3-length combinations of a rule and enumerate their abundance.
learner.learn(max_length=3)
# Out:
# INFO:root:Enumerating 733 item-sets, i
# INFO:root:i=0; n(matrix)=0
# INFO:root:i=200; n(matrix)=472,753
# INFO:root:i=400; n(matrix)=563,913
# INFO:root:i=600; n(matrix)=572,065
# INFO:root:584,887 contingency matrices made
# INFO:root:i=0 matrix not-rules enumerated
# INFO:root:i=2500 matrix not-rules enumerated
# INFO:root:i=5000 matrix not-rules enumerated
# INFO:root:i=7500 matrix not-rules enumerated
# INFO:root:i=10000 matrix not-rules enumerated
# INFO:root:i=12500 matrix not-rules enumerated
# INFO:root:i=15000 matrix not-rules enumerated
# INFO:root:i=17500 matrix not-rules enumerated
# INFO:root:i=20000 matrix not-rules enumerated
# INFO:root:i=22500 matrix not-rules enumerated
# INFO:root:i=25000 matrix not-rules enumerated
# INFO:root:i=27500 matrix not-rules enumerated
# INFO:root:i=30000 matrix not-rules enumerated
# INFO:root:i=32500 matrix not-rules enumerated
# INFO:root:i=35000 matrix not-rules enumerated
# INFO:root:i=37500 matrix not-rules enumerated
# INFO:root:i=40000 matrix not-rules enumerated
# INFO:root:i=42500 matrix not-rules enumerated
# INFO:root:i=45000 matrix not-rules enumerated
# INFO:root:i=47500 matrix not-rules enumerated
# INFO:root:i=50000 matrix not-rules enumerated
# INFO:root:i=52500 matrix not-rules enumerated
# INFO:root:i=55000 matrix not-rules enumerated
# INFO:root:i=57500 matrix not-rules enumerated
# INFO:root:i=60000 matrix not-rules enumerated
# INFO:root:i=62500 matrix not-rules enumerated
# INFO:root:i=65000 matrix not-rules enumerated
# INFO:root:i=67500 matrix not-rules enumerated
# INFO:root:i=70000 matrix not-rules enumerated
# INFO:root:i=72500 matrix not-rules enumerated
# INFO:root:i=75000 matrix not-rules enumerated
# INFO:root:i=77500 matrix not-rules enumerated
# INFO:root:i=80000 matrix not-rules enumerated
# INFO:root:i=82500 matrix not-rules enumerated
# INFO:root:i=85000 matrix not-rules enumerated
# INFO:root:i=87500 matrix not-rules enumerated
# INFO:root:i=90000 matrix not-rules enumerated
# INFO:root:i=92500 matrix not-rules enumerated
# INFO:root:i=95000 matrix not-rules enumerated
# INFO:root:i=97500 matrix not-rules enumerated
# INFO:root:i=100000 matrix not-rules enumerated
# INFO:root:i=102500 matrix not-rules enumerated
# INFO:root:i=105000 matrix not-rules enumerated
# INFO:root:i=107500 matrix not-rules enumerated
# INFO:root:i=110000 matrix not-rules enumerated
# INFO:root:i=112500 matrix not-rules enumerated
# INFO:root:i=115000 matrix not-rules enumerated
# INFO:root:i=117500 matrix not-rules enumerated
# INFO:root:i=120000 matrix not-rules enumerated
# INFO:root:i=122500 matrix not-rules enumerated
# INFO:root:i=125000 matrix not-rules enumerated
# INFO:root:i=127500 matrix not-rules enumerated
# INFO:root:i=130000 matrix not-rules enumerated
# INFO:root:i=132500 matrix not-rules enumerated
# INFO:root:i=135000 matrix not-rules enumerated
# INFO:root:i=137500 matrix not-rules enumerated
# INFO:root:i=140000 matrix not-rules enumerated
# INFO:root:i=142500 matrix not-rules enumerated
# INFO:root:i=145000 matrix not-rules enumerated
# INFO:root:i=147500 matrix not-rules enumerated
# INFO:root:i=150000 matrix not-rules enumerated
# INFO:root:i=152500 matrix not-rules enumerated
# INFO:root:i=155000 matrix not-rules enumerated
# INFO:root:i=157500 matrix not-rules enumerated
# INFO:root:i=160000 matrix not-rules enumerated
# INFO:root:i=162500 matrix not-rules enumerated
# INFO:root:i=165000 matrix not-rules enumerated
# INFO:root:i=167500 matrix not-rules enumerated
# INFO:root:i=170000 matrix not-rules enumerated
# INFO:root:i=172500 matrix not-rules enumerated
# INFO:root:i=175000 matrix not-rules enumerated
# INFO:root:i=177500 matrix not-rules enumerated
# INFO:root:i=180000 matrix not-rules enumerated
# INFO:root:i=182500 matrix not-rules enumerated
# INFO:root:i=185000 matrix not-rules enumerated
# INFO:root:i=187500 matrix not-rules enumerated
# INFO:root:i=190000 matrix not-rules enumerated
# INFO:root:i=192500 matrix not-rules enumerated
# INFO:root:i=195000 matrix not-rules enumerated
# INFO:root:i=197500 matrix not-rules enumerated
# INFO:root:i=200000 matrix not-rules enumerated
# INFO:root:i=202500 matrix not-rules enumerated
# INFO:root:i=205000 matrix not-rules enumerated
# INFO:root:i=207500 matrix not-rules enumerated
# INFO:root:i=210000 matrix not-rules enumerated
# INFO:root:i=212500 matrix not-rules enumerated
# INFO:root:i=215000 matrix not-rules enumerated
# INFO:root:i=217500 matrix not-rules enumerated
# INFO:root:i=220000 matrix not-rules enumerated
# INFO:root:i=222500 matrix not-rules enumerated
# INFO:root:i=225000 matrix not-rules enumerated
# INFO:root:i=227500 matrix not-rules enumerated
# INFO:root:i=230000 matrix not-rules enumerated
# INFO:root:i=232500 matrix not-rules enumerated
# INFO:root:i=235000 matrix not-rules enumerated
# INFO:root:i=237500 matrix not-rules enumerated
# INFO:root:i=240000 matrix not-rules enumerated
# INFO:root:i=242500 matrix not-rules enumerated
# INFO:root:i=245000 matrix not-rules enumerated
# INFO:root:i=247500 matrix not-rules enumerated
# INFO:root:i=250000 matrix not-rules enumerated
# INFO:root:i=252500 matrix not-rules enumerated
# INFO:root:i=255000 matrix not-rules enumerated
# INFO:root:i=257500 matrix not-rules enumerated
# INFO:root:i=260000 matrix not-rules enumerated
# INFO:root:i=262500 matrix not-rules enumerated
# INFO:root:i=265000 matrix not-rules enumerated
# INFO:root:i=267500 matrix not-rules enumerated
# INFO:root:i=270000 matrix not-rules enumerated
# INFO:root:i=272500 matrix not-rules enumerated
# INFO:root:i=275000 matrix not-rules enumerated
# INFO:root:i=277500 matrix not-rules enumerated
# INFO:root:i=280000 matrix not-rules enumerated
# INFO:root:i=282500 matrix not-rules enumerated
# INFO:root:i=285000 matrix not-rules enumerated
# INFO:root:i=287500 matrix not-rules enumerated
# INFO:root:i=290000 matrix not-rules enumerated
# INFO:root:i=292500 matrix not-rules enumerated
# INFO:root:i=295000 matrix not-rules enumerated
# INFO:root:i=297500 matrix not-rules enumerated
# INFO:root:i=300000 matrix not-rules enumerated
# INFO:root:i=302500 matrix not-rules enumerated
# INFO:root:i=305000 matrix not-rules enumerated
# INFO:root:i=307500 matrix not-rules enumerated
# INFO:root:i=310000 matrix not-rules enumerated
# INFO:root:i=312500 matrix not-rules enumerated
# INFO:root:i=315000 matrix not-rules enumerated
# INFO:root:i=317500 matrix not-rules enumerated
# INFO:root:i=320000 matrix not-rules enumerated
# INFO:root:i=322500 matrix not-rules enumerated
# INFO:root:i=325000 matrix not-rules enumerated
# INFO:root:i=327500 matrix not-rules enumerated
# INFO:root:i=330000 matrix not-rules enumerated
# INFO:root:i=332500 matrix not-rules enumerated
# INFO:root:i=335000 matrix not-rules enumerated
# INFO:root:i=337500 matrix not-rules enumerated
# INFO:root:i=340000 matrix not-rules enumerated
# INFO:root:i=342500 matrix not-rules enumerated
# INFO:root:i=345000 matrix not-rules enumerated
# INFO:root:i=347500 matrix not-rules enumerated
# INFO:root:i=350000 matrix not-rules enumerated
# INFO:root:i=352500 matrix not-rules enumerated
# INFO:root:i=355000 matrix not-rules enumerated
# INFO:root:i=357500 matrix not-rules enumerated
# INFO:root:i=360000 matrix not-rules enumerated
# INFO:root:i=362500 matrix not-rules enumerated
# INFO:root:i=365000 matrix not-rules enumerated
# INFO:root:i=367500 matrix not-rules enumerated
# INFO:root:i=370000 matrix not-rules enumerated
# INFO:root:i=372500 matrix not-rules enumerated
# INFO:root:i=375000 matrix not-rules enumerated
# INFO:root:i=377500 matrix not-rules enumerated
# INFO:root:i=380000 matrix not-rules enumerated
# INFO:root:i=382500 matrix not-rules enumerated
# INFO:root:i=385000 matrix not-rules enumerated
# INFO:root:i=387500 matrix not-rules enumerated
# INFO:root:i=390000 matrix not-rules enumerated
# INFO:root:i=392500 matrix not-rules enumerated
# INFO:root:i=395000 matrix not-rules enumerated
# INFO:root:i=397500 matrix not-rules enumerated
# INFO:root:i=400000 matrix not-rules enumerated
# INFO:root:i=402500 matrix not-rules enumerated
# INFO:root:i=405000 matrix not-rules enumerated
# INFO:root:i=407500 matrix not-rules enumerated
# INFO:root:i=410000 matrix not-rules enumerated
# INFO:root:i=412500 matrix not-rules enumerated
# INFO:root:i=415000 matrix not-rules enumerated
# INFO:root:i=417500 matrix not-rules enumerated
# INFO:root:i=420000 matrix not-rules enumerated
# INFO:root:i=422500 matrix not-rules enumerated
# INFO:root:i=425000 matrix not-rules enumerated
# INFO:root:i=427500 matrix not-rules enumerated
# INFO:root:i=430000 matrix not-rules enumerated
# INFO:root:i=432500 matrix not-rules enumerated
# INFO:root:i=435000 matrix not-rules enumerated
# INFO:root:i=437500 matrix not-rules enumerated
# INFO:root:i=440000 matrix not-rules enumerated
# INFO:root:i=442500 matrix not-rules enumerated
# INFO:root:i=445000 matrix not-rules enumerated
# INFO:root:i=447500 matrix not-rules enumerated
# INFO:root:i=450000 matrix not-rules enumerated
# INFO:root:i=452500 matrix not-rules enumerated
# INFO:root:i=455000 matrix not-rules enumerated
# INFO:root:i=457500 matrix not-rules enumerated
# INFO:root:i=460000 matrix not-rules enumerated
# INFO:root:i=462500 matrix not-rules enumerated
# INFO:root:i=465000 matrix not-rules enumerated
# INFO:root:i=467500 matrix not-rules enumerated
# INFO:root:i=470000 matrix not-rules enumerated
# INFO:root:i=472500 matrix not-rules enumerated
# INFO:root:i=475000 matrix not-rules enumerated
# INFO:root:i=477500 matrix not-rules enumerated
# INFO:root:i=480000 matrix not-rules enumerated
# INFO:root:i=482500 matrix not-rules enumerated
# INFO:root:i=485000 matrix not-rules enumerated
# INFO:root:i=487500 matrix not-rules enumerated
# INFO:root:i=490000 matrix not-rules enumerated
# INFO:root:i=492500 matrix not-rules enumerated
# INFO:root:i=495000 matrix not-rules enumerated
# INFO:root:i=497500 matrix not-rules enumerated
# INFO:root:i=500000 matrix not-rules enumerated
# INFO:root:i=502500 matrix not-rules enumerated
# INFO:root:i=505000 matrix not-rules enumerated
# INFO:root:i=507500 matrix not-rules enumerated
# INFO:root:i=510000 matrix not-rules enumerated
# INFO:root:i=512500 matrix not-rules enumerated
# INFO:root:i=515000 matrix not-rules enumerated
# INFO:root:i=517500 matrix not-rules enumerated
# INFO:root:i=520000 matrix not-rules enumerated
# INFO:root:i=522500 matrix not-rules enumerated
# INFO:root:i=525000 matrix not-rules enumerated
# INFO:root:i=527500 matrix not-rules enumerated
# INFO:root:i=530000 matrix not-rules enumerated
# INFO:root:i=532500 matrix not-rules enumerated
# INFO:root:i=535000 matrix not-rules enumerated
# INFO:root:i=537500 matrix not-rules enumerated
# INFO:root:i=540000 matrix not-rules enumerated
# INFO:root:i=542500 matrix not-rules enumerated
# INFO:root:i=545000 matrix not-rules enumerated
# INFO:root:i=547500 matrix not-rules enumerated
# INFO:root:i=550000 matrix not-rules enumerated
# INFO:root:i=552500 matrix not-rules enumerated
# INFO:root:i=555000 matrix not-rules enumerated
# INFO:root:i=557500 matrix not-rules enumerated
# INFO:root:i=560000 matrix not-rules enumerated
# INFO:root:i=562500 matrix not-rules enumerated
# INFO:root:i=565000 matrix not-rules enumerated
# INFO:root:i=567500 matrix not-rules enumerated
# INFO:root:i=570000 matrix not-rules enumerated
# INFO:root:i=572500 matrix not-rules enumerated
# INFO:root:i=575000 matrix not-rules enumerated
# INFO:root:i=577500 matrix not-rules enumerated
# INFO:root:i=580000 matrix not-rules enumerated
# INFO:root:i=582500 matrix not-rules enumerated
# 584887

# %%
output = learner.score(min_lift=3)
# Out:
# Streaming output truncated to the last 5000 lines.
# INFO:root:487731 / 584887: {'rule': ('change_flag_category=>ch_increase', 'ch_per_col_00_18=>(0.12629115737172042, 0.5259549840785538)', 'aboverm_pctch_real_mhval_90_00=>1'), 'group': 'typology=>7.0', 'lift': 3.09328968903437}
# INFO:root:487734 / 584887: {'rule': ('change_flag_category=>ch_increase', 'ch_per_col_00_18=>(0.12629115737172042, 0.5259549840785538)', 'hotmarket_00=>1.0'), 'group': 'typology=>7.0', 'lift': 3.0384615384615388}
# INFO:root:487735 / 584887: {'rule': ('change_flag_category=>ch_increase', 'ch_per_limove_12_18=>(-0.11515484392352675, 0.0120040381554824)', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>7.0', 'lift': 4.2727272727272725}
# INFO:root:487736 / 584887: {'rule': ('change_flag_category=>ch_increase', 'ch_per_limove_12_18=>(-0.11515484392352675, 0.0120040381554824)', 'aboverm_real_mrent_18=>1'), 'group': 'typology=>7.0', 'lift': 4.037617554858934}
# INFO:root:487743 / 584887: {'rule': ('change_flag_category=>ch_increase', 'aboverm_per_all_li_18=>0', 'aboverm_per_rent_00=>0'), 'group': 'typology=>7.0', 'lift': 3.347763347763348}
# INFO:root:487744 / 584887: {'rule': ('change_flag_category=>ch_increase', 'aboverm_per_all_li_18=>0', 'aboverm_per_rent_18=>0'), 'group': 'typology=>7.0', 'lift': 3.0918918918918923}
# INFO:root:487748 / 584887: {'rule': ('change_flag_category=>ch_increase', 'aboverm_per_all_li_18=>0', 'aboverm_real_mrent_90=>0'), 'group': 'typology=>7.0', 'lift': 3.1339285714285716}
# INFO:root:487750 / 584887: {'rule': ('change_flag_category=>ch_increase', 'aboverm_per_all_li_18=>0', 'aboverm_real_mrent_12=>1'), 'group': 'typology=>7.0', 'lift': 3.163888888888889}
# INFO:root:487751 / 584887: {'rule': ('change_flag_category=>ch_increase', 'aboverm_per_all_li_18=>0', 'aboverm_real_mrent_18=>1'), 'group': 'typology=>7.0', 'lift': 3.092245989304813}
# INFO:root:487755 / 584887: {'rule': ('change_flag_category=>ch_increase', 'aboverm_per_all_li_18=>0', 'aboverm_pctch_real_mhval_00_18=>1'), 'group': 'typology=>7.0', 'lift': 3.1170112781954886}
# INFO:root:487756 / 584887: {'rule': ('change_flag_category=>ch_increase', 'aboverm_per_all_li_18=>0', 'aboverm_pctch_real_mrent_00_18=>1'), 'group': 'typology=>7.0', 'lift': 3.488575268817204}
# INFO:root:487759 / 584887: {'rule': ('change_flag_category=>ch_increase', 'aboverm_per_all_li_18=>0', 'aboverm_pctch_real_mrent_90_00=>1'), 'group': 'typology=>7.0', 'lift': 3.1212765957446806}
# INFO:root:487760 / 584887: {'rule': ('change_flag_category=>ch_increase', 'aboverm_per_all_li_18=>0', 'aboverm_pctch_real_hinc_90_00=>1'), 'group': 'typology=>7.0', 'lift': 3.1799564270152505}
# INFO:root:487761 / 584887: {'rule': ('change_flag_category=>ch_increase', 'aboverm_per_all_li_18=>0', 'aboverm_pctch_real_hinc_00_18=>1'), 'group': 'typology=>7.0', 'lift': 3.2521395655036205}
# INFO:root:487768 / 584887: {'rule': ('change_flag_category=>ch_increase', 'aboverm_per_all_li_18=>0', 'dp_RentGap=>0'), 'group': 'typology=>7.0', 'lift': 3.2189542483660127}
# INFO:root:487769 / 584887: {'rule': ('change_flag_category=>ch_increase', 'aboverm_per_nonwhite_18=>0', 'aboverm_per_rent_18=>0'), 'group': 'typology=>7.0', 'lift': 3.214599609375}
# INFO:root:487770 / 584887: {'rule': ('change_flag_category=>ch_increase', 'aboverm_per_nonwhite_18=>0', 'aboverm_real_mrent_12=>1'), 'group': 'typology=>7.0', 'lift': 3.3644388398486758}
# INFO:root:487771 / 584887: {'rule': ('change_flag_category=>ch_increase', 'aboverm_per_rent_18=>0', 'aboverm_per_col_18=>1'), 'group': 'typology=>7.0', 'lift': 3.139550264550264}
# INFO:root:487772 / 584887: {'rule': ('change_flag_category=>ch_increase', 'aboverm_per_rent_18=>0', 'aboverm_real_mhval_00=>1'), 'group': 'typology=>7.0', 'lift': 3.34389400921659}
# INFO:root:487776 / 584887: {'rule': ('change_flag_category=>ch_increase', 'aboverm_real_mrent_12=>1', 'aboverm_real_mhval_18=>1'), 'group': 'typology=>7.0', 'lift': 3.0270522388059704}
# INFO:root:487777 / 584887: {'rule': ('change_flag_category=>ch_increase', 'aboverm_real_mhval_00=>1', 'aboverm_pctch_real_mrent_00_18=>1'), 'group': 'typology=>7.0', 'lift': 5.086505190311419}
# INFO:root:487975 / 584887: {'rule': ('pctch_real_hinc_90_00=>(0.9712088708758688, 10.305674021866304)', 'pctch_real_hinc_00_18=>(0.4703229190617628, 13.2930781809602)', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>6.0', 'lift': 3.5459411239964314}
# INFO:root:487976 / 584887: {'rule': ('pctch_real_hinc_90_00=>(0.9712088708758688, 10.305674021866304)', 'pctch_real_hinc_00_18=>(0.4703229190617628, 13.2930781809602)', 'aboverm_per_rent_18=>0'), 'group': 'typology=>6.0', 'lift': 3.466107617051013}
# INFO:root:488011 / 584887: {'rule': ('pctch_real_hinc_90_00=>(0.9712088708758688, 10.305674021866304)', 'aboverm_per_all_li_18=>0', 'aboverm_pctch_real_hinc_00_18=>1'), 'group': 'typology=>6.0', 'lift': 3.0024213075060526}
# INFO:root:488036 / 584887: {'rule': ('pctch_real_hinc_00_18=>(0.4703229190617628, 13.2930781809602)', 'ch_per_col_00_18=>(0.12629115737172042, 0.5259549840785538)', 'aboverm_per_nonwhite_18=>0'), 'group': 'typology=>6.0', 'lift': 3.3416435826408124}
# INFO:root:488038 / 584887: {'rule': ('pctch_real_hinc_00_18=>(0.4703229190617628, 13.2930781809602)', 'ch_per_limove_12_18=>(-0.11515484392352675, 0.0120040381554824)', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>6.0', 'lift': 3.109463276836158}
# INFO:root:488060 / 584887: {'rule': ('pctch_real_hinc_00_18=>(0.4703229190617628, 13.2930781809602)', 'aboverm_per_all_li_18=>0', 'aboverm_real_mhval_00=>1'), 'group': 'typology=>6.0', 'lift': 3.0896551724137926}
# INFO:root:488082 / 584887: {'rule': ('pctch_real_hinc_00_18=>(0.4703229190617628, 13.2930781809602)', 'aboverm_per_nonwhite_18=>0', 'aboverm_real_mhval_00=>1'), 'group': 'typology=>6.0', 'lift': 3.371647509578544}
# INFO:root:488098 / 584887: {'rule': ('pctch_real_hinc_00_18=>(0.4703229190617628, 13.2930781809602)', 'aboverm_per_rent_18=>0', 'aboverm_pctch_real_hinc_90_00=>1'), 'group': 'typology=>6.0', 'lift': 3.013793103448276}
# INFO:root:488125 / 584887: {'rule': ('pctch_real_hinc_00_18=>(0.4703229190617628, 13.2930781809602)', 'aboverm_real_mrent_18=>1', 'aboverm_real_mhval_00=>1'), 'group': 'typology=>6.0', 'lift': 3.1202976436544025}
# INFO:root:488169 / 584887: {'rule': ('ch_per_col_90_00=>(0.05934939469326905, 0.3515358258461552)', 'aboverm_real_mrent_00=>1', 'aboverm_pctch_real_mrent_00_18=>1'), 'group': 'typology=>6.0', 'lift': 3.6666666666666665}
# INFO:root:488171 / 584887: {'rule': ('ch_per_col_90_00=>(0.05934939469326905, 0.3515358258461552)', 'aboverm_real_mhval_00=>1', 'aboverm_pctch_real_mhval_00_18=>1'), 'group': 'typology=>6.0', 'lift': 3.2364341085271318}
# INFO:root:489023 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'per_rent_90=>(0.20694121298986293, 0.4940525125143268)', 'aboverm_real_mhval_18=>1'), 'group': 'typology=>7.0', 'lift': 3.599037690457097}
# INFO:root:489024 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'per_limove_18=>(0.0, 0.3587786259541985)', 'change_flag_category=>ch_increase'), 'group': 'typology=>7.0', 'lift': 5.148837209302326}
# INFO:root:489030 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'change_flag_category=>ch_increase', 'aboverm_real_mhval_18=>1'), 'group': 'typology=>7.0', 'lift': 4.2875}
# INFO:root:489031 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'change_flag_category=>ch_increase', 'aboverm_ch_per_col_00_18=>1'), 'group': 'typology=>7.0', 'lift': 3.0962099125364433}
# INFO:root:489037 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'pctch_real_hinc_00_18=>(-0.15966386554621848, 0.4699254345260441)', 'aboverm_per_rent_18=>0'), 'group': 'typology=>7.0', 'lift': 4.302118171683389}
# INFO:root:489038 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'pctch_real_hinc_00_18=>(-0.15966386554621848, 0.4699254345260441)', 'aboverm_real_mhval_00=>1'), 'group': 'typology=>7.0', 'lift': 3.994405594405594}
# INFO:root:489048 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'aboverm_real_mhval_00=>1', 'aboverm_real_mhval_18=>1'), 'group': 'typology=>7.0', 'lift': 3.2532894736842106}
# INFO:root:489122 / 584887: {'rule': ('mod_80120_18=>(0.0, 0.14915062877716348)', 'aboverm_per_rent_18=>0', 'aboverm_pctch_real_mrent_00_18=>0'), 'group': 'typology=>9.0', 'lift': 3.0181818181818185}
# INFO:root:489135 / 584887: {'rule': ('high_80120_18=>(0.27895633700219913, 0.4989205633363413)', 'per_limove_18=>(0.0, 0.3587786259541985)', 'change_flag_category=>ch_increase'), 'group': 'typology=>7.0', 'lift': 5.288888888888889}
# INFO:root:489139 / 584887: {'rule': ('high_80120_18=>(0.27895633700219913, 0.4989205633363413)', 'pctch_real_hinc_00_18=>(-0.15966386554621848, 0.4699254345260441)', 'aboverm_real_mhval_00=>1'), 'group': 'typology=>7.0', 'lift': 4.315856777493606}
# INFO:root:489142 / 584887: {'rule': ('high_80120_18=>(0.27895633700219913, 0.4989205633363413)', 'aboverm_per_rent_18=>0', 'aboverm_per_col_18=>1'), 'group': 'typology=>7.0', 'lift': 4.269449715370019}
# INFO:root:489148 / 584887: {'rule': ('mod_80120_00=>(0.13511341422585155, 0.1874154094272155)', 'pctch_real_hinc_00_18=>(-0.15966386554621848, 0.4699254345260441)', 'aboverm_per_rent_18=>0'), 'group': 'typology=>7.0', 'lift': 4.036486486486487}
# INFO:root:489164 / 584887: {'rule': ('per_all_li_18=>(0.31029137931224604, 0.5131951992771498)', 'per_rent_90=>(0.20694121298986293, 0.4940525125143268)', 'aboverm_real_mhval_18=>1'), 'group': 'typology=>7.0', 'lift': 3.599037690457097}
# INFO:root:489165 / 584887: {'rule': ('per_all_li_18=>(0.31029137931224604, 0.5131951992771498)', 'per_limove_18=>(0.0, 0.3587786259541985)', 'change_flag_category=>ch_increase'), 'group': 'typology=>7.0', 'lift': 5.148837209302326}
# INFO:root:489171 / 584887: {'rule': ('per_all_li_18=>(0.31029137931224604, 0.5131951992771498)', 'change_flag_category=>ch_increase', 'aboverm_real_mhval_18=>1'), 'group': 'typology=>7.0', 'lift': 4.2875}
# INFO:root:489172 / 584887: {'rule': ('per_all_li_18=>(0.31029137931224604, 0.5131951992771498)', 'change_flag_category=>ch_increase', 'aboverm_ch_per_col_00_18=>1'), 'group': 'typology=>7.0', 'lift': 3.0962099125364433}
# INFO:root:489178 / 584887: {'rule': ('per_all_li_18=>(0.31029137931224604, 0.5131951992771498)', 'pctch_real_hinc_00_18=>(-0.15966386554621848, 0.4699254345260441)', 'aboverm_per_rent_18=>0'), 'group': 'typology=>7.0', 'lift': 4.302118171683389}
# INFO:root:489179 / 584887: {'rule': ('per_all_li_18=>(0.31029137931224604, 0.5131951992771498)', 'pctch_real_hinc_00_18=>(-0.15966386554621848, 0.4699254345260441)', 'aboverm_real_mhval_00=>1'), 'group': 'typology=>7.0', 'lift': 3.994405594405594}
# INFO:root:489189 / 584887: {'rule': ('per_all_li_18=>(0.31029137931224604, 0.5131951992771498)', 'aboverm_real_mhval_00=>1', 'aboverm_real_mhval_18=>1'), 'group': 'typology=>7.0', 'lift': 3.2532894736842106}
# INFO:root:489198 / 584887: {'rule': ('per_nonwhite_18=>(0.4391561615641884, 0.7929311852129387)', 'aboverm_per_rent_18=>0', 'aboverm_per_col_18=>1'), 'group': 'typology=>6.0', 'lift': 3.84180790960452}
# INFO:root:489199 / 584887: {'rule': ('per_nonwhite_18=>(0.4391561615641884, 0.7929311852129387)', 'aboverm_per_rent_18=>0', 'aboverm_real_mhval_18=>1'), 'group': 'typology=>6.0', 'lift': 3.446969696969697}
# INFO:root:489206 / 584887: {'rule': ('per_rent_00=>(0.18094430308170767, 0.5098722415795587)', 'pctch_real_hinc_00_18=>(-0.15966386554621848, 0.4699254345260441)', 'aboverm_real_mhval_00=>1'), 'group': 'typology=>7.0', 'lift': 3.892222222222222}
# INFO:root:489212 / 584887: {'rule': ('per_rent_18=>(0.2671149144254279, 0.533678756476684)', 'pctch_real_hinc_00_18=>(-0.15966386554621848, 0.4699254345260441)', 'aboverm_real_mhval_00=>1'), 'group': 'typology=>7.0', 'lift': 4.5676274944567625}
# INFO:root:489219 / 584887: {'rule': ('per_rent_18=>(0.2671149144254279, 0.533678756476684)', 'aboverm_per_rent_18=>0', 'aboverm_per_col_18=>1'), 'group': 'typology=>7.0', 'lift': 3.2628603730921424}
# INFO:root:489219 / 584887: {'rule': ('per_rent_18=>(0.2671149144254279, 0.533678756476684)', 'aboverm_per_rent_18=>0', 'aboverm_per_col_18=>1'), 'group': 'typology=>6.0', 'lift': 3.184426229508196}
# INFO:root:489220 / 584887: {'rule': ('per_rent_18=>(0.2671149144254279, 0.533678756476684)', 'aboverm_per_rent_18=>0', 'aboverm_real_mhval_18=>1'), 'group': 'typology=>6.0', 'lift': 3.1365698729582583}
# INFO:root:489229 / 584887: {'rule': ('per_limove_18=>(0.0, 0.3587786259541985)', 'change_flag_category=>ch_increase', 'rent_abrm_ch=>0'), 'group': 'typology=>7.0', 'lift': 4.657575757575756}
# INFO:root:489230 / 584887: {'rule': ('per_limove_18=>(0.0, 0.3587786259541985)', 'change_flag_category=>ch_increase', 'pctch_real_hinc_00_18=>(-0.15966386554621848, 0.4699254345260441)'), 'group': 'typology=>7.0', 'lift': 3.2283333333333335}
# INFO:root:489232 / 584887: {'rule': ('per_limove_18=>(0.0, 0.3587786259541985)', 'change_flag_category=>ch_increase', 'aboverm_pctch_real_mrent_12_18=>0'), 'group': 'typology=>7.0', 'lift': 4.575757575757575}
# INFO:root:489233 / 584887: {'rule': ('per_limove_18=>(0.0, 0.3587786259541985)', 'change_flag_category=>ch_increase', 'dp_PChRent=>0'), 'group': 'typology=>7.0', 'lift': 4.797419354838709}
# INFO:root:489237 / 584887: {'rule': ('per_limove_18=>(0.0, 0.3587786259541985)', 'pctch_real_hinc_00_18=>(-0.15966386554621848, 0.4699254345260441)', 'aboverm_real_mhval_00=>1'), 'group': 'typology=>7.0', 'lift': 3.170779220779221}
# INFO:root:489256 / 584887: {'rule': ('per_limove_12=>(0.4183758589806106, 0.5804297868813998)', 'pctch_real_mhval_00_18=>(0.6809936015811531, 11.346507165928381)', 'aboverm_per_rent_18=>0'), 'group': 'typology=>6.0', 'lift': 3.37037037037037}
# INFO:root:489268 / 584887: {'rule': ('pctch_real_mhval_00_18=>(0.6809936015811531, 11.346507165928381)', 'ch_per_limove_12_18=>(-0.8921741728193341, -0.11753510981433699)', 'aboverm_per_rent_18=>0'), 'group': 'typology=>6.0', 'lift': 3.360544217687075}
# INFO:root:489272 / 584887: {'rule': ('pctch_real_mrent_12_18=>(-2860003.857142857, -0.028851012435143864)', 'change_flag_category=>ch_increase', 'aboverm_real_mhval_00=>1'), 'group': 'typology=>7.0', 'lift': 6.790123456790124}
# INFO:root:489370 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'per_nonwhite_18=>(0.4391561615641884, 0.7929311852129387)', 'aboverm_real_mrent_12=>1'), 'group': 'typology=>7.0', 'lift': 3.2593206296603143}
# INFO:root:489376 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'per_limove_18=>(0.3590909090909091, 0.5175905614502105)', 'aboverm_real_mrent_12=>1'), 'group': 'typology=>7.0', 'lift': 3.7634408602150535}
# INFO:root:489380 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'pctch_real_mhval_00_18=>(0.6809936015811531, 11.346507165928381)', 'per_ch_zillow_12_18=>(0.4646652935118433, 0.6627272727272727)'), 'group': 'typology=>6.0', 'lift': 4.8798076923076925}
# INFO:root:489381 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'pctch_real_mhval_00_18=>(0.6809936015811531, 11.346507165928381)', 'aboverm_real_mrent_12=>1'), 'group': 'typology=>6.0', 'lift': 3.839622641509433}
# INFO:root:489383 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'pctch_real_mrent_12_18=>(-0.02777423983833035, 0.09707838679801292)', 'aboverm_real_mrent_12=>1'), 'group': 'typology=>7.0', 'lift': 3.8313782991202348}
# INFO:root:489384 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'change_flag_category=>ch_rapid_increase', 'per_ch_zillow_12_18=>(0.4646652935118433, 0.6627272727272727)'), 'group': 'typology=>6.0', 'lift': 6.2439024390243905}
# INFO:root:489385 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'change_flag_category=>ch_rapid_increase', 'aboverm_real_mrent_12=>1'), 'group': 'typology=>6.0', 'lift': 4.478134110787172}
# INFO:root:489387 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'per_ch_zillow_12_18=>(0.4646652935118433, 0.6627272727272727)', 'pctch_real_hinc_00_18=>(0.4703229190617628, 13.2930781809602)'), 'group': 'typology=>6.0', 'lift': 5.064935064935065}
# INFO:root:489390 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'per_ch_zillow_12_18=>(0.4646652935118433, 0.6627272727272727)', 'aboverm_real_mhval_18=>1'), 'group': 'typology=>6.0', 'lift': 4.46218487394958}
# INFO:root:489393 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'pctch_real_hinc_90_00=>(0.08264666351098605, 0.9712088431308392)', 'aboverm_real_mrent_12=>1'), 'group': 'typology=>7.0', 'lift': 4.206837606837607}
# INFO:root:489395 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'pctch_real_hinc_00_18=>(0.4703229190617628, 13.2930781809602)', 'aboverm_real_mrent_12=>1'), 'group': 'typology=>6.0', 'lift': 4.138591800356506}
# INFO:root:489396 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'pctch_real_hinc_00_18=>(0.4703229190617628, 13.2930781809602)', 'aboverm_real_mhval_18=>1'), 'group': 'typology=>6.0', 'lift': 5.486486486486486}
# INFO:root:489398 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'ch_per_col_90_00=>(0.0014736766741444418, 0.05906785786139401)', 'aboverm_real_mrent_12=>1'), 'group': 'typology=>7.0', 'lift': 3.460164835164835}
# INFO:root:489402 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'ch_per_limove_12_18=>(0.012112565319646162, 0.4741770226163629)', 'aboverm_real_mrent_12=>1'), 'group': 'typology=>7.0', 'lift': 3.4659459459459456}
# INFO:root:489410 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'aboverm_real_mrent_12=>1', 'aboverm_real_mhval_18=>1'), 'group': 'typology=>7.0', 'lift': 4.35959595959596}
# INFO:root:489416 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'aboverm_real_mrent_12=>1', 'aboverm_ch_per_col_00_18=>1'), 'group': 'typology=>7.0', 'lift': 3.1481481481481475}
# INFO:root:489471 / 584887: {'rule': ('high_80120_18=>(0.27895633700219913, 0.4989205633363413)', 'per_limove_18=>(0.3590909090909091, 0.5175905614502105)', 'aboverm_real_mrent_12=>1'), 'group': 'typology=>7.0', 'lift': 3.509677419354839}
# INFO:root:489474 / 584887: {'rule': ('high_80120_18=>(0.27895633700219913, 0.4989205633363413)', 'pctch_real_hinc_00_18=>(0.4703229190617628, 13.2930781809602)', 'ch_per_col_90_00=>(0.0014736766741444418, 0.05906785786139401)'), 'group': 'typology=>6.0', 'lift': 4.600155279503106}
# INFO:root:489476 / 584887: {'rule': ('high_80120_18=>(0.27895633700219913, 0.4989205633363413)', 'ch_per_col_90_00=>(0.0014736766741444418, 0.05906785786139401)', 'aboverm_pctch_real_hinc_00_18=>1'), 'group': 'typology=>6.0', 'lift': 3.7879616963064295}
# INFO:root:489481 / 584887: {'rule': ('high_80120_18=>(0.27895633700219913, 0.4989205633363413)', 'aboverm_real_mrent_12=>1', 'aboverm_real_mhval_18=>1'), 'group': 'typology=>7.0', 'lift': 4.110512129380054}
# INFO:root:489487 / 584887: {'rule': ('mod_80120_00=>(0.13511341422585155, 0.1874154094272155)', 'per_nonwhite_18=>(0.4391561615641884, 0.7929311852129387)', 'pctch_real_hinc_00_18=>(0.4703229190617628, 13.2930781809602)'), 'group': 'typology=>6.0', 'lift': 4.083292978208233}
# INFO:root:489492 / 584887: {'rule': ('mod_80120_00=>(0.13511341422585155, 0.1874154094272155)', 'change_flag_category=>ch_rapid_increase', 'aboverm_real_mrent_12=>1'), 'group': 'typology=>6.0', 'lift': 3.867334167709637}
# INFO:root:489494 / 584887: {'rule': ('mod_80120_00=>(0.13511341422585155, 0.1874154094272155)', 'per_ch_zillow_12_18=>(0.4646652935118433, 0.6627272727272727)', 'pctch_real_hinc_00_18=>(0.4703229190617628, 13.2930781809602)'), 'group': 'typology=>6.0', 'lift': 3.783242258652095}
# INFO:root:489507 / 584887: {'rule': ('per_all_li_18=>(0.31029137931224604, 0.5131951992771498)', 'per_nonwhite_18=>(0.4391561615641884, 0.7929311852129387)', 'aboverm_real_mrent_12=>1'), 'group': 'typology=>7.0', 'lift': 3.2593206296603143}
# INFO:root:489513 / 584887: {'rule': ('per_all_li_18=>(0.31029137931224604, 0.5131951992771498)', 'per_limove_18=>(0.3590909090909091, 0.5175905614502105)', 'aboverm_real_mrent_12=>1'), 'group': 'typology=>7.0', 'lift': 3.7634408602150535}
# INFO:root:489517 / 584887: {'rule': ('per_all_li_18=>(0.31029137931224604, 0.5131951992771498)', 'pctch_real_mhval_00_18=>(0.6809936015811531, 11.346507165928381)', 'per_ch_zillow_12_18=>(0.4646652935118433, 0.6627272727272727)'), 'group': 'typology=>6.0', 'lift': 4.8798076923076925}
# INFO:root:489518 / 584887: {'rule': ('per_all_li_18=>(0.31029137931224604, 0.5131951992771498)', 'pctch_real_mhval_00_18=>(0.6809936015811531, 11.346507165928381)', 'aboverm_real_mrent_12=>1'), 'group': 'typology=>6.0', 'lift': 3.839622641509433}
# INFO:root:489520 / 584887: {'rule': ('per_all_li_18=>(0.31029137931224604, 0.5131951992771498)', 'pctch_real_mrent_12_18=>(-0.02777423983833035, 0.09707838679801292)', 'aboverm_real_mrent_12=>1'), 'group': 'typology=>7.0', 'lift': 3.8313782991202348}
# INFO:root:489521 / 584887: {'rule': ('per_all_li_18=>(0.31029137931224604, 0.5131951992771498)', 'change_flag_category=>ch_rapid_increase', 'per_ch_zillow_12_18=>(0.4646652935118433, 0.6627272727272727)'), 'group': 'typology=>6.0', 'lift': 6.2439024390243905}
# INFO:root:489522 / 584887: {'rule': ('per_all_li_18=>(0.31029137931224604, 0.5131951992771498)', 'change_flag_category=>ch_rapid_increase', 'aboverm_real_mrent_12=>1'), 'group': 'typology=>6.0', 'lift': 4.478134110787172}
# INFO:root:489524 / 584887: {'rule': ('per_all_li_18=>(0.31029137931224604, 0.5131951992771498)', 'per_ch_zillow_12_18=>(0.4646652935118433, 0.6627272727272727)', 'pctch_real_hinc_00_18=>(0.4703229190617628, 13.2930781809602)'), 'group': 'typology=>6.0', 'lift': 5.064935064935065}
# INFO:root:489527 / 584887: {'rule': ('per_all_li_18=>(0.31029137931224604, 0.5131951992771498)', 'per_ch_zillow_12_18=>(0.4646652935118433, 0.6627272727272727)', 'aboverm_real_mhval_18=>1'), 'group': 'typology=>6.0', 'lift': 4.46218487394958}
# INFO:root:489530 / 584887: {'rule': ('per_all_li_18=>(0.31029137931224604, 0.5131951992771498)', 'pctch_real_hinc_90_00=>(0.08264666351098605, 0.9712088431308392)', 'aboverm_real_mrent_12=>1'), 'group': 'typology=>7.0', 'lift': 4.206837606837607}
# INFO:root:489532 / 584887: {'rule': ('per_all_li_18=>(0.31029137931224604, 0.5131951992771498)', 'pctch_real_hinc_00_18=>(0.4703229190617628, 13.2930781809602)', 'aboverm_real_mrent_12=>1'), 'group': 'typology=>6.0', 'lift': 4.138591800356506}
# INFO:root:489533 / 584887: {'rule': ('per_all_li_18=>(0.31029137931224604, 0.5131951992771498)', 'pctch_real_hinc_00_18=>(0.4703229190617628, 13.2930781809602)', 'aboverm_real_mhval_18=>1'), 'group': 'typology=>6.0', 'lift': 5.486486486486486}
# INFO:root:489535 / 584887: {'rule': ('per_all_li_18=>(0.31029137931224604, 0.5131951992771498)', 'ch_per_col_90_00=>(0.0014736766741444418, 0.05906785786139401)', 'aboverm_real_mrent_12=>1'), 'group': 'typology=>7.0', 'lift': 3.460164835164835}
# INFO:root:489539 / 584887: {'rule': ('per_all_li_18=>(0.31029137931224604, 0.5131951992771498)', 'ch_per_limove_12_18=>(0.012112565319646162, 0.4741770226163629)', 'aboverm_real_mrent_12=>1'), 'group': 'typology=>7.0', 'lift': 3.4659459459459456}
# INFO:root:489547 / 584887: {'rule': ('per_all_li_18=>(0.31029137931224604, 0.5131951992771498)', 'aboverm_real_mrent_12=>1', 'aboverm_real_mhval_18=>1'), 'group': 'typology=>7.0', 'lift': 4.35959595959596}
# INFO:root:489553 / 584887: {'rule': ('per_all_li_18=>(0.31029137931224604, 0.5131951992771498)', 'aboverm_real_mrent_12=>1', 'aboverm_ch_per_col_00_18=>1'), 'group': 'typology=>7.0', 'lift': 3.1481481481481475}
# INFO:root:489558 / 584887: {'rule': ('per_nonwhite_18=>(0.4391561615641884, 0.7929311852129387)', 'per_limove_12=>(0.0, 0.4183621076571469)', 'pctch_real_hinc_00_18=>(0.4703229190617628, 13.2930781809602)'), 'group': 'typology=>6.0', 'lift': 4.2613510520487266}
# INFO:root:489565 / 584887: {'rule': ('per_limove_12=>(0.0, 0.4183621076571469)', 'pctch_real_hinc_90_00=>(0.08264666351098605, 0.9712088431308392)', 'pctch_real_hinc_00_18=>(0.4703229190617628, 13.2930781809602)'), 'group': 'typology=>6.0', 'lift': 3.1195652173913047}
# INFO:root:489620 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'mod_80120_00=>(0.0, 0.13497400961808964)', 'change_flag_category=>ch_rapid_increase'), 'group': 'typology=>6.0', 'lift': 8.663333333333334}
# INFO:root:489634 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'mod_80120_00=>(0.0, 0.13497400961808964)', 'aboverm_real_mrent_90=>1'), 'group': 'typology=>7.0', 'lift': 4.666666666666667}
# INFO:root:489676 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'change_flag_category=>ch_rapid_increase', 'pctch_real_hinc_90_00=>(-0.6695022241228893, 0.0823777783067917)'), 'group': 'typology=>6.0', 'lift': 5.864134404674945}
# INFO:root:489677 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'change_flag_category=>ch_rapid_increase', 'aboverm_real_mhval_90=>1'), 'group': 'typology=>6.0', 'lift': 4.283033033033034}
# INFO:root:489681 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'pctch_real_hinc_90_00=>(-0.6695022241228893, 0.0823777783067917)', 'aboverm_real_mhval_18=>1'), 'group': 'typology=>6.0', 'lift': 3.686390532544379}
# INFO:root:489682 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'pctch_real_hinc_00_18=>(0.4703229190617628, 13.2930781809602)', 'aboverm_per_nonwhite_18=>0'), 'group': 'typology=>6.0', 'lift': 5.942857142857143}
# INFO:root:489693 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'aboverm_real_mhval_18=>1', 'dp_RentGap=>0'), 'group': 'typology=>6.0', 'lift': 3.9768115942028976}
# INFO:root:489725 / 584887: {'rule': ('mod_80120_00=>(0.0, 0.13497400961808964)', 'per_all_li_18=>(0.31029137931224604, 0.5131951992771498)', 'change_flag_category=>ch_rapid_increase'), 'group': 'typology=>6.0', 'lift': 8.663333333333334}
# INFO:root:489739 / 584887: {'rule': ('mod_80120_00=>(0.0, 0.13497400961808964)', 'per_all_li_18=>(0.31029137931224604, 0.5131951992771498)', 'aboverm_real_mrent_90=>1'), 'group': 'typology=>7.0', 'lift': 4.666666666666667}
# INFO:root:489757 / 584887: {'rule': ('mod_80120_00=>(0.0, 0.13497400961808964)', 'per_nonwhite_18=>(0.4391561615641884, 0.7929311852129387)', 'pctch_real_mhval_00_18=>(0.6809936015811531, 11.346507165928381)'), 'group': 'typology=>6.0', 'lift': 3.9853801169590644}
# INFO:root:489760 / 584887: {'rule': ('mod_80120_00=>(0.0, 0.13497400961808964)', 'pctch_real_mhval_00_18=>(0.6809936015811531, 11.346507165928381)', 'aboverm_per_nonwhite_18=>0'), 'group': 'typology=>6.0', 'lift': 3.021925925925926}
# INFO:root:489764 / 584887: {'rule': ('mod_80120_00=>(0.0, 0.13497400961808964)', 'pctch_real_hinc_00_18=>(0.4703229190617628, 13.2930781809602)', 'aboverm_per_nonwhite_18=>0'), 'group': 'typology=>6.0', 'lift': 3.256796593514576}
# INFO:root:489766 / 584887: {'rule': ('mod_80120_00=>(0.0, 0.13497400961808964)', 'pctch_real_hinc_00_18=>(0.4703229190617628, 13.2930781809602)', 'aboverm_real_mrent_18=>1'), 'group': 'typology=>6.0', 'lift': 3.097333152836063}
# INFO:root:489800 / 584887: {'rule': ('per_all_li_18=>(0.31029137931224604, 0.5131951992771498)', 'change_flag_category=>ch_rapid_increase', 'pctch_real_hinc_90_00=>(-0.6695022241228893, 0.0823777783067917)'), 'group': 'typology=>6.0', 'lift': 5.864134404674945}
# INFO:root:489801 / 584887: {'rule': ('per_all_li_18=>(0.31029137931224604, 0.5131951992771498)', 'change_flag_category=>ch_rapid_increase', 'aboverm_real_mhval_90=>1'), 'group': 'typology=>6.0', 'lift': 4.283033033033034}
# INFO:root:489805 / 584887: {'rule': ('per_all_li_18=>(0.31029137931224604, 0.5131951992771498)', 'pctch_real_hinc_90_00=>(-0.6695022241228893, 0.0823777783067917)', 'aboverm_real_mhval_18=>1'), 'group': 'typology=>6.0', 'lift': 3.686390532544379}
# INFO:root:489806 / 584887: {'rule': ('per_all_li_18=>(0.31029137931224604, 0.5131951992771498)', 'pctch_real_hinc_00_18=>(0.4703229190617628, 13.2930781809602)', 'aboverm_per_nonwhite_18=>0'), 'group': 'typology=>6.0', 'lift': 5.942857142857143}
# INFO:root:489817 / 584887: {'rule': ('per_all_li_18=>(0.31029137931224604, 0.5131951992771498)', 'aboverm_real_mhval_18=>1', 'dp_RentGap=>0'), 'group': 'typology=>6.0', 'lift': 3.9768115942028976}
# INFO:root:489829 / 584887: {'rule': ('per_rent_18=>(0.5360149672591207, 1.0)', 'pctch_real_hinc_00_18=>(0.4703229190617628, 13.2930781809602)', 'aboverm_per_nonwhite_18=>0'), 'group': 'typology=>6.0', 'lift': 4.151472650771389}
# INFO:root:489835 / 584887: {'rule': ('pctch_real_mhval_00_18=>(0.6809936015811531, 11.346507165928381)', 'pctch_real_hinc_90_00=>(-0.6695022241228893, 0.0823777783067917)', 'aboverm_per_nonwhite_18=>0'), 'group': 'typology=>6.0', 'lift': 4.343980343980344}
# INFO:root:489836 / 584887: {'rule': ('pctch_real_mhval_00_18=>(0.6809936015811531, 11.346507165928381)', 'pctch_real_hinc_90_00=>(-0.6695022241228893, 0.0823777783067917)', 'aboverm_ch_per_col_90_00=>1'), 'group': 'typology=>6.0', 'lift': 3.1965811965811968}
# INFO:root:489847 / 584887: {'rule': ('change_flag_category=>ch_rapid_increase', 'pctch_real_hinc_90_00=>(-0.6695022241228893, 0.0823777783067917)', 'ch_per_col_90_00=>(0.05934939469326905, 0.3515358258461552)'), 'group': 'typology=>6.0', 'lift': 5.870967741935483}
# INFO:root:489848 / 584887: {'rule': ('change_flag_category=>ch_rapid_increase', 'pctch_real_hinc_90_00=>(-0.6695022241228893, 0.0823777783067917)', 'aboverm_per_nonwhite_18=>0'), 'group': 'typology=>6.0', 'lift': 3.8697674418604655}
# INFO:root:489853 / 584887: {'rule': ('pctch_real_hinc_90_00=>(-0.6695022241228893, 0.0823777783067917)', 'pctch_real_hinc_00_18=>(0.4703229190617628, 13.2930781809602)', 'aboverm_per_nonwhite_18=>0'), 'group': 'typology=>6.0', 'lift': 4.18}
# INFO:root:489856 / 584887: {'rule': ('pctch_real_hinc_00_18=>(0.4703229190617628, 13.2930781809602)', 'aboverm_per_nonwhite_18=>0', 'aboverm_real_mrent_90=>1'), 'group': 'typology=>6.0', 'lift': 3.1725146198830414}
# INFO:root:489857 / 584887: {'rule': ('pctch_real_hinc_00_18=>(0.4703229190617628, 13.2930781809602)', 'aboverm_per_nonwhite_18=>0', 'aboverm_real_mhval_90=>1'), 'group': 'typology=>6.0', 'lift': 3.02834008097166}
# INFO:root:489900 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'high_80120_18=>(0.27895633700219913, 0.4989205633363413)', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>6.0', 'lift': 3.0837458745874584}
# INFO:root:489906 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'mod_80120_00=>(0.18794961137525085, 0.30689313384273537)', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>7.0', 'lift': 4.826086956521739}
# INFO:root:489913 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'per_all_li_90=>(0.11245780102783734, 2.5580707817006085)', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>6.0', 'lift': 3.7050505050505054}
# INFO:root:489917 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'per_nonwhite_90=>(0.2490144837206553, 1.0)', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>6.0', 'lift': 3.3846153846153846}
# INFO:root:489920 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'per_nonwhite_18=>(0.4391561615641884, 0.7929311852129387)', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>7.0', 'lift': 3.841191066997518}
# INFO:root:489923 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'per_rent_90=>(0.20694121298986293, 0.4940525125143268)', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>7.0', 'lift': 5.222222222222222}
# INFO:root:489925 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'per_rent_00=>(0.18094430308170767, 0.5098722415795587)', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>7.0', 'lift': 5.051282051282051}
# INFO:root:489943 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'per_rent_18=>(0.0, 0.2670671764063353)', 'aboverm_real_mrent_90=>1'), 'group': 'typology=>7.0', 'lift': 4.9184782608695645}
# INFO:root:489944 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'per_rent_18=>(0.0, 0.2670671764063353)', 'aboverm_real_mrent_12=>1'), 'group': 'typology=>7.0', 'lift': 4.592592592592593}
# INFO:root:489945 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'per_rent_18=>(0.0, 0.2670671764063353)', 'aboverm_real_mhval_90=>1'), 'group': 'typology=>7.0', 'lift': 5.432000000000001}
# INFO:root:489954 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'per_rent_18=>(0.0, 0.2670671764063353)', 'presence_ph_LIHTC=>False'), 'group': 'typology=>7.0', 'lift': 3.1473214285714293}
# INFO:root:489966 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'per_limove_12=>(0.0, 0.4183621076571469)', 'aboverm_per_rent_18=>0'), 'group': 'typology=>7.0', 'lift': 5.062500000000001}
# INFO:root:489971 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'lmh_flag_category=>aff_mix_mod', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>7.0', 'lift': 3.734375}
# INFO:root:489971 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'lmh_flag_category=>aff_mix_mod', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>6.0', 'lift': 3.4577546296296298}
# INFO:root:489975 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'pctch_real_mhval_00_18=>(-0.04152805179652031, 0.6749802695599537)', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>7.0', 'lift': 4.702127659574469}
# INFO:root:489976 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'pctch_real_mhval_00_18=>(-0.04152805179652031, 0.6749802695599537)', 'aboverm_real_mrent_12=>1'), 'group': 'typology=>7.0', 'lift': 4.888888888888888}
# INFO:root:489977 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'pctch_real_mhval_00_18=>(-0.04152805179652031, 0.6749802695599537)', 'aboverm_real_mhval_18=>1'), 'group': 'typology=>7.0', 'lift': 3.8194444444444446}
# INFO:root:489979 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'pctch_real_mrent_12_18=>(-0.02777423983833035, 0.09707838679801292)', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>7.0', 'lift': 4.360416666666667}
# INFO:root:489981 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'change_flag_category=>ch_increase', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>7.0', 'lift': 5.37983193277311}
# INFO:root:489982 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'change_flag_category=>ch_increase', 'aboverm_real_mrent_12=>1'), 'group': 'typology=>7.0', 'lift': 4.758518518518519}
# INFO:root:489984 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'per_ch_zillow_12_18=>(0.6674104683195591, 1.5301098901098902)', 'aboverm_real_mrent_12=>1'), 'group': 'typology=>7.0', 'lift': 3.0394345238095237}
# INFO:root:489986 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'hv_abrm_ch=>1', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>7.0', 'lift': 3.03125}
# INFO:root:489990 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'pctch_real_hinc_90_00=>(-0.6695022241228893, 0.0823777783067917)', 'aboverm_real_mrent_12=>1'), 'group': 'typology=>7.0', 'lift': 3.507523148148148}
# INFO:root:489991 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'pctch_real_hinc_00_18=>(-0.15966386554621848, 0.4699254345260441)', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>7.0', 'lift': 4.531914893617021}
# INFO:root:489992 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'pctch_real_hinc_00_18=>(-0.15966386554621848, 0.4699254345260441)', 'aboverm_real_mrent_00=>1'), 'group': 'typology=>7.0', 'lift': 3.338068181818181}
# INFO:root:489993 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'pctch_real_hinc_00_18=>(-0.15966386554621848, 0.4699254345260441)', 'aboverm_real_mrent_12=>1'), 'group': 'typology=>7.0', 'lift': 4.530483972344438}
# INFO:root:490000 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'ch_per_limove_12_18=>(-0.11515484392352675, 0.0120040381554824)', 'aboverm_per_rent_18=>0'), 'group': 'typology=>7.0', 'lift': 4.5703125}
# INFO:root:490012 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'aboverm_per_all_li_18=>0', 'aboverm_per_rent_18=>0'), 'group': 'typology=>7.0', 'lift': 3.5766492643569054}
# INFO:root:490012 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'aboverm_per_all_li_18=>0', 'aboverm_per_rent_18=>0'), 'group': 'typology=>6.0', 'lift': 3.4589963280293756}
# INFO:root:490015 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'aboverm_per_all_li_18=>0', 'aboverm_per_col_18=>1'), 'group': 'typology=>7.0', 'lift': 3.8823529411764706}
# INFO:root:490018 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'aboverm_per_all_li_18=>0', 'aboverm_real_mrent_12=>1'), 'group': 'typology=>7.0', 'lift': 3.4482758620689657}
# INFO:root:490018 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'aboverm_per_all_li_18=>0', 'aboverm_real_mrent_12=>1'), 'group': 'typology=>6.0', 'lift': 3.275862068965518}
# INFO:root:490020 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'aboverm_per_all_li_18=>0', 'aboverm_real_mhval_90=>1'), 'group': 'typology=>7.0', 'lift': 3.106941838649156}
# INFO:root:490022 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'aboverm_per_all_li_18=>0', 'aboverm_real_mhval_18=>1'), 'group': 'typology=>7.0', 'lift': 3.92548841435711}
# INFO:root:490022 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'aboverm_per_all_li_18=>0', 'aboverm_real_mhval_18=>1'), 'group': 'typology=>6.0', 'lift': 3.8535211267605627}
# INFO:root:490023 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'aboverm_per_all_li_18=>0', 'aboverm_pctch_real_mhval_00_18=>1'), 'group': 'typology=>6.0', 'lift': 3.7498110355253202}
# INFO:root:490029 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'aboverm_per_all_li_18=>0', 'aboverm_pctch_real_hinc_00_18=>1'), 'group': 'typology=>6.0', 'lift': 4.0225779967159285}
# INFO:root:490031 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'aboverm_per_all_li_18=>0', 'aboverm_ch_per_col_00_18=>1'), 'group': 'typology=>6.0', 'lift': 3.1378299120234607}
# INFO:root:490036 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'aboverm_per_all_li_18=>0', 'dp_RentGap=>0'), 'group': 'typology=>7.0', 'lift': 3.405797101449276}
# INFO:root:490036 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'aboverm_per_all_li_18=>0', 'dp_RentGap=>0'), 'group': 'typology=>6.0', 'lift': 3.2265446224256293}
# INFO:root:490043 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'aboverm_real_mrent_12=>1', 'aboverm_real_mhval_90=>1'), 'group': 'typology=>7.0', 'lift': 3.159973666886109}
# INFO:root:490094 / 584887: {'rule': ('high_80120_18=>(0.27895633700219913, 0.4989205633363413)', 'per_all_li_18=>(0.31029137931224604, 0.5131951992771498)', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>6.0', 'lift': 3.0837458745874584}
# INFO:root:490098 / 584887: {'rule': ('high_80120_18=>(0.27895633700219913, 0.4989205633363413)', 'per_nonwhite_18=>(0.4391561615641884, 0.7929311852129387)', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>7.0', 'lift': 3.3333333333333335}
# INFO:root:490119 / 584887: {'rule': ('high_80120_18=>(0.27895633700219913, 0.4989205633363413)', 'per_rent_18=>(0.0, 0.2670671764063353)', 'aboverm_real_mrent_90=>1'), 'group': 'typology=>7.0', 'lift': 4.517857142857143}
# INFO:root:490120 / 584887: {'rule': ('high_80120_18=>(0.27895633700219913, 0.4989205633363413)', 'per_rent_18=>(0.0, 0.2670671764063353)', 'aboverm_real_mrent_12=>1'), 'group': 'typology=>7.0', 'lift': 3.733149389042176}
# INFO:root:490138 / 584887: {'rule': ('high_80120_18=>(0.27895633700219913, 0.4989205633363413)', 'lmh_flag_category=>aff_mix_mod', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>7.0', 'lift': 3.8942751615881814}
# INFO:root:490139 / 584887: {'rule': ('high_80120_18=>(0.27895633700219913, 0.4989205633363413)', 'pctch_real_mhval_00_18=>(-0.04152805179652031, 0.6749802695599537)', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>7.0', 'lift': 4.40531561461794}
# INFO:root:490140 / 584887: {'rule': ('high_80120_18=>(0.27895633700219913, 0.4989205633363413)', 'pctch_real_mhval_00_18=>(-0.04152805179652031, 0.6749802695599537)', 'aboverm_per_rent_18=>0'), 'group': 'typology=>7.0', 'lift': 4.641891891891892}
# INFO:root:490141 / 584887: {'rule': ('high_80120_18=>(0.27895633700219913, 0.4989205633363413)', 'pctch_real_mhval_00_18=>(-0.04152805179652031, 0.6749802695599537)', 'aboverm_real_mrent_12=>1'), 'group': 'typology=>7.0', 'lift': 4.894736842105265}
# INFO:root:490143 / 584887: {'rule': ('high_80120_18=>(0.27895633700219913, 0.4989205633363413)', 'change_flag_category=>ch_increase', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>7.0', 'lift': 5.2771836007130135}
# INFO:root:490144 / 584887: {'rule': ('high_80120_18=>(0.27895633700219913, 0.4989205633363413)', 'change_flag_category=>ch_increase', 'aboverm_real_mrent_12=>1'), 'group': 'typology=>7.0', 'lift': 5.0652439024390254}
# INFO:root:490150 / 584887: {'rule': ('high_80120_18=>(0.27895633700219913, 0.4989205633363413)', 'pctch_real_hinc_00_18=>(-0.15966386554621848, 0.4699254345260441)', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>7.0', 'lift': 4.55}
# INFO:root:490151 / 584887: {'rule': ('high_80120_18=>(0.27895633700219913, 0.4989205633363413)', 'pctch_real_hinc_00_18=>(-0.15966386554621848, 0.4699254345260441)', 'aboverm_real_mrent_12=>1'), 'group': 'typology=>7.0', 'lift': 4.824324324324325}
# INFO:root:490152 / 584887: {'rule': ('high_80120_18=>(0.27895633700219913, 0.4989205633363413)', 'ch_per_col_90_00=>(0.0014736766741444418, 0.05906785786139401)', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>6.0', 'lift': 3.547839506172839}
# INFO:root:490163 / 584887: {'rule': ('high_80120_18=>(0.27895633700219913, 0.4989205633363413)', 'aboverm_per_all_li_18=>0', 'aboverm_per_rent_18=>0'), 'group': 'typology=>7.0', 'lift': 3.1379797979797983}
# INFO:root:490166 / 584887: {'rule': ('high_80120_18=>(0.27895633700219913, 0.4989205633363413)', 'aboverm_per_all_li_18=>0', 'aboverm_per_col_18=>1'), 'group': 'typology=>7.0', 'lift': 3.3516260162601625}
# INFO:root:490169 / 584887: {'rule': ('high_80120_18=>(0.27895633700219913, 0.4989205633363413)', 'aboverm_per_all_li_18=>0', 'aboverm_real_mrent_12=>1'), 'group': 'typology=>7.0', 'lift': 3.103378103378103}
# INFO:root:490171 / 584887: {'rule': ('high_80120_18=>(0.27895633700219913, 0.4989205633363413)', 'aboverm_per_all_li_18=>0', 'aboverm_real_mhval_90=>1'), 'group': 'typology=>7.0', 'lift': 3.035330261136713}
# INFO:root:490173 / 584887: {'rule': ('high_80120_18=>(0.27895633700219913, 0.4989205633363413)', 'aboverm_per_all_li_18=>0', 'aboverm_real_mhval_18=>1'), 'group': 'typology=>7.0', 'lift': 3.438640132669983}
# INFO:root:490173 / 584887: {'rule': ('high_80120_18=>(0.27895633700219913, 0.4989205633363413)', 'aboverm_per_all_li_18=>0', 'aboverm_real_mhval_18=>1'), 'group': 'typology=>6.0', 'lift': 3.474488024991323}
# INFO:root:490174 / 584887: {'rule': ('high_80120_18=>(0.27895633700219913, 0.4989205633363413)', 'aboverm_per_all_li_18=>0', 'aboverm_pctch_real_mhval_00_18=>1'), 'group': 'typology=>6.0', 'lift': 3.274397244546498}
# INFO:root:490180 / 584887: {'rule': ('high_80120_18=>(0.27895633700219913, 0.4989205633363413)', 'aboverm_per_all_li_18=>0', 'aboverm_pctch_real_hinc_00_18=>1'), 'group': 'typology=>6.0', 'lift': 3.5384615384615383}
# INFO:root:490243 / 584887: {'rule': ('mod_80120_00=>(0.18794961137525085, 0.30689313384273537)', 'per_all_li_18=>(0.31029137931224604, 0.5131951992771498)', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>7.0', 'lift': 4.826086956521739}
# INFO:root:490375 / 584887: {'rule': ('per_all_li_90=>(0.11245780102783734, 2.5580707817006085)', 'per_all_li_18=>(0.31029137931224604, 0.5131951992771498)', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>6.0', 'lift': 3.7050505050505054}
# INFO:root:490452 / 584887: {'rule': ('per_all_li_18=>(0.31029137931224604, 0.5131951992771498)', 'per_nonwhite_90=>(0.2490144837206553, 1.0)', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>6.0', 'lift': 3.3846153846153846}
# INFO:root:490455 / 584887: {'rule': ('per_all_li_18=>(0.31029137931224604, 0.5131951992771498)', 'per_nonwhite_18=>(0.4391561615641884, 0.7929311852129387)', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>7.0', 'lift': 3.841191066997518}
# INFO:root:490458 / 584887: {'rule': ('per_all_li_18=>(0.31029137931224604, 0.5131951992771498)', 'per_rent_90=>(0.20694121298986293, 0.4940525125143268)', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>7.0', 'lift': 5.222222222222222}
# INFO:root:490460 / 584887: {'rule': ('per_all_li_18=>(0.31029137931224604, 0.5131951992771498)', 'per_rent_00=>(0.18094430308170767, 0.5098722415795587)', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>7.0', 'lift': 5.051282051282051}
# INFO:root:490478 / 584887: {'rule': ('per_all_li_18=>(0.31029137931224604, 0.5131951992771498)', 'per_rent_18=>(0.0, 0.2670671764063353)', 'aboverm_real_mrent_90=>1'), 'group': 'typology=>7.0', 'lift': 4.9184782608695645}
# INFO:root:490479 / 584887: {'rule': ('per_all_li_18=>(0.31029137931224604, 0.5131951992771498)', 'per_rent_18=>(0.0, 0.2670671764063353)', 'aboverm_real_mrent_12=>1'), 'group': 'typology=>7.0', 'lift': 4.592592592592593}
# INFO:root:490480 / 584887: {'rule': ('per_all_li_18=>(0.31029137931224604, 0.5131951992771498)', 'per_rent_18=>(0.0, 0.2670671764063353)', 'aboverm_real_mhval_90=>1'), 'group': 'typology=>7.0', 'lift': 5.432000000000001}
# INFO:root:490489 / 584887: {'rule': ('per_all_li_18=>(0.31029137931224604, 0.5131951992771498)', 'per_rent_18=>(0.0, 0.2670671764063353)', 'presence_ph_LIHTC=>False'), 'group': 'typology=>7.0', 'lift': 3.1473214285714293}
# INFO:root:490501 / 584887: {'rule': ('per_all_li_18=>(0.31029137931224604, 0.5131951992771498)', 'per_limove_12=>(0.0, 0.4183621076571469)', 'aboverm_per_rent_18=>0'), 'group': 'typology=>7.0', 'lift': 5.062500000000001}
# INFO:root:490506 / 584887: {'rule': ('per_all_li_18=>(0.31029137931224604, 0.5131951992771498)', 'lmh_flag_category=>aff_mix_mod', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>7.0', 'lift': 3.734375}
# INFO:root:490506 / 584887: {'rule': ('per_all_li_18=>(0.31029137931224604, 0.5131951992771498)', 'lmh_flag_category=>aff_mix_mod', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>6.0', 'lift': 3.4577546296296298}
# INFO:root:490510 / 584887: {'rule': ('per_all_li_18=>(0.31029137931224604, 0.5131951992771498)', 'pctch_real_mhval_00_18=>(-0.04152805179652031, 0.6749802695599537)', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>7.0', 'lift': 4.702127659574469}
# INFO:root:490511 / 584887: {'rule': ('per_all_li_18=>(0.31029137931224604, 0.5131951992771498)', 'pctch_real_mhval_00_18=>(-0.04152805179652031, 0.6749802695599537)', 'aboverm_real_mrent_12=>1'), 'group': 'typology=>7.0', 'lift': 4.888888888888888}
# INFO:root:490512 / 584887: {'rule': ('per_all_li_18=>(0.31029137931224604, 0.5131951992771498)', 'pctch_real_mhval_00_18=>(-0.04152805179652031, 0.6749802695599537)', 'aboverm_real_mhval_18=>1'), 'group': 'typology=>7.0', 'lift': 3.8194444444444446}
# ...
# INFO:root:569788 / 584887: {'rule': ('pctch_real_mhval_00_18=>(-0.04152805179652031, 0.6749802695599537)', 'change_flag_category=>ch_decrease_marginal', 'aboverm_real_mrent_18=>1'), 'group': 'typology=>7.0', 'lift': 5.5}
# INFO:root:569789 / 584887: {'rule': ('change_flag_category=>ch_decrease_marginal', 'pctch_real_hinc_90_00=>(-0.6695022241228893, 0.0823777783067917)', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>7.0', 'lift': 4.083333333333333}
# INFO:root:569790 / 584887: {'rule': ('change_flag_category=>ch_decrease_marginal', 'pctch_real_hinc_90_00=>(-0.6695022241228893, 0.0823777783067917)', 'aboverm_per_nonwhite_18=>0'), 'group': 'typology=>7.0', 'lift': 3.977272727272727}
# INFO:root:569808 / 584887: {'rule': ('low_80120_00=>(0.15830365223018047, 0.28529591975394564)', 'change_flag_category=>ch_increase', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>7.0', 'lift': 4.189655172413793}
# INFO:root:569814 / 584887: {'rule': ('high_80120_00=>(0.5073109149617284, 0.6875844745696654)', 'change_flag_category=>ch_increase', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>7.0', 'lift': 4.1898437500000005}
# INFO:root:569818 / 584887: {'rule': ('per_all_li_00=>(0.15830365223018047, 0.28529591975394564)', 'change_flag_category=>ch_increase', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>7.0', 'lift': 4.189655172413793}
# INFO:root:569820 / 584887: {'rule': ('per_nonwhite_00=>(0.21351125938281895, 0.6248096947861976)', 'change_flag_category=>ch_increase', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>7.0', 'lift': 4.416260162601626}
# INFO:root:569842 / 584887: {'rule': ('mod_80120_18=>(0.14979915312287986, 0.19909462371423306)', 'change_flag_category=>ch_decrease_marginal', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>7.0', 'lift': 4.046511627906977}
# INFO:root:569877 / 584887: {'rule': ('lmh_flag_category=>aff_predominantly_MI', 'change_flag_category=>ch_decrease_marginal', 'aboverm_per_rent_90=>0'), 'group': 'typology=>7.0', 'lift': 4.09433962264151}
# INFO:root:569878 / 584887: {'rule': ('lmh_flag_category=>aff_predominantly_MI', 'change_flag_category=>ch_decrease_marginal', 'aboverm_per_rent_18=>0'), 'group': 'typology=>7.0', 'lift': 4.040816326530612}
# INFO:root:569896 / 584887: {'rule': ('lmh_flag_category=>aff_predominantly_MI', 'change_flag_category=>ch_increase', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>7.0', 'lift': 5.864864864864864}
# INFO:root:569911 / 584887: {'rule': ('low_80120_00=>(0.016062884483937116, 0.1574425407123878)', 'change_flag_category=>ch_increase', 'aboverm_per_col_00=>0'), 'group': 'typology=>7.0', 'lift': 4.466666666666666}
# INFO:root:569914 / 584887: {'rule': ('high_80120_00=>(0.6881347730655349, 0.9559629885287712)', 'change_flag_category=>ch_increase', 'aboverm_per_col_00=>0'), 'group': 'typology=>7.0', 'lift': 4.84}
# INFO:root:569917 / 584887: {'rule': ('per_all_li_00=>(0.016062884483937116, 0.1574425407123878)', 'change_flag_category=>ch_increase', 'aboverm_per_col_00=>0'), 'group': 'typology=>7.0', 'lift': 4.466666666666666}
# INFO:root:569927 / 584887: {'rule': ('per_rent_18=>(0.0, 0.2670671764063353)', 'change_flag_category=>ch_increase', 'aboverm_per_col_18=>0'), 'group': 'typology=>7.0', 'lift': 4.27027027027027}
# INFO:root:569956 / 584887: {'rule': ('per_nonwhite_00=>(0.21351125938281895, 0.6248096947861976)', 'change_flag_category=>ch_decrease_marginal', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>7.0', 'lift': 5.75}
# INFO:root:569966 / 584887: {'rule': ('change_flag_category=>ch_increase', 'ch_per_col_00_18=>(-0.1818961143373392, 0.043834730785590637)', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>7.0', 'lift': 4.955357142857142}
# INFO:root:569973 / 584887: {'rule': ('low_80120_00=>(0.016062884483937116, 0.1574425407123878)', 'change_flag_category=>ch_increase', 'aboverm_per_nonwhite_18=>1'), 'group': 'typology=>7.0', 'lift': 4.571428571428571}
# INFO:root:569975 / 584887: {'rule': ('per_all_li_00=>(0.016062884483937116, 0.1574425407123878)', 'change_flag_category=>ch_increase', 'aboverm_per_nonwhite_18=>1'), 'group': 'typology=>7.0', 'lift': 4.571428571428571}
# INFO:root:570031 / 584887: {'rule': ('low_80120_00=>(0.016062884483937116, 0.1574425407123878)', 'aboverm_per_nonwhite_00=>1', 'aboverm_real_mrent_00=>1'), 'group': 'typology=>7.0', 'lift': 3.1153846153846154}
# INFO:root:570033 / 584887: {'rule': ('low_80120_00=>(0.016062884483937116, 0.1574425407123878)', 'aboverm_per_nonwhite_00=>1', 'aboverm_real_mhval_00=>1'), 'group': 'typology=>7.0', 'lift': 3.0526315789473686}
# INFO:root:570034 / 584887: {'rule': ('low_80120_00=>(0.016062884483937116, 0.1574425407123878)', 'aboverm_per_nonwhite_00=>1', 'aboverm_pctch_real_mhval_00_18=>0'), 'group': 'typology=>7.0', 'lift': 3.076923076923077}
# INFO:root:570035 / 584887: {'rule': ('low_80120_00=>(0.016062884483937116, 0.1574425407123878)', 'aboverm_per_nonwhite_00=>1', 'aboverm_pctch_real_mrent_00_18=>0'), 'group': 'typology=>7.0', 'lift': 3.4583333333333335}
# INFO:root:570036 / 584887: {'rule': ('low_80120_00=>(0.016062884483937116, 0.1574425407123878)', 'aboverm_per_nonwhite_00=>1', 'aboverm_pctch_real_hinc_00_18=>0'), 'group': 'typology=>7.0', 'lift': 3.4782608695652177}
# INFO:root:570054 / 584887: {'rule': ('per_all_li_00=>(0.016062884483937116, 0.1574425407123878)', 'aboverm_per_nonwhite_00=>1', 'aboverm_real_mrent_00=>1'), 'group': 'typology=>7.0', 'lift': 3.1153846153846154}
# INFO:root:570056 / 584887: {'rule': ('per_all_li_00=>(0.016062884483937116, 0.1574425407123878)', 'aboverm_per_nonwhite_00=>1', 'aboverm_real_mhval_00=>1'), 'group': 'typology=>7.0', 'lift': 3.0526315789473686}
# INFO:root:570057 / 584887: {'rule': ('per_all_li_00=>(0.016062884483937116, 0.1574425407123878)', 'aboverm_per_nonwhite_00=>1', 'aboverm_pctch_real_mhval_00_18=>0'), 'group': 'typology=>7.0', 'lift': 3.076923076923077}
# INFO:root:570058 / 584887: {'rule': ('per_all_li_00=>(0.016062884483937116, 0.1574425407123878)', 'aboverm_per_nonwhite_00=>1', 'aboverm_pctch_real_mrent_00_18=>0'), 'group': 'typology=>7.0', 'lift': 3.4583333333333335}
# INFO:root:570059 / 584887: {'rule': ('per_all_li_00=>(0.016062884483937116, 0.1574425407123878)', 'aboverm_per_nonwhite_00=>1', 'aboverm_pctch_real_hinc_00_18=>0'), 'group': 'typology=>7.0', 'lift': 3.4782608695652177}
# INFO:root:570388 / 584887: {'rule': ('per_rent_18=>(0.2671149144254279, 0.533678756476684)', 'change_flag_category=>ch_decrease_marginal', 'aboverm_per_all_li_18=>0'), 'group': 'typology=>7.0', 'lift': 5.21875}
# INFO:root:570504 / 584887: {'rule': ('mod_80120_18=>(0.19918605296266, 0.3197199878206777)', 'change_flag_category=>ch_decrease_marginal', 'aboverm_per_col_18=>1'), 'group': 'typology=>7.0', 'lift': 4.142857142857143}
# INFO:root:570507 / 584887: {'rule': ('high_80120_18=>(0.27895633700219913, 0.4989205633363413)', 'change_flag_category=>ch_decrease_marginal', 'aboverm_ch_per_col_90_00=>1'), 'group': 'typology=>7.0', 'lift': 3.5510204081632653}
# INFO:root:570508 / 584887: {'rule': ('high_80120_18=>(0.27895633700219913, 0.4989205633363413)', 'change_flag_category=>ch_decrease_marginal', 'dp_PChRent=>1'), 'group': 'typology=>7.0', 'lift': 3.387096774193548}
# INFO:root:570548 / 584887: {'rule': ('low_80120_00=>(0.016062884483937116, 0.1574425407123878)', 'change_flag_category=>ch_decrease_marginal', 'aboverm_per_nonwhite_90=>1'), 'group': 'typology=>7.0', 'lift': 3.128205128205128}
# INFO:root:570560 / 584887: {'rule': ('low_80120_00=>(0.016062884483937116, 0.1574425407123878)', 'aboverm_per_nonwhite_90=>1', 'aboverm_real_mrent_00=>1'), 'group': 'typology=>7.0', 'lift': 3.6086956521739126}
# INFO:root:570562 / 584887: {'rule': ('low_80120_00=>(0.016062884483937116, 0.1574425407123878)', 'aboverm_per_nonwhite_90=>1', 'aboverm_real_mhval_00=>1'), 'group': 'typology=>7.0', 'lift': 3.272727272727273}
# INFO:root:570564 / 584887: {'rule': ('low_80120_00=>(0.016062884483937116, 0.1574425407123878)', 'aboverm_per_nonwhite_90=>1', 'aboverm_pctch_real_mhval_00_18=>0'), 'group': 'typology=>7.0', 'lift': 3.434782608695652}
# INFO:root:570565 / 584887: {'rule': ('low_80120_00=>(0.016062884483937116, 0.1574425407123878)', 'aboverm_per_nonwhite_90=>1', 'aboverm_pctch_real_mrent_00_18=>0'), 'group': 'typology=>7.0', 'lift': 3.818181818181818}
# INFO:root:570569 / 584887: {'rule': ('low_80120_00=>(0.016062884483937116, 0.1574425407123878)', 'aboverm_per_nonwhite_90=>1', 'aboverm_pctch_real_hinc_00_18=>0'), 'group': 'typology=>7.0', 'lift': 3.85}
# INFO:root:570586 / 584887: {'rule': ('per_all_li_00=>(0.016062884483937116, 0.1574425407123878)', 'change_flag_category=>ch_decrease_marginal', 'aboverm_per_nonwhite_90=>1'), 'group': 'typology=>7.0', 'lift': 3.128205128205128}
# INFO:root:570598 / 584887: {'rule': ('per_all_li_00=>(0.016062884483937116, 0.1574425407123878)', 'aboverm_per_nonwhite_90=>1', 'aboverm_real_mrent_00=>1'), 'group': 'typology=>7.0', 'lift': 3.6086956521739126}
# INFO:root:570600 / 584887: {'rule': ('per_all_li_00=>(0.016062884483937116, 0.1574425407123878)', 'aboverm_per_nonwhite_90=>1', 'aboverm_real_mhval_00=>1'), 'group': 'typology=>7.0', 'lift': 3.272727272727273}
# INFO:root:570602 / 584887: {'rule': ('per_all_li_00=>(0.016062884483937116, 0.1574425407123878)', 'aboverm_per_nonwhite_90=>1', 'aboverm_pctch_real_mhval_00_18=>0'), 'group': 'typology=>7.0', 'lift': 3.434782608695652}
# INFO:root:570603 / 584887: {'rule': ('per_all_li_00=>(0.016062884483937116, 0.1574425407123878)', 'aboverm_per_nonwhite_90=>1', 'aboverm_pctch_real_mrent_00_18=>0'), 'group': 'typology=>7.0', 'lift': 3.818181818181818}
# INFO:root:570607 / 584887: {'rule': ('per_all_li_00=>(0.016062884483937116, 0.1574425407123878)', 'aboverm_per_nonwhite_90=>1', 'aboverm_pctch_real_hinc_00_18=>0'), 'group': 'typology=>7.0', 'lift': 3.85}
# INFO:root:570719 / 584887: {'rule': ('low_80120_00=>(0.016062884483937116, 0.1574425407123878)', 'per_nonwhite_18=>(0.7931034482758621, 1.0)', 'aboverm_real_mrent_00=>1'), 'group': 'typology=>7.0', 'lift': 4.28125}
# INFO:root:570721 / 584887: {'rule': ('low_80120_00=>(0.016062884483937116, 0.1574425407123878)', 'per_nonwhite_18=>(0.7931034482758621, 1.0)', 'aboverm_real_mhval_00=>1'), 'group': 'typology=>7.0', 'lift': 4.869565217391305}
# INFO:root:570722 / 584887: {'rule': ('low_80120_00=>(0.016062884483937116, 0.1574425407123878)', 'per_nonwhite_18=>(0.7931034482758621, 1.0)', 'aboverm_pctch_real_mhval_00_18=>0'), 'group': 'typology=>7.0', 'lift': 4.212121212121212}
# INFO:root:570723 / 584887: {'rule': ('low_80120_00=>(0.016062884483937116, 0.1574425407123878)', 'per_nonwhite_18=>(0.7931034482758621, 1.0)', 'aboverm_pctch_real_mrent_00_18=>0'), 'group': 'typology=>7.0', 'lift': 4.225806451612903}
# INFO:root:570724 / 584887: {'rule': ('low_80120_00=>(0.016062884483937116, 0.1574425407123878)', 'per_nonwhite_18=>(0.7931034482758621, 1.0)', 'aboverm_pctch_real_hinc_00_18=>0'), 'group': 'typology=>7.0', 'lift': 4.212121212121213}
# INFO:root:570744 / 584887: {'rule': ('high_80120_00=>(0.6881347730655349, 0.9559629885287712)', 'per_nonwhite_18=>(0.7931034482758621, 1.0)', 'aboverm_real_mhval_00=>1'), 'group': 'typology=>7.0', 'lift': 5.333333333333334}
# INFO:root:570747 / 584887: {'rule': ('high_80120_00=>(0.6881347730655349, 0.9559629885287712)', 'per_nonwhite_18=>(0.7931034482758621, 1.0)', 'aboverm_pctch_real_hinc_00_18=>0'), 'group': 'typology=>7.0', 'lift': 4.32258064516129}
# INFO:root:570767 / 584887: {'rule': ('per_all_li_00=>(0.016062884483937116, 0.1574425407123878)', 'per_nonwhite_18=>(0.7931034482758621, 1.0)', 'aboverm_real_mrent_00=>1'), 'group': 'typology=>7.0', 'lift': 4.28125}
# INFO:root:570769 / 584887: {'rule': ('per_all_li_00=>(0.016062884483937116, 0.1574425407123878)', 'per_nonwhite_18=>(0.7931034482758621, 1.0)', 'aboverm_real_mhval_00=>1'), 'group': 'typology=>7.0', 'lift': 4.869565217391305}
# INFO:root:570770 / 584887: {'rule': ('per_all_li_00=>(0.016062884483937116, 0.1574425407123878)', 'per_nonwhite_18=>(0.7931034482758621, 1.0)', 'aboverm_pctch_real_mhval_00_18=>0'), 'group': 'typology=>7.0', 'lift': 4.212121212121212}
# INFO:root:570771 / 584887: {'rule': ('per_all_li_00=>(0.016062884483937116, 0.1574425407123878)', 'per_nonwhite_18=>(0.7931034482758621, 1.0)', 'aboverm_pctch_real_mrent_00_18=>0'), 'group': 'typology=>7.0', 'lift': 4.225806451612903}
# INFO:root:570772 / 584887: {'rule': ('per_all_li_00=>(0.016062884483937116, 0.1574425407123878)', 'per_nonwhite_18=>(0.7931034482758621, 1.0)', 'aboverm_pctch_real_hinc_00_18=>0'), 'group': 'typology=>7.0', 'lift': 4.212121212121213}
# INFO:root:570862 / 584887: {'rule': ('low_80120_00=>(0.016062884483937116, 0.1574425407123878)', 'pctch_real_mhval_00_18=>(-inf, -0.041758049908889545)', 'aboverm_per_nonwhite_90=>1'), 'group': 'typology=>7.0', 'lift': 3.21875}
# INFO:root:570898 / 584887: {'rule': ('per_all_li_00=>(0.016062884483937116, 0.1574425407123878)', 'pctch_real_mhval_00_18=>(-inf, -0.041758049908889545)', 'aboverm_per_nonwhite_90=>1'), 'group': 'typology=>7.0', 'lift': 3.21875}
# INFO:root:571206 / 584887: {'rule': ('low_80120_00=>(0.016062884483937116, 0.1574425407123878)', 'rent_abrm_ch=>0', 'aboverm_per_all_li_18=>1'), 'group': 'typology=>7.0', 'lift': 3.1142857142857143}
# INFO:root:571207 / 584887: {'rule': ('low_80120_00=>(0.016062884483937116, 0.1574425407123878)', 'aboverm_per_all_li_18=>1', 'aboverm_pctch_real_mrent_12_18=>0'), 'group': 'typology=>7.0', 'lift': 3.1142857142857143}
# INFO:root:571222 / 584887: {'rule': ('per_all_li_00=>(0.016062884483937116, 0.1574425407123878)', 'rent_abrm_ch=>0', 'aboverm_per_all_li_18=>1'), 'group': 'typology=>7.0', 'lift': 3.1142857142857143}
# INFO:root:571223 / 584887: {'rule': ('per_all_li_00=>(0.016062884483937116, 0.1574425407123878)', 'aboverm_per_all_li_18=>1', 'aboverm_pctch_real_mrent_12_18=>0'), 'group': 'typology=>7.0', 'lift': 3.1142857142857143}
# INFO:root:571444 / 584887: {'rule': ('low_80120_18=>(0.31029137931224604, 0.5131951992771498)', 'per_rent_00=>(0.0112, 0.18094430308170764)', 'change_flag_category=>ch_increase'), 'group': 'typology=>7.0', 'lift': 8.096774193548388}
# INFO:root:571489 / 584887: {'rule': ('per_all_li_18=>(0.31029137931224604, 0.5131951992771498)', 'per_rent_00=>(0.0112, 0.18094430308170764)', 'change_flag_category=>ch_increase'), 'group': 'typology=>7.0', 'lift': 8.096774193548388}
# INFO:root:574150 / 584887: {'rule': ('lmh_flag_category=>aff_mix_high', 'hv_abrm_ch=>0', 'presence_ph_LIHTC=>False'), 'group': 'typology=>9.0', 'lift': 9.666666666666666}
# INFO:root:574616 / 584887: {'rule': ('lmh_flag_category=>aff_mix_high', 'presence_ph_LIHTC=>False', 'dp_PChRent=>1'), 'group': 'typology=>9.0', 'lift': 7.866666666666667}
# INFO:root:575402 / 584887: {'rule': ('mod_80120_18=>(0.0, 0.14915062877716348)', 'lmh_flag_category=>aff_predominantly_HI', 'presence_ph_LIHTC=>False'), 'group': 'typology=>9.0', 'lift': 9.2}
# INFO:root:577052 / 584887: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'aboverm_real_mhval_90=>1', 'presence_ph_LIHTC=>False'), 'group': 'typology=>9.0', 'lift': 8.692307692307693}
# INFO:root:577067 / 584887: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'aboverm_real_mhval_00=>1', 'presence_ph_LIHTC=>False'), 'group': 'typology=>9.0', 'lift': 9.571428571428571}
# INFO:root:577127 / 584887: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'aboverm_pctch_real_mhval_90_00=>0', 'presence_ph_LIHTC=>False'), 'group': 'typology=>9.0', 'lift': 6.846153846153847}
# INFO:root:577144 / 584887: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'aboverm_pctch_real_hinc_90_00=>0', 'presence_ph_LIHTC=>False'), 'group': 'typology=>9.0', 'lift': 7.1818181818181825}
# INFO:root:577162 / 584887: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'aboverm_ch_per_col_00_18=>1', 'presence_ph_LIHTC=>False'), 'group': 'typology=>9.0', 'lift': 6.928571428571429}
# INFO:root:577171 / 584887: {'rule': ('lmh_flag_category=>aff_predominantly_HI', 'presence_ph_LIHTC=>False', 'dp_PChRent=>1'), 'group': 'typology=>9.0', 'lift': 7.437500000000001}

# %%
output.to_csv("{}/data/stucco/stucco_{}".format(customized_path_to_homework, file_name))

# %% [markdown]
# ###  Rule Metrics

# %% [markdown]
# **Rules with high Lift and Confidence**

# %% [markdown]
# ref: http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.150.6616&rep=rep1&type=pdf
#
# Confidence ranges from 0 to 1. Confidence is an estimate of Pr(C | A), the
# probability of observing C given A. After obtaining a rule set, one can immediatly
# use confidence as a basis for classifying one new case x. Of all the rules that
# apply to x (i.e., the rules whose antecedent is true in x), we choose the one
# with highest confidence. This loosely follows the optimal Bayes classifier

# %% [markdown]
# ref: http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.150.6616&rep=rep1&type=pdf
#
# Conviction is another measure proposed in [4] to tackle some of the weaknesses of confidence and lift. Unlike lift, conviction is sensitive to rule direction
# (conv(A → C) 6= conv(C → A)). Conviction is somewhat inspired in the logical
# definition of implication and attempts to measure the degree of implication of
# a rule. Conviction is infinite for logical implications (confidence 1), and is 1 if
# A and C are independent

# %% [markdown]
# ref: http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.150.6616&rep=rep1&type=pdf
#
# Lift measures how far from independence are A and C. It ranges within
# [0, +∞[. Values close to 1 imply that A and C are independent and the rule
# is not interesting.
